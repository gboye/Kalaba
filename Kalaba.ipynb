# %%
# -*- coding: utf8 -*-

#########################IMPORTS############################################
import codecs, optparse
import re, random
import sys,os,time
import string
import yaml
import ParFuMor as PFM
from ParFuMor import *
import pickle

# %%
#########################VARIABLES##########################################
version=os.path.basename("__file__")
time_stamp='%s' % time.strftime("%y%m%d-%H%M")
debug=0
debug_now=0
print_no=False
print_coffee=True
print_commands=True
print_phrases=True
print_glose=0
print_lexique=False
print_cloze=False
print_racines=False
no_form="***"
genre=[u'M',u'F',u'A', u'I']
classe=[u'H',u'NH']
nombre=[u'SG',u'DU',u'PL',u'NSG']
nombre_sdp=[u'SG',u'DU',u'PL']
nombre_sp=[u'SG',u'NSG']
cas=[u'',u'ERG',u'ABS']
# no_grapho=['dormir', 'lit']
# no_phono=['gros', 'coussin']
no_grapho=['petit','Nabil',"sur"]
no_phono=["grand","autruche",'dans']
phono_no=u"XXXXX"
grapho_no=u"XXXXX"

# %%
with open("Kalaba-Phonology.yaml", 'r') as stream:
    phonology=yaml.load(stream)
with open("Kalaba-MorphoSyntax.yaml", 'r') as stream:
    morphosyntax=yaml.load(stream)
with open('PFM-Hierarchie.pkl', 'rb') as input:
   PFM.hierarchieCF = pickle.load(input)
with open('PFM-Lexique.pkl', 'rb') as input:
   PFM.lexique = pickle.load(input)
with open('PFM-Regles.pkl', 'rb') as input:
   PFM.regles = pickle.load(input)

# %%
lexemes=[]
graphies={}
lexique={}
base={}
categorie_v={}
temps_v={}
radical_n={}
radical_v={}
noms=[]
cloze_noms=[]
tableau_noms=[]
verbes=[]
cloze_verbes=[]
tableau_verbes=[]
determinants=[]
tableau_determinants=[]
prepositions=[]
tableau_prepositions=[]
adjectifs=[]
tableau_adjectifs=[]
francais=[]
kalaba=[]

# %% [markdown]
# ####Définition des entêtes

# %%
#########################CONSTANTS##########################################
head = [
"\\begin{tabular}[t]{|l|l|l|}",
"\\addlinespace[-1.0em]\\hline",
"Mot & Roman & Glose  \\\\",
"\\hline\\strutgh{14pt}%"
]
head_n = [
"\\begin{tabular}[t]{|l|c|c|c|}",
"\\addlinespace[-1.0em]\\hline",
"Nom & Genre & C\\indice{1}C\\indice{2}C\\indice{3} & V\\indice{L}  \\\\",
"\\hline\\strutgh{14pt}%"
]
head_v = [
"\\begin{tabular}[t]{|l|c|c|}",
"\\addlinespace[-1.0em]\\hline",
"Verbe & Type & C\\indice{1}C\\indice{2}C\\indice{3} \\\\",
"\\hline\\strutgh{14pt}%"
]

# %%
tail = [
"\\hline"
"\\end{tabular}\\\\"
]

# %% [markdown]
# ####Définition des segments

# %%
consonnes=phonology["consonnes"]
voyelles=phonology["voyelles"]

# %%
gabarits=phonology["gabarits"]
derives=phonology["derives"]
nom_classe=phonology["nom_classe"]
nom_apo=phonology["apophonies"]

# %%
nom_mut=phonology["mutations"]

# %%
nom_nombre=morphosyntax["N"]["Nombre"]
nom_cas=morphosyntax["N"]["Cas"]
verbe_classe=morphosyntax["V"]["Type"]
verbe_genre=morphosyntax["V"]["Genre-Abs"]
verbe_nombre=morphosyntax["V"]["Nombre-Abs"]
verbe_temps=morphosyntax["V"]["Temps"]
i=2
verbe_forme={}
for forme in morphosyntax["V"]["FormesBase"]:
    verbe_forme[i]=forme
    i+=1
det_nb=morphosyntax["DET"]["Nombre"]
det_cas=morphosyntax["DET"]["Cas"]
adjectif_genre=morphosyntax["ADJ"]["Genre"]
adjectif_nb=morphosyntax["ADJ"]["Nombre"]
adj_types_nombre=morphosyntax["ADJ"]["CF"]["Nombre"]
adj_types_genre=morphosyntax["ADJ"]["CF"]["Genre"]

# %%
syntagmes=morphosyntax["Syntagmes"]

# %%
contractions=morphosyntax["Contractions"]

# %%
syllabes=phonology["syllabes"]

# %%
def taches(chaine):
    result=[]
    choix=random.sample(["a","b","c","d","e","f","g","h"],len(chaine)//2+len(chaine)%2)
    for n in range(0, len(chaine), 2):
        result.append("\\cache%s{%s}" % (choix[n//2],chaine[n:n+2]))
    return "".join(result)

# %%
def parse_grapho(graphie):
    chunks=re.findall(r"([djkmnpqrstwz][aeiou]?)|[aeiou]|[.…,;!?:—–()\[\]\/# ""«»<>]", graphie)
    result=[]
    for chunk in chunks:
        if chunk in syllabes.keys():
            result.append(syllabes[chunk])
        else:
            result.append(chunk)
    return "".join(result)

# %%
def blanc(chaine):
    result="\\blanc{"+chaine+"}"
    return result

# %%
def apophone(voyelle):
    result=nom_apo[voyelle]
    return result

# %%
def mutation(consonne):
    result=nom_mut[consonne]
    return result

# %%
def fait_racine(simple):
    if debug: print "simple : ", simple
    c=1
    result={'1':'','2':'','3':'','V':''}
    for lettre in simple:
        if debug: print "lettre : ",lettre
        if lettre in consonnes:
            result[str(c)]=lettre
            c=c+1
        elif lettre in voyelles:
            if result['V']=='':
                result['V']=lettre
        else:
            if debug: print "erreur sur racine", simple
    return result

# %%
def affixe(debut, fin):
    return debut+fin

# %%
def gabarit(forme,racine):					#met la racine dans le gabarit forme
    if debug: print "gabarit : ", forme, racine
    result=""
    for signe in forme:
        if signe in "123":				#place les consonnes en 1, 2, 3
            result=result+racine[signe]
        elif signe in "456":
            result=result+mutation(racine[str(int(signe)-3)])
        elif signe in "789":
            result=result+mutation(mutation(racine[str(int(signe)-6)]))
        elif signe in "VC":				#place la voyelle radicale V et la voyelle de classe C
            result=result+racine[signe]
        elif signe in "AD":
            result=result+apophone(racine[derives[signe]])	#place les apophones de V et C (resp. A et D)
        elif signe in "U":
            result=result+apophone(apophone(racine['V']))	#place le bi-apophone de V
        else:
            result=result+signe
        if debug: print signe, result
    if debug: print result
    return result

# %%
def n_nombre(nombre, nom, classe):
    radical=nom
    if debug: print "radical : ",radical
    racine=fait_racine(radical)
    racine["C"]=nom_classe[classe]
    if debug: print "racine : ", radical, racine
    forme=nom_nombre[nombre]
    if debug: print "n_nombre :", nombre, forme
    if nombre in gabarits :
        if debug: print "forme gabaritique : ", forme, racine
        result=gabarit(forme, racine)
    else:
        result=affixe(nom_nombre[nombre], radical)
    return result

# %%
def n_cas(cas, nom, classe):
    if cas!='Ø':
        result=nom_cas[cas]+nom
    else:
        result=nom
    return result

# %%
def paradigme_nom(nom):
    genre=nom[0]
    racine=nom[1]
    lemme=nom[2]
    if not lemme.istitle():
        lemme=lemme.lower()
    if debug: print lemme, racine, genre
    extrait=fait_racine(racine)
    radical_n[lemme]= ("%s%s%s" % (extrait['1'],extrait['2'],extrait['3']), extrait['V'], genre)
    for nombre in nombres:
        if debug: print nombre
        if debug: print nombre, racine, genre
        phono_n=n_nombre(nombre, racine, genre)
        if nombre in gabarits:
            gloss_n=lemme+str(blanc("."+genre.capitalize()+"x"+nombre.upper()))
            gloss_n_cloze=lemme+";."+genre.capitalize()+";x"+nombre.upper()
        else:
            gloss_n=lemme+str(blanc("."+genre.capitalize()+"."+nombre.upper()))
            gloss_n_cloze=lemme+";."+genre.capitalize()+";."+nombre.upper()
        for case in cases:
            if debug: print case
            phono=n_cas(case, phono_n, classe)
            grapho=phono
            grapho=parse_grapho(grapho.translate(translit))
            if case!='Ø':
                gloss=str(blanc(case.upper()+"-"))+gloss_n
                gloss_cloze=case.upper()+"-;"+gloss_n_cloze
                ref=lemme.translate(deaccent)+genre.capitalize()+nombre.capitalize()+case.capitalize()
            else:
                gloss=gloss_n
                gloss_cloze=gloss_n_cloze
                ref=lemme.translate(deaccent)+genre.capitalize()+nombre.capitalize()
            if nom[2] in no_grapho and print_no:
                grapho_no=taches(grapho)
                noms.append("\\newcommand{\\"+ref+"}{\\strutgb{0pt}\\grapho{"+grapho_no+"}}")
                grapho=grapho_no
            else:
                noms.append("\\newcommand{\\"+ref+"}{\\strutgb{0pt}\\grapho{"+grapho+"}}")
            if nom[2] in no_phono and print_no:
                phono_no=taches(phono)
                noms.append("\\newcommand{\\"+ref+"P}{\\textipa{"+phono_no+"}}")
                phono=phono_no
            else:
                noms.append("\\newcommand{\\"+ref+"P}{\\textipa{"+phono+"}}")
                cloze_noms.append((phono,gloss_cloze))
            graphies["\\"+ref]=grapho
            noms.append("\\newcommand{\\"+ref+"G}{"+gloss+"}")
            if print_glose:
                tableau_noms.append("\\"+ref+" & \\"+ref+"P & \\"+ref+"G \\\\")
            else:
                tableau_noms.append("\\"+ref+" & \\"+ref+"P & \\\\")

# %%
def v_temps(tense, verbe, type, genre):
    radical=verbe
    if debug: print "radical : ",radical
    racine=fait_racine(radical)
    racine["V"]=verbe_classe[type]
    racine["C"]=verbe_genre[genre]
    if debug: print "racine : ", radical,type,genre, racine
    forme=verbe_temps[tense]
    if debug: print "v_temps :", tense, forme
    if tense in gabarits :
        if debug: print "forme gabaritique : ", forme, racine
        result=gabarit(forme, racine)
    else:
        result=affixe(verbe_temps[tense], radical)
    return result

# %%
def v_nombre(nombre, verbe):
    if debug: print nombre, verbe
    result=verbe_nombre[nombre]+verbe
    return result

# %%
def paradigme_verbe(verbe):
    type=verbe[0]
    racine=verbe[1]
    lemme=verbe[2]
    if debug: print lemme, racine, type
    extrait=fait_racine(racine)
    radical_v[lemme]= ("%s%s%s" % (extrait['1'],extrait['2'],extrait['3']), type)
    for tense in temps:
        if debug: print tense
        for genre in genres:
            if debug: print genre
            phono_t=v_temps(tense,racine,type,genre)
            if tense in gabarits:
                gloss_t=lemme.lower()+str(blanc("."+type.upper()+"x"+tense.upper()+"x"+genre.upper()))
                gloss_t_cloze=lemme.lower()+";."+type.upper()+";x"+tense.upper()+";x"+genre.upper()
            else:
                gloss_t=lemme.lower()+str(blanc("."+type.upper()+"-"+tense.upper()+"-"+genre.upper()))
                gloss_t_cloze=lemme.lower()+";."+type.upper()+";-"+tense.upper()+";-"+genre.upper()
            for nombre in nombres:
                if debug: print nombre
                phono=v_nombre(nombre,phono_t)
                grapho=phono
                gloss=str(blanc(nombre+"-"))+gloss_t
                gloss_cloze=nombre+"-;"+gloss_t_cloze
                ref=lemme.translate(deaccent)+type.capitalize()+tense.capitalize()+genre.capitalize()+nombre.capitalize()
                grapho=parse_grapho(grapho.translate(translit))
                if verbe[2] in no_grapho and print_no:
                    grapho_no=taches(grapho)
                    verbes.append("\\newcommand{\\"+ref+"}{\\strutgb{0pt}\\grapho{"+grapho_no+"}}")
                    grapho=grapho_no
                else:
                    verbes.append("\\newcommand{\\"+ref+"}{\\strutgb{0pt}\\grapho{"+grapho+"}}")
                if verbe[2] in no_phono and print_no:
                    phono_no=taches(phono)
                    verbes.append("\\newcommand{\\"+ref+"P}{\\textipa{"+phono_no+"}}")
                    phono=phono_no
                else:
                    verbes.append("\\newcommand{\\"+ref+"P}{\\textipa{"+phono+"}}")
                    cloze_verbes.append((phono,gloss_cloze))
                graphies["\\"+ref]=grapho
                
                verbes.append("\\newcommand{\\"+ref+"G}{"+gloss+"}")
                if print_glose:
                    tableau_verbes.append("\\"+ref+" & \\"+ref+"P & \\"+ref+"G \\\\")
                else:
                    tableau_verbes.append("\\"+ref+" & \\"+ref+"P & \\\\")

# %%
def adj_nombre(nombre, adjectif,type=0):
    if debug: print nombre, adjectif
    if type==0:
        result=adjectif+adjectif_nb[nombre]
    elif type in adj_types_nombre.keys():
        result=adjectif+adj_types_nombre[type][nombre]
    return result

# %%
def adj_genre(genre, adjectif,type=0):
    if debug: print genre, adjectif
    if type==0:
        result=adjectif+adjectif_genre[genre]
    elif type in adj_types_genre.keys():
        result=adjectif+adj_types_genre[type][genre]
    return result

# %%
def paradigme_adj(lexeme):
    cat_adj=lexeme[0].split('.')
    if len(cat_adj)==2:
        classe_flex=cat_adj[1]
        adj_flex=".A"+str(classe_flex)
    else:
        classe_flex=0
        adj_flex=""
    radical=lexeme[1]
    lemme=lexeme[2]
    if debug: print lemme, radical
    for nombre in nombres:
        if debug: print genre
        phono_n=adj_nombre(nombre,radical,classe_flex)
        for genre in genres:
            phono=adj_genre(genre,phono_n,classe_flex)
            gloss=lemme.lower()+str(blanc(adj_flex+"-"+nombre.upper()+"-"+genre.upper()))
            ref=lemme.lower()+nombre.capitalize()+genre.capitalize()
            grapho=phono
            grapho=parse_grapho(grapho.translate(translit))
            if lexeme[2] in no_grapho and print_no:
                grapho_no=taches(grapho)
                adjectifs.append("\\newcommand{\\"+ref+"}{\\strutgb{0pt}\\grapho{"+grapho_no+"}}")
#				grapho=grapho_no
            else:
                adjectifs.append("\\newcommand{\\"+ref+"}{\\strutgb{0pt}\\grapho{"+grapho+"}}")
            if lexeme[2] in no_phono and print_no:
                phono_no=taches(phono)
                adjectifs.append("\\newcommand{\\"+ref+"P}{\\textipa{"+phono_no+"}}")
#				phono=phono_no
            else:
                adjectifs.append("\\newcommand{\\"+ref+"P}{\\textipa{"+phono+"}}")
            graphies["\\"+ref]=grapho
            adjectifs.append("\\newcommand{\\"+ref+"G}{"+gloss+"}")
            if print_glose:
                tableau_adjectifs.append("\\"+ref+" & \\"+ref+"P & \\"+ref+"G \\\\")
            else:
                tableau_adjectifs.append("\\"+ref+" & \\"+ref+"P & \\\\")

# %%
def paradigme_det(lexeme):
    radical=lexeme[1]
    lemme=lexeme[2]
    if debug: print lemme, radical
    for nombre in nombres:
        if debug: print nombre
        phono_n=radical+det_nb[nombre]
        for case in cases:
            if case!='Ø':
                phono=phono_n+det_cas[case]
                gloss=lemme.upper()+str(blanc("-"+nombre.upper()+"-"+case.upper()))
                ref=lemme.lower()+nombre.capitalize()+case.capitalize()
            else:
                phono=phono_n
                gloss=lemme.upper()+str(blanc("-"+nombre.upper()))
                ref=lemme.lower()+nombre.capitalize()
            grapho=phono
            if lexeme[2] in no_grapho and print_no: grapho=taches(grapho)
            if lexeme[2] in no_phono and print_no: phono=taches(phono)
            determinants.append("\\newcommand{\\"+ref+"}{\\strutgb{0pt}\\grapho{"+parse_grapho(grapho.translate(translit))+"}}")
            graphies["\\"+ref]=grapho
            determinants.append("\\newcommand{\\"+ref+"P}{\\textipa{"+phono+"}}")
            determinants.append("\\newcommand{\\"+ref+"G}{"+gloss+"}")
            if print_glose:
                tableau_determinants.append("\\"+ref+" & \\"+ref+"P & \\"+ref+"G \\\\")
            else:
                tableau_determinants.append("\\"+ref+" & \\"+ref+"P & \\\\")

# %%
def paradigme_prep(lexeme):
    phono=lexeme[1]
    lemme=lexeme[2].translate(deaccent)
    gloss=lemme.upper()
    grapho=phono
    grapho=parse_grapho(grapho.translate(translit))
    ref=lemme.upper()
    if lexeme[2] in no_grapho and print_no: grapho=taches(grapho)
    if lexeme[2] in no_phono and print_no: phono=taches(phono)
    prepositions.append("\\newcommand{\\"+ref+"}{\\strutgb{0pt}\\grapho{"+grapho+"}}")
    graphies["\\"+ref]=grapho
    prepositions.append("\\newcommand{\\"+ref+"P}{\\textipa{"+phono+"}}")
    prepositions.append("\\newcommand{\\"+ref+"G}{"+gloss+"}")
    if print_glose:
        tableau_prepositions.append("\\"+ref+" & \\"+ref+"P & \\"+ref+"G \\\\")
    else:
        tableau_prepositions.append("\\"+ref+" & \\"+ref+"P & \\\\")

# %%
def faire_tableau(tableau,tab=(head,tail,"")):
    if len(tableau)==0: return
    comment=tab[2]
    for element in tab[0]:
        print comment+element
    for element in tableau:
        print comment+element
    for element in tab[1]:
        print comment+element

# %%
def print_tableaux(cols,tableau,texte="",debut=0,tab=(head,tail,"")):
    print tab[2]+"\\begin{multicols}{"+str(cols)+"}"
    if texte!="":
        table=filtrer_tableau(tableau,texte)
    else:
        table=tableau
    chunk=(len(table)-debut*cols)/cols+1
    faire_tableaux(table,debut,cols,tab)
    print tab[2]+"\\end{multicols}"

# %%
#def faire_tableaux(tableau,taille=16,debut=16,nombre=0):
#	for i in range(nombre):
#		faire_tableau(tableau[debut*i:debut*(i+1)])
#	longueur=len(tableau)-nombre*debut
#	chunks=longueur/taille
##	print longueur, taille, chunks
#	for i in range(chunks+1):
##		print i
#		faire_tableau(tableau[nombre*debut+taille*i:nombre*debut+taille*(i+1)])

def faire_tableaux(tableau,debut=16,nombre=1,tab=(head,tail,"")):
    reste=[]
    if debug: print nombre,debut,tableau
    if debut!=0:
        for i in range(nombre):
            faire_tableau(tableau[debut*i:debut*(i+1)],tab)
        table=tableau[debut*nombre:]
    else:
        table=tableau
    longueur=len(table)
    chunk=longueur/nombre+1
    if debug: print "CHUNKING : ",longueur, nombre, chunk, table
    if chunk<48:
        chunks=chunk
    else:
        chunks=48
        reste=table[48*nombre:]
    if debug: print "RESTE : ", chunk, reste
#	print longueur, taille, chunks
    for i in range(nombre):
#		print i
        faire_tableau(table[chunks*i:chunks*(i+1)],tab)
    if reste:
        faire_tableaux(reste,0,nombre,tab)

# %%
def filtrer_tableau(tableau,filtre):
    result=[]
    for line in tableau:
        elements=line.split(" ")
        if elements[0] in filtre: result.append(line)
    return result

# %%
def faire_gn(depart,cas):
    global erg_genre, erg_nombre, abs_genre, abs_nombre
    if debug: print "groupe depart :", depart
    groupe_nom=[]
    groupe_nom.append(depart[0])
    if debug: print depart[0]
    for mot in depart[1:]:
        if debug: print mot
        groupe_nom.extend(etendre_contraction([mot]))
    if debug: print "groupe nom :", groupe_nom
    mots=[]
    det=[]
    adj=[]
    nom=[]
    gp=[]
    tete=""
    nombre=""
    reste=0
    for mot in groupe_nom:
        if reste==0:
            if mot=="deux":
                nombre="DU"
                if det==[]: det.append(base["des"])
            else:
                if debug:
                    print mot,
                    print base[mot],
                    print lexique[base[mot]]
                categorie=lexique[base[mot]]
                if categorie in genres:
                    tete=categorie
                    if debug: print "tête :", tete
                    tampon=tete.split('.')
                    classe=tampon[0]
                    try:
                        type=tampon[1]
                    except IndexError:
                        type=''
                    if mot[len(mot)-1]=='s':
                        if nombre=="": nombre="PL"
                    else:
                        if nombre=="": nombre="SG"
                    nom.append(base[mot])
                    cellule=classe.capitalize()+nombre.capitalize()+cas.capitalize()
                    if cas=="ERG":
                        erg_genre=classe
                        erg_nombre=nombre
                    elif cas=="ABS":
                        abs_genre=classe
                        abs_nombre=nombre
                elif categorie in ["DEF","DEM","IND"]:
                    det.append(categorie)
                elif categorie.startswith("ADJ"):
                    adj.append(base[mot])
                elif categorie=="PREP":			#Si on trouve une PREP, elle et le reste forment un GP
                    gp.append(mot)
                    reste=1
        else:							#On a trouvé une PREP, toute la suite va dans DP
            gp.append(mot)
    if debug: print "accord :", tete
    if reste==1: gp=faire_gp(gp)
    if debug: print "GP dans le GN : ", gp
    if debug: print "GN sans det ? ", det
    if not det: det.append("IND")
    for mot in det:
#		glose=faire_glose(mot,classe,type,nombre)
        ref="\\"+mot.lower()+nombre.capitalize()+cas.capitalize()
        mots.append(ref)
        texte.append(ref)
    for mot in gp: mots.append(mot)
    for mot in adj:
#		glose=faire_glose(mot,classe,type,nombre)
        ref="\\"+mot.lower()+nombre.capitalize()+classe.capitalize()
        mots.append(ref)
        texte.append(ref)
    for mot in nom:
#		glose=faire_glose(mot,classe,type,nombre)
        if mot.istitle():
            ref="\\"+mot+cellule
        else:
            ref="\\"+mot.lower()+cellule
        mots.append(ref)
        texte.append(ref)
    return mots

# %%
def faire_gp(groupe_prep):
    mots=[]
    groupe_prep=etendre_contraction(groupe_prep)
    if debug: print "faire_gp", groupe_prep
    if groupe_prep[0]!=u"à" :
        if debug: print "PREP!=à"
        ref="\\"+groupe_prep[0].upper()
        mots.append(ref)
        texte.append(ref)
        if debug:
            print "groupe prep :", groupe_prep
            print ref
        if len(groupe_prep)>1:
            groupe_nom=groupe_prep[1:]
            mots.insert(0,faire_gn(groupe_nom,"OBL"))
        return mots
    else:
        groupe_nom=groupe_prep[1:]
        if debug: print "faire_gn", groupe_nom, faire_gn(groupe_nom,"DAT")
        mots.append(faire_gn(groupe_nom,"DAT"))
        return mots

# %%
def etendre_contraction(liste):
    result=[]
    if liste[0] in contractions.keys():
        if debug: print "EXT : ", liste, contractions[liste[0]],liste[1:] 
        result.extend(contractions[liste[0]])
        result.extend(liste[1:])
    else:
        result=liste
    #for element in liste:
    #	if element in contractions.keys(): result.extend(contractions[element])
    #	else: result.append(element)
    return result

# %%
def printflat(liste,suffixe="",prefixe=""):
    if debug: print "printflat", liste
    if not isinstance(liste, basestring):
        for element in liste:
            print prefixe,
            printflat(element,suffixe)
    else: print prefixe,liste+suffixe,

# %%
#######################
#
#	INITIALISATION DES VARIABLES
#
#######################

genres=nom_classe.keys()
types=verbe_classe.keys()
nombres=nom_nombre.keys()
cases=nom_cas.keys()
temps=verbe_temps.keys()

try:
    __IPYTHON__ 
    ipython=True
except: 
    ipython=False

# %%
################
#
# LECTURE DU FICHIER DE LEXEMES
#
#		LES LIGNES QUI COMMENCENT PAR # SONT IGNOREES
#
################
print "%% version : "+version
print "%% traitement : "+time_stamp

if ipython:
    lexeme_nom="lexemes.txt"
    phrase_nom="phrases.txt"
else:
    parser=optparse.OptionParser()
    parser.add_option("-o", "--out", dest="outfile", action="store_true", help="write to FILE")
    parser.add_option("-c", "--cloze", dest="print_cloze", action="store_true", help="write a CLOZE FILE")
    parser.add_option("-l", "--lexicon", dest="print_lexique", action="store_true", help="append a lexicon")
    parser.add_option("-r", "--roots", dest="print_racines", action="store_true", help="append a root list")

    (options, args) = parser.parse_args()
    lexeme_nom=args[0]
    phrase_nom=args[1]
# Out:
# %% version : __file__
# %% traitement : 140912-1019

# %% [markdown]
# ####Ouverture du fichier lexique

# %%
try:
    lexeme_file = codecs.open(lexeme_nom,"r","utf-8")
except IOError:
    print 'I could not open the lexeme file', lexeme_nom
    sys.exit()

# %% [markdown]
# ####Ouverture du fichier phrases

# %%
try:
    phrase_file = codecs.open(phrase_nom,"r","utf-8")
except IOError:
    print 'I could not open the sentence file', phrase_nom
    sys.exit()

# %%
#translit=string.maketrans(u'iueoaftgzZvjkSpN',u'tgazpHTGZJVkXyxI')
phonlit =  u"ptkbdgmnNfsSvzZrljw"
graphlit = u"ptkpdkmnnqssqzzrrjw"
translit = dict((ord(a), b) for a, b in zip(phonlit, graphlit))

# %%
#deaccent=string.maketrans(u'àâçéèêîùô',u'aaceeeiuo')
accented =  u"àâçéèêîùô"
unaccented = u"aaceeeiuo"
deaccent = dict((ord(a), b) for a, b in zip(accented, unaccented))

# %%
tipa = u"SZN"
ipa = u"ʃʒŋ"
toipa = dict((ord(a), b) for a, b in zip(tipa, ipa))

# %%
lexemes=[]
graphies={}
noms=[]
tableau_noms=[]
verbes=[]
tableau_verbes=[]
determinants=[]
tableau_determinants=[]
prepositions=[]
tableau_prepositions=[]
adjectifs=[]
tableau_adjectifs=[]
francais=[]
kalaba=[]

# %% [markdown]
# for line in lexeme_file:
#     tampon=(line.strip()).split(',')
#     if not tampon[0].startswith("#"):
#         lexemes.append(tampon)
# lexeme_file.close()

# %%
for categorie in PFM.lexique.catLexeme:
    print categorie
    for lexeme in PFM.lexique.catLexeme[categorie]:
        print PFM.lexique.lexemes[lexeme]
        for case in PFM.lexique.lexemes[lexeme].paradigme.cases:
            ref=PFM.modifierGlose(PFM.lexique.lexemes[lexeme].nom,case.sigma,"ref")
            print "\\newcommand{\\"+ref+"}{\\strutgb{0pt}\\grapho{"+case.forme+"}}"
            print "\\newcommand{\\"+ref+"P}{\\textipa{"+case.forme+"}}"
            print "\\newcommand{\\"+ref+"G}{"+case.glose+"}"
#    prepositions.append("\\newcommand{\\"+ref+"}{\\strutgb{0pt}\\grapho{"+grapho+"}}")
#    prepositions.append("\\newcommand{\\"+ref+"P}{\\textipa{"+phono+"}}")
#    prepositions.append("\\newcommand{\\"+ref+"G}{"+gloss+"}")
# Out:
# ADJ
# big, ADJ, petit
# 		big :
# 			ADJ, Genre=M, Nombre=Sg:	bigo	petit-\blanc{M.Sg}
# 			ADJ, Genre=M, Nombre=Du:	ibig	\blanc{Du}-petit
# 			ADJ, Genre=M, Nombre=Pl:	ebig	\blanc{Pl}-petit
# 			ADJ, Genre=F, Nombre=Sg:	abig	\blanc{Sg}-petit
# 			ADJ, Genre=F, Nombre=Du:	ibig	\blanc{Du}-petit
# 			ADJ, Genre=F, Nombre=Pl:	biga	petit-\blanc{F.Pl}
# 			ADJ, Genre=A, Nombre=Sg:	abig	\blanc{Sg}-petit
# 			ADJ, Genre=A, Nombre=Du:	bige	petit-\blanc{A.Du}
# 			ADJ, Genre=A, Nombre=Pl:	ebig	\blanc{Pl}-petit
# 			ADJ, Genre=I, Nombre=Sg:	abig	\blanc{Sg}-petit
# 			ADJ, Genre=I, Nombre=Du:	ibig	\blanc{Du}-petit
# 			ADJ, Genre=I, Nombre=Pl:	ebig	\blanc{Pl}-petit
#
# \newcommand{\petitMSg}{\strutgb{0pt}\grapho{bigo}}
# \newcommand{\petitMSgP}{\textipa{bigo}}
# \newcommand{\petitMSgG}{petit-\blanc{M.Sg}}
# \newcommand{\petitMDu}{\strutgb{0pt}\grapho{ibig}}
# \newcommand{\petitMDuP}{\textipa{ibig}}
# \newcommand{\petitMDuG}{\blanc{Du}-petit}
# \newcommand{\petitMPl}{\strutgb{0pt}\grapho{ebig}}
# \newcommand{\petitMPlP}{\textipa{ebig}}
# \newcommand{\petitMPlG}{\blanc{Pl}-petit}
# \newcommand{\petitFSg}{\strutgb{0pt}\grapho{abig}}
# \newcommand{\petitFSgP}{\textipa{abig}}
# \newcommand{\petitFSgG}{\blanc{Sg}-petit}
# \newcommand{\petitFDu}{\strutgb{0pt}\grapho{ibig}}
# \newcommand{\petitFDuP}{\textipa{ibig}}
# \newcommand{\petitFDuG}{\blanc{Du}-petit}
# \newcommand{\petitFPl}{\strutgb{0pt}\grapho{biga}}
# \newcommand{\petitFPlP}{\textipa{biga}}
# \newcommand{\petitFPlG}{petit-\blanc{F.Pl}}
# \newcommand{\petitASg}{\strutgb{0pt}\grapho{abig}}
# \newcommand{\petitASgP}{\textipa{abig}}
# \newcommand{\petitASgG}{\blanc{Sg}-petit}
# \newcommand{\petitADu}{\strutgb{0pt}\grapho{bige}}
# \newcommand{\petitADuP}{\textipa{bige}}
# \newcommand{\petitADuG}{petit-\blanc{A.Du}}
# \newcommand{\petitAPl}{\strutgb{0pt}\grapho{ebig}}
# \newcommand{\petitAPlP}{\textipa{ebig}}
# \newcommand{\petitAPlG}{\blanc{Pl}-petit}
# \newcommand{\petitISg}{\strutgb{0pt}\grapho{abig}}
# \newcommand{\petitISgP}{\textipa{abig}}
# \newcommand{\petitISgG}{\blanc{Sg}-petit}
# \newcommand{\petitIDu}{\strutgb{0pt}\grapho{ibig}}
# \newcommand{\petitIDuP}{\textipa{ibig}}
# \newcommand{\petitIDuG}{\blanc{Du}-petit}
# \newcommand{\petitIPl}{\strutgb{0pt}\grapho{ebig}}
# \newcommand{\petitIPlP}{\textipa{ebig}}
# \newcommand{\petitIPlG}{\blanc{Pl}-petit}
# nul, ADJ, grand
# 		nul :
# 			ADJ, Genre=M, Nombre=Sg:	nulo	grand-\blanc{M.Sg}
# 			ADJ, Genre=M, Nombre=Du:	inul	\blanc{Du}-grand
# 			ADJ, Genre=M, Nombre=Pl:	enul	\blanc{Pl}-grand
# 			ADJ, Genre=F, Nombre=Sg:	anul	\blanc{Sg}-grand
# 			ADJ, Genre=F, Nombre=Du:	inul	\blanc{Du}-grand
# 			ADJ, Genre=F, Nombre=Pl:	nula	grand-\blanc{F.Pl}
# 			ADJ, Genre=A, Nombre=Sg:	anul	\blanc{Sg}-grand
# 			ADJ, Genre=A, Nombre=Du:	nule	grand-\blanc{A.Du}
# 			ADJ, Genre=A, Nombre=Pl:	enul	\blanc{Pl}-grand
# 			ADJ, Genre=I, Nombre=Sg:	anul	\blanc{Sg}-grand
# 			ADJ, Genre=I, Nombre=Du:	inul	\blanc{Du}-grand
# 			ADJ, Genre=I, Nombre=Pl:	enul	\blanc{Pl}-grand
#
# \newcommand{\grandMSg}{\strutgb{0pt}\grapho{nulo}}
# \newcommand{\grandMSgP}{\textipa{nulo}}
# \newcommand{\grandMSgG}{grand-\blanc{M.Sg}}
# \newcommand{\grandMDu}{\strutgb{0pt}\grapho{inul}}
# \newcommand{\grandMDuP}{\textipa{inul}}
# \newcommand{\grandMDuG}{\blanc{Du}-grand}
# \newcommand{\grandMPl}{\strutgb{0pt}\grapho{enul}}
# \newcommand{\grandMPlP}{\textipa{enul}}
# \newcommand{\grandMPlG}{\blanc{Pl}-grand}
# \newcommand{\grandFSg}{\strutgb{0pt}\grapho{anul}}
# \newcommand{\grandFSgP}{\textipa{anul}}
# \newcommand{\grandFSgG}{\blanc{Sg}-grand}
# \newcommand{\grandFDu}{\strutgb{0pt}\grapho{inul}}
# \newcommand{\grandFDuP}{\textipa{inul}}
# \newcommand{\grandFDuG}{\blanc{Du}-grand}
# \newcommand{\grandFPl}{\strutgb{0pt}\grapho{nula}}
# \newcommand{\grandFPlP}{\textipa{nula}}
# \newcommand{\grandFPlG}{grand-\blanc{F.Pl}}
# \newcommand{\grandASg}{\strutgb{0pt}\grapho{anul}}
# \newcommand{\grandASgP}{\textipa{anul}}
# \newcommand{\grandASgG}{\blanc{Sg}-grand}
# \newcommand{\grandADu}{\strutgb{0pt}\grapho{nule}}
# \newcommand{\grandADuP}{\textipa{nule}}
# \newcommand{\grandADuG}{grand-\blanc{A.Du}}
# \newcommand{\grandAPl}{\strutgb{0pt}\grapho{enul}}
# \newcommand{\grandAPlP}{\textipa{enul}}
# \newcommand{\grandAPlG}{\blanc{Pl}-grand}
# \newcommand{\grandISg}{\strutgb{0pt}\grapho{anul}}
# \newcommand{\grandISgP}{\textipa{anul}}
# \newcommand{\grandISgG}{\blanc{Sg}-grand}
# \newcommand{\grandIDu}{\strutgb{0pt}\grapho{inul}}
# \newcommand{\grandIDuP}{\textipa{inul}}
# \newcommand{\grandIDuG}{\blanc{Du}-grand}
# \newcommand{\grandIPl}{\strutgb{0pt}\grapho{enul}}
# \newcommand{\grandIPlP}{\textipa{enul}}
# \newcommand{\grandIPlG}{\blanc{Pl}-grand}
# gil, ADJ, gros
# 		gil :
# 			ADJ, Genre=M, Nombre=Sg:	gilo	gros-\blanc{M.Sg}
# 			ADJ, Genre=M, Nombre=Du:	igil	\blanc{Du}-gros
# 			ADJ, Genre=M, Nombre=Pl:	egil	\blanc{Pl}-gros
# 			ADJ, Genre=F, Nombre=Sg:	agil	\blanc{Sg}-gros
# 			ADJ, Genre=F, Nombre=Du:	igil	\blanc{Du}-gros
# 			ADJ, Genre=F, Nombre=Pl:	gila	gros-\blanc{F.Pl}
# 			ADJ, Genre=A, Nombre=Sg:	agil	\blanc{Sg}-gros
# 			ADJ, Genre=A, Nombre=Du:	gile	gros-\blanc{A.Du}
# 			ADJ, Genre=A, Nombre=Pl:	egil	\blanc{Pl}-gros
# 			ADJ, Genre=I, Nombre=Sg:	agil	\blanc{Sg}-gros
# 			ADJ, Genre=I, Nombre=Du:	igil	\blanc{Du}-gros
# 			ADJ, Genre=I, Nombre=Pl:	egil	\blanc{Pl}-gros
#
# \newcommand{\grosMSg}{\strutgb{0pt}\grapho{gilo}}
# \newcommand{\grosMSgP}{\textipa{gilo}}
# \newcommand{\grosMSgG}{gros-\blanc{M.Sg}}
# \newcommand{\grosMDu}{\strutgb{0pt}\grapho{igil}}
# \newcommand{\grosMDuP}{\textipa{igil}}
# \newcommand{\grosMDuG}{\blanc{Du}-gros}
# \newcommand{\grosMPl}{\strutgb{0pt}\grapho{egil}}
# \newcommand{\grosMPlP}{\textipa{egil}}
# \newcommand{\grosMPlG}{\blanc{Pl}-gros}
# \newcommand{\grosFSg}{\strutgb{0pt}\grapho{agil}}
# \newcommand{\grosFSgP}{\textipa{agil}}
# \newcommand{\grosFSgG}{\blanc{Sg}-gros}
# \newcommand{\grosFDu}{\strutgb{0pt}\grapho{igil}}
# \newcommand{\grosFDuP}{\textipa{igil}}
# \newcommand{\grosFDuG}{\blanc{Du}-gros}
# \newcommand{\grosFPl}{\strutgb{0pt}\grapho{gila}}
# \newcommand{\grosFPlP}{\textipa{gila}}
# \newcommand{\grosFPlG}{gros-\blanc{F.Pl}}
# \newcommand{\grosASg}{\strutgb{0pt}\grapho{agil}}
# \newcommand{\grosASgP}{\textipa{agil}}
# \newcommand{\grosASgG}{\blanc{Sg}-gros}
# \newcommand{\grosADu}{\strutgb{0pt}\grapho{gile}}
# \newcommand{\grosADuP}{\textipa{gile}}
# \newcommand{\grosADuG}{gros-\blanc{A.Du}}
# \newcommand{\grosAPl}{\strutgb{0pt}\grapho{egil}}
# \newcommand{\grosAPlP}{\textipa{egil}}
# \newcommand{\grosAPlG}{\blanc{Pl}-gros}
# \newcommand{\grosISg}{\strutgb{0pt}\grapho{agil}}
# \newcommand{\grosISgP}{\textipa{agil}}
# \newcommand{\grosISgG}{\blanc{Sg}-gros}
# \newcommand{\grosIDu}{\strutgb{0pt}\grapho{igil}}
# \newcommand{\grosIDuP}{\textipa{igil}}
# \newcommand{\grosIDuG}{\blanc{Du}-gros}
# \newcommand{\grosIPl}{\strutgb{0pt}\grapho{egil}}
# \newcommand{\grosIPlP}{\textipa{egil}}
# \newcommand{\grosIPlG}{\blanc{Pl}-gros}
# nor, ADJ, blanc
# 		nor :
# 			ADJ, Genre=M, Nombre=Sg:	noro	blanc-\blanc{M.Sg}
# 			ADJ, Genre=M, Nombre=Du:	inor	\blanc{Du}-blanc
# 			ADJ, Genre=M, Nombre=Pl:	enor	\blanc{Pl}-blanc
# 			ADJ, Genre=F, Nombre=Sg:	anor	\blanc{Sg}-blanc
# 			ADJ, Genre=F, Nombre=Du:	inor	\blanc{Du}-blanc
# 			ADJ, Genre=F, Nombre=Pl:	nora	blanc-\blanc{F.Pl}
# 			ADJ, Genre=A, Nombre=Sg:	anor	\blanc{Sg}-blanc
# 			ADJ, Genre=A, Nombre=Du:	nore	blanc-\blanc{A.Du}
# 			ADJ, Genre=A, Nombre=Pl:	enor	\blanc{Pl}-blanc
# 			ADJ, Genre=I, Nombre=Sg:	anor	\blanc{Sg}-blanc
# 			ADJ, Genre=I, Nombre=Du:	inor	\blanc{Du}-blanc
# 			ADJ, Genre=I, Nombre=Pl:	enor	\blanc{Pl}-blanc
#
# \newcommand{\blancMSg}{\strutgb{0pt}\grapho{noro}}
# \newcommand{\blancMSgP}{\textipa{noro}}
# \newcommand{\blancMSgG}{blanc-\blanc{M.Sg}}
# \newcommand{\blancMDu}{\strutgb{0pt}\grapho{inor}}
# \newcommand{\blancMDuP}{\textipa{inor}}
# \newcommand{\blancMDuG}{\blanc{Du}-blanc}
# \newcommand{\blancMPl}{\strutgb{0pt}\grapho{enor}}
# \newcommand{\blancMPlP}{\textipa{enor}}
# \newcommand{\blancMPlG}{\blanc{Pl}-blanc}
# \newcommand{\blancFSg}{\strutgb{0pt}\grapho{anor}}
# \newcommand{\blancFSgP}{\textipa{anor}}
# \newcommand{\blancFSgG}{\blanc{Sg}-blanc}
# \newcommand{\blancFDu}{\strutgb{0pt}\grapho{inor}}
# \newcommand{\blancFDuP}{\textipa{inor}}
# \newcommand{\blancFDuG}{\blanc{Du}-blanc}
# \newcommand{\blancFPl}{\strutgb{0pt}\grapho{nora}}
# \newcommand{\blancFPlP}{\textipa{nora}}
# \newcommand{\blancFPlG}{blanc-\blanc{F.Pl}}
# \newcommand{\blancASg}{\strutgb{0pt}\grapho{anor}}
# \newcommand{\blancASgP}{\textipa{anor}}
# \newcommand{\blancASgG}{\blanc{Sg}-blanc}
# \newcommand{\blancADu}{\strutgb{0pt}\grapho{nore}}
# \newcommand{\blancADuP}{\textipa{nore}}
# \newcommand{\blancADuG}{blanc-\blanc{A.Du}}
# \newcommand{\blancAPl}{\strutgb{0pt}\grapho{enor}}
# \newcommand{\blancAPlP}{\textipa{enor}}
# \newcommand{\blancAPlG}{\blanc{Pl}-blanc}
# \newcommand{\blancISg}{\strutgb{0pt}\grapho{anor}}
# \newcommand{\blancISgP}{\textipa{anor}}
# \newcommand{\blancISgG}{\blanc{Sg}-blanc}
# \newcommand{\blancIDu}{\strutgb{0pt}\grapho{inor}}
# \newcommand{\blancIDuP}{\textipa{inor}}
# \newcommand{\blancIDuG}{\blanc{Du}-blanc}
# \newcommand{\blancIPl}{\strutgb{0pt}\grapho{enor}}
# \newcommand{\blancIPlP}{\textipa{enor}}
# \newcommand{\blancIPlG}{\blanc{Pl}-blanc}
# lab, ADJ, noir
# 		lab :
# 			ADJ, Genre=M, Nombre=Sg:	labo	noir-\blanc{M.Sg}
# 			ADJ, Genre=M, Nombre=Du:	ilab	\blanc{Du}-noir
# 			ADJ, Genre=M, Nombre=Pl:	elab	\blanc{Pl}-noir
# 			ADJ, Genre=F, Nombre=Sg:	alab	\blanc{Sg}-noir
# 			ADJ, Genre=F, Nombre=Du:	ilab	\blanc{Du}-noir
# 			ADJ, Genre=F, Nombre=Pl:	laba	noir-\blanc{F.Pl}
# 			ADJ, Genre=A, Nombre=Sg:	alab	\blanc{Sg}-noir
# 			ADJ, Genre=A, Nombre=Du:	labe	noir-\blanc{A.Du}
# 			ADJ, Genre=A, Nombre=Pl:	elab	\blanc{Pl}-noir
# 			ADJ, Genre=I, Nombre=Sg:	alab	\blanc{Sg}-noir
# 			ADJ, Genre=I, Nombre=Du:	ilab	\blanc{Du}-noir
# 			ADJ, Genre=I, Nombre=Pl:	elab	\blanc{Pl}-noir
#
# \newcommand{\noirMSg}{\strutgb{0pt}\grapho{labo}}
# \newcommand{\noirMSgP}{\textipa{labo}}
# \newcommand{\noirMSgG}{noir-\blanc{M.Sg}}
# \newcommand{\noirMDu}{\strutgb{0pt}\grapho{ilab}}
# \newcommand{\noirMDuP}{\textipa{ilab}}
# \newcommand{\noirMDuG}{\blanc{Du}-noir}
# \newcommand{\noirMPl}{\strutgb{0pt}\grapho{elab}}
# \newcommand{\noirMPlP}{\textipa{elab}}
# \newcommand{\noirMPlG}{\blanc{Pl}-noir}
# \newcommand{\noirFSg}{\strutgb{0pt}\grapho{alab}}
# \newcommand{\noirFSgP}{\textipa{alab}}
# \newcommand{\noirFSgG}{\blanc{Sg}-noir}
# \newcommand{\noirFDu}{\strutgb{0pt}\grapho{ilab}}
# \newcommand{\noirFDuP}{\textipa{ilab}}
# \newcommand{\noirFDuG}{\blanc{Du}-noir}
# \newcommand{\noirFPl}{\strutgb{0pt}\grapho{laba}}
# \newcommand{\noirFPlP}{\textipa{laba}}
# \newcommand{\noirFPlG}{noir-\blanc{F.Pl}}
# \newcommand{\noirASg}{\strutgb{0pt}\grapho{alab}}
# \newcommand{\noirASgP}{\textipa{alab}}
# \newcommand{\noirASgG}{\blanc{Sg}-noir}
# \newcommand{\noirADu}{\strutgb{0pt}\grapho{labe}}
# \newcommand{\noirADuP}{\textipa{labe}}
# \newcommand{\noirADuG}{noir-\blanc{A.Du}}
# \newcommand{\noirAPl}{\strutgb{0pt}\grapho{elab}}
# \newcommand{\noirAPlP}{\textipa{elab}}
# \newcommand{\noirAPlG}{\blanc{Pl}-noir}
# \newcommand{\noirISg}{\strutgb{0pt}\grapho{alab}}
# \newcommand{\noirISgP}{\textipa{alab}}
# \newcommand{\noirISgG}{\blanc{Sg}-noir}
# \newcommand{\noirIDu}{\strutgb{0pt}\grapho{ilab}}
# \newcommand{\noirIDuP}{\textipa{ilab}}
# \newcommand{\noirIDuG}{\blanc{Du}-noir}
# \newcommand{\noirIPl}{\strutgb{0pt}\grapho{elab}}
# \newcommand{\noirIPlP}{\textipa{elab}}
# \newcommand{\noirIPlG}{\blanc{Pl}-noir}
# N
# bal, A, autruche.A
# 		bal :
# 			N, Genre=A, Nombre=Sg, Cas=Erg:	balx	autruche.A-\blanc{Erg.Sg}
# 			N, Genre=A, Nombre=Sg, Cas=Abs:	bali	autruche.A-\blanc{Abs.A}
# 			N, Genre=A, Nombre=Sg, Cas=Nu:	bal	autruche.A
# 			N, Genre=A, Nombre=Du, Cas=Erg:	bals	autruche.A-\blanc{Erg}
# 			N, Genre=A, Nombre=Du, Cas=Abs:	balid	autruche.A-\blanc{Abs.A}-\blanc{Abs.Du}
# 			N, Genre=A, Nombre=Du, Cas=Nu:	bal	autruche.A
# 			N, Genre=A, Nombre=Pl, Cas=Erg:	balt	autruche.A-\blanc{Erg.Pl}
# 			N, Genre=A, Nombre=Pl, Cas=Abs:	bali	autruche.A-\blanc{Abs.A}
# 			N, Genre=A, Nombre=Pl, Cas=Nu:	bal	autruche.A
#
# \newcommand{\autrucheAASgErg}{\strutgb{0pt}\grapho{balx}}
# \newcommand{\autrucheAASgErgP}{\textipa{balx}}
# \newcommand{\autrucheAASgErgG}{autruche.A-\blanc{Erg.Sg}}
# \newcommand{\autrucheAASgAbs}{\strutgb{0pt}\grapho{bali}}
# \newcommand{\autrucheAASgAbsP}{\textipa{bali}}
# \newcommand{\autrucheAASgAbsG}{autruche.A-\blanc{Abs.A}}
# \newcommand{\autrucheAASgNu}{\strutgb{0pt}\grapho{bal}}
# \newcommand{\autrucheAASgNuP}{\textipa{bal}}
# \newcommand{\autrucheAASgNuG}{autruche.A}
# \newcommand{\autrucheAADuErg}{\strutgb{0pt}\grapho{bals}}
# \newcommand{\autrucheAADuErgP}{\textipa{bals}}
# \newcommand{\autrucheAADuErgG}{autruche.A-\blanc{Erg}}
# \newcommand{\autrucheAADuAbs}{\strutgb{0pt}\grapho{balid}}
# \newcommand{\autrucheAADuAbsP}{\textipa{balid}}
# \newcommand{\autrucheAADuAbsG}{autruche.A-\blanc{Abs.A}-\blanc{Abs.Du}}
# \newcommand{\autrucheAADuNu}{\strutgb{0pt}\grapho{bal}}
# \newcommand{\autrucheAADuNuP}{\textipa{bal}}
# \newcommand{\autrucheAADuNuG}{autruche.A}
# \newcommand{\autrucheAAPlErg}{\strutgb{0pt}\grapho{balt}}
# \newcommand{\autrucheAAPlErgP}{\textipa{balt}}
# \newcommand{\autrucheAAPlErgG}{autruche.A-\blanc{Erg.Pl}}
# \newcommand{\autrucheAAPlAbs}{\strutgb{0pt}\grapho{bali}}
# \newcommand{\autrucheAAPlAbsP}{\textipa{bali}}
# \newcommand{\autrucheAAPlAbsG}{autruche.A-\blanc{Abs.A}}
# \newcommand{\autrucheAAPlNu}{\strutgb{0pt}\grapho{bal}}
# \newcommand{\autrucheAAPlNuP}{\textipa{bal}}
# \newcommand{\autrucheAAPlNuG}{autruche.A}
# rat, A, chat.A
# 		rat :
# 			N, Genre=A, Nombre=Sg, Cas=Erg:	ratx	chat.A-\blanc{Erg.Sg}
# 			N, Genre=A, Nombre=Sg, Cas=Abs:	rati	chat.A-\blanc{Abs.A}
# 			N, Genre=A, Nombre=Sg, Cas=Nu:	rat	chat.A
# 			N, Genre=A, Nombre=Du, Cas=Erg:	rats	chat.A-\blanc{Erg}
# 			N, Genre=A, Nombre=Du, Cas=Abs:	ratid	chat.A-\blanc{Abs.A}-\blanc{Abs.Du}
# 			N, Genre=A, Nombre=Du, Cas=Nu:	rat	chat.A
# 			N, Genre=A, Nombre=Pl, Cas=Erg:	ratt	chat.A-\blanc{Erg.Pl}
# 			N, Genre=A, Nombre=Pl, Cas=Abs:	rati	chat.A-\blanc{Abs.A}
# 			N, Genre=A, Nombre=Pl, Cas=Nu:	rat	chat.A
#
# \newcommand{\chatAASgErg}{\strutgb{0pt}\grapho{ratx}}
# \newcommand{\chatAASgErgP}{\textipa{ratx}}
# \newcommand{\chatAASgErgG}{chat.A-\blanc{Erg.Sg}}
# \newcommand{\chatAASgAbs}{\strutgb{0pt}\grapho{rati}}
# \newcommand{\chatAASgAbsP}{\textipa{rati}}
# \newcommand{\chatAASgAbsG}{chat.A-\blanc{Abs.A}}
# \newcommand{\chatAASgNu}{\strutgb{0pt}\grapho{rat}}
# \newcommand{\chatAASgNuP}{\textipa{rat}}
# \newcommand{\chatAASgNuG}{chat.A}
# \newcommand{\chatAADuErg}{\strutgb{0pt}\grapho{rats}}
# \newcommand{\chatAADuErgP}{\textipa{rats}}
# \newcommand{\chatAADuErgG}{chat.A-\blanc{Erg}}
# \newcommand{\chatAADuAbs}{\strutgb{0pt}\grapho{ratid}}
# \newcommand{\chatAADuAbsP}{\textipa{ratid}}
# \newcommand{\chatAADuAbsG}{chat.A-\blanc{Abs.A}-\blanc{Abs.Du}}
# \newcommand{\chatAADuNu}{\strutgb{0pt}\grapho{rat}}
# \newcommand{\chatAADuNuP}{\textipa{rat}}
# \newcommand{\chatAADuNuG}{chat.A}
# \newcommand{\chatAAPlErg}{\strutgb{0pt}\grapho{ratt}}
# \newcommand{\chatAAPlErgP}{\textipa{ratt}}
# \newcommand{\chatAAPlErgG}{chat.A-\blanc{Erg.Pl}}
# \newcommand{\chatAAPlAbs}{\strutgb{0pt}\grapho{rati}}
# \newcommand{\chatAAPlAbsP}{\textipa{rati}}
# \newcommand{\chatAAPlAbsG}{chat.A-\blanc{Abs.A}}
# \newcommand{\chatAAPlNu}{\strutgb{0pt}\grapho{rat}}
# \newcommand{\chatAAPlNuP}{\textipa{rat}}
# \newcommand{\chatAAPlNuG}{chat.A}
# kat, A, souris.A
# 		kat :
# 			N, Genre=A, Nombre=Sg, Cas=Erg:	katx	souris.A-\blanc{Erg.Sg}
# 			N, Genre=A, Nombre=Sg, Cas=Abs:	kati	souris.A-\blanc{Abs.A}
# 			N, Genre=A, Nombre=Sg, Cas=Nu:	kat	souris.A
# 			N, Genre=A, Nombre=Du, Cas=Erg:	kats	souris.A-\blanc{Erg}
# 			N, Genre=A, Nombre=Du, Cas=Abs:	katid	souris.A-\blanc{Abs.A}-\blanc{Abs.Du}
# 			N, Genre=A, Nombre=Du, Cas=Nu:	kat	souris.A
# 			N, Genre=A, Nombre=Pl, Cas=Erg:	katt	souris.A-\blanc{Erg.Pl}
# 			N, Genre=A, Nombre=Pl, Cas=Abs:	kati	souris.A-\blanc{Abs.A}
# 			N, Genre=A, Nombre=Pl, Cas=Nu:	kat	souris.A
#
# \newcommand{\sourisAASgErg}{\strutgb{0pt}\grapho{katx}}
# \newcommand{\sourisAASgErgP}{\textipa{katx}}
# \newcommand{\sourisAASgErgG}{souris.A-\blanc{Erg.Sg}}
# \newcommand{\sourisAASgAbs}{\strutgb{0pt}\grapho{kati}}
# \newcommand{\sourisAASgAbsP}{\textipa{kati}}
# \newcommand{\sourisAASgAbsG}{souris.A-\blanc{Abs.A}}
# \newcommand{\sourisAASgNu}{\strutgb{0pt}\grapho{kat}}
# \newcommand{\sourisAASgNuP}{\textipa{kat}}
# \newcommand{\sourisAASgNuG}{souris.A}
# \newcommand{\sourisAADuErg}{\strutgb{0pt}\grapho{kats}}
# \newcommand{\sourisAADuErgP}{\textipa{kats}}
# \newcommand{\sourisAADuErgG}{souris.A-\blanc{Erg}}
# \newcommand{\sourisAADuAbs}{\strutgb{0pt}\grapho{katid}}
# \newcommand{\sourisAADuAbsP}{\textipa{katid}}
# \newcommand{\sourisAADuAbsG}{souris.A-\blanc{Abs.A}-\blanc{Abs.Du}}
# \newcommand{\sourisAADuNu}{\strutgb{0pt}\grapho{kat}}
# \newcommand{\sourisAADuNuP}{\textipa{kat}}
# \newcommand{\sourisAADuNuG}{souris.A}
# \newcommand{\sourisAAPlErg}{\strutgb{0pt}\grapho{katt}}
# \newcommand{\sourisAAPlErgP}{\textipa{katt}}
# \newcommand{\sourisAAPlErgG}{souris.A-\blanc{Erg.Pl}}
# \newcommand{\sourisAAPlAbs}{\strutgb{0pt}\grapho{kati}}
# \newcommand{\sourisAAPlAbsP}{\textipa{kati}}
# \newcommand{\sourisAAPlAbsG}{souris.A-\blanc{Abs.A}}
# \newcommand{\sourisAAPlNu}{\strutgb{0pt}\grapho{kat}}
# \newcommand{\sourisAAPlNuP}{\textipa{kat}}
# \newcommand{\sourisAAPlNuG}{souris.A}
# kab, I, table.I
# 		kab :
# 			N, Genre=I, Nombre=Sg, Cas=Erg:	kabx	table.I-\blanc{Erg.Sg}
# 			N, Genre=I, Nombre=Sg, Cas=Abs:	kab	table.I
# 			N, Genre=I, Nombre=Sg, Cas=Nu:	kab	table.I
# 			N, Genre=I, Nombre=Du, Cas=Erg:	kabs	table.I-\blanc{Erg}
# 			N, Genre=I, Nombre=Du, Cas=Abs:	kabd	table.I-\blanc{Abs.Du}
# 			N, Genre=I, Nombre=Du, Cas=Nu:	kab	table.I
# 			N, Genre=I, Nombre=Pl, Cas=Erg:	kabt	table.I-\blanc{Erg.Pl}
# 			N, Genre=I, Nombre=Pl, Cas=Abs:	kab	table.I
# 			N, Genre=I, Nombre=Pl, Cas=Nu:	kab	table.I
#
# \newcommand{\tableIISgErg}{\strutgb{0pt}\grapho{kabx}}
# \newcommand{\tableIISgErgP}{\textipa{kabx}}
# \newcommand{\tableIISgErgG}{table.I-\blanc{Erg.Sg}}
# \newcommand{\tableIISgAbs}{\strutgb{0pt}\grapho{kab}}
# \newcommand{\tableIISgAbsP}{\textipa{kab}}
# \newcommand{\tableIISgAbsG}{table.I}
# \newcommand{\tableIISgNu}{\strutgb{0pt}\grapho{kab}}
# \newcommand{\tableIISgNuP}{\textipa{kab}}
# \newcommand{\tableIISgNuG}{table.I}
# \newcommand{\tableIIDuErg}{\strutgb{0pt}\grapho{kabs}}
# \newcommand{\tableIIDuErgP}{\textipa{kabs}}
# \newcommand{\tableIIDuErgG}{table.I-\blanc{Erg}}
# \newcommand{\tableIIDuAbs}{\strutgb{0pt}\grapho{kabd}}
# \newcommand{\tableIIDuAbsP}{\textipa{kabd}}
# \newcommand{\tableIIDuAbsG}{table.I-\blanc{Abs.Du}}
# \newcommand{\tableIIDuNu}{\strutgb{0pt}\grapho{kab}}
# \newcommand{\tableIIDuNuP}{\textipa{kab}}
# \newcommand{\tableIIDuNuG}{table.I}
# \newcommand{\tableIIPlErg}{\strutgb{0pt}\grapho{kabt}}
# \newcommand{\tableIIPlErgP}{\textipa{kabt}}
# \newcommand{\tableIIPlErgG}{table.I-\blanc{Erg.Pl}}
# \newcommand{\tableIIPlAbs}{\strutgb{0pt}\grapho{kab}}
# \newcommand{\tableIIPlAbsP}{\textipa{kab}}
# \newcommand{\tableIIPlAbsG}{table.I}
# \newcommand{\tableIIPlNu}{\strutgb{0pt}\grapho{kab}}
# \newcommand{\tableIIPlNuP}{\textipa{kab}}
# \newcommand{\tableIIPlNuG}{table.I}
# non, I, oeuf.I
# 		non :
# 			N, Genre=I, Nombre=Sg, Cas=Erg:	nonx	oeuf.I-\blanc{Erg.Sg}
# 			N, Genre=I, Nombre=Sg, Cas=Abs:	non	oeuf.I
# 			N, Genre=I, Nombre=Sg, Cas=Nu:	non	oeuf.I
# 			N, Genre=I, Nombre=Du, Cas=Erg:	nons	oeuf.I-\blanc{Erg}
# 			N, Genre=I, Nombre=Du, Cas=Abs:	nond	oeuf.I-\blanc{Abs.Du}
# 			N, Genre=I, Nombre=Du, Cas=Nu:	non	oeuf.I
# 			N, Genre=I, Nombre=Pl, Cas=Erg:	nont	oeuf.I-\blanc{Erg.Pl}
# 			N, Genre=I, Nombre=Pl, Cas=Abs:	non	oeuf.I
# 			N, Genre=I, Nombre=Pl, Cas=Nu:	non	oeuf.I
#
# \newcommand{\oeufIISgErg}{\strutgb{0pt}\grapho{nonx}}
# \newcommand{\oeufIISgErgP}{\textipa{nonx}}
# \newcommand{\oeufIISgErgG}{oeuf.I-\blanc{Erg.Sg}}
# \newcommand{\oeufIISgAbs}{\strutgb{0pt}\grapho{non}}
# \newcommand{\oeufIISgAbsP}{\textipa{non}}
# \newcommand{\oeufIISgAbsG}{oeuf.I}
# \newcommand{\oeufIISgNu}{\strutgb{0pt}\grapho{non}}
# \newcommand{\oeufIISgNuP}{\textipa{non}}
# \newcommand{\oeufIISgNuG}{oeuf.I}
# \newcommand{\oeufIIDuErg}{\strutgb{0pt}\grapho{nons}}
# \newcommand{\oeufIIDuErgP}{\textipa{nons}}
# \newcommand{\oeufIIDuErgG}{oeuf.I-\blanc{Erg}}
# \newcommand{\oeufIIDuAbs}{\strutgb{0pt}\grapho{nond}}
# \newcommand{\oeufIIDuAbsP}{\textipa{nond}}
# \newcommand{\oeufIIDuAbsG}{oeuf.I-\blanc{Abs.Du}}
# \newcommand{\oeufIIDuNu}{\strutgb{0pt}\grapho{non}}
# \newcommand{\oeufIIDuNuP}{\textipa{non}}
# \newcommand{\oeufIIDuNuG}{oeuf.I}
# \newcommand{\oeufIIPlErg}{\strutgb{0pt}\grapho{nont}}
# \newcommand{\oeufIIPlErgP}{\textipa{nont}}
# \newcommand{\oeufIIPlErgG}{oeuf.I-\blanc{Erg.Pl}}
# \newcommand{\oeufIIPlAbs}{\strutgb{0pt}\grapho{non}}
# \newcommand{\oeufIIPlAbsP}{\textipa{non}}
# \newcommand{\oeufIIPlAbsG}{oeuf.I}
# \newcommand{\oeufIIPlNu}{\strutgb{0pt}\grapho{non}}
# \newcommand{\oeufIIPlNuP}{\textipa{non}}
# \newcommand{\oeufIIPlNuG}{oeuf.I}
# bol, I, café.I
# 		bol :
# 			N, Genre=I, Nombre=Sg, Cas=Erg:	bolx	café.I-\blanc{Erg.Sg}
# 			N, Genre=I, Nombre=Sg, Cas=Abs:	bol	café.I
# 			N, Genre=I, Nombre=Sg, Cas=Nu:	bol	café.I
# 			N, Genre=I, Nombre=Du, Cas=Erg:	bols	café.I-\blanc{Erg}
# 			N, Genre=I, Nombre=Du, Cas=Abs:	bold	café.I-\blanc{Abs.Du}
# 			N, Genre=I, Nombre=Du, Cas=Nu:	bol	café.I
# 			N, Genre=I, Nombre=Pl, Cas=Erg:	bolt	café.I-\blanc{Erg.Pl}
# 			N, Genre=I, Nombre=Pl, Cas=Abs:	bol	café.I
# 			N, Genre=I, Nombre=Pl, Cas=Nu:	bol	café.I
#
# \newcommand{\caféIISgErg}{\strutgb{0pt}\grapho{bolx}}
# \newcommand{\caféIISgErgP}{\textipa{bolx}}
# \newcommand{\caféIISgErgG}{café.I-\blanc{Erg.Sg}}
# \newcommand{\caféIISgAbs}{\strutgb{0pt}\grapho{bol}}
# \newcommand{\caféIISgAbsP}{\textipa{bol}}
# \newcommand{\caféIISgAbsG}{café.I}
# \newcommand{\caféIISgNu}{\strutgb{0pt}\grapho{bol}}
# \newcommand{\caféIISgNuP}{\textipa{bol}}
# \newcommand{\caféIISgNuG}{café.I}
# \newcommand{\caféIIDuErg}{\strutgb{0pt}\grapho{bols}}
# \newcommand{\caféIIDuErgP}{\textipa{bols}}
# \newcommand{\caféIIDuErgG}{café.I-\blanc{Erg}}
# \newcommand{\caféIIDuAbs}{\strutgb{0pt}\grapho{bold}}
# \newcommand{\caféIIDuAbsP}{\textipa{bold}}
# \newcommand{\caféIIDuAbsG}{café.I-\blanc{Abs.Du}}
# \newcommand{\caféIIDuNu}{\strutgb{0pt}\grapho{bol}}
# \newcommand{\caféIIDuNuP}{\textipa{bol}}
# \newcommand{\caféIIDuNuG}{café.I}
# \newcommand{\caféIIPlErg}{\strutgb{0pt}\grapho{bolt}}
# \newcommand{\caféIIPlErgP}{\textipa{bolt}}
# \newcommand{\caféIIPlErgG}{café.I-\blanc{Erg.Pl}}
# \newcommand{\caféIIPlAbs}{\strutgb{0pt}\grapho{bol}}
# \newcommand{\caféIIPlAbsP}{\textipa{bol}}
# \newcommand{\caféIIPlAbsG}{café.I}
# \newcommand{\caféIIPlNu}{\strutgb{0pt}\grapho{bol}}
# \newcommand{\caféIIPlNuP}{\textipa{bol}}
# \newcommand{\caféIIPlNuG}{café.I}
# kol, I, thé.I
# 		kol :
# 			N, Genre=I, Nombre=Sg, Cas=Erg:	kolx	thé.I-\blanc{Erg.Sg}
# 			N, Genre=I, Nombre=Sg, Cas=Abs:	kol	thé.I
# 			N, Genre=I, Nombre=Sg, Cas=Nu:	kol	thé.I
# 			N, Genre=I, Nombre=Du, Cas=Erg:	kols	thé.I-\blanc{Erg}
# 			N, Genre=I, Nombre=Du, Cas=Abs:	kold	thé.I-\blanc{Abs.Du}
# 			N, Genre=I, Nombre=Du, Cas=Nu:	kol	thé.I
# 			N, Genre=I, Nombre=Pl, Cas=Erg:	kolt	thé.I-\blanc{Erg.Pl}
# 			N, Genre=I, Nombre=Pl, Cas=Abs:	kol	thé.I
# 			N, Genre=I, Nombre=Pl, Cas=Nu:	kol	thé.I
#
# \newcommand{\théIISgErg}{\strutgb{0pt}\grapho{kolx}}
# \newcommand{\théIISgErgP}{\textipa{kolx}}
# \newcommand{\théIISgErgG}{thé.I-\blanc{Erg.Sg}}
# \newcommand{\théIISgAbs}{\strutgb{0pt}\grapho{kol}}
# \newcommand{\théIISgAbsP}{\textipa{kol}}
# \newcommand{\théIISgAbsG}{thé.I}
# \newcommand{\théIISgNu}{\strutgb{0pt}\grapho{kol}}
# \newcommand{\théIISgNuP}{\textipa{kol}}
# \newcommand{\théIISgNuG}{thé.I}
# \newcommand{\théIIDuErg}{\strutgb{0pt}\grapho{kols}}
# \newcommand{\théIIDuErgP}{\textipa{kols}}
# \newcommand{\théIIDuErgG}{thé.I-\blanc{Erg}}
# \newcommand{\théIIDuAbs}{\strutgb{0pt}\grapho{kold}}
# \newcommand{\théIIDuAbsP}{\textipa{kold}}
# \newcommand{\théIIDuAbsG}{thé.I-\blanc{Abs.Du}}
# \newcommand{\théIIDuNu}{\strutgb{0pt}\grapho{kol}}
# \newcommand{\théIIDuNuP}{\textipa{kol}}
# \newcommand{\théIIDuNuG}{thé.I}
# \newcommand{\théIIPlErg}{\strutgb{0pt}\grapho{kolt}}
# \newcommand{\théIIPlErgP}{\textipa{kolt}}
# \newcommand{\théIIPlErgG}{thé.I-\blanc{Erg.Pl}}
# \newcommand{\théIIPlAbs}{\strutgb{0pt}\grapho{kol}}
# \newcommand{\théIIPlAbsP}{\textipa{kol}}
# \newcommand{\théIIPlAbsG}{thé.I}
# \newcommand{\théIIPlNu}{\strutgb{0pt}\grapho{kol}}
# \newcommand{\théIIPlNuP}{\textipa{kol}}
# \newcommand{\théIIPlNuG}{thé.I}
# ban, I, chambre.I
# 		ban :
# 			N, Genre=I, Nombre=Sg, Cas=Erg:	banx	chambre.I-\blanc{Erg.Sg}
# 			N, Genre=I, Nombre=Sg, Cas=Abs:	ban	chambre.I
# 			N, Genre=I, Nombre=Sg, Cas=Nu:	ban	chambre.I
# 			N, Genre=I, Nombre=Du, Cas=Erg:	bans	chambre.I-\blanc{Erg}
# 			N, Genre=I, Nombre=Du, Cas=Abs:	band	chambre.I-\blanc{Abs.Du}
# 			N, Genre=I, Nombre=Du, Cas=Nu:	ban	chambre.I
# 			N, Genre=I, Nombre=Pl, Cas=Erg:	bant	chambre.I-\blanc{Erg.Pl}
# 			N, Genre=I, Nombre=Pl, Cas=Abs:	ban	chambre.I
# 			N, Genre=I, Nombre=Pl, Cas=Nu:	ban	chambre.I
#
# \newcommand{\chambreIISgErg}{\strutgb{0pt}\grapho{banx}}
# \newcommand{\chambreIISgErgP}{\textipa{banx}}
# \newcommand{\chambreIISgErgG}{chambre.I-\blanc{Erg.Sg}}
# \newcommand{\chambreIISgAbs}{\strutgb{0pt}\grapho{ban}}
# \newcommand{\chambreIISgAbsP}{\textipa{ban}}
# \newcommand{\chambreIISgAbsG}{chambre.I}
# \newcommand{\chambreIISgNu}{\strutgb{0pt}\grapho{ban}}
# \newcommand{\chambreIISgNuP}{\textipa{ban}}
# \newcommand{\chambreIISgNuG}{chambre.I}
# \newcommand{\chambreIIDuErg}{\strutgb{0pt}\grapho{bans}}
# \newcommand{\chambreIIDuErgP}{\textipa{bans}}
# \newcommand{\chambreIIDuErgG}{chambre.I-\blanc{Erg}}
# \newcommand{\chambreIIDuAbs}{\strutgb{0pt}\grapho{band}}
# \newcommand{\chambreIIDuAbsP}{\textipa{band}}
# \newcommand{\chambreIIDuAbsG}{chambre.I-\blanc{Abs.Du}}
# \newcommand{\chambreIIDuNu}{\strutgb{0pt}\grapho{ban}}
# \newcommand{\chambreIIDuNuP}{\textipa{ban}}
# \newcommand{\chambreIIDuNuG}{chambre.I}
# \newcommand{\chambreIIPlErg}{\strutgb{0pt}\grapho{bant}}
# \newcommand{\chambreIIPlErgP}{\textipa{bant}}
# \newcommand{\chambreIIPlErgG}{chambre.I-\blanc{Erg.Pl}}
# \newcommand{\chambreIIPlAbs}{\strutgb{0pt}\grapho{ban}}
# \newcommand{\chambreIIPlAbsP}{\textipa{ban}}
# \newcommand{\chambreIIPlAbsG}{chambre.I}
# \newcommand{\chambreIIPlNu}{\strutgb{0pt}\grapho{ban}}
# \newcommand{\chambreIIPlNuP}{\textipa{ban}}
# \newcommand{\chambreIIPlNuG}{chambre.I}
# suk, I, coussin.I
# 		suk :
# 			N, Genre=I, Nombre=Sg, Cas=Erg:	sukx	coussin.I-\blanc{Erg.Sg}
# 			N, Genre=I, Nombre=Sg, Cas=Abs:	suk	coussin.I
# 			N, Genre=I, Nombre=Sg, Cas=Nu:	suk	coussin.I
# 			N, Genre=I, Nombre=Du, Cas=Erg:	suks	coussin.I-\blanc{Erg}
# 			N, Genre=I, Nombre=Du, Cas=Abs:	sukd	coussin.I-\blanc{Abs.Du}
# 			N, Genre=I, Nombre=Du, Cas=Nu:	suk	coussin.I
# 			N, Genre=I, Nombre=Pl, Cas=Erg:	sukt	coussin.I-\blanc{Erg.Pl}
# 			N, Genre=I, Nombre=Pl, Cas=Abs:	suk	coussin.I
# 			N, Genre=I, Nombre=Pl, Cas=Nu:	suk	coussin.I
#
# \newcommand{\coussinIISgErg}{\strutgb{0pt}\grapho{sukx}}
# \newcommand{\coussinIISgErgP}{\textipa{sukx}}
# \newcommand{\coussinIISgErgG}{coussin.I-\blanc{Erg.Sg}}
# \newcommand{\coussinIISgAbs}{\strutgb{0pt}\grapho{suk}}
# \newcommand{\coussinIISgAbsP}{\textipa{suk}}
# \newcommand{\coussinIISgAbsG}{coussin.I}
# \newcommand{\coussinIISgNu}{\strutgb{0pt}\grapho{suk}}
# \newcommand{\coussinIISgNuP}{\textipa{suk}}
# \newcommand{\coussinIISgNuG}{coussin.I}
# \newcommand{\coussinIIDuErg}{\strutgb{0pt}\grapho{suks}}
# \newcommand{\coussinIIDuErgP}{\textipa{suks}}
# \newcommand{\coussinIIDuErgG}{coussin.I-\blanc{Erg}}
# \newcommand{\coussinIIDuAbs}{\strutgb{0pt}\grapho{sukd}}
# \newcommand{\coussinIIDuAbsP}{\textipa{sukd}}
# \newcommand{\coussinIIDuAbsG}{coussin.I-\blanc{Abs.Du}}
# \newcommand{\coussinIIDuNu}{\strutgb{0pt}\grapho{suk}}
# \newcommand{\coussinIIDuNuP}{\textipa{suk}}
# \newcommand{\coussinIIDuNuG}{coussin.I}
# \newcommand{\coussinIIPlErg}{\strutgb{0pt}\grapho{sukt}}
# \newcommand{\coussinIIPlErgP}{\textipa{sukt}}
# \newcommand{\coussinIIPlErgG}{coussin.I-\blanc{Erg.Pl}}
# \newcommand{\coussinIIPlAbs}{\strutgb{0pt}\grapho{suk}}
# \newcommand{\coussinIIPlAbsP}{\textipa{suk}}
# \newcommand{\coussinIIPlAbsG}{coussin.I}
# \newcommand{\coussinIIPlNu}{\strutgb{0pt}\grapho{suk}}
# \newcommand{\coussinIIPlNuP}{\textipa{suk}}
# \newcommand{\coussinIIPlNuG}{coussin.I}
# pok, I, lit.I
# 		pok :
# 			N, Genre=I, Nombre=Sg, Cas=Erg:	pokx	lit.I-\blanc{Erg.Sg}
# 			N, Genre=I, Nombre=Sg, Cas=Abs:	pok	lit.I
# 			N, Genre=I, Nombre=Sg, Cas=Nu:	pok	lit.I
# 			N, Genre=I, Nombre=Du, Cas=Erg:	poks	lit.I-\blanc{Erg}
# 			N, Genre=I, Nombre=Du, Cas=Abs:	pokd	lit.I-\blanc{Abs.Du}
# 			N, Genre=I, Nombre=Du, Cas=Nu:	pok	lit.I
# 			N, Genre=I, Nombre=Pl, Cas=Erg:	pokt	lit.I-\blanc{Erg.Pl}
# 			N, Genre=I, Nombre=Pl, Cas=Abs:	pok	lit.I
# 			N, Genre=I, Nombre=Pl, Cas=Nu:	pok	lit.I
#
# \newcommand{\litIISgErg}{\strutgb{0pt}\grapho{pokx}}
# \newcommand{\litIISgErgP}{\textipa{pokx}}
# \newcommand{\litIISgErgG}{lit.I-\blanc{Erg.Sg}}
# \newcommand{\litIISgAbs}{\strutgb{0pt}\grapho{pok}}
# \newcommand{\litIISgAbsP}{\textipa{pok}}
# \newcommand{\litIISgAbsG}{lit.I}
# \newcommand{\litIISgNu}{\strutgb{0pt}\grapho{pok}}
# \newcommand{\litIISgNuP}{\textipa{pok}}
# \newcommand{\litIISgNuG}{lit.I}
# \newcommand{\litIIDuErg}{\strutgb{0pt}\grapho{poks}}
# \newcommand{\litIIDuErgP}{\textipa{poks}}
# \newcommand{\litIIDuErgG}{lit.I-\blanc{Erg}}
# \newcommand{\litIIDuAbs}{\strutgb{0pt}\grapho{pokd}}
# \newcommand{\litIIDuAbsP}{\textipa{pokd}}
# \newcommand{\litIIDuAbsG}{lit.I-\blanc{Abs.Du}}
# \newcommand{\litIIDuNu}{\strutgb{0pt}\grapho{pok}}
# \newcommand{\litIIDuNuP}{\textipa{pok}}
# \newcommand{\litIIDuNuG}{lit.I}
# \newcommand{\litIIPlErg}{\strutgb{0pt}\grapho{pokt}}
# \newcommand{\litIIPlErgP}{\textipa{pokt}}
# \newcommand{\litIIPlErgG}{lit.I-\blanc{Erg.Pl}}
# \newcommand{\litIIPlAbs}{\strutgb{0pt}\grapho{pok}}
# \newcommand{\litIIPlAbsP}{\textipa{pok}}
# \newcommand{\litIIPlAbsG}{lit.I}
# \newcommand{\litIIPlNu}{\strutgb{0pt}\grapho{pok}}
# \newcommand{\litIIPlNuP}{\textipa{pok}}
# \newcommand{\litIIPlNuG}{lit.I}
# dil, M, Adil.M
# 		dil :
# 			N, Genre=M, Nombre=Sg, Cas=Erg:	dilox	Adil.M-\blanc{Erg.M}-\blanc{Erg.Sg}
# 			N, Genre=M, Nombre=Sg, Cas=Abs:	dile	Adil.M-\blanc{Abs.M}
# 			N, Genre=M, Nombre=Sg, Cas=Nu:	dil	Adil.M
# 			N, Genre=M, Nombre=Du, Cas=Erg:	dilos	Adil.M-\blanc{Erg.M}-\blanc{Erg}
# 			N, Genre=M, Nombre=Du, Cas=Abs:	diled	Adil.M-\blanc{Abs.M}-\blanc{Abs.Du}
# 			N, Genre=M, Nombre=Du, Cas=Nu:	dil	Adil.M
# 			N, Genre=M, Nombre=Pl, Cas=Erg:	dilot	Adil.M-\blanc{Erg.M}-\blanc{Erg.Pl}
# 			N, Genre=M, Nombre=Pl, Cas=Abs:	dile	Adil.M-\blanc{Abs.M}
# 			N, Genre=M, Nombre=Pl, Cas=Nu:	dil	Adil.M
#
# \newcommand{\AdilMMSgErg}{\strutgb{0pt}\grapho{dilox}}
# \newcommand{\AdilMMSgErgP}{\textipa{dilox}}
# \newcommand{\AdilMMSgErgG}{Adil.M-\blanc{Erg.M}-\blanc{Erg.Sg}}
# \newcommand{\AdilMMSgAbs}{\strutgb{0pt}\grapho{dile}}
# \newcommand{\AdilMMSgAbsP}{\textipa{dile}}
# \newcommand{\AdilMMSgAbsG}{Adil.M-\blanc{Abs.M}}
# \newcommand{\AdilMMSgNu}{\strutgb{0pt}\grapho{dil}}
# \newcommand{\AdilMMSgNuP}{\textipa{dil}}
# \newcommand{\AdilMMSgNuG}{Adil.M}
# \newcommand{\AdilMMDuErg}{\strutgb{0pt}\grapho{dilos}}
# \newcommand{\AdilMMDuErgP}{\textipa{dilos}}
# \newcommand{\AdilMMDuErgG}{Adil.M-\blanc{Erg.M}-\blanc{Erg}}
# \newcommand{\AdilMMDuAbs}{\strutgb{0pt}\grapho{diled}}
# \newcommand{\AdilMMDuAbsP}{\textipa{diled}}
# \newcommand{\AdilMMDuAbsG}{Adil.M-\blanc{Abs.M}-\blanc{Abs.Du}}
# \newcommand{\AdilMMDuNu}{\strutgb{0pt}\grapho{dil}}
# \newcommand{\AdilMMDuNuP}{\textipa{dil}}
# \newcommand{\AdilMMDuNuG}{Adil.M}
# \newcommand{\AdilMMPlErg}{\strutgb{0pt}\grapho{dilot}}
# \newcommand{\AdilMMPlErgP}{\textipa{dilot}}
# \newcommand{\AdilMMPlErgG}{Adil.M-\blanc{Erg.M}-\blanc{Erg.Pl}}
# \newcommand{\AdilMMPlAbs}{\strutgb{0pt}\grapho{dile}}
# \newcommand{\AdilMMPlAbsP}{\textipa{dile}}
# \newcommand{\AdilMMPlAbsG}{Adil.M-\blanc{Abs.M}}
# \newcommand{\AdilMMPlNu}{\strutgb{0pt}\grapho{dil}}
# \newcommand{\AdilMMPlNuP}{\textipa{dil}}
# \newcommand{\AdilMMPlNuG}{Adil.M}
# rup, M, pompier.M
# 		rup :
# 			N, Genre=M, Nombre=Sg, Cas=Erg:	rupox	pompier.M-\blanc{Erg.M}-\blanc{Erg.Sg}
# 			N, Genre=M, Nombre=Sg, Cas=Abs:	rupe	pompier.M-\blanc{Abs.M}
# 			N, Genre=M, Nombre=Sg, Cas=Nu:	rup	pompier.M
# 			N, Genre=M, Nombre=Du, Cas=Erg:	rupos	pompier.M-\blanc{Erg.M}-\blanc{Erg}
# 			N, Genre=M, Nombre=Du, Cas=Abs:	ruped	pompier.M-\blanc{Abs.M}-\blanc{Abs.Du}
# 			N, Genre=M, Nombre=Du, Cas=Nu:	rup	pompier.M
# 			N, Genre=M, Nombre=Pl, Cas=Erg:	rupot	pompier.M-\blanc{Erg.M}-\blanc{Erg.Pl}
# 			N, Genre=M, Nombre=Pl, Cas=Abs:	rupe	pompier.M-\blanc{Abs.M}
# 			N, Genre=M, Nombre=Pl, Cas=Nu:	rup	pompier.M
#
# \newcommand{\pompierMMSgErg}{\strutgb{0pt}\grapho{rupox}}
# \newcommand{\pompierMMSgErgP}{\textipa{rupox}}
# \newcommand{\pompierMMSgErgG}{pompier.M-\blanc{Erg.M}-\blanc{Erg.Sg}}
# \newcommand{\pompierMMSgAbs}{\strutgb{0pt}\grapho{rupe}}
# \newcommand{\pompierMMSgAbsP}{\textipa{rupe}}
# \newcommand{\pompierMMSgAbsG}{pompier.M-\blanc{Abs.M}}
# \newcommand{\pompierMMSgNu}{\strutgb{0pt}\grapho{rup}}
# \newcommand{\pompierMMSgNuP}{\textipa{rup}}
# \newcommand{\pompierMMSgNuG}{pompier.M}
# \newcommand{\pompierMMDuErg}{\strutgb{0pt}\grapho{rupos}}
# \newcommand{\pompierMMDuErgP}{\textipa{rupos}}
# \newcommand{\pompierMMDuErgG}{pompier.M-\blanc{Erg.M}-\blanc{Erg}}
# \newcommand{\pompierMMDuAbs}{\strutgb{0pt}\grapho{ruped}}
# \newcommand{\pompierMMDuAbsP}{\textipa{ruped}}
# \newcommand{\pompierMMDuAbsG}{pompier.M-\blanc{Abs.M}-\blanc{Abs.Du}}
# \newcommand{\pompierMMDuNu}{\strutgb{0pt}\grapho{rup}}
# \newcommand{\pompierMMDuNuP}{\textipa{rup}}
# \newcommand{\pompierMMDuNuG}{pompier.M}
# \newcommand{\pompierMMPlErg}{\strutgb{0pt}\grapho{rupot}}
# \newcommand{\pompierMMPlErgP}{\textipa{rupot}}
# \newcommand{\pompierMMPlErgG}{pompier.M-\blanc{Erg.M}-\blanc{Erg.Pl}}
# \newcommand{\pompierMMPlAbs}{\strutgb{0pt}\grapho{rupe}}
# \newcommand{\pompierMMPlAbsP}{\textipa{rupe}}
# \newcommand{\pompierMMPlAbsG}{pompier.M-\blanc{Abs.M}}
# \newcommand{\pompierMMPlNu}{\strutgb{0pt}\grapho{rup}}
# \newcommand{\pompierMMPlNuP}{\textipa{rup}}
# \newcommand{\pompierMMPlNuG}{pompier.M}
# donis, M, Adonis.M
# 		donis :
# 			N, Genre=M, Nombre=Sg, Cas=Erg:	donisox	Adonis.M-\blanc{Erg.M}-\blanc{Erg.Sg}
# 			N, Genre=M, Nombre=Sg, Cas=Abs:	donise	Adonis.M-\blanc{Abs.M}
# 			N, Genre=M, Nombre=Sg, Cas=Nu:	donis	Adonis.M
# 			N, Genre=M, Nombre=Du, Cas=Erg:	donisos	Adonis.M-\blanc{Erg.M}-\blanc{Erg}
# 			N, Genre=M, Nombre=Du, Cas=Abs:	donised	Adonis.M-\blanc{Abs.M}-\blanc{Abs.Du}
# 			N, Genre=M, Nombre=Du, Cas=Nu:	donis	Adonis.M
# 			N, Genre=M, Nombre=Pl, Cas=Erg:	donisot	Adonis.M-\blanc{Erg.M}-\blanc{Erg.Pl}
# 			N, Genre=M, Nombre=Pl, Cas=Abs:	donise	Adonis.M-\blanc{Abs.M}
# 			N, Genre=M, Nombre=Pl, Cas=Nu:	donis	Adonis.M
#
# \newcommand{\AdonisMMSgErg}{\strutgb{0pt}\grapho{donisox}}
# \newcommand{\AdonisMMSgErgP}{\textipa{donisox}}
# \newcommand{\AdonisMMSgErgG}{Adonis.M-\blanc{Erg.M}-\blanc{Erg.Sg}}
# \newcommand{\AdonisMMSgAbs}{\strutgb{0pt}\grapho{donise}}
# \newcommand{\AdonisMMSgAbsP}{\textipa{donise}}
# \newcommand{\AdonisMMSgAbsG}{Adonis.M-\blanc{Abs.M}}
# \newcommand{\AdonisMMSgNu}{\strutgb{0pt}\grapho{donis}}
# \newcommand{\AdonisMMSgNuP}{\textipa{donis}}
# \newcommand{\AdonisMMSgNuG}{Adonis.M}
# \newcommand{\AdonisMMDuErg}{\strutgb{0pt}\grapho{donisos}}
# \newcommand{\AdonisMMDuErgP}{\textipa{donisos}}
# \newcommand{\AdonisMMDuErgG}{Adonis.M-\blanc{Erg.M}-\blanc{Erg}}
# \newcommand{\AdonisMMDuAbs}{\strutgb{0pt}\grapho{donised}}
# \newcommand{\AdonisMMDuAbsP}{\textipa{donised}}
# \newcommand{\AdonisMMDuAbsG}{Adonis.M-\blanc{Abs.M}-\blanc{Abs.Du}}
# \newcommand{\AdonisMMDuNu}{\strutgb{0pt}\grapho{donis}}
# \newcommand{\AdonisMMDuNuP}{\textipa{donis}}
# \newcommand{\AdonisMMDuNuG}{Adonis.M}
# \newcommand{\AdonisMMPlErg}{\strutgb{0pt}\grapho{donisot}}
# \newcommand{\AdonisMMPlErgP}{\textipa{donisot}}
# \newcommand{\AdonisMMPlErgG}{Adonis.M-\blanc{Erg.M}-\blanc{Erg.Pl}}
# \newcommand{\AdonisMMPlAbs}{\strutgb{0pt}\grapho{donise}}
# \newcommand{\AdonisMMPlAbsP}{\textipa{donise}}
# \newcommand{\AdonisMMPlAbsG}{Adonis.M-\blanc{Abs.M}}
# \newcommand{\AdonisMMPlNu}{\strutgb{0pt}\grapho{donis}}
# \newcommand{\AdonisMMPlNuP}{\textipa{donis}}
# \newcommand{\AdonisMMPlNuG}{Adonis.M}
# bet, M, garçon.M
# 		bet :
# 			N, Genre=M, Nombre=Sg, Cas=Erg:	betox	garçon.M-\blanc{Erg.M}-\blanc{Erg.Sg}
# 			N, Genre=M, Nombre=Sg, Cas=Abs:	bete	garçon.M-\blanc{Abs.M}
# 			N, Genre=M, Nombre=Sg, Cas=Nu:	bet	garçon.M
# 			N, Genre=M, Nombre=Du, Cas=Erg:	betos	garçon.M-\blanc{Erg.M}-\blanc{Erg}
# 			N, Genre=M, Nombre=Du, Cas=Abs:	beted	garçon.M-\blanc{Abs.M}-\blanc{Abs.Du}
# 			N, Genre=M, Nombre=Du, Cas=Nu:	bet	garçon.M
# 			N, Genre=M, Nombre=Pl, Cas=Erg:	betot	garçon.M-\blanc{Erg.M}-\blanc{Erg.Pl}
# 			N, Genre=M, Nombre=Pl, Cas=Abs:	bete	garçon.M-\blanc{Abs.M}
# 			N, Genre=M, Nombre=Pl, Cas=Nu:	bet	garçon.M
#
# \newcommand{\garçonMMSgErg}{\strutgb{0pt}\grapho{betox}}
# \newcommand{\garçonMMSgErgP}{\textipa{betox}}
# \newcommand{\garçonMMSgErgG}{garçon.M-\blanc{Erg.M}-\blanc{Erg.Sg}}
# \newcommand{\garçonMMSgAbs}{\strutgb{0pt}\grapho{bete}}
# \newcommand{\garçonMMSgAbsP}{\textipa{bete}}
# \newcommand{\garçonMMSgAbsG}{garçon.M-\blanc{Abs.M}}
# \newcommand{\garçonMMSgNu}{\strutgb{0pt}\grapho{bet}}
# \newcommand{\garçonMMSgNuP}{\textipa{bet}}
# \newcommand{\garçonMMSgNuG}{garçon.M}
# \newcommand{\garçonMMDuErg}{\strutgb{0pt}\grapho{betos}}
# \newcommand{\garçonMMDuErgP}{\textipa{betos}}
# \newcommand{\garçonMMDuErgG}{garçon.M-\blanc{Erg.M}-\blanc{Erg}}
# \newcommand{\garçonMMDuAbs}{\strutgb{0pt}\grapho{beted}}
# \newcommand{\garçonMMDuAbsP}{\textipa{beted}}
# \newcommand{\garçonMMDuAbsG}{garçon.M-\blanc{Abs.M}-\blanc{Abs.Du}}
# \newcommand{\garçonMMDuNu}{\strutgb{0pt}\grapho{bet}}
# \newcommand{\garçonMMDuNuP}{\textipa{bet}}
# \newcommand{\garçonMMDuNuG}{garçon.M}
# \newcommand{\garçonMMPlErg}{\strutgb{0pt}\grapho{betot}}
# \newcommand{\garçonMMPlErgP}{\textipa{betot}}
# \newcommand{\garçonMMPlErgG}{garçon.M-\blanc{Erg.M}-\blanc{Erg.Pl}}
# \newcommand{\garçonMMPlAbs}{\strutgb{0pt}\grapho{bete}}
# \newcommand{\garçonMMPlAbsP}{\textipa{bete}}
# \newcommand{\garçonMMPlAbsG}{garçon.M-\blanc{Abs.M}}
# \newcommand{\garçonMMPlNu}{\strutgb{0pt}\grapho{bet}}
# \newcommand{\garçonMMPlNuP}{\textipa{bet}}
# \newcommand{\garçonMMPlNuG}{garçon.M}
# zabel, F, Isabelle.F
# 		zabel :
# 			N, Genre=F, Nombre=Sg, Cas=Erg:	zabelax	Isabelle.F-\blanc{F}-\blanc{Erg.Sg}
# 			N, Genre=F, Nombre=Sg, Cas=Abs:	zabela	Isabelle.F-\blanc{F}
# 			N, Genre=F, Nombre=Sg, Cas=Nu:	zabela	Isabelle.F-\blanc{F}
# 			N, Genre=F, Nombre=Du, Cas=Erg:	zabelas	Isabelle.F-\blanc{F}-\blanc{Erg}
# 			N, Genre=F, Nombre=Du, Cas=Abs:	zabelab	Isabelle.F-\blanc{F}-\blanc{Abs.F.Du}
# 			N, Genre=F, Nombre=Du, Cas=Nu:	zabela	Isabelle.F-\blanc{F}
# 			N, Genre=F, Nombre=Pl, Cas=Erg:	zabelat	Isabelle.F-\blanc{F}-\blanc{Erg.Pl}
# 			N, Genre=F, Nombre=Pl, Cas=Abs:	zabela	Isabelle.F-\blanc{F}
# 			N, Genre=F, Nombre=Pl, Cas=Nu:	zabela	Isabelle.F-\blanc{F}
#
# \newcommand{\IsabelleFFSgErg}{\strutgb{0pt}\grapho{zabelax}}
# \newcommand{\IsabelleFFSgErgP}{\textipa{zabelax}}
# \newcommand{\IsabelleFFSgErgG}{Isabelle.F-\blanc{F}-\blanc{Erg.Sg}}
# \newcommand{\IsabelleFFSgAbs}{\strutgb{0pt}\grapho{zabela}}
# \newcommand{\IsabelleFFSgAbsP}{\textipa{zabela}}
# \newcommand{\IsabelleFFSgAbsG}{Isabelle.F-\blanc{F}}
# \newcommand{\IsabelleFFSgNu}{\strutgb{0pt}\grapho{zabela}}
# \newcommand{\IsabelleFFSgNuP}{\textipa{zabela}}
# \newcommand{\IsabelleFFSgNuG}{Isabelle.F-\blanc{F}}
# \newcommand{\IsabelleFFDuErg}{\strutgb{0pt}\grapho{zabelas}}
# \newcommand{\IsabelleFFDuErgP}{\textipa{zabelas}}
# \newcommand{\IsabelleFFDuErgG}{Isabelle.F-\blanc{F}-\blanc{Erg}}
# \newcommand{\IsabelleFFDuAbs}{\strutgb{0pt}\grapho{zabelab}}
# \newcommand{\IsabelleFFDuAbsP}{\textipa{zabelab}}
# \newcommand{\IsabelleFFDuAbsG}{Isabelle.F-\blanc{F}-\blanc{Abs.F.Du}}
# \newcommand{\IsabelleFFDuNu}{\strutgb{0pt}\grapho{zabela}}
# \newcommand{\IsabelleFFDuNuP}{\textipa{zabela}}
# \newcommand{\IsabelleFFDuNuG}{Isabelle.F-\blanc{F}}
# \newcommand{\IsabelleFFPlErg}{\strutgb{0pt}\grapho{zabelat}}
# \newcommand{\IsabelleFFPlErgP}{\textipa{zabelat}}
# \newcommand{\IsabelleFFPlErgG}{Isabelle.F-\blanc{F}-\blanc{Erg.Pl}}
# \newcommand{\IsabelleFFPlAbs}{\strutgb{0pt}\grapho{zabela}}
# \newcommand{\IsabelleFFPlAbsP}{\textipa{zabela}}
# \newcommand{\IsabelleFFPlAbsG}{Isabelle.F-\blanc{F}}
# \newcommand{\IsabelleFFPlNu}{\strutgb{0pt}\grapho{zabela}}
# \newcommand{\IsabelleFFPlNuP}{\textipa{zabela}}
# \newcommand{\IsabelleFFPlNuG}{Isabelle.F-\blanc{F}}
# rum, F, infirmière.F
# 		rum :
# 			N, Genre=F, Nombre=Sg, Cas=Erg:	rumax	infirmière.F-\blanc{F}-\blanc{Erg.Sg}
# 			N, Genre=F, Nombre=Sg, Cas=Abs:	ruma	infirmière.F-\blanc{F}
# 			N, Genre=F, Nombre=Sg, Cas=Nu:	ruma	infirmière.F-\blanc{F}
# 			N, Genre=F, Nombre=Du, Cas=Erg:	rumas	infirmière.F-\blanc{F}-\blanc{Erg}
# 			N, Genre=F, Nombre=Du, Cas=Abs:	rumab	infirmière.F-\blanc{F}-\blanc{Abs.F.Du}
# 			N, Genre=F, Nombre=Du, Cas=Nu:	ruma	infirmière.F-\blanc{F}
# 			N, Genre=F, Nombre=Pl, Cas=Erg:	rumat	infirmière.F-\blanc{F}-\blanc{Erg.Pl}
# 			N, Genre=F, Nombre=Pl, Cas=Abs:	ruma	infirmière.F-\blanc{F}
# 			N, Genre=F, Nombre=Pl, Cas=Nu:	ruma	infirmière.F-\blanc{F}
#
# \newcommand{\infirmièreFFSgErg}{\strutgb{0pt}\grapho{rumax}}
# \newcommand{\infirmièreFFSgErgP}{\textipa{rumax}}
# \newcommand{\infirmièreFFSgErgG}{infirmière.F-\blanc{F}-\blanc{Erg.Sg}}
# \newcommand{\infirmièreFFSgAbs}{\strutgb{0pt}\grapho{ruma}}
# \newcommand{\infirmièreFFSgAbsP}{\textipa{ruma}}
# \newcommand{\infirmièreFFSgAbsG}{infirmière.F-\blanc{F}}
# \newcommand{\infirmièreFFSgNu}{\strutgb{0pt}\grapho{ruma}}
# \newcommand{\infirmièreFFSgNuP}{\textipa{ruma}}
# \newcommand{\infirmièreFFSgNuG}{infirmière.F-\blanc{F}}
# \newcommand{\infirmièreFFDuErg}{\strutgb{0pt}\grapho{rumas}}
# \newcommand{\infirmièreFFDuErgP}{\textipa{rumas}}
# \newcommand{\infirmièreFFDuErgG}{infirmière.F-\blanc{F}-\blanc{Erg}}
# \newcommand{\infirmièreFFDuAbs}{\strutgb{0pt}\grapho{rumab}}
# \newcommand{\infirmièreFFDuAbsP}{\textipa{rumab}}
# \newcommand{\infirmièreFFDuAbsG}{infirmière.F-\blanc{F}-\blanc{Abs.F.Du}}
# \newcommand{\infirmièreFFDuNu}{\strutgb{0pt}\grapho{ruma}}
# \newcommand{\infirmièreFFDuNuP}{\textipa{ruma}}
# \newcommand{\infirmièreFFDuNuG}{infirmière.F-\blanc{F}}
# \newcommand{\infirmièreFFPlErg}{\strutgb{0pt}\grapho{rumat}}
# \newcommand{\infirmièreFFPlErgP}{\textipa{rumat}}
# \newcommand{\infirmièreFFPlErgG}{infirmière.F-\blanc{F}-\blanc{Erg.Pl}}
# \newcommand{\infirmièreFFPlAbs}{\strutgb{0pt}\grapho{ruma}}
# \newcommand{\infirmièreFFPlAbsP}{\textipa{ruma}}
# \newcommand{\infirmièreFFPlAbsG}{infirmière.F-\blanc{F}}
# \newcommand{\infirmièreFFPlNu}{\strutgb{0pt}\grapho{ruma}}
# \newcommand{\infirmièreFFPlNuP}{\textipa{ruma}}
# \newcommand{\infirmièreFFPlNuG}{infirmière.F-\blanc{F}}
# sot, F, fille.F
# 		sot :
# 			N, Genre=F, Nombre=Sg, Cas=Erg:	sotax	fille.F-\blanc{F}-\blanc{Erg.Sg}
# 			N, Genre=F, Nombre=Sg, Cas=Abs:	sota	fille.F-\blanc{F}
# 			N, Genre=F, Nombre=Sg, Cas=Nu:	sota	fille.F-\blanc{F}
# 			N, Genre=F, Nombre=Du, Cas=Erg:	sotas	fille.F-\blanc{F}-\blanc{Erg}
# 			N, Genre=F, Nombre=Du, Cas=Abs:	sotab	fille.F-\blanc{F}-\blanc{Abs.F.Du}
# 			N, Genre=F, Nombre=Du, Cas=Nu:	sota	fille.F-\blanc{F}
# 			N, Genre=F, Nombre=Pl, Cas=Erg:	sotat	fille.F-\blanc{F}-\blanc{Erg.Pl}
# 			N, Genre=F, Nombre=Pl, Cas=Abs:	sota	fille.F-\blanc{F}
# 			N, Genre=F, Nombre=Pl, Cas=Nu:	sota	fille.F-\blanc{F}
#
# \newcommand{\filleFFSgErg}{\strutgb{0pt}\grapho{sotax}}
# \newcommand{\filleFFSgErgP}{\textipa{sotax}}
# \newcommand{\filleFFSgErgG}{fille.F-\blanc{F}-\blanc{Erg.Sg}}
# \newcommand{\filleFFSgAbs}{\strutgb{0pt}\grapho{sota}}
# \newcommand{\filleFFSgAbsP}{\textipa{sota}}
# \newcommand{\filleFFSgAbsG}{fille.F-\blanc{F}}
# \newcommand{\filleFFSgNu}{\strutgb{0pt}\grapho{sota}}
# \newcommand{\filleFFSgNuP}{\textipa{sota}}
# \newcommand{\filleFFSgNuG}{fille.F-\blanc{F}}
# \newcommand{\filleFFDuErg}{\strutgb{0pt}\grapho{sotas}}
# \newcommand{\filleFFDuErgP}{\textipa{sotas}}
# \newcommand{\filleFFDuErgG}{fille.F-\blanc{F}-\blanc{Erg}}
# \newcommand{\filleFFDuAbs}{\strutgb{0pt}\grapho{sotab}}
# \newcommand{\filleFFDuAbsP}{\textipa{sotab}}
# \newcommand{\filleFFDuAbsG}{fille.F-\blanc{F}-\blanc{Abs.F.Du}}
# \newcommand{\filleFFDuNu}{\strutgb{0pt}\grapho{sota}}
# \newcommand{\filleFFDuNuP}{\textipa{sota}}
# \newcommand{\filleFFDuNuG}{fille.F-\blanc{F}}
# \newcommand{\filleFFPlErg}{\strutgb{0pt}\grapho{sotat}}
# \newcommand{\filleFFPlErgP}{\textipa{sotat}}
# \newcommand{\filleFFPlErgG}{fille.F-\blanc{F}-\blanc{Erg.Pl}}
# \newcommand{\filleFFPlAbs}{\strutgb{0pt}\grapho{sota}}
# \newcommand{\filleFFPlAbsP}{\textipa{sota}}
# \newcommand{\filleFFPlAbsG}{fille.F-\blanc{F}}
# \newcommand{\filleFFPlNu}{\strutgb{0pt}\grapho{sota}}
# \newcommand{\filleFFPlNuP}{\textipa{sota}}
# \newcommand{\filleFFPlNuG}{fille.F-\blanc{F}}
# nes, F, Inès.F
# 		nes :
# 			N, Genre=F, Nombre=Sg, Cas=Erg:	nesax	Inès.F-\blanc{F}-\blanc{Erg.Sg}
# 			N, Genre=F, Nombre=Sg, Cas=Abs:	nesa	Inès.F-\blanc{F}
# 			N, Genre=F, Nombre=Sg, Cas=Nu:	nesa	Inès.F-\blanc{F}
# 			N, Genre=F, Nombre=Du, Cas=Erg:	nesas	Inès.F-\blanc{F}-\blanc{Erg}
# 			N, Genre=F, Nombre=Du, Cas=Abs:	nesab	Inès.F-\blanc{F}-\blanc{Abs.F.Du}
# 			N, Genre=F, Nombre=Du, Cas=Nu:	nesa	Inès.F-\blanc{F}
# 			N, Genre=F, Nombre=Pl, Cas=Erg:	nesat	Inès.F-\blanc{F}-\blanc{Erg.Pl}
# 			N, Genre=F, Nombre=Pl, Cas=Abs:	nesa	Inès.F-\blanc{F}
# 			N, Genre=F, Nombre=Pl, Cas=Nu:	nesa	Inès.F-\blanc{F}
#
# \newcommand{\InèsFFSgErg}{\strutgb{0pt}\grapho{nesax}}
# \newcommand{\InèsFFSgErgP}{\textipa{nesax}}
# \newcommand{\InèsFFSgErgG}{Inès.F-\blanc{F}-\blanc{Erg.Sg}}
# \newcommand{\InèsFFSgAbs}{\strutgb{0pt}\grapho{nesa}}
# \newcommand{\InèsFFSgAbsP}{\textipa{nesa}}
# \newcommand{\InèsFFSgAbsG}{Inès.F-\blanc{F}}
# \newcommand{\InèsFFSgNu}{\strutgb{0pt}\grapho{nesa}}
# \newcommand{\InèsFFSgNuP}{\textipa{nesa}}
# \newcommand{\InèsFFSgNuG}{Inès.F-\blanc{F}}
# \newcommand{\InèsFFDuErg}{\strutgb{0pt}\grapho{nesas}}
# \newcommand{\InèsFFDuErgP}{\textipa{nesas}}
# \newcommand{\InèsFFDuErgG}{Inès.F-\blanc{F}-\blanc{Erg}}
# \newcommand{\InèsFFDuAbs}{\strutgb{0pt}\grapho{nesab}}
# \newcommand{\InèsFFDuAbsP}{\textipa{nesab}}
# \newcommand{\InèsFFDuAbsG}{Inès.F-\blanc{F}-\blanc{Abs.F.Du}}
# \newcommand{\InèsFFDuNu}{\strutgb{0pt}\grapho{nesa}}
# \newcommand{\InèsFFDuNuP}{\textipa{nesa}}
# \newcommand{\InèsFFDuNuG}{Inès.F-\blanc{F}}
# \newcommand{\InèsFFPlErg}{\strutgb{0pt}\grapho{nesat}}
# \newcommand{\InèsFFPlErgP}{\textipa{nesat}}
# \newcommand{\InèsFFPlErgG}{Inès.F-\blanc{F}-\blanc{Erg.Pl}}
# \newcommand{\InèsFFPlAbs}{\strutgb{0pt}\grapho{nesa}}
# \newcommand{\InèsFFPlAbsP}{\textipa{nesa}}
# \newcommand{\InèsFFPlAbsG}{Inès.F-\blanc{F}}
# \newcommand{\InèsFFPlNu}{\strutgb{0pt}\grapho{nesa}}
# \newcommand{\InèsFFPlNuP}{\textipa{nesa}}
# \newcommand{\InèsFFPlNuG}{Inès.F-\blanc{F}}
# DET
# l, IND, IND.IND
# 		l :
# 			DET, Nombre=Sg, Type=IND:	ili	\blanc{Sg}-IND.IND-\blanc{IND}
# 			DET, Nombre=Du, Type=IND:	uli	\blanc{Du}-IND.IND-\blanc{IND}
# 			DET, Nombre=Pl, Type=IND:	eli	\blanc{Pl}-IND.IND-\blanc{IND}
#
# \newcommand{\INDINDSgInd}{\strutgb{0pt}\grapho{ili}}
# \newcommand{\INDINDSgIndP}{\textipa{ili}}
# \newcommand{\INDINDSgIndG}{\blanc{Sg}-IND.IND-\blanc{IND}}
# \newcommand{\INDINDDuInd}{\strutgb{0pt}\grapho{uli}}
# \newcommand{\INDINDDuIndP}{\textipa{uli}}
# \newcommand{\INDINDDuIndG}{\blanc{Du}-IND.IND-\blanc{IND}}
# \newcommand{\INDINDPlInd}{\strutgb{0pt}\grapho{eli}}
# \newcommand{\INDINDPlIndP}{\textipa{eli}}
# \newcommand{\INDINDPlIndG}{\blanc{Pl}-IND.IND-\blanc{IND}}
# b, DEM, DEM.DEM
# 		b :
# 			DET, Nombre=Sg, Type=DEM:	dib	\blanc{DEM}-\blanc{Sg}-DEM.DEM
# 			DET, Nombre=Du, Type=DEM:	dub	\blanc{DEM}-\blanc{Du}-DEM.DEM
# 			DET, Nombre=Pl, Type=DEM:	deb	\blanc{DEM}-\blanc{Pl}-DEM.DEM
#
# \newcommand{\DEMDEMSgDem}{\strutgb{0pt}\grapho{dib}}
# \newcommand{\DEMDEMSgDemP}{\textipa{dib}}
# \newcommand{\DEMDEMSgDemG}{\blanc{DEM}-\blanc{Sg}-DEM.DEM}
# \newcommand{\DEMDEMDuDem}{\strutgb{0pt}\grapho{dub}}
# \newcommand{\DEMDEMDuDemP}{\textipa{dub}}
# \newcommand{\DEMDEMDuDemG}{\blanc{DEM}-\blanc{Du}-DEM.DEM}
# \newcommand{\DEMDEMPlDem}{\strutgb{0pt}\grapho{deb}}
# \newcommand{\DEMDEMPlDemP}{\textipa{deb}}
# \newcommand{\DEMDEMPlDemG}{\blanc{DEM}-\blanc{Pl}-DEM.DEM}
# k, DEF, DEF.DEF
# 		k :
# 			DET, Nombre=Sg, Type=DEF:	aik	\blanc{DEF.Sg}-\blanc{Sg}-DEF.DEF
# 			DET, Nombre=Du, Type=DEF:	uk	\blanc{Du}-DEF.DEF
# 			DET, Nombre=Pl, Type=DEF:	ku	DEF.DEF-\blanc{Pl.DEF}
#
# \newcommand{\DEFDEFSgDef}{\strutgb{0pt}\grapho{aik}}
# \newcommand{\DEFDEFSgDefP}{\textipa{aik}}
# \newcommand{\DEFDEFSgDefG}{\blanc{DEF.Sg}-\blanc{Sg}-DEF.DEF}
# \newcommand{\DEFDEFDuDef}{\strutgb{0pt}\grapho{uk}}
# \newcommand{\DEFDEFDuDefP}{\textipa{uk}}
# \newcommand{\DEFDEFDuDefG}{\blanc{Du}-DEF.DEF}
# \newcommand{\DEFDEFPlDef}{\strutgb{0pt}\grapho{ku}}
# \newcommand{\DEFDEFPlDefP}{\textipa{ku}}
# \newcommand{\DEFDEFPlDefG}{DEF.DEF-\blanc{Pl.DEF}}
# PREP
# dem, PREP, avec
# 		dem :
# 			PREP:	dem	avec
#
# \newcommand{\avec}{\strutgb{0pt}\grapho{dem}}
# \newcommand{\avecP}{\textipa{dem}}
# \newcommand{\avecG}{avec}
# pik, PREP, sur
# 		pik :
# 			PREP:	pik	sur
#
# \newcommand{\sur}{\strutgb{0pt}\grapho{pik}}
# \newcommand{\surP}{\textipa{pik}}
# \newcommand{\surG}{sur}
# sur, PREP, dans
# 		sur :
# 			PREP:	sur	dans
#
# \newcommand{\dans}{\strutgb{0pt}\grapho{sur}}
# \newcommand{\dansP}{\textipa{sur}}
# \newcommand{\dansG}{dans}
# zon, PREP, sous
# 		zon :
# 			PREP:	zon	sous
#
# \newcommand{\sous}{\strutgb{0pt}\grapho{zon}}
# \newcommand{\sousP}{\textipa{zon}}
# \newcommand{\sousG}{sous}
# man, PREP, de
# 		man :
# 			PREP:	man	de
#
# \newcommand{\de}{\strutgb{0pt}\grapho{man}}
# \newcommand{\deP}{\textipa{man}}
# \newcommand{\deG}{de}
# V
# fatig, VI, tomber.VI
# 		fatig :
# 			V, Nombre-Abs=Sg, Type=VI, Genre-Abs=H:	fatagu	tomber.VIx\blanc{VI.H}
# 			V, Nombre-Abs=Sg, Type=VI, Genre-Abs=Nh:	fatign	tomber.VI-\blanc{VI.Nh}
# 			V, Nombre-Abs=Du, Type=VI, Genre-Abs=H:	fatagu	tomber.VIx\blanc{VI.H}
# 			V, Nombre-Abs=Du, Type=VI, Genre-Abs=Nh:	fatign	tomber.VI-\blanc{VI.Nh}
# 			V, Nombre-Abs=Pl, Type=VI, Genre-Abs=H:	fatagu	tomber.VIx\blanc{VI.H}
# 			V, Nombre-Abs=Pl, Type=VI, Genre-Abs=Nh:	fatign	tomber.VI-\blanc{VI.Nh}
#
# \newcommand{\tomberVISgViH}{\strutgb{0pt}\grapho{fatagu}}
# \newcommand{\tomberVISgViHP}{\textipa{fatagu}}
# \newcommand{\tomberVISgViHG}{tomber.VIx\blanc{VI.H}}
# \newcommand{\tomberVISgViNh}{\strutgb{0pt}\grapho{fatign}}
# \newcommand{\tomberVISgViNhP}{\textipa{fatign}}
# \newcommand{\tomberVISgViNhG}{tomber.VI-\blanc{VI.Nh}}
# \newcommand{\tomberVIDuViH}{\strutgb{0pt}\grapho{fatagu}}
# \newcommand{\tomberVIDuViHP}{\textipa{fatagu}}
# \newcommand{\tomberVIDuViHG}{tomber.VIx\blanc{VI.H}}
# \newcommand{\tomberVIDuViNh}{\strutgb{0pt}\grapho{fatign}}
# \newcommand{\tomberVIDuViNhP}{\textipa{fatign}}
# \newcommand{\tomberVIDuViNhG}{tomber.VI-\blanc{VI.Nh}}
# \newcommand{\tomberVIPlViH}{\strutgb{0pt}\grapho{fatagu}}
# \newcommand{\tomberVIPlViHP}{\textipa{fatagu}}
# \newcommand{\tomberVIPlViHG}{tomber.VIx\blanc{VI.H}}
# \newcommand{\tomberVIPlViNh}{\strutgb{0pt}\grapho{fatign}}
# \newcommand{\tomberVIPlViNhP}{\textipa{fatign}}
# \newcommand{\tomberVIPlViNhG}{tomber.VI-\blanc{VI.Nh}}
# topaz, VI, dormir.VI
# 		topaz :
# 			V, Nombre-Abs=Sg, Type=VI, Genre-Abs=H:	tapozo	dormir.VIx\blanc{VI.H}
# 			V, Nombre-Abs=Sg, Type=VI, Genre-Abs=Nh:	topazn	dormir.VI-\blanc{VI.Nh}
# 			V, Nombre-Abs=Du, Type=VI, Genre-Abs=H:	tapozo	dormir.VIx\blanc{VI.H}
# 			V, Nombre-Abs=Du, Type=VI, Genre-Abs=Nh:	topazn	dormir.VI-\blanc{VI.Nh}
# 			V, Nombre-Abs=Pl, Type=VI, Genre-Abs=H:	tapozo	dormir.VIx\blanc{VI.H}
# 			V, Nombre-Abs=Pl, Type=VI, Genre-Abs=Nh:	topazn	dormir.VI-\blanc{VI.Nh}
#
# \newcommand{\dormirVISgViH}{\strutgb{0pt}\grapho{tapozo}}
# \newcommand{\dormirVISgViHP}{\textipa{tapozo}}
# \newcommand{\dormirVISgViHG}{dormir.VIx\blanc{VI.H}}
# \newcommand{\dormirVISgViNh}{\strutgb{0pt}\grapho{topazn}}
# \newcommand{\dormirVISgViNhP}{\textipa{topazn}}
# \newcommand{\dormirVISgViNhG}{dormir.VI-\blanc{VI.Nh}}
# \newcommand{\dormirVIDuViH}{\strutgb{0pt}\grapho{tapozo}}
# \newcommand{\dormirVIDuViHP}{\textipa{tapozo}}
# \newcommand{\dormirVIDuViHG}{dormir.VIx\blanc{VI.H}}
# \newcommand{\dormirVIDuViNh}{\strutgb{0pt}\grapho{topazn}}
# \newcommand{\dormirVIDuViNhP}{\textipa{topazn}}
# \newcommand{\dormirVIDuViNhG}{dormir.VI-\blanc{VI.Nh}}
# \newcommand{\dormirVIPlViH}{\strutgb{0pt}\grapho{tapozo}}
# \newcommand{\dormirVIPlViHP}{\textipa{tapozo}}
# \newcommand{\dormirVIPlViHG}{dormir.VIx\blanc{VI.H}}
# \newcommand{\dormirVIPlViNh}{\strutgb{0pt}\grapho{topazn}}
# \newcommand{\dormirVIPlViNhP}{\textipa{topazn}}
# \newcommand{\dormirVIPlViNhG}{dormir.VI-\blanc{VI.Nh}}
# balad, VI, arriver.VI
# 		balad :
# 			V, Nombre-Abs=Sg, Type=VI, Genre-Abs=H:	baladu	arriver.VIx\blanc{VI.H}
# 			V, Nombre-Abs=Sg, Type=VI, Genre-Abs=Nh:	baladn	arriver.VI-\blanc{VI.Nh}
# 			V, Nombre-Abs=Du, Type=VI, Genre-Abs=H:	baladu	arriver.VIx\blanc{VI.H}
# 			V, Nombre-Abs=Du, Type=VI, Genre-Abs=Nh:	baladn	arriver.VI-\blanc{VI.Nh}
# 			V, Nombre-Abs=Pl, Type=VI, Genre-Abs=H:	baladu	arriver.VIx\blanc{VI.H}
# 			V, Nombre-Abs=Pl, Type=VI, Genre-Abs=Nh:	baladn	arriver.VI-\blanc{VI.Nh}
#
# \newcommand{\arriverVISgViH}{\strutgb{0pt}\grapho{baladu}}
# \newcommand{\arriverVISgViHP}{\textipa{baladu}}
# \newcommand{\arriverVISgViHG}{arriver.VIx\blanc{VI.H}}
# \newcommand{\arriverVISgViNh}{\strutgb{0pt}\grapho{baladn}}
# \newcommand{\arriverVISgViNhP}{\textipa{baladn}}
# \newcommand{\arriverVISgViNhG}{arriver.VI-\blanc{VI.Nh}}
# \newcommand{\arriverVIDuViH}{\strutgb{0pt}\grapho{baladu}}
# \newcommand{\arriverVIDuViHP}{\textipa{baladu}}
# \newcommand{\arriverVIDuViHG}{arriver.VIx\blanc{VI.H}}
# \newcommand{\arriverVIDuViNh}{\strutgb{0pt}\grapho{baladn}}
# \newcommand{\arriverVIDuViNhP}{\textipa{baladn}}
# \newcommand{\arriverVIDuViNhG}{arriver.VI-\blanc{VI.Nh}}
# \newcommand{\arriverVIPlViH}{\strutgb{0pt}\grapho{baladu}}
# \newcommand{\arriverVIPlViHP}{\textipa{baladu}}
# \newcommand{\arriverVIPlViHG}{arriver.VIx\blanc{VI.H}}
# \newcommand{\arriverVIPlViNh}{\strutgb{0pt}\grapho{baladn}}
# \newcommand{\arriverVIPlViNhP}{\textipa{baladn}}
# \newcommand{\arriverVIPlViNhG}{arriver.VI-\blanc{VI.Nh}}
# bogot, VT, manger.VT
# 		bogot :
# 			V, Nombre-Abs=Sg, Type=VT, Genre-Abs=H:	sijabgotur	\blanc{VT.Sg}+manger.VTx\blanc{VT}+\blanc{VT.Sg}
# 			V, Nombre-Abs=Sg, Type=VT, Genre-Abs=Nh:	sijabgotur	\blanc{VT.Sg}+manger.VTx\blanc{VT}+\blanc{VT.Sg}
# 			V, Nombre-Abs=Du, Type=VT, Genre-Abs=H:	jabgotudu	manger.VTx\blanc{VT}-\blanc{VT.Du}
# 			V, Nombre-Abs=Du, Type=VT, Genre-Abs=Nh:	jabgotudu	manger.VTx\blanc{VT}-\blanc{VT.Du}
# 			V, Nombre-Abs=Pl, Type=VT, Genre-Abs=H:	lujabgotu	\blanc{VT.Pl}-manger.VTx\blanc{VT}
# 			V, Nombre-Abs=Pl, Type=VT, Genre-Abs=Nh:	lujabgotu	\blanc{VT.Pl}-manger.VTx\blanc{VT}
#
# \newcommand{\mangerVTSgVtH}{\strutgb{0pt}\grapho{sijabgotur}}
# \newcommand{\mangerVTSgVtHP}{\textipa{sijabgotur}}
# \newcommand{\mangerVTSgVtHG}{\blanc{VT.Sg}+manger.VTx\blanc{VT}+\blanc{VT.Sg}}
# \newcommand{\mangerVTSgVtNh}{\strutgb{0pt}\grapho{sijabgotur}}
# \newcommand{\mangerVTSgVtNhP}{\textipa{sijabgotur}}
# \newcommand{\mangerVTSgVtNhG}{\blanc{VT.Sg}+manger.VTx\blanc{VT}+\blanc{VT.Sg}}
# \newcommand{\mangerVTDuVtH}{\strutgb{0pt}\grapho{jabgotudu}}
# \newcommand{\mangerVTDuVtHP}{\textipa{jabgotudu}}
# \newcommand{\mangerVTDuVtHG}{manger.VTx\blanc{VT}-\blanc{VT.Du}}
# \newcommand{\mangerVTDuVtNh}{\strutgb{0pt}\grapho{jabgotudu}}
# \newcommand{\mangerVTDuVtNhP}{\textipa{jabgotudu}}
# \newcommand{\mangerVTDuVtNhG}{manger.VTx\blanc{VT}-\blanc{VT.Du}}
# \newcommand{\mangerVTPlVtH}{\strutgb{0pt}\grapho{lujabgotu}}
# \newcommand{\mangerVTPlVtHP}{\textipa{lujabgotu}}
# \newcommand{\mangerVTPlVtHG}{\blanc{VT.Pl}-manger.VTx\blanc{VT}}
# \newcommand{\mangerVTPlVtNh}{\strutgb{0pt}\grapho{lujabgotu}}
# \newcommand{\mangerVTPlVtNhP}{\textipa{lujabgotu}}
# \newcommand{\mangerVTPlVtNhG}{\blanc{VT.Pl}-manger.VTx\blanc{VT}}
# milit, VT, boire.VT
# 		milit :
# 			V, Nombre-Abs=Sg, Type=VT, Genre-Abs=H:	sijamlatur	\blanc{VT.Sg}+boire.VTx\blanc{VT}+\blanc{VT.Sg}
# 			V, Nombre-Abs=Sg, Type=VT, Genre-Abs=Nh:	sijamlatur	\blanc{VT.Sg}+boire.VTx\blanc{VT}+\blanc{VT.Sg}
# 			V, Nombre-Abs=Du, Type=VT, Genre-Abs=H:	jamlatudu	boire.VTx\blanc{VT}-\blanc{VT.Du}
# 			V, Nombre-Abs=Du, Type=VT, Genre-Abs=Nh:	jamlatudu	boire.VTx\blanc{VT}-\blanc{VT.Du}
# 			V, Nombre-Abs=Pl, Type=VT, Genre-Abs=H:	lujamlatu	\blanc{VT.Pl}-boire.VTx\blanc{VT}
# 			V, Nombre-Abs=Pl, Type=VT, Genre-Abs=Nh:	lujamlatu	\blanc{VT.Pl}-boire.VTx\blanc{VT}
#
# \newcommand{\boireVTSgVtH}{\strutgb{0pt}\grapho{sijamlatur}}
# \newcommand{\boireVTSgVtHP}{\textipa{sijamlatur}}
# \newcommand{\boireVTSgVtHG}{\blanc{VT.Sg}+boire.VTx\blanc{VT}+\blanc{VT.Sg}}
# \newcommand{\boireVTSgVtNh}{\strutgb{0pt}\grapho{sijamlatur}}
# \newcommand{\boireVTSgVtNhP}{\textipa{sijamlatur}}
# \newcommand{\boireVTSgVtNhG}{\blanc{VT.Sg}+boire.VTx\blanc{VT}+\blanc{VT.Sg}}
# \newcommand{\boireVTDuVtH}{\strutgb{0pt}\grapho{jamlatudu}}
# \newcommand{\boireVTDuVtHP}{\textipa{jamlatudu}}
# \newcommand{\boireVTDuVtHG}{boire.VTx\blanc{VT}-\blanc{VT.Du}}
# \newcommand{\boireVTDuVtNh}{\strutgb{0pt}\grapho{jamlatudu}}
# \newcommand{\boireVTDuVtNhP}{\textipa{jamlatudu}}
# \newcommand{\boireVTDuVtNhG}{boire.VTx\blanc{VT}-\blanc{VT.Du}}
# \newcommand{\boireVTPlVtH}{\strutgb{0pt}\grapho{lujamlatu}}
# \newcommand{\boireVTPlVtHP}{\textipa{lujamlatu}}
# \newcommand{\boireVTPlVtHG}{\blanc{VT.Pl}-boire.VTx\blanc{VT}}
# \newcommand{\boireVTPlVtNh}{\strutgb{0pt}\grapho{lujamlatu}}
# \newcommand{\boireVTPlVtNhP}{\textipa{lujamlatu}}
# \newcommand{\boireVTPlVtNhG}{\blanc{VT.Pl}-boire.VTx\blanc{VT}}
# lamab, VT, acheter.VT
# 		lamab :
# 			V, Nombre-Abs=Sg, Type=VT, Genre-Abs=H:	sijalmubur	\blanc{VT.Sg}+acheter.VTx\blanc{VT}+\blanc{VT.Sg}
# 			V, Nombre-Abs=Sg, Type=VT, Genre-Abs=Nh:	sijalmubur	\blanc{VT.Sg}+acheter.VTx\blanc{VT}+\blanc{VT.Sg}
# 			V, Nombre-Abs=Du, Type=VT, Genre-Abs=H:	jalmubudu	acheter.VTx\blanc{VT}-\blanc{VT.Du}
# 			V, Nombre-Abs=Du, Type=VT, Genre-Abs=Nh:	jalmubudu	acheter.VTx\blanc{VT}-\blanc{VT.Du}
# 			V, Nombre-Abs=Pl, Type=VT, Genre-Abs=H:	lujalmubu	\blanc{VT.Pl}-acheter.VTx\blanc{VT}
# 			V, Nombre-Abs=Pl, Type=VT, Genre-Abs=Nh:	lujalmubu	\blanc{VT.Pl}-acheter.VTx\blanc{VT}
#
# \newcommand{\acheterVTSgVtH}{\strutgb{0pt}\grapho{sijalmubur}}
# \newcommand{\acheterVTSgVtHP}{\textipa{sijalmubur}}
# \newcommand{\acheterVTSgVtHG}{\blanc{VT.Sg}+acheter.VTx\blanc{VT}+\blanc{VT.Sg}}
# \newcommand{\acheterVTSgVtNh}{\strutgb{0pt}\grapho{sijalmubur}}
# \newcommand{\acheterVTSgVtNhP}{\textipa{sijalmubur}}
# \newcommand{\acheterVTSgVtNhG}{\blanc{VT.Sg}+acheter.VTx\blanc{VT}+\blanc{VT.Sg}}
# \newcommand{\acheterVTDuVtH}{\strutgb{0pt}\grapho{jalmubudu}}
# \newcommand{\acheterVTDuVtHP}{\textipa{jalmubudu}}
# \newcommand{\acheterVTDuVtHG}{acheter.VTx\blanc{VT}-\blanc{VT.Du}}
# \newcommand{\acheterVTDuVtNh}{\strutgb{0pt}\grapho{jalmubudu}}
# \newcommand{\acheterVTDuVtNhP}{\textipa{jalmubudu}}
# \newcommand{\acheterVTDuVtNhG}{acheter.VTx\blanc{VT}-\blanc{VT.Du}}
# \newcommand{\acheterVTPlVtH}{\strutgb{0pt}\grapho{lujalmubu}}
# \newcommand{\acheterVTPlVtHP}{\textipa{lujalmubu}}
# \newcommand{\acheterVTPlVtHG}{\blanc{VT.Pl}-acheter.VTx\blanc{VT}}
# \newcommand{\acheterVTPlVtNh}{\strutgb{0pt}\grapho{lujalmubu}}
# \newcommand{\acheterVTPlVtNhP}{\textipa{lujalmubu}}
# \newcommand{\acheterVTPlVtNhG}{\blanc{VT.Pl}-acheter.VTx\blanc{VT}}
# disak, VT, supporter.VT
# 		disak :
# 			V, Nombre-Abs=Sg, Type=VT, Genre-Abs=H:	sijadsakur	\blanc{VT.Sg}+supporter.VTx\blanc{VT}+\blanc{VT.Sg}
# 			V, Nombre-Abs=Sg, Type=VT, Genre-Abs=Nh:	sijadsakur	\blanc{VT.Sg}+supporter.VTx\blanc{VT}+\blanc{VT.Sg}
# 			V, Nombre-Abs=Du, Type=VT, Genre-Abs=H:	jadsakudu	supporter.VTx\blanc{VT}-\blanc{VT.Du}
# 			V, Nombre-Abs=Du, Type=VT, Genre-Abs=Nh:	jadsakudu	supporter.VTx\blanc{VT}-\blanc{VT.Du}
# 			V, Nombre-Abs=Pl, Type=VT, Genre-Abs=H:	lujadsaku	\blanc{VT.Pl}-supporter.VTx\blanc{VT}
# 			V, Nombre-Abs=Pl, Type=VT, Genre-Abs=Nh:	lujadsaku	\blanc{VT.Pl}-supporter.VTx\blanc{VT}
#
# \newcommand{\supporterVTSgVtH}{\strutgb{0pt}\grapho{sijadsakur}}
# \newcommand{\supporterVTSgVtHP}{\textipa{sijadsakur}}
# \newcommand{\supporterVTSgVtHG}{\blanc{VT.Sg}+supporter.VTx\blanc{VT}+\blanc{VT.Sg}}
# \newcommand{\supporterVTSgVtNh}{\strutgb{0pt}\grapho{sijadsakur}}
# \newcommand{\supporterVTSgVtNhP}{\textipa{sijadsakur}}
# \newcommand{\supporterVTSgVtNhG}{\blanc{VT.Sg}+supporter.VTx\blanc{VT}+\blanc{VT.Sg}}
# \newcommand{\supporterVTDuVtH}{\strutgb{0pt}\grapho{jadsakudu}}
# \newcommand{\supporterVTDuVtHP}{\textipa{jadsakudu}}
# \newcommand{\supporterVTDuVtHG}{supporter.VTx\blanc{VT}-\blanc{VT.Du}}
# \newcommand{\supporterVTDuVtNh}{\strutgb{0pt}\grapho{jadsakudu}}
# \newcommand{\supporterVTDuVtNhP}{\textipa{jadsakudu}}
# \newcommand{\supporterVTDuVtNhG}{supporter.VTx\blanc{VT}-\blanc{VT.Du}}
# \newcommand{\supporterVTPlVtH}{\strutgb{0pt}\grapho{lujadsaku}}
# \newcommand{\supporterVTPlVtHP}{\textipa{lujadsaku}}
# \newcommand{\supporterVTPlVtHG}{\blanc{VT.Pl}-supporter.VTx\blanc{VT}}
# \newcommand{\supporterVTPlVtNh}{\strutgb{0pt}\grapho{lujadsaku}}
# \newcommand{\supporterVTPlVtNhP}{\textipa{lujadsaku}}
# \newcommand{\supporterVTPlVtNhG}{\blanc{VT.Pl}-supporter.VTx\blanc{VT}}

# %% [markdown]
# for lexeme in lexemes:
#     lemme=lexeme[2].translate(deaccent)
#     categorie=lexeme[0]
#     lexique[lemme]=categorie
#     for forme in lexeme[2:]:
#         base[forme]=lemme
#         if debug: print "base :", forme, lexeme[2]
#         if categorie in types:
#             categorie_v[forme]=categorie
#             temps_v[forme]=verbe_forme[lexeme.index(forme)]
#             if debug: print forme, lemme, lexeme.index(forme), temps_v[forme]
#     if lexeme[0] in genres:
#         paradigme_nom(lexeme)
#     elif lexeme[0] in types:
#         paradigme_verbe(lexeme)
#     elif lexeme[0].startswith("ADJ"):
#         paradigme_adj(lexeme)
#     elif lexeme[0] in ["DEF","IND","DEM"]:
#         paradigme_det(lexeme)
#     elif lexeme[0]=="PREP":
#         paradigme_prep(lexeme)
#     else: print "erreur de catégorie : ",lexeme[0]

# %%
if print_commands:
    comment=""
else:
    comment="%"	
for nom in noms:
    print comment+nom
print
print
print
for adjectif in adjectifs:
    print comment+adjectif
print
print
print
for verbe in verbes:
    print comment+verbe
print
print
print
for determinant in determinants:
    print comment+determinant
print
print
print
for preposition in prepositions:
    print comment+preposition
print
print
# Out:
# \newcommand{\KatishaADuDat}{\strutgb{0pt}\grapho{Ovp3s}}
# \newcommand{\KatishaADuDatP}{\textipa{likupatisØ}}
# \newcommand{\KatishaADuDatG}{\blanc{DAT-}Katisha\blanc{.AxDU}}
# \newcommand{\KatishaADuObl}{\strutgb{0pt}\grapho{hvp3s}}
# \newcommand{\KatishaADuOblP}{\textipa{kokupatisØ}}
# \newcommand{\KatishaADuOblG}{\blanc{OBL-}Katisha\blanc{.AxDU}}
# \newcommand{\KatishaADuErg}{\strutgb{0pt}\grapho{Rvp3s}}
# \newcommand{\KatishaADuErgP}{\textipa{rekupatisØ}}
# \newcommand{\KatishaADuErgG}{\blanc{ERG-}Katisha\blanc{.AxDU}}
# \newcommand{\KatishaADuAbs}{\strutgb{0pt}\grapho{Hvp3s}}
# \newcommand{\KatishaADuAbsP}{\textipa{bokupatisØ}}
# \newcommand{\KatishaADuAbsG}{\blanc{ABS-}Katisha\blanc{.AxDU}}
# \newcommand{\KatishaASgDat}{\strutgb{0pt}\grapho{Ok5tS}}
# \newcommand{\KatishaASgDatP}{\textipa{likatutaSe}}
# \newcommand{\KatishaASgDatG}{\blanc{DAT-}Katisha\blanc{.AxSG}}
# \newcommand{\KatishaASgObl}{\strutgb{0pt}\grapho{hk5tS}}
# \newcommand{\KatishaASgOblP}{\textipa{kokatutaSe}}
# \newcommand{\KatishaASgOblG}{\blanc{OBL-}Katisha\blanc{.AxSG}}
# \newcommand{\KatishaASgErg}{\strutgb{0pt}\grapho{Rk5tS}}
# \newcommand{\KatishaASgErgP}{\textipa{rekatutaSe}}
# \newcommand{\KatishaASgErgG}{\blanc{ERG-}Katisha\blanc{.AxSG}}
# \newcommand{\KatishaASgAbs}{\strutgb{0pt}\grapho{Hk5tS}}
# \newcommand{\KatishaASgAbsP}{\textipa{bokatutaSe}}
# \newcommand{\KatishaASgAbsG}{\blanc{ABS-}Katisha\blanc{.AxSG}}
# \newcommand{\KatishaAPlDat}{\strutgb{0pt}\grapho{O55quY}}
# \newcommand{\KatishaAPlDatP}{\textipa{litutufuSi}}
# \newcommand{\KatishaAPlDatG}{\blanc{DAT-}Katisha\blanc{.AxPL}}
# \newcommand{\KatishaAPlObl}{\strutgb{0pt}\grapho{h55quY}}
# \newcommand{\KatishaAPlOblP}{\textipa{kotutufuSi}}
# \newcommand{\KatishaAPlOblG}{\blanc{OBL-}Katisha\blanc{.AxPL}}
# \newcommand{\KatishaAPlErg}{\strutgb{0pt}\grapho{R55quY}}
# \newcommand{\KatishaAPlErgP}{\textipa{retutufuSi}}
# \newcommand{\KatishaAPlErgG}{\blanc{ERG-}Katisha\blanc{.AxPL}}
# \newcommand{\KatishaAPlAbs}{\strutgb{0pt}\grapho{H55quY}}
# \newcommand{\KatishaAPlAbsP}{\textipa{botutufuSi}}
# \newcommand{\KatishaAPlAbsG}{\blanc{ABS-}Katisha\blanc{.AxPL}}
# \newcommand{\viandeADuDat}{\strutgb{0pt}\grapho{OIpfn}}
# \newcommand{\viandeADuDatP}{\textipa{lipupadinØ}}
# \newcommand{\viandeADuDatG}{\blanc{DAT-}viande\blanc{.AxDU}}
# \newcommand{\viandeADuObl}{\strutgb{0pt}\grapho{hIpfn}}
# \newcommand{\viandeADuOblP}{\textipa{kopupadinØ}}
# \newcommand{\viandeADuOblG}{\blanc{OBL-}viande\blanc{.AxDU}}
# \newcommand{\viandeADuErg}{\strutgb{0pt}\grapho{RIpfn}}
# \newcommand{\viandeADuErgP}{\textipa{repupadinØ}}
# \newcommand{\viandeADuErgG}{\blanc{ERG-}viande\blanc{.AxDU}}
# \newcommand{\viandeADuAbs}{\strutgb{0pt}\grapho{HIpfn}}
# \newcommand{\viandeADuAbsP}{\textipa{bopupadinØ}}
# \newcommand{\viandeADuAbsG}{\blanc{ABS-}viande\blanc{.AxDU}}
# \newcommand{\viandeASgDat}{\strutgb{0pt}\grapho{OpIdN}}
# \newcommand{\viandeASgDatP}{\textipa{lipapudaNe}}
# \newcommand{\viandeASgDatG}{\blanc{DAT-}viande\blanc{.AxSG}}
# \newcommand{\viandeASgObl}{\strutgb{0pt}\grapho{hpIdN}}
# \newcommand{\viandeASgOblP}{\textipa{kopapudaNe}}
# \newcommand{\viandeASgOblG}{\blanc{OBL-}viande\blanc{.AxSG}}
# \newcommand{\viandeASgErg}{\strutgb{0pt}\grapho{RpIdN}}
# \newcommand{\viandeASgErgP}{\textipa{repapudaNe}}
# \newcommand{\viandeASgErgG}{\blanc{ERG-}viande\blanc{.AxSG}}
# \newcommand{\viandeASgAbs}{\strutgb{0pt}\grapho{HpIdN}}
# \newcommand{\viandeASgAbsP}{\textipa{bopapudaNe}}
# \newcommand{\viandeASgAbsG}{\blanc{ABS-}viande\blanc{.AxSG}}
# \newcommand{\viandeAPlDat}{\strutgb{0pt}\grapho{OIxBC}}
# \newcommand{\viandeAPlDatP}{\textipa{lipudumuNi}}
# \newcommand{\viandeAPlDatG}{\blanc{DAT-}viande\blanc{.AxPL}}
# \newcommand{\viandeAPlObl}{\strutgb{0pt}\grapho{hIxBC}}
# \newcommand{\viandeAPlOblP}{\textipa{kopudumuNi}}
# \newcommand{\viandeAPlOblG}{\blanc{OBL-}viande\blanc{.AxPL}}
# \newcommand{\viandeAPlErg}{\strutgb{0pt}\grapho{RIxBC}}
# \newcommand{\viandeAPlErgP}{\textipa{repudumuNi}}
# \newcommand{\viandeAPlErgG}{\blanc{ERG-}viande\blanc{.AxPL}}
# \newcommand{\viandeAPlAbs}{\strutgb{0pt}\grapho{HIxBC}}
# \newcommand{\viandeAPlAbsP}{\textipa{bopudumuNi}}
# \newcommand{\viandeAPlAbsG}{\blanc{ABS-}viande\blanc{.AxPL}}
# \newcommand{\fruitADuDat}{\strutgb{0pt}\grapho{O48Yt}}
# \newcommand{\fruitADuDatP}{\textipa{litofoSitØ}}
# \newcommand{\fruitADuDatG}{\blanc{DAT-}fruit\blanc{.AxDU}}
# \newcommand{\fruitADuObl}{\strutgb{0pt}\grapho{h48Yt}}
# \newcommand{\fruitADuOblP}{\textipa{kotofoSitØ}}
# \newcommand{\fruitADuOblG}{\blanc{OBL-}fruit\blanc{.AxDU}}
# \newcommand{\fruitADuErg}{\strutgb{0pt}\grapho{R48Yt}}
# \newcommand{\fruitADuErgP}{\textipa{retofoSitØ}}
# \newcommand{\fruitADuErgG}{\blanc{ERG-}fruit\blanc{.AxDU}}
# \newcommand{\fruitADuAbs}{\strutgb{0pt}\grapho{H48Yt}}
# \newcommand{\fruitADuAbsP}{\textipa{botofoSitØ}}
# \newcommand{\fruitADuAbsG}{\blanc{ABS-}fruit\blanc{.AxDU}}
# \newcommand{\fruitASgDat}{\strutgb{0pt}\grapho{OtH1K}}
# \newcommand{\fruitASgDatP}{\textipa{litapoSoke}}
# \newcommand{\fruitASgDatG}{\blanc{DAT-}fruit\blanc{.AxSG}}
# \newcommand{\fruitASgObl}{\strutgb{0pt}\grapho{htH1K}}
# \newcommand{\fruitASgOblP}{\textipa{kotapoSoke}}
# \newcommand{\fruitASgOblG}{\blanc{OBL-}fruit\blanc{.AxSG}}
# \newcommand{\fruitASgErg}{\strutgb{0pt}\grapho{RtH1K}}
# \newcommand{\fruitASgErgP}{\textipa{retapoSoke}}
# \newcommand{\fruitASgErgG}{\blanc{ERG-}fruit\blanc{.AxSG}}
# \newcommand{\fruitASgAbs}{\strutgb{0pt}\grapho{HtH1K}}
# \newcommand{\fruitASgAbsP}{\textipa{botapoSoke}}
# \newcommand{\fruitASgAbsG}{\blanc{ABS-}fruit\blanc{.AxSG}}
# \newcommand{\fruitAPlDat}{\strutgb{0pt}\grapho{OH1Ic}}
# \newcommand{\fruitAPlDatP}{\textipa{lipoSopuki}}
# \newcommand{\fruitAPlDatG}{\blanc{DAT-}fruit\blanc{.AxPL}}
# \newcommand{\fruitAPlObl}{\strutgb{0pt}\grapho{hH1Ic}}
# \newcommand{\fruitAPlOblP}{\textipa{kopoSopuki}}
# \newcommand{\fruitAPlOblG}{\blanc{OBL-}fruit\blanc{.AxPL}}
# \newcommand{\fruitAPlErg}{\strutgb{0pt}\grapho{RH1Ic}}
# \newcommand{\fruitAPlErgP}{\textipa{repoSopuki}}
# \newcommand{\fruitAPlErgG}{\blanc{ERG-}fruit\blanc{.AxPL}}
# \newcommand{\fruitAPlAbs}{\strutgb{0pt}\grapho{HH1Ic}}
# \newcommand{\fruitAPlAbsP}{\textipa{bopoSopuki}}
# \newcommand{\fruitAPlAbsG}{\blanc{ABS-}fruit\blanc{.AxPL}}
# \newcommand{\infirmiereADuDat}{\strutgb{0pt}\grapho{OAHft}}
# \newcommand{\infirmiereADuDatP}{\textipa{limopoditØ}}
# \newcommand{\infirmiereADuDatG}{\blanc{DAT-}infirmière\blanc{.AxDU}}
# \newcommand{\infirmiereADuObl}{\strutgb{0pt}\grapho{hAHft}}
# \newcommand{\infirmiereADuOblP}{\textipa{komopoditØ}}
# \newcommand{\infirmiereADuOblG}{\blanc{OBL-}infirmière\blanc{.AxDU}}
# \newcommand{\infirmiereADuErg}{\strutgb{0pt}\grapho{RAHft}}
# \newcommand{\infirmiereADuErgP}{\textipa{remopoditØ}}
# \newcommand{\infirmiereADuErgG}{\blanc{ERG-}infirmière\blanc{.AxDU}}
# \newcommand{\infirmiereADuAbs}{\strutgb{0pt}\grapho{HAHft}}
# \newcommand{\infirmiereADuAbsP}{\textipa{bomopoditØ}}
# \newcommand{\infirmiereADuAbsG}{\blanc{ABS-}infirmière\blanc{.AxDU}}
# \newcommand{\infirmiereASgDat}{\strutgb{0pt}\grapho{OmAgK}}
# \newcommand{\infirmiereASgDatP}{\textipa{limamodoke}}
# \newcommand{\infirmiereASgDatG}{\blanc{DAT-}infirmière\blanc{.AxSG}}
# \newcommand{\infirmiereASgObl}{\strutgb{0pt}\grapho{hmAgK}}
# \newcommand{\infirmiereASgOblP}{\textipa{komamodoke}}
# \newcommand{\infirmiereASgOblG}{\blanc{OBL-}infirmière\blanc{.AxSG}}
# \newcommand{\infirmiereASgErg}{\strutgb{0pt}\grapho{RmAgK}}
# \newcommand{\infirmiereASgErgP}{\textipa{remamodoke}}
# \newcommand{\infirmiereASgErgG}{\blanc{ERG-}infirmière\blanc{.AxSG}}
# \newcommand{\infirmiereASgAbs}{\strutgb{0pt}\grapho{HmAgK}}
# \newcommand{\infirmiereASgAbsP}{\textipa{bomamodoke}}
# \newcommand{\infirmiereASgAbsG}{\blanc{ABS-}infirmière\blanc{.AxSG}}
# \newcommand{\infirmiereAPlDat}{\strutgb{0pt}\grapho{OAgIc}}
# \newcommand{\infirmiereAPlDatP}{\textipa{limodopuki}}
# \newcommand{\infirmiereAPlDatG}{\blanc{DAT-}infirmière\blanc{.AxPL}}
# \newcommand{\infirmiereAPlObl}{\strutgb{0pt}\grapho{hAgIc}}
# \newcommand{\infirmiereAPlOblP}{\textipa{komodopuki}}
# \newcommand{\infirmiereAPlOblG}{\blanc{OBL-}infirmière\blanc{.AxPL}}
# \newcommand{\infirmiereAPlErg}{\strutgb{0pt}\grapho{RAgIc}}
# \newcommand{\infirmiereAPlErgP}{\textipa{remodopuki}}
# \newcommand{\infirmiereAPlErgG}{\blanc{ERG-}infirmière\blanc{.AxPL}}
# \newcommand{\infirmiereAPlAbs}{\strutgb{0pt}\grapho{HAgIc}}
# \newcommand{\infirmiereAPlAbsP}{\textipa{bomodopuki}}
# \newcommand{\infirmiereAPlAbsG}{\blanc{ABS-}infirmière\blanc{.AxPL}}
# \newcommand{\balaiADuDat}{\strutgb{0pt}\grapho{Ovp3t}}
# \newcommand{\balaiADuDatP}{\textipa{ligupatitØ}}
# \newcommand{\balaiADuDatG}{\blanc{DAT-}balai\blanc{.AxDU}}
# \newcommand{\balaiADuObl}{\strutgb{0pt}\grapho{hvp3t}}
# \newcommand{\balaiADuOblP}{\textipa{kogupatitØ}}
# \newcommand{\balaiADuOblG}{\blanc{OBL-}balai\blanc{.AxDU}}
# \newcommand{\balaiADuErg}{\strutgb{0pt}\grapho{Rvp3t}}
# \newcommand{\balaiADuErgP}{\textipa{regupatitØ}}
# \newcommand{\balaiADuErgG}{\blanc{ERG-}balai\blanc{.AxDU}}
# \newcommand{\balaiADuAbs}{\strutgb{0pt}\grapho{Hvp3t}}
# \newcommand{\balaiADuAbsP}{\textipa{bogupatitØ}}
# \newcommand{\balaiADuAbsG}{\blanc{ABS-}balai\blanc{.AxDU}}
# \newcommand{\balaiASgDat}{\strutgb{0pt}\grapho{OkxtK}}
# \newcommand{\balaiASgDatP}{\textipa{ligadutake}}
# \newcommand{\balaiASgDatG}{\blanc{DAT-}balai\blanc{.AxSG}}
# \newcommand{\balaiASgObl}{\strutgb{0pt}\grapho{hkxtK}}
# \newcommand{\balaiASgOblP}{\textipa{kogadutake}}
# \newcommand{\balaiASgOblG}{\blanc{OBL-}balai\blanc{.AxSG}}
# \newcommand{\balaiASgErg}{\strutgb{0pt}\grapho{RkxtK}}
# \newcommand{\balaiASgErgP}{\textipa{regadutake}}
# \newcommand{\balaiASgErgG}{\blanc{ERG-}balai\blanc{.AxSG}}
# \newcommand{\balaiASgAbs}{\strutgb{0pt}\grapho{HkxtK}}
# \newcommand{\balaiASgAbsP}{\textipa{bogadutake}}
# \newcommand{\balaiASgAbsG}{\blanc{ABS-}balai\blanc{.AxSG}}
# \newcommand{\balaiAPlDat}{\strutgb{0pt}\grapho{Ox5Ic}}
# \newcommand{\balaiAPlDatP}{\textipa{lidutupuki}}
# \newcommand{\balaiAPlDatG}{\blanc{DAT-}balai\blanc{.AxPL}}
# \newcommand{\balaiAPlObl}{\strutgb{0pt}\grapho{hx5Ic}}
# \newcommand{\balaiAPlOblP}{\textipa{kodutupuki}}
# \newcommand{\balaiAPlOblG}{\blanc{OBL-}balai\blanc{.AxPL}}
# \newcommand{\balaiAPlErg}{\strutgb{0pt}\grapho{Rx5Ic}}
# \newcommand{\balaiAPlErgP}{\textipa{redutupuki}}
# \newcommand{\balaiAPlErgG}{\blanc{ERG-}balai\blanc{.AxPL}}
# \newcommand{\balaiAPlAbs}{\strutgb{0pt}\grapho{Hx5Ic}}
# \newcommand{\balaiAPlAbsP}{\textipa{bodutupuki}}
# \newcommand{\balaiAPlAbsG}{\blanc{ABS-}balai\blanc{.AxPL}}
# \newcommand{\plaineADuDat}{\strutgb{0pt}\grapho{OHPGq}}
# \newcommand{\plaineADuDatP}{\textipa{lipopebivØ}}
# \newcommand{\plaineADuDatG}{\blanc{DAT-}plaine\blanc{.AxDU}}
# \newcommand{\plaineADuObl}{\strutgb{0pt}\grapho{hHPGq}}
# \newcommand{\plaineADuOblP}{\textipa{kopopebivØ}}
# \newcommand{\plaineADuOblG}{\blanc{OBL-}plaine\blanc{.AxDU}}
# \newcommand{\plaineADuErg}{\strutgb{0pt}\grapho{RHPGq}}
# \newcommand{\plaineADuErgP}{\textipa{repopebivØ}}
# \newcommand{\plaineADuErgG}{\blanc{ERG-}plaine\blanc{.AxDU}}
# \newcommand{\plaineADuAbs}{\strutgb{0pt}\grapho{HHPGq}}
# \newcommand{\plaineADuAbsP}{\textipa{bopopebivØ}}
# \newcommand{\plaineADuAbsG}{\blanc{ABS-}plaine\blanc{.AxDU}}
# \newcommand{\plaineASgDat}{\strutgb{0pt}\grapho{OpHPZ}}
# \newcommand{\plaineASgDatP}{\textipa{lipapobeze}}
# \newcommand{\plaineASgDatG}{\blanc{DAT-}plaine\blanc{.AxSG}}
# \newcommand{\plaineASgObl}{\strutgb{0pt}\grapho{hpHPZ}}
# \newcommand{\plaineASgOblP}{\textipa{kopapobeze}}
# \newcommand{\plaineASgOblG}{\blanc{OBL-}plaine\blanc{.AxSG}}
# \newcommand{\plaineASgErg}{\strutgb{0pt}\grapho{RpHPZ}}
# \newcommand{\plaineASgErgP}{\textipa{repapobeze}}
# \newcommand{\plaineASgErgG}{\blanc{ERG-}plaine\blanc{.AxSG}}
# \newcommand{\plaineASgAbs}{\strutgb{0pt}\grapho{HpHPZ}}
# \newcommand{\plaineASgAbsP}{\textipa{bopapobeze}}
# \newcommand{\plaineASgAbsG}{\blanc{ABS-}plaine\blanc{.AxSG}}
# \newcommand{\plaineAPlDat}{\strutgb{0pt}\grapho{OHHquzi}}
# \newcommand{\plaineAPlDatP}{\textipa{lipobofuzi}}
# \newcommand{\plaineAPlDatG}{\blanc{DAT-}plaine\blanc{.AxPL}}
# \newcommand{\plaineAPlObl}{\strutgb{0pt}\grapho{hHHquzi}}
# \newcommand{\plaineAPlOblP}{\textipa{kopobofuzi}}
# \newcommand{\plaineAPlOblG}{\blanc{OBL-}plaine\blanc{.AxPL}}
# \newcommand{\plaineAPlErg}{\strutgb{0pt}\grapho{RHHquzi}}
# \newcommand{\plaineAPlErgP}{\textipa{repobofuzi}}
# \newcommand{\plaineAPlErgG}{\blanc{ERG-}plaine\blanc{.AxPL}}
# \newcommand{\plaineAPlAbs}{\strutgb{0pt}\grapho{HHHquzi}}
# \newcommand{\plaineAPlAbsP}{\textipa{bopobofuzi}}
# \newcommand{\plaineAPlAbsG}{\blanc{ABS-}plaine\blanc{.AxPL}}
# \newcommand{\NicoleBDuDat}{\strutgb{0pt}\grapho{OnGcO}}
# \newcommand{\NicoleBDuDatP}{\textipa{linapikiri}}
# \newcommand{\NicoleBDuDatG}{\blanc{DAT-}Nicole\blanc{.BxDU}}
# \newcommand{\NicoleBDuObl}{\strutgb{0pt}\grapho{hnGcO}}
# \newcommand{\NicoleBDuOblP}{\textipa{konapikiri}}
# \newcommand{\NicoleBDuOblG}{\blanc{OBL-}Nicole\blanc{.BxDU}}
# \newcommand{\NicoleBDuErg}{\strutgb{0pt}\grapho{RnGcO}}
# \newcommand{\NicoleBDuErgP}{\textipa{renapikiri}}
# \newcommand{\NicoleBDuErgG}{\blanc{ERG-}Nicole\blanc{.BxDU}}
# \newcommand{\NicoleBDuAbs}{\strutgb{0pt}\grapho{HnGcO}}
# \newcommand{\NicoleBDuAbsP}{\textipa{bonapikiri}}
# \newcommand{\NicoleBDuAbsG}{\blanc{ABS-}Nicole\blanc{.BxDU}}
# \newcommand{\NicoleBSgDat}{\strutgb{0pt}\grapho{OnmcR}}
# \newcommand{\NicoleBSgDatP}{\textipa{linamakile}}
# \newcommand{\NicoleBSgDatG}{\blanc{DAT-}Nicole\blanc{.BxSG}}
# \newcommand{\NicoleBSgObl}{\strutgb{0pt}\grapho{hnmcR}}
# \newcommand{\NicoleBSgOblP}{\textipa{konamakile}}
# \newcommand{\NicoleBSgOblG}{\blanc{OBL-}Nicole\blanc{.BxSG}}
# \newcommand{\NicoleBSgErg}{\strutgb{0pt}\grapho{RnmcR}}
# \newcommand{\NicoleBSgErgP}{\textipa{renamakile}}
# \newcommand{\NicoleBSgErgG}{\blanc{ERG-}Nicole\blanc{.BxSG}}
# \newcommand{\NicoleBSgAbs}{\strutgb{0pt}\grapho{HnmcR}}
# \newcommand{\NicoleBSgAbsP}{\textipa{bonamakile}}
# \newcommand{\NicoleBSgAbsG}{\blanc{ABS-}Nicole\blanc{.BxSG}}
# \newcommand{\NicoleBPlDat}{\strutgb{0pt}\grapho{OBkwur}}
# \newcommand{\NicoleBPlDatP}{\textipa{limukawula}}
# \newcommand{\NicoleBPlDatG}{\blanc{DAT-}Nicole\blanc{.BxPL}}
# \newcommand{\NicoleBPlObl}{\strutgb{0pt}\grapho{hBkwur}}
# \newcommand{\NicoleBPlOblP}{\textipa{komukawula}}
# \newcommand{\NicoleBPlOblG}{\blanc{OBL-}Nicole\blanc{.BxPL}}
# \newcommand{\NicoleBPlErg}{\strutgb{0pt}\grapho{RBkwur}}
# \newcommand{\NicoleBPlErgP}{\textipa{remukawula}}
# \newcommand{\NicoleBPlErgG}{\blanc{ERG-}Nicole\blanc{.BxPL}}
# \newcommand{\NicoleBPlAbs}{\strutgb{0pt}\grapho{HBkwur}}
# \newcommand{\NicoleBPlAbsP}{\textipa{bomukawula}}
# \newcommand{\NicoleBPlAbsG}{\blanc{ABS-}Nicole\blanc{.BxPL}}
# \newcommand{\autrucheBDuDat}{\strutgb{0pt}\grapho{OmyCG}}
# \newcommand{\autrucheBDuDatP}{\textipa{limaminipi}}
# \newcommand{\autrucheBDuDatG}{\blanc{DAT-}autruche\blanc{.BxDU}}
# \newcommand{\autrucheBDuObl}{\strutgb{0pt}\grapho{hmyCG}}
# \newcommand{\autrucheBDuOblP}{\textipa{komaminipi}}
# \newcommand{\autrucheBDuOblG}{\blanc{OBL-}autruche\blanc{.BxDU}}
# \newcommand{\autrucheBDuErg}{\strutgb{0pt}\grapho{RmyCG}}
# \newcommand{\autrucheBDuErgP}{\textipa{remaminipi}}
# \newcommand{\autrucheBDuErgG}{\blanc{ERG-}autruche\blanc{.BxDU}}
# \newcommand{\autrucheBDuAbs}{\strutgb{0pt}\grapho{HmyCG}}
# \newcommand{\autrucheBDuAbsP}{\textipa{bomaminipi}}
# \newcommand{\autrucheBDuAbsG}{\blanc{ABS-}autruche\blanc{.BxDU}}
# \newcommand{\autrucheBSgDat}{\strutgb{0pt}\grapho{OmmCT}}
# \newcommand{\autrucheBSgDatP}{\textipa{limamanite}}
# \newcommand{\autrucheBSgDatG}{\blanc{DAT-}autruche\blanc{.BxSG}}
# \newcommand{\autrucheBSgObl}{\strutgb{0pt}\grapho{hmmCT}}
# \newcommand{\autrucheBSgOblP}{\textipa{komamanite}}
# \newcommand{\autrucheBSgOblG}{\blanc{OBL-}autruche\blanc{.BxSG}}
# \newcommand{\autrucheBSgErg}{\strutgb{0pt}\grapho{RmmCT}}
# \newcommand{\autrucheBSgErgP}{\textipa{remamanite}}
# \newcommand{\autrucheBSgErgG}{\blanc{ERG-}autruche\blanc{.BxSG}}
# \newcommand{\autrucheBSgAbs}{\strutgb{0pt}\grapho{HmmCT}}
# \newcommand{\autrucheBSgAbsP}{\textipa{bomamanite}}
# \newcommand{\autrucheBSgAbsG}{\blanc{ABS-}autruche\blanc{.BxSG}}
# \newcommand{\autrucheBPlDat}{\strutgb{0pt}\grapho{OBnIt}}
# \newcommand{\autrucheBPlDatP}{\textipa{limunaputa}}
# \newcommand{\autrucheBPlDatG}{\blanc{DAT-}autruche\blanc{.BxPL}}
# \newcommand{\autrucheBPlObl}{\strutgb{0pt}\grapho{hBnIt}}
# \newcommand{\autrucheBPlOblP}{\textipa{komunaputa}}
# \newcommand{\autrucheBPlOblG}{\blanc{OBL-}autruche\blanc{.BxPL}}
# \newcommand{\autrucheBPlErg}{\strutgb{0pt}\grapho{RBnIt}}
# \newcommand{\autrucheBPlErgP}{\textipa{remunaputa}}
# \newcommand{\autrucheBPlErgG}{\blanc{ERG-}autruche\blanc{.BxPL}}
# \newcommand{\autrucheBPlAbs}{\strutgb{0pt}\grapho{HBnIt}}
# \newcommand{\autrucheBPlAbsP}{\textipa{bomunaputa}}
# \newcommand{\autrucheBPlAbsG}{\blanc{ABS-}autruche\blanc{.BxPL}}
# \newcommand{\sourisBDuDat}{\strutgb{0pt}\grapho{O1MCy}}
# \newcommand{\sourisBDuDatP}{\textipa{liSomeNimi}}
# \newcommand{\sourisBDuDatG}{\blanc{DAT-}souris\blanc{.BxDU}}
# \newcommand{\sourisBDuObl}{\strutgb{0pt}\grapho{h1MCy}}
# \newcommand{\sourisBDuOblP}{\textipa{koSomeNimi}}
# \newcommand{\sourisBDuOblG}{\blanc{OBL-}souris\blanc{.BxDU}}
# \newcommand{\sourisBDuErg}{\strutgb{0pt}\grapho{R1MCy}}
# \newcommand{\sourisBDuErgP}{\textipa{reSomeNimi}}
# \newcommand{\sourisBDuErgG}{\blanc{ERG-}souris\blanc{.BxDU}}
# \newcommand{\sourisBDuAbs}{\strutgb{0pt}\grapho{H1MCy}}
# \newcommand{\sourisBDuAbsP}{\textipa{boSomeNimi}}
# \newcommand{\sourisBDuAbsG}{\blanc{ABS-}souris\blanc{.BxDU}}
# \newcommand{\sourisBSgDat}{\strutgb{0pt}\grapho{Os1NN}}
# \newcommand{\sourisBSgDatP}{\textipa{liSasoNene}}
# \newcommand{\sourisBSgDatG}{\blanc{DAT-}souris\blanc{.BxSG}}
# \newcommand{\sourisBSgObl}{\strutgb{0pt}\grapho{hs1NN}}
# \newcommand{\sourisBSgOblP}{\textipa{koSasoNene}}
# \newcommand{\sourisBSgOblG}{\blanc{OBL-}souris\blanc{.BxSG}}
# \newcommand{\sourisBSgErg}{\strutgb{0pt}\grapho{Rs1NN}}
# \newcommand{\sourisBSgErgP}{\textipa{reSasoNene}}
# \newcommand{\sourisBSgErgG}{\blanc{ERG-}souris\blanc{.BxSG}}
# \newcommand{\sourisBSgAbs}{\strutgb{0pt}\grapho{Hs1NN}}
# \newcommand{\sourisBSgAbsP}{\textipa{boSasoNene}}
# \newcommand{\sourisBSgAbsG}{\blanc{ABS-}souris\blanc{.BxSG}}
# \newcommand{\sourisBPlDat}{\strutgb{0pt}\grapho{O1noBn}}
# \newcommand{\sourisBPlDatP}{\textipa{lisoNomuna}}
# \newcommand{\sourisBPlDatG}{\blanc{DAT-}souris\blanc{.BxPL}}
# \newcommand{\sourisBPlObl}{\strutgb{0pt}\grapho{h1noBn}}
# \newcommand{\sourisBPlOblP}{\textipa{kosoNomuna}}
# \newcommand{\sourisBPlOblG}{\blanc{OBL-}souris\blanc{.BxPL}}
# \newcommand{\sourisBPlErg}{\strutgb{0pt}\grapho{R1noBn}}
# \newcommand{\sourisBPlErgP}{\textipa{resoNomuna}}
# \newcommand{\sourisBPlErgG}{\blanc{ERG-}souris\blanc{.BxPL}}
# \newcommand{\sourisBPlAbs}{\strutgb{0pt}\grapho{H1noBn}}
# \newcommand{\sourisBPlAbsP}{\textipa{bosoNomuna}}
# \newcommand{\sourisBPlAbsG}{\blanc{ABS-}souris\blanc{.BxPL}}
# \newcommand{\coussinBDuDat}{\strutgb{0pt}\grapho{O2pGy}}
# \newcommand{\coussinBDuDatP}{\textipa{lisupapimi}}
# \newcommand{\coussinBDuDatG}{\blanc{DAT-}coussin\blanc{.BxDU}}
# \newcommand{\coussinBDuObl}{\strutgb{0pt}\grapho{h2pGy}}
# \newcommand{\coussinBDuOblP}{\textipa{kosupapimi}}
# \newcommand{\coussinBDuOblG}{\blanc{OBL-}coussin\blanc{.BxDU}}
# \newcommand{\coussinBDuErg}{\strutgb{0pt}\grapho{R2pGy}}
# \newcommand{\coussinBDuErgP}{\textipa{resupapimi}}
# \newcommand{\coussinBDuErgG}{\blanc{ERG-}coussin\blanc{.BxDU}}
# \newcommand{\coussinBDuAbs}{\strutgb{0pt}\grapho{H2pGy}}
# \newcommand{\coussinBDuAbsP}{\textipa{bosupapimi}}
# \newcommand{\coussinBDuAbsG}{\blanc{ABS-}coussin\blanc{.BxDU}}
# \newcommand{\coussinBSgDat}{\strutgb{0pt}\grapho{OsqupM}}
# \newcommand{\coussinBSgDatP}{\textipa{lisafupame}}
# \newcommand{\coussinBSgDatG}{\blanc{DAT-}coussin\blanc{.BxSG}}
# \newcommand{\coussinBSgObl}{\strutgb{0pt}\grapho{hsqupM}}
# \newcommand{\coussinBSgOblP}{\textipa{kosafupame}}
# \newcommand{\coussinBSgOblG}{\blanc{OBL-}coussin\blanc{.BxSG}}
# \newcommand{\coussinBSgErg}{\strutgb{0pt}\grapho{RsqupM}}
# \newcommand{\coussinBSgErgP}{\textipa{resafupame}}
# \newcommand{\coussinBSgErgG}{\blanc{ERG-}coussin\blanc{.BxSG}}
# \newcommand{\coussinBSgAbs}{\strutgb{0pt}\grapho{HsqupM}}
# \newcommand{\coussinBSgAbsP}{\textipa{bosafupame}}
# \newcommand{\coussinBSgAbsG}{\blanc{ABS-}coussin\blanc{.BxSG}}
# \newcommand{\coussinBPlDat}{\strutgb{0pt}\grapho{OquIBm}}
# \newcommand{\coussinBPlDatP}{\textipa{lifupumuma}}
# \newcommand{\coussinBPlDatG}{\blanc{DAT-}coussin\blanc{.BxPL}}
# \newcommand{\coussinBPlObl}{\strutgb{0pt}\grapho{hquIBm}}
# \newcommand{\coussinBPlOblP}{\textipa{kofupumuma}}
# \newcommand{\coussinBPlOblG}{\blanc{OBL-}coussin\blanc{.BxPL}}
# \newcommand{\coussinBPlErg}{\strutgb{0pt}\grapho{RquIBm}}
# \newcommand{\coussinBPlErgP}{\textipa{refupumuma}}
# \newcommand{\coussinBPlErgG}{\blanc{ERG-}coussin\blanc{.BxPL}}
# \newcommand{\coussinBPlAbs}{\strutgb{0pt}\grapho{HquIBm}}
# \newcommand{\coussinBPlAbsP}{\textipa{bofupumuma}}
# \newcommand{\coussinBPlAbsG}{\blanc{ABS-}coussin\blanc{.BxPL}}
# \newcommand{\chambreBDuDat}{\strutgb{0pt}\grapho{OkG3y}}
# \newcommand{\chambreBDuDatP}{\textipa{ligapitimi}}
# \newcommand{\chambreBDuDatG}{\blanc{DAT-}chambre\blanc{.BxDU}}
# \newcommand{\chambreBDuObl}{\strutgb{0pt}\grapho{hkG3y}}
# \newcommand{\chambreBDuOblP}{\textipa{kogapitimi}}
# \newcommand{\chambreBDuOblG}{\blanc{OBL-}chambre\blanc{.BxDU}}
# \newcommand{\chambreBDuErg}{\strutgb{0pt}\grapho{RkG3y}}
# \newcommand{\chambreBDuErgP}{\textipa{regapitimi}}
# \newcommand{\chambreBDuErgG}{\blanc{ERG-}chambre\blanc{.BxDU}}
# \newcommand{\chambreBDuAbs}{\strutgb{0pt}\grapho{HkG3y}}
# \newcommand{\chambreBDuAbsP}{\textipa{bogapitimi}}
# \newcommand{\chambreBDuAbsG}{\blanc{ABS-}chambre\blanc{.BxDU}}
# \newcommand{\chambreBSgDat}{\strutgb{0pt}\grapho{Okd3N}}
# \newcommand{\chambreBSgDatP}{\textipa{ligadatine}}
# \newcommand{\chambreBSgDatG}{\blanc{DAT-}chambre\blanc{.BxSG}}
# \newcommand{\chambreBSgObl}{\strutgb{0pt}\grapho{hkd3N}}
# \newcommand{\chambreBSgOblP}{\textipa{kogadatine}}
# \newcommand{\chambreBSgOblG}{\blanc{OBL-}chambre\blanc{.BxSG}}
# \newcommand{\chambreBSgErg}{\strutgb{0pt}\grapho{Rkd3N}}
# \newcommand{\chambreBSgErgP}{\textipa{regadatine}}
# \newcommand{\chambreBSgErgG}{\blanc{ERG-}chambre\blanc{.BxSG}}
# \newcommand{\chambreBSgAbs}{\strutgb{0pt}\grapho{Hkd3N}}
# \newcommand{\chambreBSgAbsP}{\textipa{bogadatine}}
# \newcommand{\chambreBSgAbsG}{\blanc{ABS-}chambre\blanc{.BxSG}}
# \newcommand{\chambreBPlDat}{\strutgb{0pt}\grapho{OxtBn}}
# \newcommand{\chambreBPlDatP}{\textipa{lidutamuna}}
# \newcommand{\chambreBPlDatG}{\blanc{DAT-}chambre\blanc{.BxPL}}
# \newcommand{\chambreBPlObl}{\strutgb{0pt}\grapho{hxtBn}}
# \newcommand{\chambreBPlOblP}{\textipa{kodutamuna}}
# \newcommand{\chambreBPlOblG}{\blanc{OBL-}chambre\blanc{.BxPL}}
# \newcommand{\chambreBPlErg}{\strutgb{0pt}\grapho{RxtBn}}
# \newcommand{\chambreBPlErgP}{\textipa{redutamuna}}
# \newcommand{\chambreBPlErgG}{\blanc{ERG-}chambre\blanc{.BxPL}}
# \newcommand{\chambreBPlAbs}{\strutgb{0pt}\grapho{HxtBn}}
# \newcommand{\chambreBPlAbsP}{\textipa{bodutamuna}}
# \newcommand{\chambreBPlAbsG}{\blanc{ABS-}chambre\blanc{.BxPL}}
# \newcommand{\theBDuDat}{\strutgb{0pt}\grapho{OBwOy}}
# \newcommand{\theBDuDatP}{\textipa{limuwarimi}}
# \newcommand{\theBDuDatG}{\blanc{DAT-}thé\blanc{.BxDU}}
# \newcommand{\theBDuObl}{\strutgb{0pt}\grapho{hBwOy}}
# \newcommand{\theBDuOblP}{\textipa{komuwarimi}}
# \newcommand{\theBDuOblG}{\blanc{OBL-}thé\blanc{.BxDU}}
# \newcommand{\theBDuErg}{\strutgb{0pt}\grapho{RBwOy}}
# \newcommand{\theBDuErgP}{\textipa{remuwarimi}}
# \newcommand{\theBDuErgG}{\blanc{ERG-}thé\blanc{.BxDU}}
# \newcommand{\theBDuAbs}{\strutgb{0pt}\grapho{HBwOy}}
# \newcommand{\theBDuAbsP}{\textipa{bomuwarimi}}
# \newcommand{\theBDuAbsG}{\blanc{ABS-}thé\blanc{.BxDU}}
# \newcommand{\theBSgDat}{\strutgb{0pt}\grapho{OmBrN}}
# \newcommand{\theBSgDatP}{\textipa{limamurane}}
# \newcommand{\theBSgDatG}{\blanc{DAT-}thé\blanc{.BxSG}}
# \newcommand{\theBSgObl}{\strutgb{0pt}\grapho{hmBrN}}
# \newcommand{\theBSgOblP}{\textipa{komamurane}}
# \newcommand{\theBSgOblG}{\blanc{OBL-}thé\blanc{.BxSG}}
# \newcommand{\theBSgErg}{\strutgb{0pt}\grapho{RmBrN}}
# \newcommand{\theBSgErgP}{\textipa{remamurane}}
# \newcommand{\theBSgErgG}{\blanc{ERG-}thé\blanc{.BxSG}}
# \newcommand{\theBSgAbs}{\strutgb{0pt}\grapho{HmBrN}}
# \newcommand{\theBSgAbsP}{\textipa{bomamurane}}
# \newcommand{\theBSgAbsG}{\blanc{ABS-}thé\blanc{.BxSG}}
# \newcommand{\theBPlDat}{\strutgb{0pt}\grapho{OBVBn}}
# \newcommand{\theBPlDatP}{\textipa{limurumuna}}
# \newcommand{\theBPlDatG}{\blanc{DAT-}thé\blanc{.BxPL}}
# \newcommand{\theBPlObl}{\strutgb{0pt}\grapho{hBVBn}}
# \newcommand{\theBPlOblP}{\textipa{komurumuna}}
# \newcommand{\theBPlOblG}{\blanc{OBL-}thé\blanc{.BxPL}}
# \newcommand{\theBPlErg}{\strutgb{0pt}\grapho{RBVBn}}
# \newcommand{\theBPlErgP}{\textipa{remurumuna}}
# \newcommand{\theBPlErgG}{\blanc{ERG-}thé\blanc{.BxPL}}
# \newcommand{\theBPlAbs}{\strutgb{0pt}\grapho{HBVBn}}
# \newcommand{\theBPlAbsP}{\textipa{bomurumuna}}
# \newcommand{\theBPlAbsG}{\blanc{ABS-}thé\blanc{.BxPL}}
# \newcommand{\chasseurCDuDat}{\strutgb{0pt}\grapho{OdyCr}}
# \newcommand{\chasseurCDuDatP}{\textipa{lidamiNira}}
# \newcommand{\chasseurCDuDatG}{\blanc{DAT-}chasseur\blanc{.CxDU}}
# \newcommand{\chasseurCDuObl}{\strutgb{0pt}\grapho{hdyCr}}
# \newcommand{\chasseurCDuOblP}{\textipa{kodamiNira}}
# \newcommand{\chasseurCDuOblG}{\blanc{OBL-}chasseur\blanc{.CxDU}}
# \newcommand{\chasseurCDuErg}{\strutgb{0pt}\grapho{RdyCr}}
# \newcommand{\chasseurCDuErgP}{\textipa{redamiNira}}
# \newcommand{\chasseurCDuErgG}{\blanc{ERG-}chasseur\blanc{.CxDU}}
# \newcommand{\chasseurCDuAbs}{\strutgb{0pt}\grapho{HdyCr}}
# \newcommand{\chasseurCDuAbsP}{\textipa{bodamiNira}}
# \newcommand{\chasseurCDuAbsG}{\blanc{ABS-}chasseur\blanc{.CxDU}}
# \newcommand{\chasseurCSgDat}{\strutgb{0pt}\grapho{OdpCR}}
# \newcommand{\chasseurCSgDatP}{\textipa{lidabaNile}}
# \newcommand{\chasseurCSgDatG}{\blanc{DAT-}chasseur\blanc{.CxSG}}
# \newcommand{\chasseurCSgObl}{\strutgb{0pt}\grapho{hdpCR}}
# \newcommand{\chasseurCSgOblP}{\textipa{kodabaNile}}
# \newcommand{\chasseurCSgOblG}{\blanc{OBL-}chasseur\blanc{.CxSG}}
# \newcommand{\chasseurCSgErg}{\strutgb{0pt}\grapho{RdpCR}}
# \newcommand{\chasseurCSgErgP}{\textipa{redabaNile}}
# \newcommand{\chasseurCSgErgG}{\blanc{ERG-}chasseur\blanc{.CxSG}}
# \newcommand{\chasseurCSgAbs}{\strutgb{0pt}\grapho{HdpCR}}
# \newcommand{\chasseurCSgAbsP}{\textipa{bodabaNile}}
# \newcommand{\chasseurCSgAbsG}{\blanc{ABS-}chasseur\blanc{.CxSG}}
# \newcommand{\chasseurCPlDat}{\strutgb{0pt}\grapho{OInwuV}}
# \newcommand{\chasseurCPlDatP}{\textipa{libuNawulu}}
# \newcommand{\chasseurCPlDatG}{\blanc{DAT-}chasseur\blanc{.CxPL}}
# \newcommand{\chasseurCPlObl}{\strutgb{0pt}\grapho{hInwuV}}
# \newcommand{\chasseurCPlOblP}{\textipa{kobuNawulu}}
# \newcommand{\chasseurCPlOblG}{\blanc{OBL-}chasseur\blanc{.CxPL}}
# \newcommand{\chasseurCPlErg}{\strutgb{0pt}\grapho{RInwuV}}
# \newcommand{\chasseurCPlErgP}{\textipa{rebuNawulu}}
# \newcommand{\chasseurCPlErgG}{\blanc{ERG-}chasseur\blanc{.CxPL}}
# \newcommand{\chasseurCPlAbs}{\strutgb{0pt}\grapho{HInwuV}}
# \newcommand{\chasseurCPlAbsP}{\textipa{bobuNawulu}}
# \newcommand{\chasseurCPlAbsG}{\blanc{ABS-}chasseur\blanc{.CxPL}}
# \newcommand{\filleCDuDat}{\strutgb{0pt}\grapho{OmyCp}}
# \newcommand{\filleCDuDatP}{\textipa{limaminipa}}
# \newcommand{\filleCDuDatG}{\blanc{DAT-}fille\blanc{.CxDU}}
# \newcommand{\filleCDuObl}{\strutgb{0pt}\grapho{hmyCp}}
# \newcommand{\filleCDuOblP}{\textipa{komaminipa}}
# \newcommand{\filleCDuOblG}{\blanc{OBL-}fille\blanc{.CxDU}}
# \newcommand{\filleCDuErg}{\strutgb{0pt}\grapho{RmyCp}}
# \newcommand{\filleCDuErgP}{\textipa{remaminipa}}
# \newcommand{\filleCDuErgG}{\blanc{ERG-}fille\blanc{.CxDU}}
# \newcommand{\filleCDuAbs}{\strutgb{0pt}\grapho{HmyCp}}
# \newcommand{\filleCDuAbsP}{\textipa{bomaminipa}}
# \newcommand{\filleCDuAbsG}{\blanc{ABS-}fille\blanc{.CxDU}}
# \newcommand{\filleCSgDat}{\strutgb{0pt}\grapho{OmmCT}}
# \newcommand{\filleCSgDatP}{\textipa{limamanite}}
# \newcommand{\filleCSgDatG}{\blanc{DAT-}fille\blanc{.CxSG}}
# \newcommand{\filleCSgObl}{\strutgb{0pt}\grapho{hmmCT}}
# \newcommand{\filleCSgOblP}{\textipa{komamanite}}
# \newcommand{\filleCSgOblG}{\blanc{OBL-}fille\blanc{.CxSG}}
# \newcommand{\filleCSgErg}{\strutgb{0pt}\grapho{RmmCT}}
# \newcommand{\filleCSgErgP}{\textipa{remamanite}}
# \newcommand{\filleCSgErgG}{\blanc{ERG-}fille\blanc{.CxSG}}
# \newcommand{\filleCSgAbs}{\strutgb{0pt}\grapho{HmmCT}}
# \newcommand{\filleCSgAbsP}{\textipa{bomamanite}}
# \newcommand{\filleCSgAbsG}{\blanc{ABS-}fille\blanc{.CxSG}}
# \newcommand{\filleCPlDat}{\strutgb{0pt}\grapho{OBnI5}}
# \newcommand{\filleCPlDatP}{\textipa{limunaputu}}
# \newcommand{\filleCPlDatG}{\blanc{DAT-}fille\blanc{.CxPL}}
# \newcommand{\filleCPlObl}{\strutgb{0pt}\grapho{hBnI5}}
# \newcommand{\filleCPlOblP}{\textipa{komunaputu}}
# \newcommand{\filleCPlOblG}{\blanc{OBL-}fille\blanc{.CxPL}}
# \newcommand{\filleCPlErg}{\strutgb{0pt}\grapho{RBnI5}}
# \newcommand{\filleCPlErgP}{\textipa{remunaputu}}
# \newcommand{\filleCPlErgG}{\blanc{ERG-}fille\blanc{.CxPL}}
# \newcommand{\filleCPlAbs}{\strutgb{0pt}\grapho{HBnI5}}
# \newcommand{\filleCPlAbsP}{\textipa{bomunaputu}}
# \newcommand{\filleCPlAbsG}{\blanc{ABS-}fille\blanc{.CxPL}}
# \newcommand{\oeufCDuDat}{\strutgb{0pt}\grapho{O9WOm}}
# \newcommand{\oeufCDuDatP}{\textipa{liZowerima}}
# \newcommand{\oeufCDuDatG}{\blanc{DAT-}oeuf\blanc{.CxDU}}
# \newcommand{\oeufCDuObl}{\strutgb{0pt}\grapho{h9WOm}}
# \newcommand{\oeufCDuOblP}{\textipa{koZowerima}}
# \newcommand{\oeufCDuOblG}{\blanc{OBL-}oeuf\blanc{.CxDU}}
# \newcommand{\oeufCDuErg}{\strutgb{0pt}\grapho{R9WOm}}
# \newcommand{\oeufCDuErgP}{\textipa{reZowerima}}
# \newcommand{\oeufCDuErgG}{\blanc{ERG-}oeuf\blanc{.CxDU}}
# \newcommand{\oeufCDuAbs}{\strutgb{0pt}\grapho{H9WOm}}
# \newcommand{\oeufCDuAbsP}{\textipa{boZowerima}}
# \newcommand{\oeufCDuAbsG}{\blanc{ABS-}oeuf\blanc{.CxDU}}
# \newcommand{\oeufCSgDat}{\strutgb{0pt}\grapho{Oz9RM}}
# \newcommand{\oeufCSgDatP}{\textipa{liZazoreme}}
# \newcommand{\oeufCSgDatG}{\blanc{DAT-}oeuf\blanc{.CxSG}}
# \newcommand{\oeufCSgObl}{\strutgb{0pt}\grapho{hz9RM}}
# \newcommand{\oeufCSgOblP}{\textipa{koZazoreme}}
# \newcommand{\oeufCSgOblG}{\blanc{OBL-}oeuf\blanc{.CxSG}}
# \newcommand{\oeufCSgErg}{\strutgb{0pt}\grapho{Rz9RM}}
# \newcommand{\oeufCSgErgP}{\textipa{reZazoreme}}
# \newcommand{\oeufCSgErgG}{\blanc{ERG-}oeuf\blanc{.CxSG}}
# \newcommand{\oeufCSgAbs}{\strutgb{0pt}\grapho{Hz9RM}}
# \newcommand{\oeufCSgAbsP}{\textipa{boZazoreme}}
# \newcommand{\oeufCSgAbsG}{\blanc{ABS-}oeuf\blanc{.CxSG}}
# \newcommand{\oeufCPlDat}{\strutgb{0pt}\grapho{O9UBB}}
# \newcommand{\oeufCPlDatP}{\textipa{lizoromumu}}
# \newcommand{\oeufCPlDatG}{\blanc{DAT-}oeuf\blanc{.CxPL}}
# \newcommand{\oeufCPlObl}{\strutgb{0pt}\grapho{h9UBB}}
# \newcommand{\oeufCPlOblP}{\textipa{kozoromumu}}
# \newcommand{\oeufCPlOblG}{\blanc{OBL-}oeuf\blanc{.CxPL}}
# \newcommand{\oeufCPlErg}{\strutgb{0pt}\grapho{R9UBB}}
# \newcommand{\oeufCPlErgP}{\textipa{rezoromumu}}
# \newcommand{\oeufCPlErgG}{\blanc{ERG-}oeuf\blanc{.CxPL}}
# \newcommand{\oeufCPlAbs}{\strutgb{0pt}\grapho{H9UBB}}
# \newcommand{\oeufCPlAbsP}{\textipa{bozoromumu}}
# \newcommand{\oeufCPlAbsG}{\blanc{ABS-}oeuf\blanc{.CxPL}}
# \newcommand{\cafeCDuDat}{\strutgb{0pt}\grapho{O8WOp}}
# \newcommand{\cafeCDuDatP}{\textipa{lifowelipa}}
# \newcommand{\cafeCDuDatG}{\blanc{DAT-}café\blanc{.CxDU}}
# \newcommand{\cafeCDuObl}{\strutgb{0pt}\grapho{h8WOp}}
# \newcommand{\cafeCDuOblP}{\textipa{kofowelipa}}
# \newcommand{\cafeCDuOblG}{\blanc{OBL-}café\blanc{.CxDU}}
# \newcommand{\cafeCDuErg}{\strutgb{0pt}\grapho{R8WOp}}
# \newcommand{\cafeCDuErgP}{\textipa{refowelipa}}
# \newcommand{\cafeCDuErgG}{\blanc{ERG-}café\blanc{.CxDU}}
# \newcommand{\cafeCDuAbs}{\strutgb{0pt}\grapho{H8WOp}}
# \newcommand{\cafeCDuAbsP}{\textipa{bofowelipa}}
# \newcommand{\cafeCDuAbsG}{\blanc{ABS-}café\blanc{.CxDU}}
# \newcommand{\cafeCSgDat}{\strutgb{0pt}\grapho{Oq8RT}}
# \newcommand{\cafeCSgDatP}{\textipa{lifafolete}}
# \newcommand{\cafeCSgDatG}{\blanc{DAT-}café\blanc{.CxSG}}
# \newcommand{\cafeCSgObl}{\strutgb{0pt}\grapho{hq8RT}}
# \newcommand{\cafeCSgOblP}{\textipa{kofafolete}}
# \newcommand{\cafeCSgOblG}{\blanc{OBL-}café\blanc{.CxSG}}
# \newcommand{\cafeCSgErg}{\strutgb{0pt}\grapho{Rq8RT}}
# \newcommand{\cafeCSgErgP}{\textipa{refafolete}}
# \newcommand{\cafeCSgErgG}{\blanc{ERG-}café\blanc{.CxSG}}
# \newcommand{\cafeCSgAbs}{\strutgb{0pt}\grapho{Hq8RT}}
# \newcommand{\cafeCSgAbsP}{\textipa{bofafolete}}
# \newcommand{\cafeCSgAbsG}{\blanc{ABS-}café\blanc{.CxSG}}
# \newcommand{\cafeCPlDat}{\strutgb{0pt}\grapho{O8UI5}}
# \newcommand{\cafeCPlDatP}{\textipa{lifoloputu}}
# \newcommand{\cafeCPlDatG}{\blanc{DAT-}café\blanc{.CxPL}}
# \newcommand{\cafeCPlObl}{\strutgb{0pt}\grapho{h8UI5}}
# \newcommand{\cafeCPlOblP}{\textipa{kofoloputu}}
# \newcommand{\cafeCPlOblG}{\blanc{OBL-}café\blanc{.CxPL}}
# \newcommand{\cafeCPlErg}{\strutgb{0pt}\grapho{R8UI5}}
# \newcommand{\cafeCPlErgP}{\textipa{refoloputu}}
# \newcommand{\cafeCPlErgG}{\blanc{ERG-}café\blanc{.CxPL}}
# \newcommand{\cafeCPlAbs}{\strutgb{0pt}\grapho{H8UI5}}
# \newcommand{\cafeCPlAbsP}{\textipa{bofoloputu}}
# \newcommand{\cafeCPlAbsG}{\blanc{ABS-}café\blanc{.CxPL}}
# \newcommand{\coyoteCDuDat}{\strutgb{0pt}\grapho{OHH3s}}
# \newcommand{\coyoteCDuDatP}{\textipa{lipopotisa}}
# \newcommand{\coyoteCDuDatG}{\blanc{DAT-}coyote\blanc{.CxDU}}
# \newcommand{\coyoteCDuObl}{\strutgb{0pt}\grapho{hHH3s}}
# \newcommand{\coyoteCDuOblP}{\textipa{kopopotisa}}
# \newcommand{\coyoteCDuOblG}{\blanc{OBL-}coyote\blanc{.CxDU}}
# \newcommand{\coyoteCDuErg}{\strutgb{0pt}\grapho{RHH3s}}
# \newcommand{\coyoteCDuErgP}{\textipa{repopotisa}}
# \newcommand{\coyoteCDuErgG}{\blanc{ERG-}coyote\blanc{.CxDU}}
# \newcommand{\coyoteCDuAbs}{\strutgb{0pt}\grapho{HHH3s}}
# \newcommand{\coyoteCDuAbsP}{\textipa{bopopotisa}}
# \newcommand{\coyoteCDuAbsG}{\blanc{ABS-}coyote\blanc{.CxDU}}
# \newcommand{\coyoteCSgDat}{\strutgb{0pt}\grapho{OpH4S}}
# \newcommand{\coyoteCSgDatP}{\textipa{lipapotoSe}}
# \newcommand{\coyoteCSgDatG}{\blanc{DAT-}coyote\blanc{.CxSG}}
# \newcommand{\coyoteCSgObl}{\strutgb{0pt}\grapho{hpH4S}}
# \newcommand{\coyoteCSgOblP}{\textipa{kopapotoSe}}
# \newcommand{\coyoteCSgOblG}{\blanc{OBL-}coyote\blanc{.CxSG}}
# \newcommand{\coyoteCSgErg}{\strutgb{0pt}\grapho{RpH4S}}
# \newcommand{\coyoteCSgErgP}{\textipa{repapotoSe}}
# \newcommand{\coyoteCSgErgG}{\blanc{ERG-}coyote\blanc{.CxSG}}
# \newcommand{\coyoteCSgAbs}{\strutgb{0pt}\grapho{HpH4S}}
# \newcommand{\coyoteCSgAbsP}{\textipa{bopapotoSe}}
# \newcommand{\coyoteCSgAbsG}{\blanc{ABS-}coyote\blanc{.CxSG}}
# \newcommand{\coyoteCPlDat}{\strutgb{0pt}\grapho{OH4qu2}}
# \newcommand{\coyoteCPlDatP}{\textipa{lipotofuSu}}
# \newcommand{\coyoteCPlDatG}{\blanc{DAT-}coyote\blanc{.CxPL}}
# \newcommand{\coyoteCPlObl}{\strutgb{0pt}\grapho{hH4qu2}}
# \newcommand{\coyoteCPlOblP}{\textipa{kopotofuSu}}
# \newcommand{\coyoteCPlOblG}{\blanc{OBL-}coyote\blanc{.CxPL}}
# \newcommand{\coyoteCPlErg}{\strutgb{0pt}\grapho{RH4qu2}}
# \newcommand{\coyoteCPlErgP}{\textipa{repotofuSu}}
# \newcommand{\coyoteCPlErgG}{\blanc{ERG-}coyote\blanc{.CxPL}}
# \newcommand{\coyoteCPlAbs}{\strutgb{0pt}\grapho{HH4qu2}}
# \newcommand{\coyoteCPlAbsP}{\textipa{bopotofuSu}}
# \newcommand{\coyoteCPlAbsG}{\blanc{ABS-}coyote\blanc{.CxPL}}
# \newcommand{\villageCDuDat}{\strutgb{0pt}\grapho{OvqYp}}
# \newcommand{\villageCDuDatP}{\textipa{likufasipa}}
# \newcommand{\villageCDuDatG}{\blanc{DAT-}village\blanc{.CxDU}}
# \newcommand{\villageCDuObl}{\strutgb{0pt}\grapho{hvqYp}}
# \newcommand{\villageCDuOblP}{\textipa{kokufasipa}}
# \newcommand{\villageCDuOblG}{\blanc{OBL-}village\blanc{.CxDU}}
# \newcommand{\villageCDuErg}{\strutgb{0pt}\grapho{RvqYp}}
# \newcommand{\villageCDuErgP}{\textipa{rekufasipa}}
# \newcommand{\villageCDuErgG}{\blanc{ERG-}village\blanc{.CxDU}}
# \newcommand{\villageCDuAbs}{\strutgb{0pt}\grapho{HvqYp}}
# \newcommand{\villageCDuAbsP}{\textipa{bokufasipa}}
# \newcommand{\villageCDuAbsG}{\blanc{ABS-}village\blanc{.CxDU}}
# \newcommand{\villageCSgDat}{\strutgb{0pt}\grapho{Ok5sP}}
# \newcommand{\villageCSgDatP}{\textipa{likatusabe}}
# \newcommand{\villageCSgDatG}{\blanc{DAT-}village\blanc{.CxSG}}
# \newcommand{\villageCSgObl}{\strutgb{0pt}\grapho{hk5sP}}
# \newcommand{\villageCSgOblP}{\textipa{kokatusabe}}
# \newcommand{\villageCSgOblG}{\blanc{OBL-}village\blanc{.CxSG}}
# \newcommand{\villageCSgErg}{\strutgb{0pt}\grapho{Rk5sP}}
# \newcommand{\villageCSgErgP}{\textipa{rekatusabe}}
# \newcommand{\villageCSgErgG}{\blanc{ERG-}village\blanc{.CxSG}}
# \newcommand{\villageCSgAbs}{\strutgb{0pt}\grapho{Hk5sP}}
# \newcommand{\villageCSgAbsP}{\textipa{bokatusabe}}
# \newcommand{\villageCSgAbsG}{\blanc{ABS-}village\blanc{.CxSG}}
# \newcommand{\villageCPlDat}{\strutgb{0pt}\grapho{O52II}}
# \newcommand{\villageCPlDatP}{\textipa{litusupubu}}
# \newcommand{\villageCPlDatG}{\blanc{DAT-}village\blanc{.CxPL}}
# \newcommand{\villageCPlObl}{\strutgb{0pt}\grapho{h52II}}
# \newcommand{\villageCPlOblP}{\textipa{kotusupubu}}
# \newcommand{\villageCPlOblG}{\blanc{OBL-}village\blanc{.CxPL}}
# \newcommand{\villageCPlErg}{\strutgb{0pt}\grapho{R52II}}
# \newcommand{\villageCPlErgP}{\textipa{retusupubu}}
# \newcommand{\villageCPlErgG}{\blanc{ERG-}village\blanc{.CxPL}}
# \newcommand{\villageCPlAbs}{\strutgb{0pt}\grapho{H52II}}
# \newcommand{\villageCPlAbsP}{\textipa{botusupubu}}
# \newcommand{\villageCPlAbsG}{\blanc{ABS-}village\blanc{.CxPL}}
# \newcommand{\NabilDDuDat}{\strutgb{0pt}\grapho{OFpGV}}
# \newcommand{\NabilDDuDatP}{\textipa{linupabiru}}
# \newcommand{\NabilDDuDatG}{\blanc{DAT-}Nabil\blanc{.DxDU}}
# \newcommand{\NabilDDuObl}{\strutgb{0pt}\grapho{hFpGV}}
# \newcommand{\NabilDDuOblP}{\textipa{konupabiru}}
# \newcommand{\NabilDDuOblG}{\blanc{OBL-}Nabil\blanc{.DxDU}}
# \newcommand{\NabilDDuErg}{\strutgb{0pt}\grapho{RFpGV}}
# \newcommand{\NabilDDuErgP}{\textipa{renupabiru}}
# \newcommand{\NabilDDuErgG}{\blanc{ERG-}Nabil\blanc{.DxDU}}
# \newcommand{\NabilDDuAbs}{\strutgb{0pt}\grapho{HFpGV}}
# \newcommand{\NabilDDuAbsP}{\textipa{bonupabiru}}
# \newcommand{\NabilDDuAbsG}{\blanc{ABS-}Nabil\blanc{.DxDU}}
# \newcommand{\NabilDSgDat}{\strutgb{0pt}\grapho{OnBpR}}
# \newcommand{\NabilDSgDatP}{\textipa{linamubale}}
# \newcommand{\NabilDSgDatG}{\blanc{DAT-}Nabil\blanc{.DxSG}}
# \newcommand{\NabilDSgObl}{\strutgb{0pt}\grapho{hnBpR}}
# \newcommand{\NabilDSgOblP}{\textipa{konamubale}}
# \newcommand{\NabilDSgOblG}{\blanc{OBL-}Nabil\blanc{.DxSG}}
# \newcommand{\NabilDSgErg}{\strutgb{0pt}\grapho{RnBpR}}
# \newcommand{\NabilDSgErgP}{\textipa{renamubale}}
# \newcommand{\NabilDSgErgG}{\blanc{ERG-}Nabil\blanc{.DxSG}}
# \newcommand{\NabilDSgAbs}{\strutgb{0pt}\grapho{HnBpR}}
# \newcommand{\NabilDSgAbsP}{\textipa{bonamubale}}
# \newcommand{\NabilDSgAbsG}{\blanc{ABS-}Nabil\blanc{.DxSG}}
# \newcommand{\NabilDPlDat}{\strutgb{0pt}\grapho{OBIwuV}}
# \newcommand{\NabilDPlDatP}{\textipa{limubuwulu}}
# \newcommand{\NabilDPlDatG}{\blanc{DAT-}Nabil\blanc{.DxPL}}
# \newcommand{\NabilDPlObl}{\strutgb{0pt}\grapho{hBIwuV}}
# \newcommand{\NabilDPlOblP}{\textipa{komubuwulu}}
# \newcommand{\NabilDPlOblG}{\blanc{OBL-}Nabil\blanc{.DxPL}}
# \newcommand{\NabilDPlErg}{\strutgb{0pt}\grapho{RBIwuV}}
# \newcommand{\NabilDPlErgP}{\textipa{remubuwulu}}
# \newcommand{\NabilDPlErgG}{\blanc{ERG-}Nabil\blanc{.DxPL}}
# \newcommand{\NabilDPlAbs}{\strutgb{0pt}\grapho{HBIwuV}}
# \newcommand{\NabilDPlAbsP}{\textipa{bomubuwulu}}
# \newcommand{\NabilDPlAbsG}{\blanc{ABS-}Nabil\blanc{.DxPL}}
# \newcommand{\garconDDuDat}{\strutgb{0pt}\grapho{OAQYzu}}
# \newcommand{\garconDDuDatP}{\textipa{limofesizu}}
# \newcommand{\garconDDuDatG}{\blanc{DAT-}garçon\blanc{.DxDU}}
# \newcommand{\garconDDuObl}{\strutgb{0pt}\grapho{hAQYzu}}
# \newcommand{\garconDDuOblP}{\textipa{komofesizu}}
# \newcommand{\garconDDuOblG}{\blanc{OBL-}garçon\blanc{.DxDU}}
# \newcommand{\garconDDuErg}{\strutgb{0pt}\grapho{RAQYzu}}
# \newcommand{\garconDDuErgP}{\textipa{remofesizu}}
# \newcommand{\garconDDuErgG}{\blanc{ERG-}garçon\blanc{.DxDU}}
# \newcommand{\garconDDuAbs}{\strutgb{0pt}\grapho{HAQYzu}}
# \newcommand{\garconDDuAbsP}{\textipa{bomofesizu}}
# \newcommand{\garconDDuAbsG}{\blanc{ABS-}garçon\blanc{.DxDU}}
# \newcommand{\garconDSgDat}{\strutgb{0pt}\grapho{OmASZ}}
# \newcommand{\garconDSgDatP}{\textipa{limamoseZe}}
# \newcommand{\garconDSgDatG}{\blanc{DAT-}garçon\blanc{.DxSG}}
# \newcommand{\garconDSgObl}{\strutgb{0pt}\grapho{hmASZ}}
# \newcommand{\garconDSgOblP}{\textipa{komamoseZe}}
# \newcommand{\garconDSgOblG}{\blanc{OBL-}garçon\blanc{.DxSG}}
# \newcommand{\garconDSgErg}{\strutgb{0pt}\grapho{RmASZ}}
# \newcommand{\garconDSgErgP}{\textipa{remamoseZe}}
# \newcommand{\garconDSgErgG}{\blanc{ERG-}garçon\blanc{.DxSG}}
# \newcommand{\garconDSgAbs}{\strutgb{0pt}\grapho{HmASZ}}
# \newcommand{\garconDSgAbsP}{\textipa{bomamoseZe}}
# \newcommand{\garconDSgAbsG}{\blanc{ABS-}garçon\blanc{.DxSG}}
# \newcommand{\garconDPlDat}{\strutgb{0pt}\grapho{OA1quzu}}
# \newcommand{\garconDPlDatP}{\textipa{limosovuZu}}
# \newcommand{\garconDPlDatG}{\blanc{DAT-}garçon\blanc{.DxPL}}
# \newcommand{\garconDPlObl}{\strutgb{0pt}\grapho{hA1quzu}}
# \newcommand{\garconDPlOblP}{\textipa{komosovuZu}}
# \newcommand{\garconDPlOblG}{\blanc{OBL-}garçon\blanc{.DxPL}}
# \newcommand{\garconDPlErg}{\strutgb{0pt}\grapho{RA1quzu}}
# \newcommand{\garconDPlErgP}{\textipa{remosovuZu}}
# \newcommand{\garconDPlErgG}{\blanc{ERG-}garçon\blanc{.DxPL}}
# \newcommand{\garconDPlAbs}{\strutgb{0pt}\grapho{HA1quzu}}
# \newcommand{\garconDPlAbsP}{\textipa{bomosovuZu}}
# \newcommand{\garconDPlAbsG}{\blanc{ABS-}garçon\blanc{.DxPL}}
# \newcommand{\cuisineDDuDat}{\strutgb{0pt}\grapho{OIwuOI}}
# \newcommand{\cuisineDDuDatP}{\textipa{lipuwulipu}}
# \newcommand{\cuisineDDuDatG}{\blanc{DAT-}cuisine\blanc{.DxDU}}
# \newcommand{\cuisineDDuObl}{\strutgb{0pt}\grapho{hIwuOI}}
# \newcommand{\cuisineDDuOblP}{\textipa{kopuwulipu}}
# \newcommand{\cuisineDDuOblG}{\blanc{OBL-}cuisine\blanc{.DxDU}}
# \newcommand{\cuisineDDuErg}{\strutgb{0pt}\grapho{RIwuOI}}
# \newcommand{\cuisineDDuErgP}{\textipa{repuwulipu}}
# \newcommand{\cuisineDDuErgG}{\blanc{ERG-}cuisine\blanc{.DxDU}}
# \newcommand{\cuisineDDuAbs}{\strutgb{0pt}\grapho{HIwuOI}}
# \newcommand{\cuisineDDuAbsP}{\textipa{bopuwulipu}}
# \newcommand{\cuisineDDuAbsG}{\blanc{ABS-}cuisine\blanc{.DxDU}}
# \newcommand{\cuisineDSgDat}{\strutgb{0pt}\grapho{OpIVP}}
# \newcommand{\cuisineDSgDatP}{\textipa{lipapulupe}}
# \newcommand{\cuisineDSgDatG}{\blanc{DAT-}cuisine\blanc{.DxSG}}
# \newcommand{\cuisineDSgObl}{\strutgb{0pt}\grapho{hpIVP}}
# \newcommand{\cuisineDSgOblP}{\textipa{kopapulupe}}
# \newcommand{\cuisineDSgOblG}{\blanc{OBL-}cuisine\blanc{.DxSG}}
# \newcommand{\cuisineDSgErg}{\strutgb{0pt}\grapho{RpIVP}}
# \newcommand{\cuisineDSgErgP}{\textipa{repapulupe}}
# \newcommand{\cuisineDSgErgG}{\blanc{ERG-}cuisine\blanc{.DxSG}}
# \newcommand{\cuisineDSgAbs}{\strutgb{0pt}\grapho{HpIVP}}
# \newcommand{\cuisineDSgAbsP}{\textipa{bopapulupe}}
# \newcommand{\cuisineDSgAbsG}{\blanc{ABS-}cuisine\blanc{.DxSG}}
# \newcommand{\cuisineDPlDat}{\strutgb{0pt}\grapho{OIVII}}
# \newcommand{\cuisineDPlDatP}{\textipa{lipulupupu}}
# \newcommand{\cuisineDPlDatG}{\blanc{DAT-}cuisine\blanc{.DxPL}}
# \newcommand{\cuisineDPlObl}{\strutgb{0pt}\grapho{hIVII}}
# \newcommand{\cuisineDPlOblP}{\textipa{kopulupupu}}
# \newcommand{\cuisineDPlOblG}{\blanc{OBL-}cuisine\blanc{.DxPL}}
# \newcommand{\cuisineDPlErg}{\strutgb{0pt}\grapho{RIVII}}
# \newcommand{\cuisineDPlErgP}{\textipa{repulupupu}}
# \newcommand{\cuisineDPlErgG}{\blanc{ERG-}cuisine\blanc{.DxPL}}
# \newcommand{\cuisineDPlAbs}{\strutgb{0pt}\grapho{HIVII}}
# \newcommand{\cuisineDPlAbsP}{\textipa{bopulupupu}}
# \newcommand{\cuisineDPlAbsG}{\blanc{ABS-}cuisine\blanc{.DxPL}}
# \newcommand{\tableDDuDat}{\strutgb{0pt}\grapho{OFqziB}}
# \newcommand{\tableDDuDatP}{\textipa{liNufazimu}}
# \newcommand{\tableDDuDatG}{\blanc{DAT-}table\blanc{.DxDU}}
# \newcommand{\tableDDuObl}{\strutgb{0pt}\grapho{hFqziB}}
# \newcommand{\tableDDuOblP}{\textipa{koNufazimu}}
# \newcommand{\tableDDuOblG}{\blanc{OBL-}table\blanc{.DxDU}}
# \newcommand{\tableDDuErg}{\strutgb{0pt}\grapho{RFqziB}}
# \newcommand{\tableDDuErgP}{\textipa{reNufazimu}}
# \newcommand{\tableDDuErgG}{\blanc{ERG-}table\blanc{.DxDU}}
# \newcommand{\tableDDuAbs}{\strutgb{0pt}\grapho{HFqziB}}
# \newcommand{\tableDDuAbsP}{\textipa{boNufazimu}}
# \newcommand{\tableDDuAbsG}{\blanc{ABS-}table\blanc{.DxDU}}
# \newcommand{\tableDSgDat}{\strutgb{0pt}\grapho{OnFzN}}
# \newcommand{\tableDSgDatP}{\textipa{liNanuzane}}
# \newcommand{\tableDSgDatG}{\blanc{DAT-}table\blanc{.DxSG}}
# \newcommand{\tableDSgObl}{\strutgb{0pt}\grapho{hnFzN}}
# \newcommand{\tableDSgOblP}{\textipa{koNanuzane}}
# \newcommand{\tableDSgOblG}{\blanc{OBL-}table\blanc{.DxSG}}
# \newcommand{\tableDSgErg}{\strutgb{0pt}\grapho{RnFzN}}
# \newcommand{\tableDSgErgP}{\textipa{reNanuzane}}
# \newcommand{\tableDSgErgG}{\blanc{ERG-}table\blanc{.DxSG}}
# \newcommand{\tableDSgAbs}{\strutgb{0pt}\grapho{HnFzN}}
# \newcommand{\tableDSgAbsP}{\textipa{boNanuzane}}
# \newcommand{\tableDSgAbsG}{\blanc{ABS-}table\blanc{.DxSG}}
# \newcommand{\tableDPlDat}{\strutgb{0pt}\grapho{OFzuBF}}
# \newcommand{\tableDPlDatP}{\textipa{linuzumunu}}
# \newcommand{\tableDPlDatG}{\blanc{DAT-}table\blanc{.DxPL}}
# \newcommand{\tableDPlObl}{\strutgb{0pt}\grapho{hFzuBF}}
# \newcommand{\tableDPlOblP}{\textipa{konuzumunu}}
# \newcommand{\tableDPlOblG}{\blanc{OBL-}table\blanc{.DxPL}}
# \newcommand{\tableDPlErg}{\strutgb{0pt}\grapho{RFzuBF}}
# \newcommand{\tableDPlErgP}{\textipa{renuzumunu}}
# \newcommand{\tableDPlErgG}{\blanc{ERG-}table\blanc{.DxPL}}
# \newcommand{\tableDPlAbs}{\strutgb{0pt}\grapho{HFzuBF}}
# \newcommand{\tableDPlAbsP}{\textipa{bonuzumunu}}
# \newcommand{\tableDPlAbsG}{\blanc{ABS-}table\blanc{.DxPL}}
# \newcommand{\chatDDuDat}{\strutgb{0pt}\grapho{OVBy5}}
# \newcommand{\chatDDuDatP}{\textipa{lirumumitu}}
# \newcommand{\chatDDuDatG}{\blanc{DAT-}chat\blanc{.DxDU}}
# \newcommand{\chatDDuObl}{\strutgb{0pt}\grapho{hVBy5}}
# \newcommand{\chatDDuOblP}{\textipa{korumumitu}}
# \newcommand{\chatDDuOblG}{\blanc{OBL-}chat\blanc{.DxDU}}
# \newcommand{\chatDDuErg}{\strutgb{0pt}\grapho{RVBy5}}
# \newcommand{\chatDDuErgP}{\textipa{rerumumitu}}
# \newcommand{\chatDDuErgG}{\blanc{ERG-}chat\blanc{.DxDU}}
# \newcommand{\chatDDuAbs}{\strutgb{0pt}\grapho{HVBy5}}
# \newcommand{\chatDDuAbsP}{\textipa{borumumitu}}
# \newcommand{\chatDDuAbsG}{\blanc{ABS-}chat\blanc{.DxDU}}
# \newcommand{\chatDSgDat}{\strutgb{0pt}\grapho{OrwuBK}}
# \newcommand{\chatDSgDatP}{\textipa{lirawumuke}}
# \newcommand{\chatDSgDatG}{\blanc{DAT-}chat\blanc{.DxSG}}
# \newcommand{\chatDSgObl}{\strutgb{0pt}\grapho{hrwuBK}}
# \newcommand{\chatDSgOblP}{\textipa{korawumuke}}
# \newcommand{\chatDSgOblG}{\blanc{OBL-}chat\blanc{.DxSG}}
# \newcommand{\chatDSgErg}{\strutgb{0pt}\grapho{RrwuBK}}
# \newcommand{\chatDSgErgP}{\textipa{rerawumuke}}
# \newcommand{\chatDSgErgG}{\blanc{ERG-}chat\blanc{.DxSG}}
# \newcommand{\chatDSgAbs}{\strutgb{0pt}\grapho{HrwuBK}}
# \newcommand{\chatDSgAbsP}{\textipa{borawumuke}}
# \newcommand{\chatDSgAbsG}{\blanc{ABS-}chat\blanc{.DxSG}}
# \newcommand{\chatDPlDat}{\strutgb{0pt}\grapho{OwuBIv}}
# \newcommand{\chatDPlDatP}{\textipa{liwumupuku}}
# \newcommand{\chatDPlDatG}{\blanc{DAT-}chat\blanc{.DxPL}}
# \newcommand{\chatDPlObl}{\strutgb{0pt}\grapho{hwuBIv}}
# \newcommand{\chatDPlOblP}{\textipa{kowumupuku}}
# \newcommand{\chatDPlOblG}{\blanc{OBL-}chat\blanc{.DxPL}}
# \newcommand{\chatDPlErg}{\strutgb{0pt}\grapho{RwuBIv}}
# \newcommand{\chatDPlErgP}{\textipa{rewumupuku}}
# \newcommand{\chatDPlErgG}{\blanc{ERG-}chat\blanc{.DxPL}}
# \newcommand{\chatDPlAbs}{\strutgb{0pt}\grapho{HwuBIv}}
# \newcommand{\chatDPlAbsP}{\textipa{bowumupuku}}
# \newcommand{\chatDPlAbsG}{\blanc{ABS-}chat\blanc{.DxPL}}
# \newcommand{\litDDuDat}{\strutgb{0pt}\grapho{OhHGI}}
# \newcommand{\litDDuDatP}{\textipa{ligopobibu}}
# \newcommand{\litDDuDatG}{\blanc{DAT-}lit\blanc{.DxDU}}
# \newcommand{\litDDuObl}{\strutgb{0pt}\grapho{hhHGI}}
# \newcommand{\litDDuOblP}{\textipa{kogopobibu}}
# \newcommand{\litDDuOblG}{\blanc{OBL-}lit\blanc{.DxDU}}
# \newcommand{\litDDuErg}{\strutgb{0pt}\grapho{RhHGI}}
# \newcommand{\litDDuErgP}{\textipa{regopobibu}}
# \newcommand{\litDDuErgG}{\blanc{ERG-}lit\blanc{.DxDU}}
# \newcommand{\litDDuAbs}{\strutgb{0pt}\grapho{HhHGI}}
# \newcommand{\litDDuAbsP}{\textipa{bogopobibu}}
# \newcommand{\litDDuAbsG}{\blanc{ABS-}lit\blanc{.DxDU}}
# \newcommand{\litDSgDat}{\strutgb{0pt}\grapho{OkgHD}}
# \newcommand{\litDSgDatP}{\textipa{ligadobode}}
# \newcommand{\litDSgDatG}{\blanc{DAT-}lit\blanc{.DxSG}}
# \newcommand{\litDSgObl}{\strutgb{0pt}\grapho{hkgHD}}
# \newcommand{\litDSgOblP}{\textipa{kogadobode}}
# \newcommand{\litDSgOblG}{\blanc{OBL-}lit\blanc{.DxSG}}
# \newcommand{\litDSgErg}{\strutgb{0pt}\grapho{RkgHD}}
# \newcommand{\litDSgErgP}{\textipa{regadobode}}
# \newcommand{\litDSgErgG}{\blanc{ERG-}lit\blanc{.DxSG}}
# \newcommand{\litDSgAbs}{\strutgb{0pt}\grapho{HkgHD}}
# \newcommand{\litDSgAbsP}{\textipa{bogadobode}}
# \newcommand{\litDSgAbsG}{\blanc{ABS-}lit\blanc{.DxSG}}
# \newcommand{\litDPlDat}{\strutgb{0pt}\grapho{OgHIx}}
# \newcommand{\litDPlDatP}{\textipa{lidobopudu}}
# \newcommand{\litDPlDatG}{\blanc{DAT-}lit\blanc{.DxPL}}
# \newcommand{\litDPlObl}{\strutgb{0pt}\grapho{hgHIx}}
# \newcommand{\litDPlOblP}{\textipa{kodobopudu}}
# \newcommand{\litDPlOblG}{\blanc{OBL-}lit\blanc{.DxPL}}
# \newcommand{\litDPlErg}{\strutgb{0pt}\grapho{RgHIx}}
# \newcommand{\litDPlErgP}{\textipa{redobopudu}}
# \newcommand{\litDPlErgG}{\blanc{ERG-}lit\blanc{.DxPL}}
# \newcommand{\litDPlAbs}{\strutgb{0pt}\grapho{HgHIx}}
# \newcommand{\litDPlAbsP}{\textipa{bodobopudu}}
# \newcommand{\litDPlAbsG}{\blanc{ABS-}lit\blanc{.DxPL}}
# ...
# \newcommand{\offrirVdPstASgG}{\blanc{SG-}offrir\blanc{.VDxPSTxA}}
# \newcommand{\offrirVdPstAPl}{\strutgb{0pt}\grapho{fwuUdn}}
# \newcommand{\offrirVdPstAPlP}{\textipa{diwurodana}}
# \newcommand{\offrirVdPstAPlG}{\blanc{PL-}offrir\blanc{.VDxPSTxA}}
# \newcommand{\offrirVdPstCDu}{\strutgb{0pt}\grapho{1wuUgn}}
# \newcommand{\offrirVdPstCDuP}{\textipa{sowurodona}}
# \newcommand{\offrirVdPstCDuG}{\blanc{DU-}offrir\blanc{.VDxPSTxC}}
# \newcommand{\offrirVdPstCSg}{\strutgb{0pt}\grapho{HwuUgn}}
# \newcommand{\offrirVdPstCSgP}{\textipa{powurodona}}
# \newcommand{\offrirVdPstCSgG}{\blanc{SG-}offrir\blanc{.VDxPSTxC}}
# \newcommand{\offrirVdPstCPl}{\strutgb{0pt}\grapho{gwuUgn}}
# \newcommand{\offrirVdPstCPlP}{\textipa{dowurodona}}
# \newcommand{\offrirVdPstCPlG}{\blanc{PL-}offrir\blanc{.VDxPSTxC}}
# \newcommand{\offrirVdPstBDu}{\strutgb{0pt}\grapho{swuUxn}}
# \newcommand{\offrirVdPstBDuP}{\textipa{sawuroduna}}
# \newcommand{\offrirVdPstBDuG}{\blanc{DU-}offrir\blanc{.VDxPSTxB}}
# \newcommand{\offrirVdPstBSg}{\strutgb{0pt}\grapho{pwuUxn}}
# \newcommand{\offrirVdPstBSgP}{\textipa{pawuroduna}}
# \newcommand{\offrirVdPstBSgG}{\blanc{SG-}offrir\blanc{.VDxPSTxB}}
# \newcommand{\offrirVdPstBPl}{\strutgb{0pt}\grapho{dwuUxn}}
# \newcommand{\offrirVdPstBPlP}{\textipa{dawuroduna}}
# \newcommand{\offrirVdPstBPlG}{\blanc{PL-}offrir\blanc{.VDxPSTxB}}
# \newcommand{\offrirVdPstDDu}{\strutgb{0pt}\grapho{SwuUgn}}
# \newcommand{\offrirVdPstDDuP}{\textipa{sewurodona}}
# \newcommand{\offrirVdPstDDuG}{\blanc{DU-}offrir\blanc{.VDxPSTxD}}
# \newcommand{\offrirVdPstDSg}{\strutgb{0pt}\grapho{PwuUgn}}
# \newcommand{\offrirVdPstDSgP}{\textipa{pewurodona}}
# \newcommand{\offrirVdPstDSgG}{\blanc{SG-}offrir\blanc{.VDxPSTxD}}
# \newcommand{\offrirVdPstDPl}{\strutgb{0pt}\grapho{DwuUgn}}
# \newcommand{\offrirVdPstDPlP}{\textipa{dewurodona}}
# \newcommand{\offrirVdPstDPlG}{\blanc{PL-}offrir\blanc{.VDxPSTxD}}
# \newcommand{\lancerVdPrsADu}{\strutgb{0pt}\grapho{2GrwV}}
# \newcommand{\lancerVdPrsADuP}{\textipa{supirawalu}}
# \newcommand{\lancerVdPrsADuG}{\blanc{DU-}lancer\blanc{.VDxPRSxA}}
# \newcommand{\lancerVdPrsASg}{\strutgb{0pt}\grapho{IGrwV}}
# \newcommand{\lancerVdPrsASgP}{\textipa{pupirawalu}}
# \newcommand{\lancerVdPrsASgG}{\blanc{SG-}lancer\blanc{.VDxPRSxA}}
# \newcommand{\lancerVdPrsAPl}{\strutgb{0pt}\grapho{xGrwV}}
# \newcommand{\lancerVdPrsAPlP}{\textipa{dupirawalu}}
# \newcommand{\lancerVdPrsAPlG}{\blanc{PL-}lancer\blanc{.VDxPRSxA}}
# \newcommand{\lancerVdPrsCDu}{\strutgb{0pt}\grapho{2HrwV}}
# \newcommand{\lancerVdPrsCDuP}{\textipa{suporawalu}}
# \newcommand{\lancerVdPrsCDuG}{\blanc{DU-}lancer\blanc{.VDxPRSxC}}
# \newcommand{\lancerVdPrsCSg}{\strutgb{0pt}\grapho{IHrwV}}
# \newcommand{\lancerVdPrsCSgP}{\textipa{puporawalu}}
# \newcommand{\lancerVdPrsCSgG}{\blanc{SG-}lancer\blanc{.VDxPRSxC}}
# \newcommand{\lancerVdPrsCPl}{\strutgb{0pt}\grapho{xHrwV}}
# \newcommand{\lancerVdPrsCPlP}{\textipa{duporawalu}}
# \newcommand{\lancerVdPrsCPlG}{\blanc{PL-}lancer\blanc{.VDxPRSxC}}
# \newcommand{\lancerVdPrsBDu}{\strutgb{0pt}\grapho{2prwV}}
# \newcommand{\lancerVdPrsBDuP}{\textipa{suparawalu}}
# \newcommand{\lancerVdPrsBDuG}{\blanc{DU-}lancer\blanc{.VDxPRSxB}}
# \newcommand{\lancerVdPrsBSg}{\strutgb{0pt}\grapho{IprwV}}
# \newcommand{\lancerVdPrsBSgP}{\textipa{puparawalu}}
# \newcommand{\lancerVdPrsBSgG}{\blanc{SG-}lancer\blanc{.VDxPRSxB}}
# \newcommand{\lancerVdPrsBPl}{\strutgb{0pt}\grapho{xprwV}}
# \newcommand{\lancerVdPrsBPlP}{\textipa{duparawalu}}
# \newcommand{\lancerVdPrsBPlG}{\blanc{PL-}lancer\blanc{.VDxPRSxB}}
# \newcommand{\lancerVdPrsDDu}{\strutgb{0pt}\grapho{2PrwV}}
# \newcommand{\lancerVdPrsDDuP}{\textipa{superawalu}}
# \newcommand{\lancerVdPrsDDuG}{\blanc{DU-}lancer\blanc{.VDxPRSxD}}
# \newcommand{\lancerVdPrsDSg}{\strutgb{0pt}\grapho{IPrwV}}
# \newcommand{\lancerVdPrsDSgP}{\textipa{puperawalu}}
# \newcommand{\lancerVdPrsDSgG}{\blanc{SG-}lancer\blanc{.VDxPRSxD}}
# \newcommand{\lancerVdPrsDPl}{\strutgb{0pt}\grapho{xPrwV}}
# \newcommand{\lancerVdPrsDPlP}{\textipa{duperawalu}}
# \newcommand{\lancerVdPrsDPlG}{\blanc{PL-}lancer\blanc{.VDxPRSxD}}
# \newcommand{\lancerVdPstADu}{\strutgb{0pt}\grapho{YIHrr}}
# \newcommand{\lancerVdPstADuP}{\textipa{sipuporala}}
# \newcommand{\lancerVdPstADuG}{\blanc{DU-}lancer\blanc{.VDxPSTxA}}
# \newcommand{\lancerVdPstASg}{\strutgb{0pt}\grapho{GIHrr}}
# \newcommand{\lancerVdPstASgP}{\textipa{pipuporala}}
# \newcommand{\lancerVdPstASgG}{\blanc{SG-}lancer\blanc{.VDxPSTxA}}
# \newcommand{\lancerVdPstAPl}{\strutgb{0pt}\grapho{fIHrr}}
# \newcommand{\lancerVdPstAPlP}{\textipa{dipuporala}}
# \newcommand{\lancerVdPstAPlG}{\blanc{PL-}lancer\blanc{.VDxPSTxA}}
# \newcommand{\lancerVdPstCDu}{\strutgb{0pt}\grapho{1IHUr}}
# \newcommand{\lancerVdPstCDuP}{\textipa{sopuporola}}
# \newcommand{\lancerVdPstCDuG}{\blanc{DU-}lancer\blanc{.VDxPSTxC}}
# \newcommand{\lancerVdPstCSg}{\strutgb{0pt}\grapho{HIHUr}}
# \newcommand{\lancerVdPstCSgP}{\textipa{popuporola}}
# \newcommand{\lancerVdPstCSgG}{\blanc{SG-}lancer\blanc{.VDxPSTxC}}
# \newcommand{\lancerVdPstCPl}{\strutgb{0pt}\grapho{gIHUr}}
# \newcommand{\lancerVdPstCPlP}{\textipa{dopuporola}}
# \newcommand{\lancerVdPstCPlG}{\blanc{PL-}lancer\blanc{.VDxPSTxC}}
# \newcommand{\lancerVdPstBDu}{\strutgb{0pt}\grapho{sIHVr}}
# \newcommand{\lancerVdPstBDuP}{\textipa{sapuporula}}
# \newcommand{\lancerVdPstBDuG}{\blanc{DU-}lancer\blanc{.VDxPSTxB}}
# \newcommand{\lancerVdPstBSg}{\strutgb{0pt}\grapho{pIHVr}}
# \newcommand{\lancerVdPstBSgP}{\textipa{papuporula}}
# \newcommand{\lancerVdPstBSgG}{\blanc{SG-}lancer\blanc{.VDxPSTxB}}
# \newcommand{\lancerVdPstBPl}{\strutgb{0pt}\grapho{dIHVr}}
# \newcommand{\lancerVdPstBPlP}{\textipa{dapuporula}}
# \newcommand{\lancerVdPstBPlG}{\blanc{PL-}lancer\blanc{.VDxPSTxB}}
# \newcommand{\lancerVdPstDDu}{\strutgb{0pt}\grapho{SIHUr}}
# \newcommand{\lancerVdPstDDuP}{\textipa{sepuporola}}
# \newcommand{\lancerVdPstDDuG}{\blanc{DU-}lancer\blanc{.VDxPSTxD}}
# \newcommand{\lancerVdPstDSg}{\strutgb{0pt}\grapho{PIHUr}}
# \newcommand{\lancerVdPstDSgP}{\textipa{pepuporola}}
# \newcommand{\lancerVdPstDSgG}{\blanc{SG-}lancer\blanc{.VDxPSTxD}}
# \newcommand{\lancerVdPstDPl}{\strutgb{0pt}\grapho{DIHUr}}
# \newcommand{\lancerVdPstDPlP}{\textipa{depuporola}}
# \newcommand{\lancerVdPstDPlG}{\blanc{PL-}lancer\blanc{.VDxPSTxD}}
# \newcommand{\montrerVdPrsADu}{\strutgb{0pt}\grapho{2GnmI}}
# \newcommand{\montrerVdPrsADuP}{\textipa{supinamabu}}
# \newcommand{\montrerVdPrsADuG}{\blanc{DU-}montrer\blanc{.VDxPRSxA}}
# \newcommand{\montrerVdPrsASg}{\strutgb{0pt}\grapho{IGnmI}}
# \newcommand{\montrerVdPrsASgP}{\textipa{pupinamabu}}
# \newcommand{\montrerVdPrsASgG}{\blanc{SG-}montrer\blanc{.VDxPRSxA}}
# \newcommand{\montrerVdPrsAPl}{\strutgb{0pt}\grapho{xGnmI}}
# \newcommand{\montrerVdPrsAPlP}{\textipa{dupinamabu}}
# \newcommand{\montrerVdPrsAPlG}{\blanc{PL-}montrer\blanc{.VDxPRSxA}}
# \newcommand{\montrerVdPrsCDu}{\strutgb{0pt}\grapho{2HnmI}}
# \newcommand{\montrerVdPrsCDuP}{\textipa{suponamabu}}
# \newcommand{\montrerVdPrsCDuG}{\blanc{DU-}montrer\blanc{.VDxPRSxC}}
# \newcommand{\montrerVdPrsCSg}{\strutgb{0pt}\grapho{IHnmI}}
# \newcommand{\montrerVdPrsCSgP}{\textipa{puponamabu}}
# \newcommand{\montrerVdPrsCSgG}{\blanc{SG-}montrer\blanc{.VDxPRSxC}}
# \newcommand{\montrerVdPrsCPl}{\strutgb{0pt}\grapho{xHnmI}}
# \newcommand{\montrerVdPrsCPlP}{\textipa{duponamabu}}
# \newcommand{\montrerVdPrsCPlG}{\blanc{PL-}montrer\blanc{.VDxPRSxC}}
# \newcommand{\montrerVdPrsBDu}{\strutgb{0pt}\grapho{2pnmI}}
# \newcommand{\montrerVdPrsBDuP}{\textipa{supanamabu}}
# \newcommand{\montrerVdPrsBDuG}{\blanc{DU-}montrer\blanc{.VDxPRSxB}}
# \newcommand{\montrerVdPrsBSg}{\strutgb{0pt}\grapho{IpnmI}}
# \newcommand{\montrerVdPrsBSgP}{\textipa{pupanamabu}}
# \newcommand{\montrerVdPrsBSgG}{\blanc{SG-}montrer\blanc{.VDxPRSxB}}
# \newcommand{\montrerVdPrsBPl}{\strutgb{0pt}\grapho{xpnmI}}
# \newcommand{\montrerVdPrsBPlP}{\textipa{dupanamabu}}
# \newcommand{\montrerVdPrsBPlG}{\blanc{PL-}montrer\blanc{.VDxPRSxB}}
# \newcommand{\montrerVdPrsDDu}{\strutgb{0pt}\grapho{2PnmI}}
# \newcommand{\montrerVdPrsDDuP}{\textipa{supenamabu}}
# \newcommand{\montrerVdPrsDDuG}{\blanc{DU-}montrer\blanc{.VDxPRSxD}}
# \newcommand{\montrerVdPrsDSg}{\strutgb{0pt}\grapho{IPnmI}}
# \newcommand{\montrerVdPrsDSgP}{\textipa{pupenamabu}}
# \newcommand{\montrerVdPrsDSgG}{\blanc{SG-}montrer\blanc{.VDxPRSxD}}
# \newcommand{\montrerVdPrsDPl}{\strutgb{0pt}\grapho{xPnmI}}
# \newcommand{\montrerVdPrsDPlP}{\textipa{dupenamabu}}
# \newcommand{\montrerVdPrsDPlG}{\blanc{PL-}montrer\blanc{.VDxPRSxD}}
# \newcommand{\montrerVdPstADu}{\strutgb{0pt}\grapho{YIHnp}}
# \newcommand{\montrerVdPstADuP}{\textipa{sipuponaba}}
# \newcommand{\montrerVdPstADuG}{\blanc{DU-}montrer\blanc{.VDxPSTxA}}
# \newcommand{\montrerVdPstASg}{\strutgb{0pt}\grapho{GIHnp}}
# \newcommand{\montrerVdPstASgP}{\textipa{pipuponaba}}
# \newcommand{\montrerVdPstASgG}{\blanc{SG-}montrer\blanc{.VDxPSTxA}}
# \newcommand{\montrerVdPstAPl}{\strutgb{0pt}\grapho{fIHnp}}
# \newcommand{\montrerVdPstAPlP}{\textipa{dipuponaba}}
# \newcommand{\montrerVdPstAPlG}{\blanc{PL-}montrer\blanc{.VDxPSTxA}}
# \newcommand{\montrerVdPstCDu}{\strutgb{0pt}\grapho{1IHnop}}
# \newcommand{\montrerVdPstCDuP}{\textipa{sopuponoba}}
# \newcommand{\montrerVdPstCDuG}{\blanc{DU-}montrer\blanc{.VDxPSTxC}}
# \newcommand{\montrerVdPstCSg}{\strutgb{0pt}\grapho{HIHnop}}
# \newcommand{\montrerVdPstCSgP}{\textipa{popuponoba}}
# \newcommand{\montrerVdPstCSgG}{\blanc{SG-}montrer\blanc{.VDxPSTxC}}
# \newcommand{\montrerVdPstCPl}{\strutgb{0pt}\grapho{gIHnop}}
# \newcommand{\montrerVdPstCPlP}{\textipa{dopuponoba}}
# \newcommand{\montrerVdPstCPlG}{\blanc{PL-}montrer\blanc{.VDxPSTxC}}
# \newcommand{\montrerVdPstBDu}{\strutgb{0pt}\grapho{sIHFp}}
# \newcommand{\montrerVdPstBDuP}{\textipa{sapuponuba}}
# \newcommand{\montrerVdPstBDuG}{\blanc{DU-}montrer\blanc{.VDxPSTxB}}
# \newcommand{\montrerVdPstBSg}{\strutgb{0pt}\grapho{pIHFp}}
# \newcommand{\montrerVdPstBSgP}{\textipa{papuponuba}}
# \newcommand{\montrerVdPstBSgG}{\blanc{SG-}montrer\blanc{.VDxPSTxB}}
# \newcommand{\montrerVdPstBPl}{\strutgb{0pt}\grapho{dIHFp}}
# \newcommand{\montrerVdPstBPlP}{\textipa{dapuponuba}}
# \newcommand{\montrerVdPstBPlG}{\blanc{PL-}montrer\blanc{.VDxPSTxB}}
# \newcommand{\montrerVdPstDDu}{\strutgb{0pt}\grapho{SIHnop}}
# \newcommand{\montrerVdPstDDuP}{\textipa{sepuponoba}}
# \newcommand{\montrerVdPstDDuG}{\blanc{DU-}montrer\blanc{.VDxPSTxD}}
# \newcommand{\montrerVdPstDSg}{\strutgb{0pt}\grapho{PIHnop}}
# \newcommand{\montrerVdPstDSgP}{\textipa{pepuponoba}}
# \newcommand{\montrerVdPstDSgG}{\blanc{SG-}montrer\blanc{.VDxPSTxD}}
# \newcommand{\montrerVdPstDPl}{\strutgb{0pt}\grapho{DIHnop}}
# \newcommand{\montrerVdPstDPlP}{\textipa{depuponoba}}
# \newcommand{\montrerVdPstDPlG}{\blanc{PL-}montrer\blanc{.VDxPSTxD}}
#
#
#
# \newcommand{\defDuDat}{\strutgb{0pt}\grapho{pt}}
# \newcommand{\defDuDatP}{\textipa{bat}}
# \newcommand{\defDuDatG}{DEF\blanc{-DU-DAT}}
# \newcommand{\defDuObl}{\strutgb{0pt}\grapho{pk}}
# \newcommand{\defDuOblP}{\textipa{bag}}
# \newcommand{\defDuOblG}{DEF\blanc{-DU-OBL}}
# \newcommand{\defDuErg}{\strutgb{0pt}\grapho{pm}}
# \newcommand{\defDuErgP}{\textipa{bam}}
# \newcommand{\defDuErgG}{DEF\blanc{-DU-ERG}}
# \newcommand{\defDuAbs}{\strutgb{0pt}\grapho{pk}}
# \newcommand{\defDuAbsP}{\textipa{bak}}
# \newcommand{\defDuAbsG}{DEF\blanc{-DU-ABS}}
# \newcommand{\defSgDat}{\strutgb{0pt}\grapho{Ht}}
# \newcommand{\defSgDatP}{\textipa{bot}}
# \newcommand{\defSgDatG}{DEF\blanc{-SG-DAT}}
# \newcommand{\defSgObl}{\strutgb{0pt}\grapho{Hk}}
# \newcommand{\defSgOblP}{\textipa{bog}}
# \newcommand{\defSgOblG}{DEF\blanc{-SG-OBL}}
# \newcommand{\defSgErg}{\strutgb{0pt}\grapho{Hm}}
# \newcommand{\defSgErgP}{\textipa{bom}}
# \newcommand{\defSgErgG}{DEF\blanc{-SG-ERG}}
# \newcommand{\defSgAbs}{\strutgb{0pt}\grapho{Hk}}
# \newcommand{\defSgAbsP}{\textipa{bok}}
# \newcommand{\defSgAbsG}{DEF\blanc{-SG-ABS}}
# \newcommand{\defPlDat}{\strutgb{0pt}\grapho{Gt}}
# \newcommand{\defPlDatP}{\textipa{bit}}
# \newcommand{\defPlDatG}{DEF\blanc{-PL-DAT}}
# \newcommand{\defPlObl}{\strutgb{0pt}\grapho{Gk}}
# \newcommand{\defPlOblP}{\textipa{big}}
# \newcommand{\defPlOblG}{DEF\blanc{-PL-OBL}}
# \newcommand{\defPlErg}{\strutgb{0pt}\grapho{Gm}}
# \newcommand{\defPlErgP}{\textipa{bim}}
# \newcommand{\defPlErgG}{DEF\blanc{-PL-ERG}}
# \newcommand{\defPlAbs}{\strutgb{0pt}\grapho{Gk}}
# \newcommand{\defPlAbsP}{\textipa{bik}}
# \newcommand{\defPlAbsG}{DEF\blanc{-PL-ABS}}
# \newcommand{\indDuDat}{\strutgb{0pt}\grapho{kt}}
# \newcommand{\indDuDatP}{\textipa{kat}}
# \newcommand{\indDuDatG}{IND\blanc{-DU-DAT}}
# \newcommand{\indDuObl}{\strutgb{0pt}\grapho{kk}}
# \newcommand{\indDuOblP}{\textipa{kag}}
# \newcommand{\indDuOblG}{IND\blanc{-DU-OBL}}
# \newcommand{\indDuErg}{\strutgb{0pt}\grapho{km}}
# \newcommand{\indDuErgP}{\textipa{kam}}
# \newcommand{\indDuErgG}{IND\blanc{-DU-ERG}}
# \newcommand{\indDuAbs}{\strutgb{0pt}\grapho{kk}}
# \newcommand{\indDuAbsP}{\textipa{kak}}
# \newcommand{\indDuAbsG}{IND\blanc{-DU-ABS}}
# \newcommand{\indSgDat}{\strutgb{0pt}\grapho{ht}}
# \newcommand{\indSgDatP}{\textipa{kot}}
# \newcommand{\indSgDatG}{IND\blanc{-SG-DAT}}
# \newcommand{\indSgObl}{\strutgb{0pt}\grapho{hk}}
# \newcommand{\indSgOblP}{\textipa{kog}}
# \newcommand{\indSgOblG}{IND\blanc{-SG-OBL}}
# \newcommand{\indSgErg}{\strutgb{0pt}\grapho{hm}}
# \newcommand{\indSgErgP}{\textipa{kom}}
# \newcommand{\indSgErgG}{IND\blanc{-SG-ERG}}
# \newcommand{\indSgAbs}{\strutgb{0pt}\grapho{hk}}
# \newcommand{\indSgAbsP}{\textipa{kok}}
# \newcommand{\indSgAbsG}{IND\blanc{-SG-ABS}}
# \newcommand{\indPlDat}{\strutgb{0pt}\grapho{ct}}
# \newcommand{\indPlDatP}{\textipa{kit}}
# \newcommand{\indPlDatG}{IND\blanc{-PL-DAT}}
# \newcommand{\indPlObl}{\strutgb{0pt}\grapho{ck}}
# \newcommand{\indPlOblP}{\textipa{kig}}
# \newcommand{\indPlOblG}{IND\blanc{-PL-OBL}}
# \newcommand{\indPlErg}{\strutgb{0pt}\grapho{cm}}
# \newcommand{\indPlErgP}{\textipa{kim}}
# \newcommand{\indPlErgG}{IND\blanc{-PL-ERG}}
# \newcommand{\indPlAbs}{\strutgb{0pt}\grapho{ck}}
# \newcommand{\indPlAbsP}{\textipa{kik}}
# \newcommand{\indPlAbsG}{IND\blanc{-PL-ABS}}
# \newcommand{\demDuDat}{\strutgb{0pt}\grapho{rt}}
# \newcommand{\demDuDatP}{\textipa{lat}}
# \newcommand{\demDuDatG}{DEM\blanc{-DU-DAT}}
# \newcommand{\demDuObl}{\strutgb{0pt}\grapho{rk}}
# \newcommand{\demDuOblP}{\textipa{lag}}
# \newcommand{\demDuOblG}{DEM\blanc{-DU-OBL}}
# \newcommand{\demDuErg}{\strutgb{0pt}\grapho{rm}}
# \newcommand{\demDuErgP}{\textipa{lam}}
# \newcommand{\demDuErgG}{DEM\blanc{-DU-ERG}}
# \newcommand{\demDuAbs}{\strutgb{0pt}\grapho{rk}}
# \newcommand{\demDuAbsP}{\textipa{lak}}
# \newcommand{\demDuAbsG}{DEM\blanc{-DU-ABS}}
# \newcommand{\demSgDat}{\strutgb{0pt}\grapho{Ut}}
# \newcommand{\demSgDatP}{\textipa{lot}}
# \newcommand{\demSgDatG}{DEM\blanc{-SG-DAT}}
# \newcommand{\demSgObl}{\strutgb{0pt}\grapho{Uk}}
# \newcommand{\demSgOblP}{\textipa{log}}
# \newcommand{\demSgOblG}{DEM\blanc{-SG-OBL}}
# \newcommand{\demSgErg}{\strutgb{0pt}\grapho{Um}}
# \newcommand{\demSgErgP}{\textipa{lom}}
# \newcommand{\demSgErgG}{DEM\blanc{-SG-ERG}}
# \newcommand{\demSgAbs}{\strutgb{0pt}\grapho{Uk}}
# \newcommand{\demSgAbsP}{\textipa{lok}}
# \newcommand{\demSgAbsG}{DEM\blanc{-SG-ABS}}
# \newcommand{\demPlDat}{\strutgb{0pt}\grapho{Ot}}
# \newcommand{\demPlDatP}{\textipa{lit}}
# \newcommand{\demPlDatG}{DEM\blanc{-PL-DAT}}
# \newcommand{\demPlObl}{\strutgb{0pt}\grapho{Ok}}
# \newcommand{\demPlOblP}{\textipa{lig}}
# \newcommand{\demPlOblG}{DEM\blanc{-PL-OBL}}
# \newcommand{\demPlErg}{\strutgb{0pt}\grapho{Om}}
# \newcommand{\demPlErgP}{\textipa{lim}}
# \newcommand{\demPlErgG}{DEM\blanc{-PL-ERG}}
# \newcommand{\demPlAbs}{\strutgb{0pt}\grapho{Ok}}
# \newcommand{\demPlAbsP}{\textipa{lik}}
# \newcommand{\demPlAbsG}{DEM\blanc{-PL-ABS}}
#
#
#
# \newcommand{\DANS}{\strutgb{0pt}\grapho{kr}}
# \newcommand{\DANSP}{\textipa{kal}}
# \newcommand{\DANSG}{DANS}
# \newcommand{\SUR}{\strutgb{0pt}\grapho{rp}}
# \newcommand{\SURP}{\textipa{lab}}
# \newcommand{\SURG}{SUR}
# \newcommand{\AVEC}{\strutgb{0pt}\grapho{pk}}
# \newcommand{\AVECP}{\textipa{bak}}
# \newcommand{\AVECG}{AVEC}
# \newcommand{\DE}{\strutgb{0pt}\grapho{Yr}}
# \newcommand{\DEP}{\textipa{sil}}
# \newcommand{\DEG}{DE}
# \newcommand{\SOUS}{\strutgb{0pt}\grapho{jn}}
# \newcommand{\SOUSP}{\textipa{jan}}
# \newcommand{\SOUSG}{SOUS}
# \newcommand{\A}{\strutgb{0pt}\grapho{Sd}}
# \newcommand{\AP}{\textipa{sed}}
# \newcommand{\AG}{A}
# \newcommand{\DEVANT}{\strutgb{0pt}\grapho{xr}}
# \newcommand{\DEVANTP}{\textipa{dul}}
# \newcommand{\DEVANTG}{DEVANT}
# \newcommand{\POUR}{\strutgb{0pt}\grapho{rn}}
# \newcommand{\POURP}{\textipa{laN}}
# \newcommand{\POURG}{POUR}

# %%
#################################################
#################################################
#################################################
##
##
##	FAIRE LE TRI DES FORMES UTILISEES DANS LES PHRASES
##	AFFICHER DANS LES TABLEAUX SEULEMENT CES FORMES
##
##
#################################################
################################################
#
#
#	FAIRE LA LISTE DES PHRASES AVEC LES 4 LIGNES
#		GRAPHO, PHONO, GLOSE, TRAD
#
#
################################################
texte=[]
graphies={}
abs_genre=""
abs_nombre=""

# %%
if debug:
    for forme in base.keys():
        print forme, base[forme]
if print_phrases:
    comment=""
else:
    comment="%"
print comment+"\\begin{exe}"
for line in phrase_file:
    phrase=[0 for i in range(len(syntagmes['Phrase']))]
    #
    # Insertion du replace("'"," ") pour la gestion des articles élidés en français
    #
    tampon=(line.strip().rstrip('.')).replace("'"," ").split("\t")
    if not tampon[0].startswith("#"):
        verbe=tampon[1].split(" ")
        if debug: print "verbe :", verbe
        if categorie_v[verbe[0]] == "VI":
            suj_cas="ABS"
        else:
            suj_cas="ERG"
            obj_cas="ABS"
        suj_genre="A"
        suj_nombre="SG"
        obj_genre="A"
        obj_nombre="SG"
        sujet=tampon[0].strip().split(" ")
        phrase[syntagmes['Phrase'].index('SUJ')]=faire_gn(sujet,suj_cas)
        if debug: print "sujet :",phrase[1]
# 		verbe=tampon[1].split(" ")
# 		if debug: print "verbe :", verbe
        if len(tampon)>=3:
            objet=tampon[2].split(" ")
            if debug: print "objet : ",objet
            if objet!=['']: phrase[syntagmes['Phrase'].index('OBJ')]=faire_gn(objet,obj_cas)
        if len(tampon)>=4:
            indirect=tampon[3].split(" ")
            if debug: print "indirect : ",indirect
            if indirect!=['']: phrase[syntagmes['Phrase'].index('IND')]=faire_gp(indirect)
        #if len(tampon)>=4:
        #	indirect=tampon[3].split(" ")
        #	if indirect!=['']: phrase[2]=faire_gp(indirect)
        if len(tampon)>=5:
            ajout=tampon[4].split(" ")
            phrase[syntagmes['Phrase'].index('AJOUT')]=faire_gp(ajout)
#		glose=faire_glose(base[verbe[0]],suj_genre,suj_num)
#		if debug: print verbe[0],categorie_v[verbe[0]], temps_v[verbe[0]], suj_genre, suj_nombre
#		glose="\\"+base[verbe[0]]+categorie_v[verbe[0]].capitalize()+temps_v[verbe[0]].capitalize()+suj_genre.capitalize()+suj_nombre.capitalize()
#  		if categorie_v[verbe[0]] == "VI":
#  			glose="\\"+base[verbe[0]]+categorie_v[verbe[0]].capitalize()+temps_v[verbe[0]].capitalize()+suj_genre.capitalize()+suj_nombre.capitalize()
#  		else:
        glose="\\"+base[verbe[0]]+categorie_v[verbe[0]].capitalize()+temps_v[verbe[0]].capitalize()+abs_genre.capitalize()+abs_nombre.capitalize()
        phrase[syntagmes['Phrase'].index('V')]=glose
        texte.append(glose)
        if print_glose:
            print comment+"\\ex\\glll"
        else:
            print comment+"\\ex\\gll"
        print comment,
        for mot in phrase:
            if mot!=0:
                printflat(mot,"{}")
        print "\\\\"
        print comment,
        for mot in phrase:
            if mot!=0:
                printflat(mot,"P{}")
        print "\\\\"
        if print_glose:
            print comment,
            for mot in phrase:
                if mot!=0:
                    printflat(mot,"G{}")
            print "\\\\"
        traduction=(line.strip().rstrip('.')).split()
        start=1
        sys.stdout.write(comment)
        for element in traduction:			# convertir les S majuscules à la finale des mots en minuscules
            if element!="":
                if start:
                    start=0
                    element=element.capitalize()
                else:
                    sys.stdout.write(' ')
                caracteres=list(element)
                if caracteres[len(caracteres)-1]=='S':
                    caracteres[len(caracteres)-1]='s'
                sys.stdout.write("".join(caracteres))
        sys.stdout.write('.\r')
        if print_coffee and random.randint(1,6)==1:
            stain=random.choice(["A","B"])
            alpha=random.random()/1.5
            angle=random.randint(0,360)
            xoff=random.randint(-200,0)
            sys.stdout.write('\\\\\\cofe%sm{%.3f}{1}{%d}{%d}{0}' % (stain,alpha,angle,xoff))
print comment+"\\end{exe}"
    
phrase_file.close()
# Out:
# \begin{exe}
# \ex\gll
#    \defSgErg{}   \chasseurCSgErg{}    \indSgDat{}   \NicoleBSgDat{}   \indSgAbs{}   \coyoteCSgAbs{}  \offrirVdPstCSg{} \\
#     \defPlOblP{}   \grosPlBP{}   \noirPlBP{}   \coussinBPlOblP{}   \SURP{}   \defPlErgP{}   \troisPlBP{}   \maigrePlBP{}   \autrucheBPlErgP{}   \indPlAbsP{}   \blancPlCP{}   \oeufCPlAbsP{}  \donnerVdPstCPlP{} \\
# \ex\gll
#     \defPlObl{}   \chasseurCPlObl{}   \AVEC{}   \demDuErg{}   \infirmiereADuErg{}   \indSgAbs{}   \cafeCSgAbs{}  \boireVtPrsCSg{} \\
#     \defPlOblP{}   \chasseurCPlOblP{}   \AVECP{}   \demDuErgP{}   \infirmiereADuErgP{}   \indSgAbsP{}   \cafeCSgAbsP{}  \boireVtPrsCSgP{} \\
# \ex\gll
#    \indSgErg{}   \petitSgC{}   \filleCSgErg{}    \defSgDat{}   \grosSgC{}   \coyoteCSgDat{}   \indDuAbs{}   \viandeADuAbs{}  \lancerVdPrsADu{} \\
#    \indSgErgP{}   \petitSgCP{}   \filleCSgErgP{}    \defSgDatP{}   \grosSgCP{}   \coyoteCSgDatP{}   \indDuAbsP{}   \viandeADuAbsP{}  \lancerVdPrsADuP{} \\
# \end{exe}

# %%
#################################################
if ('options' in globals() and options.print_cloze) or print_racines:
    tableau_racines_n=[]
    tableau_racines_v=[]
    print
    print
    print
    print "%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%RACINES%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%"
    print
    print
    print
    print "%										NOMS"
    print
    for element in sorted(radical_n.keys()):
        tableau_racines_n.append("%s & %s & \\textipa{%s} & \\textipa{%s} \\\\" % (element, radical_n[element][2], radical_n[element][0], radical_n[element][1]))
    print_tableaux(2,tableau_racines_n,"",0,(head_n,tail,"%"))	
    print
    print
    print
    print "%										VERBES"	
    print
    for element in sorted(radical_v.keys()):
        tableau_racines_v.append("%s & %s & \\textipa{%s} \\\\" % (element, radical_v[element][1], radical_v[element][0]))
    print_tableaux(2,tableau_racines_v,"",0,(head_v,tail,"%"))

# %%
if ('options' in globals() and options.print_cloze) or print_lexique:
    tab=(head,tail,"")
else:
    tab=(head,tail,"%")
print tab[2]+"\\begin{itemize}"
print tab[2]+"\\item NOMS\\\\[-3ex]"
print_tableaux(2,tableau_noms,texte,21,tab)
print tab[2]+"\\item ADJECTIFS\\\\[-3ex]"
print_tableaux(3,tableau_adjectifs,texte,4,tab)
print tab[2]+"\\item VERBES\\\\[-3ex]"
print_tableaux(2,tableau_verbes,texte,35,tab)
print tab[2]+"\\item DETERMINANTS\\\\[-3ex]"
print_tableaux(3,tableau_determinants,texte,12,tab)
print tab[2]+"\\item PREPOSITIONS\\\\[-3ex]"
print_tableaux(3,tableau_prepositions,texte,0,tab)
print tab[2]+"\\end{itemize}"
# Out:
# %\begin{itemize}
# %\item NOMS\\[-3ex]
# %\begin{multicols}{2}
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\KatishaASgDat & \KatishaASgDatP & \\
# %\KatishaASgObl & \KatishaASgOblP & \\
# %\KatishaASgErg & \KatishaASgErgP & \\
# %\viandeADuAbs & \viandeADuAbsP & \\
# %\viandeASgAbs & \viandeASgAbsP & \\
# %\viandeAPlAbs & \viandeAPlAbsP & \\
# %\chambreBPlObl & \chambreBPlOblP & \\
# %\chambreBPlErg & \chambreBPlErgP & \\
# %\theBSgErg & \theBSgErgP & \\
# %\theBSgAbs & \theBSgAbsP & \\
# %\theBPlAbs & \theBPlAbsP & \\
# %\chasseurCDuDat & \chasseurCDuDatP & \\
# %\chasseurCDuObl & \chasseurCDuOblP & \\
# %\chasseurCDuErg & \chasseurCDuErgP & \\
# %\chasseurCDuAbs & \chasseurCDuAbsP & \\
# %\chasseurCSgObl & \chasseurCSgOblP & \\
# %\chasseurCSgErg & \chasseurCSgErgP & \\
# %\chasseurCSgAbs & \chasseurCSgAbsP & \\
# %\chasseurCPlDat & \chasseurCPlDatP & \\
# %\chasseurCPlObl & \chasseurCPlOblP & \\
# %\chasseurCPlErg & \chasseurCPlErgP & \\
# %\chasseurCPlAbs & \chasseurCPlAbsP & \\
# %\filleCDuDat & \filleCDuDatP & \\
# %\filleCDuObl & \filleCDuOblP & \\
# %\filleCDuErg & \filleCDuErgP & \\
# %\filleCDuAbs & \filleCDuAbsP & \\
# %\filleCSgObl & \filleCSgOblP & \\
# %\filleCSgErg & \filleCSgErgP & \\
# %\filleCSgAbs & \filleCSgAbsP & \\
# %\filleCPlDat & \filleCPlDatP & \\
# %\filleCPlObl & \filleCPlOblP & \\
# %\filleCPlErg & \filleCPlErgP & \\
# %\filleCPlAbs & \filleCPlAbsP & \\
# %\oeufCDuObl & \oeufCDuOblP & \\
# %\oeufCDuErg & \oeufCDuErgP & \\
# %\oeufCDuAbs & \oeufCDuAbsP & \\
# %\oeufCSgAbs & \oeufCSgAbsP & \\
# %\oeufCPlAbs & \oeufCPlAbsP & \\
# %\cafeCDuAbs & \cafeCDuAbsP & \\
# %\cafeCSgAbs & \cafeCSgAbsP & \\
# %\cafeCPlAbs & \cafeCPlAbsP & \\
# %\coyoteCDuErg & \coyoteCDuErgP & \\
# %\hline\end{tabular}\\
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\coyoteCDuAbs & \coyoteCDuAbsP & \\
# %\coyoteCSgDat & \coyoteCSgDatP & \\
# %\coyoteCSgAbs & \coyoteCSgAbsP & \\
# %\coyoteCPlDat & \coyoteCPlDatP & \\
# %\coyoteCPlObl & \coyoteCPlOblP & \\
# %\coyoteCPlErg & \coyoteCPlErgP & \\
# %\coyoteCPlAbs & \coyoteCPlAbsP & \\
# %\villageCSgObl & \villageCSgOblP & \\
# %\NabilDSgDat & \NabilDSgDatP & \\
# %\NabilDSgObl & \NabilDSgOblP & \\
# %\NabilDSgErg & \NabilDSgErgP & \\
# %\NabilDSgAbs & \NabilDSgAbsP & \\
# %\garconDDuObl & \garconDDuOblP & \\
# %\garconDDuErg & \garconDDuErgP & \\
# %\garconDDuAbs & \garconDDuAbsP & \\
# %\garconDSgDat & \garconDSgDatP & \\
# %\garconDSgErg & \garconDSgErgP & \\
# %\garconDSgAbs & \garconDSgAbsP & \\
# %\blancSgC & \blancSgCP & \\
# %\blancSgB & \blancSgBP & \\
# %\blancSgD & \blancSgDP & \\
# %\blancPlC & \blancPlCP & \\
# %\blancPlB & \blancPlBP & \\
# %\blancPlD & \blancPlDP & \\
# %\noirDuC & \noirDuCP & \\
# %\noirSgC & \noirSgCP & \\
# %\noirSgB & \noirSgBP & \\
# %\hline\end{tabular}\\
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\noirSgD & \noirSgDP & \\
# %\noirPlC & \noirPlCP & \\
# %\noirPlB & \noirPlBP & \\
# %\noirPlD & \noirPlDP & \\
# %\basSgD & \basSgDP & \\
# %\grosDuC & \grosDuCP & \\
# %\grosDuB & \grosDuBP & \\
# %\grosDuD & \grosDuDP & \\
# %\grosSgC & \grosSgCP & \\
# %\grosSgB & \grosSgBP & \\
# %\grosSgD & \grosSgDP & \\
# %\grosPlC & \grosPlCP & \\
# %\grosPlB & \grosPlBP & \\
# %\maigreDuC & \maigreDuCP & \\
# %\maigreSgD & \maigreSgDP & \\
# %\maigrePlC & \maigrePlCP & \\
# %\maigrePlB & \maigrePlBP & \\
# %\hline\end{tabular}\\
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\maigrePlD & \maigrePlDP & \\
# %\jauneDuA & \jauneDuAP & \\
# %\jauneDuC & \jauneDuCP & \\
# %\jauneDuD & \jauneDuDP & \\
# %\jauneSgA & \jauneSgAP & \\
# %\jauneSgD & \jauneSgDP & \\
# %\jaunePlA & \jaunePlAP & \\
# %\jaunePlC & \jaunePlCP & \\
# %\rougeSgD & \rougeSgDP & \\
# %\rougePlA & \rougePlAP & \\
# %\rougePlB & \rougePlBP & \\
# %\troisPlC & \troisPlCP & \\
# %\troisPlB & \troisPlBP & \\
# %\troisPlD & \troisPlDP & \\
# %\quatrePlA & \quatrePlAP & \\
# %\quatrePlC & \quatrePlCP & \\
# %\hline\end{tabular}\\
# %\end{multicols}
# %\item VERBES\\[-3ex]
# %\begin{multicols}{2}
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\mangerVtPrsCDu & \mangerVtPrsCDuP & \\
# %\mangerVtPrsCSg & \mangerVtPrsCSgP & \\
# %\mangerVtPrsCPl & \mangerVtPrsCPlP & \\
# %\mangerVtPrsBDu & \mangerVtPrsBDuP & \\
# %\mangerVtPrsBPl & \mangerVtPrsBPlP & \\
# %\mangerVtPstAPl & \mangerVtPstAPlP & \\
# %\mangerVtPstCDu & \mangerVtPstCDuP & \\
# %\mangerVtPstBSg & \mangerVtPstBSgP & \\
# %\boireVtPrsCDu & \boireVtPrsCDuP & \\
# %\boireVtPrsCSg & \boireVtPrsCSgP & \\
# %\boireVtPrsCPl & \boireVtPrsCPlP & \\
# %\boireVtPrsBSg & \boireVtPrsBSgP & \\
# %\arriverViPrsAPl & \arriverViPrsAPlP & \\
# %\arriverViPrsCDu & \arriverViPrsCDuP & \\
# %\arriverViPrsBSg & \arriverViPrsBSgP & \\
# %\arriverViPrsBPl & \arriverViPrsBPlP & \\
# %\arriverViPrsDSg & \arriverViPrsDSgP & \\
# %\arriverViPrsDPl & \arriverViPrsDPlP & \\
# %\arriverViPstCDu & \arriverViPstCDuP & \\
# %\arriverViPstBSg & \arriverViPstBSgP & \\
# %\arriverViPstBPl & \arriverViPstBPlP & \\
# %\entrerViPrsADu & \entrerViPrsADuP & \\
# %\entrerViPrsCSg & \entrerViPrsCSgP & \\
# %\hline\end{tabular}\\
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\entrerViPrsBSg & \entrerViPrsBSgP & \\
# %\donnerVdPrsASg & \donnerVdPrsASgP & \\
# %\donnerVdPrsAPl & \donnerVdPrsAPlP & \\
# %\donnerVdPrsCSg & \donnerVdPrsCSgP & \\
# %\donnerVdPrsBDu & \donnerVdPrsBDuP & \\
# %\donnerVdPrsDPl & \donnerVdPrsDPlP & \\
# %\donnerVdPstAPl & \donnerVdPstAPlP & \\
# %\donnerVdPstCPl & \donnerVdPstCPlP & \\
# %\donnerVdPstBPl & \donnerVdPstBPlP & \\
# %\donnerVdPstDSg & \donnerVdPstDSgP & \\
# %\offrirVdPrsAPl & \offrirVdPrsAPlP & \\
# %\offrirVdPrsDSg & \offrirVdPrsDSgP & \\
# %\offrirVdPstCSg & \offrirVdPstCSgP & \\
# %\offrirVdPstBDu & \offrirVdPstBDuP & \\
# %\offrirVdPstBPl & \offrirVdPstBPlP & \\
# %\hline\end{tabular}\\
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\lancerVdPrsADu & \lancerVdPrsADuP & \\
# %\lancerVdPrsASg & \lancerVdPrsASgP & \\
# %\lancerVdPrsCSg & \lancerVdPrsCSgP & \\
# %\lancerVdPstASg & \lancerVdPstASgP & \\
# %\lancerVdPstCPl & \lancerVdPstCPlP & \\
# %\lancerVdPstBSg & \lancerVdPstBSgP & \\
# %\montrerVdPrsASg & \montrerVdPrsASgP & \\
# %\montrerVdPrsCPl & \montrerVdPrsCPlP & \\
# %\montrerVdPrsDSg & \montrerVdPrsDSgP & \\
# %\montrerVdPstCSg & \montrerVdPstCSgP & \\
# %\montrerVdPstBSg & \montrerVdPstBSgP & \\
# %\montrerVdPstBPl & \montrerVdPstBPlP & \\
# %\montrerVdPstDSg & \montrerVdPstDSgP & \\
# %\hline\end{tabular}\\
# %\end{multicols}
# %\item DETERMINANTS\\[-3ex]
# %\begin{multicols}{3}
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\defDuDat & \defDuDatP & \\
# %\defDuObl & \defDuOblP & \\
# %\defDuErg & \defDuErgP & \\
# %\defDuAbs & \defDuAbsP & \\
# %\defSgDat & \defSgDatP & \\
# %\defSgObl & \defSgOblP & \\
# %\defSgErg & \defSgErgP & \\
# %\defSgAbs & \defSgAbsP & \\
# %\defPlDat & \defPlDatP & \\
# %\defPlObl & \defPlOblP & \\
# %\defPlErg & \defPlErgP & \\
# %\defPlAbs & \defPlAbsP & \\
# %\hline\end{tabular}\\
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\indDuDat & \indDuDatP & \\
# %\indDuObl & \indDuOblP & \\
# %\indDuErg & \indDuErgP & \\
# %\indDuAbs & \indDuAbsP & \\
# %\indSgDat & \indSgDatP & \\
# %\indSgObl & \indSgOblP & \\
# %\indSgErg & \indSgErgP & \\
# %\indSgAbs & \indSgAbsP & \\
# %\indPlDat & \indPlDatP & \\
# %\indPlObl & \indPlOblP & \\
# %\indPlErg & \indPlErgP & \\
# %\indPlAbs & \indPlAbsP & \\
# %\hline\end{tabular}\\
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\demDuDat & \demDuDatP & \\
# %\demDuObl & \demDuOblP & \\
# %\demDuErg & \demDuErgP & \\
# %\demDuAbs & \demDuAbsP & \\
# %\demSgDat & \demSgDatP & \\
# %\demSgObl & \demSgOblP & \\
# %\demSgErg & \demSgErgP & \\
# %\demSgAbs & \demSgAbsP & \\
# %\demPlDat & \demPlDatP & \\
# %\demPlObl & \demPlOblP & \\
# %\demPlErg & \demPlErgP & \\
# %\demPlAbs & \demPlAbsP & \\
# %\hline\end{tabular}\\
# %\end{multicols}
# %\item PREPOSITIONS\\[-3ex]
# %\begin{multicols}{3}
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\DANS & \DANSP & \\
# %\SUR & \SURP & \\
# %\AVEC & \AVECP & \\
# %\hline\end{tabular}\\
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\DE & \DEP & \\
# %\SOUS & \SOUSP & \\
# %\DEVANT & \DEVANTP & \\
# %\hline\end{tabular}\\
# %\begin{tabular}[t]{|l|l|l|}
# %\addlinespace[-1.0em]\hline
# %Mot & Roman & Glose  \\
# %\hline\strutgh{14pt}%
# %\POUR & \POURP & \\
# %\hline\end{tabular}\\
# %\end{multicols}
# %\end{itemize}

# %%
if ('options' in globals() and options.print_cloze) or print_cloze:
    print
    print
    print
    print "%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%CLOZE%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%"
    print
    print
    print
    print "%										NOMS"	
    for element in cloze_noms:
        print "% ", element[0].translate(toipa)+";"+element[1]
    print
    print
    print
    print "%										VERBES"	
    for element in cloze_verbes:
        print "% ", element[0].translate(toipa)+";"+element[1]
