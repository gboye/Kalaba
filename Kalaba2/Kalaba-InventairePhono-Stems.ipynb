# %%
# %store -r numerosKalaba
# numerosKalaba=[5]
numeroKalaba="20-K%d"%numerosKalaba[0]
print numeroKalaba
# Out:
# 20-K2

# %%
# -*- coding: utf8 -*-
from os.path import expanduser
# -*- coding: utf8 -*-
home = expanduser("~")
serie=home+"/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/%s/"%numeroKalaba

nomStems=serie+"Stems.yaml"
debug=False

# %%
#########################IMPORTS############################################
import codecs, optparse
import re, random
import sys,os,time
import string
import yaml, warnings
import ParFuMor as PFM
from ParFuMor import *
import pickle
import pandas as pd

# %%
with open(serie+"Stems.yaml", 'r') as stream:
    stems=yaml.load(stream)
with open(serie+"MorphoSyntax.yaml", 'r') as stream:
    morphosyntax=yaml.safe_load(stream)
with open(serie+"Lexique-S2.pkl", 'rb') as input:
    PFM.lexique = pickle.load(input)
    
contractions=morphosyntax["Contractions"]
for contraction in contractions:
    temp=[]
    for element in contractions[contraction]:
        if isinstance(element,unicode):
            temp.append(element)
        else:
            temp.append(element.decode("utf8"))
    contractions[contraction]=temp
print contractions
# Out:
# {'aux': [u'\xe0', u'les'], 'du': [u'de', u'le'], 'des': [u'de', u'les'], 'au': [u'\xe0', u'le'], 'd': [u'de']}

# %%
phonemes={}
radicaux=[]

def printStems(c,dictC):
    if isinstance(dictC[c],dict):
        for cLocal in dictC[c]:
            printStems(cLocal,dictC[c])
    else:
        print c
        radicaux.append(c)
        for l in c:
            if l not in phonemes:
                phonemes[l]=0
            phonemes[l]+=1
            
#        for e in dictC[c]:
#            print "\t",e
    return

for cat in stems:
    printStems(cat,stems)
# Out:
# geNamoS
# gadin
# mureT
# numoT
# soret
# kazow
# jumip
# webinir
# sejen
# wobam
# gavijaz
# Sazup
# Sogeges
# jeZugiN
# buZuw
# limap
# jivoN
# fider
# pilaS
# k
# l
# b
# DuZeb
# NunaTas
# deven
# bigin
# ZevoT
# sodep
# juNoleg
# riwef
# puwak
# neZufik
# SoDim
# viDibaN
# NupiS
# Tezok
# jiDaf
# Dadojar
# murefil
# poSub
# gumeZ
# Nurenuf
# geZuNub
# ZeDej
# zibudol
# Nawusat
# toviral
# mawas
# sowoT
# daTeS
# Tagas
# sovoT
# NeZor
# seDep
# jaZap
# Navum
# navap
# Zebaf
# wudan
# taZum
# kom
# laj
# DoDi
# Tow
# DeNu
# feS
# tun
# zazo
# ruZe
# doS
# poz
# zuDun
# TaSum
# Sigobul
# Dupov
# TuziT
# povir
# pezej
# fuZiTes
# sadimel
# veguvoj
# rovujez
# vudegab
# TeNiT
# kaleb
# dujog
# Zager
# TiledaS
# vjolet
# lunogil
# dotus
# TeniS
# guwar
# liNaT
# jebof
# taDaSu
# Dazep
# modus
# vofub
# mosoN
# giNej
# meliT
# nijeT
# bubuS
# mugit
# wanozul
# moSan
# maira
# NeTim
# jirud
# nikol
# Negeg
# dosuno
# vowet
# palok
# muZapaj
# katiSa
# DomeZ
# bivas
# NaTiN
# mubeD
# bivon
# nabil
# madat
# rejav
# Togoniw
# vodun
# naTuS
# tuvej
# nagek
# wopaj
# paZov
# kuDaN
# Difib
# vadoS
# figoT
# fezil

# %%
for p in "ptkbdgmnNfTsSvDzZrljwiueoa":
    print p,phonemes[p]
if len(radicaux)!=len(set(radicaux)):
    print "duplicate"
# print "\n".join(sorted(radicaux))
# Out:
# p 20
# t 13
# k 12
# b 23
# d 20
# g 25
# m 26
# n 26
# N 22
# f 14
# T 26
# s 18
# S 20
# v 25
# D 18
# z 15
# Z 18
# r 18
# l 22
# j 24
# w 16
# i 51
# u 57
# e 61
# o 57
# a 66

# %%
def compterLexique(exemplesPhrases):
    debug=0
    lexiquePhrases={}
    lexiqueComptes={}
    for nExemple,exemple in enumerate(exemplesPhrases):
        nPhrase=nExemple+1
        motsExemple=[mot for mot in re.split(ur"[\s',]",exemple) if mot!=""]
        for mot in motsExemple:
            if mot in PFM.lexique.formeLexeme:
                lexeme=PFM.lexique.formeLexeme[mot][0]
                if not lexeme in lexiqueComptes: lexiqueComptes[lexeme]=0
                lexiqueComptes[lexeme]+=1
                if not lexeme in lexiquePhrases: lexiquePhrases[lexeme]=set()
                lexiquePhrases[lexeme].add(nPhrase)
                if debug: print lexeme,
            elif mot in contractions:
                for element in contractions[mot]:
                    lexeme=PFM.lexique.formeLexeme[element][0]
                    if not lexeme in lexiqueComptes: lexiqueComptes[lexeme]=0
                    lexiqueComptes[lexeme]+=1
                    if not lexeme in lexiquePhrases: lexiquePhrases[lexeme]=set()
                    lexiquePhrases[lexeme].add(nPhrase)
                    if debug: print lexeme,
            else:
                lexeme=u"#%s#"%mot
                if not lexeme in lexiqueComptes: lexiqueComptes[lexeme]=0
                lexiqueComptes[lexeme]+=1
                if not lexeme in lexiquePhrases: lexiquePhrases[lexeme]=set()
                lexiquePhrases[lexeme].add(nPhrase)
                if debug: print lexeme,
        if debug: print
    return lexiqueComptes,lexiquePhrases

# %%
def stripLex(lex):
    return lex.strip("#")

# %%
def printLexPhrases(lexPhrases):
    for lex in sorted(lexPhrases.keys()):
        print stripLex(lex.split(".")[0]),", ".join(["(%d)"%num for num in sorted(lexPhrases[lex])])

# %%
def printLexComptes(lexComptes):
    for lex in sorted(lexComptes, key=lexComptes.get,reverse=True):
        print stripLex(lex.split(".")[0]), lexComptes[lex]

# %%
dfLexComptes=[]
phrasesFichiers=["Phrases","Ordre","Traductions"]
complementPhrases=""

# %%
for nFichier,locFichier in enumerate(phrasesFichiers):
    fichier=serie+complementPhrases+locFichier+".csv"
    with codecs.open(fichier, 'r', encoding="utf8") as input:
       exemplesPhrases = input.readlines()
    exemplesPhrases=[exemple.strip().strip(".") for exemple in exemplesPhrases if not exemple.startswith("#")]
    lexComptes, lexPhrases=compterLexique(exemplesPhrases)
    print fichier
    dfLexComptes.append(pd.DataFrame.from_dict(lexComptes,orient="index"))
    dfLexComptes[nFichier].columns=[locFichier]
    dfLexComptes[nFichier]["lexeme"]=dfLexComptes[nFichier].index
    dfLexComptes[nFichier]=dfLexComptes[nFichier][["lexeme",locFichier]]
    if debug:
        print "lexComptes"
        printLexComptes(lexComptes)
        print
        print "lexPhrases"
        printLexPhrases(lexPhrases)
        print
        print
        print
# Out:
# /Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/20-K2/Phrases.csv
# /Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/20-K2/Ordre.csv
# /Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/20-K2/Traductions.csv

# %%
df12=dfLexComptes[0].merge(dfLexComptes[1],how="outer").merge(dfLexComptes[2],how="outer")
df12[pd.notnull(df12["Phrases"])].sort_values(by="Phrases",ascending=False)[["lexeme","Phrases"]]
# Out:
#              lexeme  Phrases
# 47          DEF.ART    248.0
# 26          IND.ART     63.0
# 18               de     53.0
# 53       louve.A.N2     34.0
# 73             dans     30.0
# 55           #deux#     29.0
# 69          DEM.DEM     28.0
# 49        loup.A.N1     26.0
# 50                à     24.0
# 81       Kaleb.A.N2     23.0
# 20    Violette.A.N2     19.0
# 78            petit     18.0
# 79       fille.C.N2     18.0
# 82       lance.C.N1     16.0
# 36      Mahira.C.N2     16.0
# 10             noir     16.0
# 88       corps.A.N2     16.0
# 90            grand     15.0
# 15             vers     14.0
# 76  loup.hyper.B.N2     14.0
# 70     village.B.N2     14.0
# 87        chef.C.N1     13.0
# 89       démon.B.N2     12.0
# 92       forêt.C.N1     12.0
# 45        nuit.B.N1     12.0
# 62             avec     12.0
# 61            blanc     11.0
# 66       prendre.V1     11.0
# 28  combattant.C.N2     11.0
# 23        croc.C.N2     10.0
# ..              ...      ...
# 30          fuir.V1      5.0
# 96          effrayé      4.0
# 16            ENTRE      4.0
# 67      chercher.V1      4.0
# 71           devant      4.0
# 5         sortir.V1      4.0
# 42       ombre.C.N1      4.0
# 14      visage.B.N1      4.0
# 60       chasser.V1      4.0
# 58     serpent.A.N1      4.0
# 56      combat.C.N1      4.0
# 93     recouvrir.V2      4.0
# 0         coup.B.N2      3.0
# 29          furieux      3.0
# 3    transformer.V2      3.0
# 51      colère.A.N1      3.0
# 44        sauter.V2      3.0
# 9         lune.B.N1      3.0
# 17      apporter.V1      3.0
# 75         derrière      2.0
# 19  souffrance.A.N2      2.0
# 77       soeur.A.N1      2.0
# 37      enfant.C.N2      2.0
# 40       dévorer.V2      2.0
# 97        passer.V2      2.0
# 91      milieu.C.N2      1.0
# 13        différent      1.0
# 86           ##et##      1.0
# 7               #;#      1.0
# 63            après      1.0
#
# [98 rows x 2 columns]

# %% [raw]
# df12.to_csv(path_or_buf=nomComptes,sep="\t",encoding="utf8")

# %% [raw]
# nomComptes
