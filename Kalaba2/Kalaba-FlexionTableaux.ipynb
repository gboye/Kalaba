# %%
import glob
import pandas as pd
from unidecode import unidecode
from os.path import expanduser
from cellbell import ding
from IPython.core.display import HTML,display

# %%
debug=0

home = expanduser("~")
repertoire=home+"/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/"
annee="19"
numerosKalabas=[5]
nomKalabas=[repertoire+annee+"-K%d/"%num for num in numerosKalabas]

print "\n".join(nomKalabas)

lexiqueTestPrep=u"dans"
lexiqueTestNoun=u"loups"
lexiqueTestHyper=u"villagEOIs"

nomDeclarationRad="Declarations-Radicaux.tex"
nomDeclarationDec="Declarations-Decoupages.tex"
nomTableauxRad="Tableaux-Gloses.yaml"
nomDeclaration="Declarations.tex"
nomTableaux="Tableaux.yaml"
# Out:
# /Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/

# %%
glob.glob(nomKalabas[0]+"*.txt")
# Out:
# ['/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Traductions-Clozes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Images-Clozes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Syntagmes-Corr.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Syntagmes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/OrdreSyntagmes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Phrases-Clozes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Clozes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Images.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Ordre.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Mots.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Mots-Clozes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Ordre-Clozes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/19-K5/Traductions.txt']

# %%
flexion=pd.read_csv(repertoire+annee+"-K5/"+"Clozes.txt",sep=";",header=None, names=list(range(20)),encoding="utf8").dropna(axis='columns', how='all')
flexion.head()
# Out:
#             0      1    2      3    4           5              6   \
# 0       #\tADJ    NaN  NaN    NaN  NaN         NaN            NaN
# 1            #    NaN  NaN    NaN  NaN         NaN            NaN
# 2            #    NaN  NaN    NaN  NaN         NaN            NaN
# 3  rougeASgErg  rouge  ADJ  miðin  NaN  momiðintes  mo-miðin-te-s
# 4  rougeASgAbs  rouge  ADJ  miðin  NaN   momiðinte    mo-miðin-te
#
#                                          7                     8    9      10  \
# 0                                       NaN                   NaN  NaN    NaN
# 1                                       NaN                   NaN  NaN    NaN
# 2                                       NaN                   NaN  NaN    NaN
# 3  ADJ, CF=A1,  Genre=A, Nombre=Sg, Cas=Erg  A1.A-rouge.A1-Sg-Erg  5.0  A1.A-
# 4  ADJ, CF=A1,  Genre=A, Nombre=Sg, Cas=Abs      A1.A-rouge.A1-Sg  4.0  A1.A-
#
#       11   12   13    14
# 0    NaN  NaN  NaN   NaN
# 1    NaN  NaN  NaN   NaN
# 2    NaN  NaN  NaN   NaN
# 3  rouge  .A1  -Sg  -Erg
# 4  rouge  .A1  -Sg   NaN

# %%
categories=flexion[2].dropna().unique().tolist()
categories
# Out:
# [u'ADJ', u'DET', u'VER', u'PREP', u'NOM']

# %% [markdown]
# bFlex sélectionne les lignes non-vides correspondant à une catégorie

# %%
bFlex={c:(flexion[7].notnull()) & (flexion[2]==c.upper()) for c in categories}
flexion[bFlex["NOM"]]
# Out:
#                   0         1    2      3     4          5   \
# 1899  chasseurASgErg  chasseur  NOM  ramez  rmza   ramzazif
# 1900  chasseurASgAbs  chasseur  NOM  ramez  rmza  koramzazi
# 1901  chasseurASgDat  chasseur  NOM  ramez  rmza   ramzaziʒ
# 1902  chasseurASgObl  chasseur  NOM  ramez  rmza   ramzazip
# 1903  chasseurADuErg  chasseur  NOM  ramez   NaN   ramezzif
# 1904  chasseurADuAbs  chasseur  NOM  ramez   NaN  koramezzi
# 1905  chasseurADuDat  chasseur  NOM  ramez   NaN  ʒoramezzi
# 1906  chasseurADuObl  chasseur  NOM  ramez   NaN   ramezzip
# 1907  chasseurAPlErg  chasseur  NOM  ramez  rmza  zuraʒmazo
# 1908  chasseurAPlAbs  chasseur  NOM  ramez  rmza  koraʒmazo
# 1909  chasseurAPlDat  chasseur  NOM  ramez  rmza  vuraʒmazo
# 1910  chasseurAPlObl  chasseur  NOM  ramez  rmza   raʒmazop
# 1911     foretASgErg     forêt  NOM  sovaʒ  svʒo   sovʒaʒif
# 1912     foretASgAbs     forêt  NOM  sovaʒ  svʒo  kosovʒaʒi
# 1913     foretASgDat     forêt  NOM  sovaʒ  svʒo   sovʒaʒiʒ
# 1914     foretASgObl     forêt  NOM  sovaʒ  svʒo   sovʒaʒip
# 1915     foretADuErg     forêt  NOM  sovaʒ   NaN   sovaʒzif
# 1916     foretADuAbs     forêt  NOM  sovaʒ   NaN  kosovaʒzi
# 1917     foretADuDat     forêt  NOM  sovaʒ   NaN  ʒosovaʒzi
# 1918     foretADuObl     forêt  NOM  sovaʒ   NaN   sovaʒzip
# 1919     foretAPlErg     forêt  NOM  sovaʒ  svʒo  zusoʒvaʒo
# 1920     foretAPlAbs     forêt  NOM  sovaʒ  svʒo  kosoʒvaʒo
# 1921     foretAPlDat     forêt  NOM  sovaʒ  svʒo  vusoʒvaʒo
# 1922     foretAPlObl     forêt  NOM  sovaʒ  svʒo   soʒvaʒop
# 1923     soeurASgErg     soeur  NOM  sanes  snsa   sansasif
# 1924     soeurASgAbs     soeur  NOM  sanes  snsa  kosansasi
# 1925     soeurASgDat     soeur  NOM  sanes  snsa   sansasiʒ
# 1926     soeurASgObl     soeur  NOM  sanes  snsa   sansasip
# 1927     soeurADuErg     soeur  NOM  sanes   NaN   saneszif
# 1928     soeurADuAbs     soeur  NOM  sanes   NaN  kosaneszi
# ...              ...       ...  ...    ...   ...        ...
# 2625     lanceDDuDat     lance  NOM  rijen  rjni  rajfunika
# 2626     lanceDDuObl     lance  NOM  rijen  rjni  murajfuni
# 2627     lanceDPlErg     lance  NOM  rijen  rjni   rijanala
# 2628     lanceDPlAbs     lance  NOM  rijen  rjni   larijana
# 2629     lanceDPlDat     lance  NOM  rijen  rjni   rijanaka
# 2630     lanceDPlObl     lance  NOM  rijen  rjni   murijana
# 2631   cuisineDSgErg   cuisine  NOM  varis   NaN  fovarisla
# 2632   cuisineDSgAbs   cuisine  NOM  varis   NaN    fovaris
# 2633   cuisineDSgDat   cuisine  NOM  varis   NaN  fovariska
# 2634   cuisineDSgObl   cuisine  NOM  varis   NaN  mufovaris
# 2635   cuisineDDuErg   cuisine  NOM  varis  vrsa  vurfusila
# 2636   cuisineDDuAbs   cuisine  NOM  varis  vrsa    vurfusi
# 2637   cuisineDDuDat   cuisine  NOM  varis  vrsa  vurfusika
# 2638   cuisineDDuObl   cuisine  NOM  varis  vrsa  muvurfusi
# 2639   cuisineDPlErg   cuisine  NOM  varis  vrsa   varasala
# 2640   cuisineDPlAbs   cuisine  NOM  varis  vrsa   lavarasa
# 2641   cuisineDPlDat   cuisine  NOM  varis  vrsa   varasaka
# 2642   cuisineDPlObl   cuisine  NOM  varis  vrsa   muvarasa
# 2643    coyoteDSgErg    coyote  NOM  juron   NaN  fojuronla
# 2644    coyoteDSgAbs    coyote  NOM  juron   NaN    fojuron
# 2645    coyoteDSgDat    coyote  NOM  juron   NaN  fojuronka
# 2646    coyoteDSgObl    coyote  NOM  juron   NaN  mufojuron
# 2647    coyoteDDuErg    coyote  NOM  juron  jrnu  jurfunila
# 2648    coyoteDDuAbs    coyote  NOM  juron  jrnu    jurfuni
# 2649    coyoteDDuDat    coyote  NOM  juron  jrnu  jurfunika
# 2650    coyoteDDuObl    coyote  NOM  juron  jrnu  mujurfuni
# 2651    coyoteDPlErg    coyote  NOM  juron  jrnu   juranala
# 2652    coyoteDPlAbs    coyote  NOM  juron  jrnu   lajurana
# 2653    coyoteDPlDat    coyote  NOM  juron  jrnu   juranaka
# 2654    coyoteDPlObl    coyote  NOM  juron  jrnu   mujurana
#
#                             6                                         7   \
# 1899   racine(ramez)x1V23a3i-f  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Erg
# 1900  ko-racine(ramez)x1V23a3i  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Abs
# 1901   racine(ramez)x1V23a3i-ʒ  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Dat
# 1902   racine(ramez)x1V23a3i-p  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Obl
# 1903                ramez-zi-f  NOM, CF=N1,  Genre=A, Nombre=Du, Cas=Erg
# 1904               ko-ramez-zi  NOM, CF=N1,  Genre=A, Nombre=Du, Cas=Abs
# 1905               ʒo-ramez-zi  NOM, CF=N1,  Genre=A, Nombre=Du, Cas=Dat
# 1906                ramez-zi-p  NOM, CF=N1,  Genre=A, Nombre=Du, Cas=Obl
# 1907  zu-racine(ramez)x1Vʒ2a3o  NOM, CF=N1,  Genre=A, Nombre=Pl, Cas=Erg
# 1908  ko-racine(ramez)x1Vʒ2a3o  NOM, CF=N1,  Genre=A, Nombre=Pl, Cas=Abs
# 1909  vu-racine(ramez)x1Vʒ2a3o  NOM, CF=N1,  Genre=A, Nombre=Pl, Cas=Dat
# 1910   racine(ramez)x1Vʒ2a3o-p  NOM, CF=N1,  Genre=A, Nombre=Pl, Cas=Obl
# 1911   racine(sovaʒ)x1V23a3i-f  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Erg
# 1912  ko-racine(sovaʒ)x1V23a3i  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Abs
# 1913   racine(sovaʒ)x1V23a3i-ʒ  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Dat
# 1914   racine(sovaʒ)x1V23a3i-p  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Obl
# 1915                sovaʒ-zi-f  NOM, CF=N1,  Genre=A, Nombre=Du, Cas=Erg
# 1916               ko-sovaʒ-zi  NOM, CF=N1,  Genre=A, Nombre=Du, Cas=Abs
# 1917               ʒo-sovaʒ-zi  NOM, CF=N1,  Genre=A, Nombre=Du, Cas=Dat
# 1918                sovaʒ-zi-p  NOM, CF=N1,  Genre=A, Nombre=Du, Cas=Obl
# 1919  zu-racine(sovaʒ)x1Vʒ2a3o  NOM, CF=N1,  Genre=A, Nombre=Pl, Cas=Erg
# 1920  ko-racine(sovaʒ)x1Vʒ2a3o  NOM, CF=N1,  Genre=A, Nombre=Pl, Cas=Abs
# 1921  vu-racine(sovaʒ)x1Vʒ2a3o  NOM, CF=N1,  Genre=A, Nombre=Pl, Cas=Dat
# 1922   racine(sovaʒ)x1Vʒ2a3o-p  NOM, CF=N1,  Genre=A, Nombre=Pl, Cas=Obl
# 1923   racine(sanes)x1V23a3i-f  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Erg
# 1924  ko-racine(sanes)x1V23a3i  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Abs
# 1925   racine(sanes)x1V23a3i-ʒ  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Dat
# 1926   racine(sanes)x1V23a3i-p  NOM, CF=N1,  Genre=A, Nombre=Sg, Cas=Obl
# 1927                sanes-zi-f  NOM, CF=N1,  Genre=A, Nombre=Du, Cas=Erg
# 1928               ko-sanes-zi  NOM, CF=N1,  Genre=A, Nombre=Du, Cas=Abs
# ...                        ...                                       ...
# 2625  racine(rijen)x1A2fu3i-ka  NOM, CF=N4,  Genre=D, Nombre=Du, Cas=Dat
# 2626  mu-racine(rijen)x1A2fu3i  NOM, CF=N4,  Genre=D, Nombre=Du, Cas=Obl
# 2627   racine(rijen)x1V2a3a-la  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Erg
# 2628   la-racine(rijen)x1V2a3a  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Abs
# 2629   racine(rijen)x1V2a3a-ka  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Dat
# 2630   mu-racine(rijen)x1V2a3a  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Obl
# 2631               fo-varis-la  NOM, CF=N4,  Genre=D, Nombre=Sg, Cas=Erg
# 2632                  fo-varis  NOM, CF=N4,  Genre=D, Nombre=Sg, Cas=Abs
# 2633               fo-varis-ka  NOM, CF=N4,  Genre=D, Nombre=Sg, Cas=Dat
# 2634               mu-fo-varis  NOM, CF=N4,  Genre=D, Nombre=Sg, Cas=Obl
# 2635  racine(varis)x1A2fu3i-la  NOM, CF=N4,  Genre=D, Nombre=Du, Cas=Erg
# 2636     racine(varis)x1A2fu3i  NOM, CF=N4,  Genre=D, Nombre=Du, Cas=Abs
# 2637  racine(varis)x1A2fu3i-ka  NOM, CF=N4,  Genre=D, Nombre=Du, Cas=Dat
# 2638  mu-racine(varis)x1A2fu3i  NOM, CF=N4,  Genre=D, Nombre=Du, Cas=Obl
# 2639   racine(varis)x1V2a3a-la  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Erg
# 2640   la-racine(varis)x1V2a3a  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Abs
# 2641   racine(varis)x1V2a3a-ka  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Dat
# 2642   mu-racine(varis)x1V2a3a  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Obl
# 2643               fo-juron-la  NOM, CF=N4,  Genre=D, Nombre=Sg, Cas=Erg
# 2644                  fo-juron  NOM, CF=N4,  Genre=D, Nombre=Sg, Cas=Abs
# 2645               fo-juron-ka  NOM, CF=N4,  Genre=D, Nombre=Sg, Cas=Dat
# 2646               mu-fo-juron  NOM, CF=N4,  Genre=D, Nombre=Sg, Cas=Obl
# 2647  racine(juron)x1A2fu3i-la  NOM, CF=N4,  Genre=D, Nombre=Du, Cas=Erg
# 2648     racine(juron)x1A2fu3i  NOM, CF=N4,  Genre=D, Nombre=Du, Cas=Abs
# 2649  racine(juron)x1A2fu3i-ka  NOM, CF=N4,  Genre=D, Nombre=Du, Cas=Dat
# 2650  mu-racine(juron)x1A2fu3i  NOM, CF=N4,  Genre=D, Nombre=Du, Cas=Obl
# 2651   racine(juron)x1V2a3a-la  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Erg
# 2652   la-racine(juron)x1V2a3a  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Abs
# 2653   racine(juron)x1V2a3a-ka  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Dat
# 2654   mu-racine(juron)x1V2a3a  NOM, CF=N4,  Genre=D, Nombre=Pl, Cas=Obl
#
#                                     8    9           10        11         12  \
# 1899        chasseur.N1.AxN1.Sg-N1.Erg  4.0    chasseur     .N1.A     xN1.Sg
# 1900        N1.Abs-chasseur.N1.AxN1.Sg  4.0     N1.Abs-  chasseur      .N1.A
# 1901     chasseur.N1.AxN1.Sg-N1.Dat.Sg  4.0    chasseur     .N1.A     xN1.Sg
# 1902        chasseur.N1.AxN1.Sg-N1.Obl  4.0    chasseur     .N1.A     xN1.Sg
# 1903     chasseur.N1.A-N1|N2.Du-N1.Erg  4.0    chasseur     .N1.A  -N1|N2.Du
# 1904     N1.Abs-chasseur.N1.A-N1|N2.Du  4.0     N1.Abs-  chasseur      .N1.A
# 1905  N1.Dat.Du-chasseur.N1.A-N1|N2.Du  4.0  N1.Dat.Du-  chasseur      .N1.A
# 1906     chasseur.N1.A-N1|N2.Du-N1.Obl  4.0    chasseur     .N1.A  -N1|N2.Du
# 1907  N1.Erg.Pl-chasseur.N1.AxN1|N2.Pl  4.0  N1.Erg.Pl-  chasseur      .N1.A
# 1908     N1.Abs-chasseur.N1.AxN1|N2.Pl  4.0     N1.Abs-  chasseur      .N1.A
# 1909  N1.Dat.Pl-chasseur.N1.AxN1|N2.Pl  4.0  N1.Dat.Pl-  chasseur      .N1.A
# 1910     chasseur.N1.AxN1|N2.Pl-N1.Obl  4.0    chasseur     .N1.A  xN1|N2.Pl
# 1911           forêt.N1.AxN1.Sg-N1.Erg  4.0       forêt     .N1.A     xN1.Sg
# 1912           N1.Abs-forêt.N1.AxN1.Sg  4.0     N1.Abs-     forêt      .N1.A
# 1913        forêt.N1.AxN1.Sg-N1.Dat.Sg  4.0       forêt     .N1.A     xN1.Sg
# 1914           forêt.N1.AxN1.Sg-N1.Obl  4.0       forêt     .N1.A     xN1.Sg
# 1915        forêt.N1.A-N1|N2.Du-N1.Erg  4.0       forêt     .N1.A  -N1|N2.Du
# 1916        N1.Abs-forêt.N1.A-N1|N2.Du  4.0     N1.Abs-     forêt      .N1.A
# 1917     N1.Dat.Du-forêt.N1.A-N1|N2.Du  4.0  N1.Dat.Du-     forêt      .N1.A
# 1918        forêt.N1.A-N1|N2.Du-N1.Obl  4.0       forêt     .N1.A  -N1|N2.Du
# 1919     N1.Erg.Pl-forêt.N1.AxN1|N2.Pl  4.0  N1.Erg.Pl-     forêt      .N1.A
# 1920        N1.Abs-forêt.N1.AxN1|N2.Pl  4.0     N1.Abs-     forêt      .N1.A
# 1921     N1.Dat.Pl-forêt.N1.AxN1|N2.Pl  4.0  N1.Dat.Pl-     forêt      .N1.A
# 1922        forêt.N1.AxN1|N2.Pl-N1.Obl  4.0       forêt     .N1.A  xN1|N2.Pl
# 1923           soeur.N1.AxN1.Sg-N1.Erg  4.0       soeur     .N1.A     xN1.Sg
# 1924           N1.Abs-soeur.N1.AxN1.Sg  4.0     N1.Abs-     soeur      .N1.A
# 1925        soeur.N1.AxN1.Sg-N1.Dat.Sg  4.0       soeur     .N1.A     xN1.Sg
# 1926           soeur.N1.AxN1.Sg-N1.Obl  4.0       soeur     .N1.A     xN1.Sg
# 1927        soeur.N1.A-N1|N2.Du-N1.Erg  4.0       soeur     .N1.A  -N1|N2.Du
# 1928        N1.Abs-soeur.N1.A-N1|N2.Du  4.0     N1.Abs-     soeur      .N1.A
# ...                                ...  ...         ...       ...        ...
# 2625        lance.N4.DxN3|N4.Du-N4.Dat  4.0       lance     .N4.D  xN3|N4.Du
# 2626        N4.Obl-lance.N4.DxN3|N4.Du  4.0     N4.Obl-     lance      .N4.D
# 2627        lance.N4.DxN3|N4.Pl-N4.Erg  4.0       lance     .N4.D  xN3|N4.Pl
# 2628     N4.Abs.Pl-lance.N4.DxN3|N4.Pl  4.0  N4.Abs.Pl-     lance      .N4.D
# 2629        lance.N4.DxN3|N4.Pl-N4.Dat  4.0       lance     .N4.D  xN3|N4.Pl
# 2630        N4.Obl-lance.N4.DxN3|N4.Pl  4.0     N4.Obl-     lance      .N4.D
# 2631         N4.Sg-cuisine.N4.D-N4.Erg  4.0      N4.Sg-   cuisine      .N4.D
# 2632                N4.Sg-cuisine.N4.D  3.0      N4.Sg-   cuisine      .N4.D
# 2633         N4.Sg-cuisine.N4.D-N4.Dat  4.0      N4.Sg-   cuisine      .N4.D
# 2634         N4.Obl-N4.Sg-cuisine.N4.D  4.0     N4.Obl-    N4.Sg-    cuisine
# 2635      cuisine.N4.DxN3|N4.Du-N4.Erg  4.0     cuisine     .N4.D  xN3|N4.Du
# 2636             cuisine.N4.DxN3|N4.Du  3.0     cuisine     .N4.D  xN3|N4.Du
# 2637      cuisine.N4.DxN3|N4.Du-N4.Dat  4.0     cuisine     .N4.D  xN3|N4.Du
# 2638      N4.Obl-cuisine.N4.DxN3|N4.Du  4.0     N4.Obl-   cuisine      .N4.D
# 2639      cuisine.N4.DxN3|N4.Pl-N4.Erg  4.0     cuisine     .N4.D  xN3|N4.Pl
# 2640   N4.Abs.Pl-cuisine.N4.DxN3|N4.Pl  4.0  N4.Abs.Pl-   cuisine      .N4.D
# 2641      cuisine.N4.DxN3|N4.Pl-N4.Dat  4.0     cuisine     .N4.D  xN3|N4.Pl
# 2642      N4.Obl-cuisine.N4.DxN3|N4.Pl  4.0     N4.Obl-   cuisine      .N4.D
# 2643          N4.Sg-coyote.N4.D-N4.Erg  4.0      N4.Sg-    coyote      .N4.D
# 2644                 N4.Sg-coyote.N4.D  3.0      N4.Sg-    coyote      .N4.D
# 2645          N4.Sg-coyote.N4.D-N4.Dat  4.0      N4.Sg-    coyote      .N4.D
# 2646          N4.Obl-N4.Sg-coyote.N4.D  4.0     N4.Obl-    N4.Sg-     coyote
# 2647       coyote.N4.DxN3|N4.Du-N4.Erg  4.0      coyote     .N4.D  xN3|N4.Du
# 2648              coyote.N4.DxN3|N4.Du  3.0      coyote     .N4.D  xN3|N4.Du
# 2649       coyote.N4.DxN3|N4.Du-N4.Dat  4.0      coyote     .N4.D  xN3|N4.Du
# 2650       N4.Obl-coyote.N4.DxN3|N4.Du  4.0     N4.Obl-    coyote      .N4.D
# 2651       coyote.N4.DxN3|N4.Pl-N4.Erg  4.0      coyote     .N4.D  xN3|N4.Pl
# 2652    N4.Abs.Pl-coyote.N4.DxN3|N4.Pl  4.0  N4.Abs.Pl-    coyote      .N4.D
# 2653       coyote.N4.DxN3|N4.Pl-N4.Dat  4.0      coyote     .N4.D  xN3|N4.Pl
# 2654       N4.Obl-coyote.N4.DxN3|N4.Pl  4.0     N4.Obl-    coyote      .N4.D
#
#               13   14
# 1899     -N1.Erg  NaN
# 1900      xN1.Sg  NaN
# 1901  -N1.Dat.Sg  NaN
# 1902     -N1.Obl  NaN
# 1903     -N1.Erg  NaN
# 1904   -N1|N2.Du  NaN
# 1905   -N1|N2.Du  NaN
# 1906     -N1.Obl  NaN
# 1907   xN1|N2.Pl  NaN
# 1908   xN1|N2.Pl  NaN
# 1909   xN1|N2.Pl  NaN
# 1910     -N1.Obl  NaN
# 1911     -N1.Erg  NaN
# 1912      xN1.Sg  NaN
# 1913  -N1.Dat.Sg  NaN
# 1914     -N1.Obl  NaN
# 1915     -N1.Erg  NaN
# 1916   -N1|N2.Du  NaN
# 1917   -N1|N2.Du  NaN
# 1918     -N1.Obl  NaN
# 1919   xN1|N2.Pl  NaN
# 1920   xN1|N2.Pl  NaN
# 1921   xN1|N2.Pl  NaN
# 1922     -N1.Obl  NaN
# 1923     -N1.Erg  NaN
# 1924      xN1.Sg  NaN
# 1925  -N1.Dat.Sg  NaN
# 1926     -N1.Obl  NaN
# 1927     -N1.Erg  NaN
# 1928   -N1|N2.Du  NaN
# ...          ...  ...
# 2625     -N4.Dat  NaN
# 2626   xN3|N4.Du  NaN
# 2627     -N4.Erg  NaN
# 2628   xN3|N4.Pl  NaN
# 2629     -N4.Dat  NaN
# 2630   xN3|N4.Pl  NaN
# 2631     -N4.Erg  NaN
# 2632         NaN  NaN
# 2633     -N4.Dat  NaN
# 2634       .N4.D  NaN
# 2635     -N4.Erg  NaN
# 2636         NaN  NaN
# 2637     -N4.Dat  NaN
# 2638   xN3|N4.Du  NaN
# 2639     -N4.Erg  NaN
# 2640   xN3|N4.Pl  NaN
# 2641     -N4.Dat  NaN
# 2642   xN3|N4.Pl  NaN
# 2643     -N4.Erg  NaN
# 2644         NaN  NaN
# 2645     -N4.Dat  NaN
# 2646       .N4.D  NaN
# 2647     -N4.Erg  NaN
# 2648         NaN  NaN
# 2649     -N4.Dat  NaN
# 2650   xN3|N4.Du  NaN
# 2651     -N4.Erg  NaN
# 2652   xN3|N4.Pl  NaN
# 2653     -N4.Dat  NaN
# 2654   xN3|N4.Pl  NaN
#
# [756 rows x 15 columns]

# %% [markdown]
# ### Analyse de la case
# on fait un dict à partir de la case pour éclater en colonne puis faire un pivot_table

# %%
def makeParadigme(row):
    result={}
    parts=row["Case"].split(", ")
    for part in parts[1:]:
        attr,val=part.split("=")
        result[attr.strip()]=val
    return result

# %% [markdown]
# # Tableaux pour une catégorie

# %%
def makeTableaux(cat):
    # sel sélectionne la catégorie cat dans flexion
    # les colonnes 1, 6 et 7 correspondent à la catégorie, la forme et la case
    sel=bFlex[cat]
    lDF=flexion[sel][[1,6,7]]
    lDF.columns=(u"%s Forme Case"%cat).split(" ")
    # on ajoute une colonne avec un dict correspondant à attribut:valeur
    lDF["dCell"]=lDF.apply(makeParadigme,axis=1)
    if lDF.iloc[0]["dCell"]!={}:
        # on éclate le dict attribut:valeur en colonnes
        # on calcule les dimensions du tableau croisé pour pivot_table
        dfCat=pd.concat([lDF.drop(['Case',"dCell"], axis=1), lDF['dCell'].apply(pd.Series)], axis=1)
        setColonnes=set(dfCat.columns.tolist())
        if "Nombre" in setColonnes:
            colonnes="Nombre"
            lignes=setColonnes-set([cat,"Forme","CF","Nombre"])
        elif "Pers" in setColonnes:
            colonnes="Pers"
            lignes=list(setColonnes-set([cat,"Forme","CF","Pers"]))
        if debug: print colonnes, lignes
        # on fait la liste des lexèmes de la catégorie cat
        listCat=dfCat[cat].unique().tolist()
        if debug: display(dfCat.head())
        catTableaux={}
        catCF={}
        cfLexemes={}
        for l in listCat:
            catL=dfCat[dfCat[cat]==l]
            if "CF" in dfCat.columns:
                lCF=catL["CF"].values[0]
                if lCF not in cfLexemes:
                    cfLexemes[lCF]=[]
                cfLexemes[lCF].append(l)
                if lCF not in catCF:
                    catTableaux[lCF]=pd.pivot_table(catL,index=lignes,columns=colonnes,values="Forme", aggfunc='first')
                    if "Sg" in catTableaux[lCF].columns:
                        catTableaux[lCF]=catTableaux[lCF].reindex("Sg Du Pl".split(" "),axis=1)
                    catCF[lCF]=l
            else:
                catCF[l]=None
                catTableaux[l]=pd.pivot_table(catL,index=lignes,columns=colonnes,values="Forme", aggfunc='first').reindex("Sg Du Pl".split(" "),axis=1)
        for t in catTableaux:   
            if debug: display(HTML("<h1>%s, %s</h1>"%(t,catCF[t])),catTableaux[t])
            print t,catCF[t]
            print catTableaux[t].to_latex(multirow=True)
    return catTableaux,cfLexemes

# %%
tableaux={}
classesFlexionnelles={}
for cat in "DET NOM ADJ VER".split(" "):
    print ur"\section{%s}"%cat
    tableaux[cat],classesFlexionnelles[cat]=makeTableaux(cat)
# Out:
# \section{DET}
# IND None
# \begin{tabular}{llll}
# \toprule
# Nombre &      Sg &      Du &      Pl \\
# Genre &         &         &         \\
# \midrule
# A     &   k-u-θ &  ða-k-u &  θo-k-u \\
# B     &  mo-k-u &   k-u-ŋ &  θo-k-u \\
# C     &  mo-k-a &  ða-k-a &   k-a-m \\
# D     &  mo-k-a &  ða-k-a &  θo-k-a \\
# \bottomrule
# \end{tabular}
#
# DEM None
# \begin{tabular}{llll}
# \toprule
# Nombre &      Sg &      Du &      Pl \\
# Genre &         &         &         \\
# \midrule
# A     &   b-u-θ &  ða-b-u &  θo-b-u \\
# B     &  mo-b-u &   b-u-ŋ &  θo-b-u \\
# C     &  mo-b-a &  ða-b-a &   b-a-m \\
# D     &  mo-b-a &  ða-b-a &  θo-b-a \\
# \bottomrule
# \end{tabular}
#
# DEF None
# \begin{tabular}{llll}
# \toprule
# Nombre &      Sg &      Du &      Pl \\
# Genre &         &         &         \\
# \midrule
# A     &   l-u-θ &  ða-l-u &  θo-l-u \\
# B     &  mo-l-u &   l-u-ŋ &  θo-l-u \\
# C     &  mo-l-a &  ða-l-a &   l-a-m \\
# D     &  mo-l-a &  ða-l-a &  θo-l-a \\
# \bottomrule
# \end{tabular}
#
# \section{NOM}
# N1 chasseur
# \begin{tabular}{lllll}
# \toprule
#     & Nombre &                        Sg &           Du &                        Pl \\
# Cas & Genre &                           &              &                           \\
# \midrule
# Abs & A &  ko-racine(ramez)x1V23a3i &  ko-ramez-zi &  ko-racine(ramez)x1Vʒ2a3o \\
# Dat & A &   racine(ramez)x1V23a3i-ʒ &  ʒo-ramez-zi &  vu-racine(ramez)x1Vʒ2a3o \\
# Erg & A &   racine(ramez)x1V23a3i-f &   ramez-zi-f &  zu-racine(ramez)x1Vʒ2a3o \\
# Obl & A &   racine(ramez)x1V23a3i-p &   ramez-zi-p &   racine(ramez)x1Vʒ2a3o-p \\
# \bottomrule
# \end{tabular}
#
# N2 enfant
# \begin{tabular}{lllll}
# \toprule
#     & Nombre &        Sg &           Du &                        Pl \\
# Cas & Genre &           &              &                           \\
# \midrule
# \multirow{2}{*}{Abs} & A &  ze-taril &  ze-taril-zi &     racine(taril)x1Vʒ2a3o \\
#     & C &  ze-koʃaŋ &  ze-koʃaŋ-zi &     racine(koʃaŋ)x1Vʒ2a3o \\
# \cline{1-5}
# \multirow{2}{*}{Dat} & A &  taril-vu &  taril-zi-vu &  racine(taril)x1Vʒ2a3o-vu \\
#     & C &  koʃaŋ-vu &  koʃaŋ-zi-vu &  racine(koʃaŋ)x1Vʒ2a3o-vu \\
# \cline{1-5}
# \multirow{2}{*}{Erg} & A &  fi-taril &  fi-taril-zi &  fi-racine(taril)x1Vʒ2a3o \\
#     & C &  fi-koʃaŋ &  fi-koʃaŋ-zi &  fi-racine(koʃaŋ)x1Vʒ2a3o \\
# \cline{1-5}
# \multirow{2}{*}{Obl} & A &  ðu-taril &  ðu-taril-zi &  ðu-racine(taril)x1Vʒ2a3o \\
#     & C &  ðu-koʃaŋ &  ðu-koʃaŋ-zi &  ðu-racine(koʃaŋ)x1Vʒ2a3o \\
# \bottomrule
# \end{tabular}
#
# N3 colère
# \begin{tabular}{lllll}
# \toprule
#     & Nombre &           Sg &                           Du &                          Pl \\
# Cas & Genre &              &                              &                             \\
# \midrule
# Abs & A &  ze-tarag-fo &     ze-racine(tarag)x1A2fu3i &        racine(tarag)x1V2a3a \\
# Dat & A &  tarag-fo-fo &     racine(tarag)x1A2fu3i-fo &     racine(tarag)x1V2a3a-fo \\
# Erg & A &  θi-tarag-fo &     fi-racine(tarag)x1A2fu3i &     fi-racine(tarag)x1V2a3a \\
# Obl & A &  tarag-fo-ʃu &  mu+racine(tarag)x1A2fu3i+ʃo &  mu+racine(tarag)x1V2a3a+ʃo \\
# \bottomrule
# \end{tabular}
#
# N4 chat
# \begin{tabular}{lllll}
# \toprule
#     & Nombre &           Sg &                        Du &                       Pl \\
# Cas & Genre &              &                           &                          \\
# \midrule
# Abs & A &     fo-lobaw &     racine(lobaw)x1A2fu3i &  la-racine(lobaw)x1V2a3a \\
# Dat & A &  fo-lobaw-ka &  racine(lobaw)x1A2fu3i-ka &  racine(lobaw)x1V2a3a-ka \\
# Erg & A &  fo-lobaw-la &  racine(lobaw)x1A2fu3i-la &  racine(lobaw)x1V2a3a-la \\
# Obl & A &  mu-fo-lobaw &  mu-racine(lobaw)x1A2fu3i &  mu-racine(lobaw)x1V2a3a \\
# \bottomrule
# \end{tabular}
#
# \section{ADJ}
# A1 rouge
# \begin{tabular}{lllll}
# \toprule
#     & Nombre &             Sg &                           Du &             Pl \\
# Cas & Genre &                &                              &                \\
# \midrule
# \multirow{4}{*}{Abs} & A &    mo-miðin-te &    mo-racine(miðin)x1A22a3mu &    mo-miðin-θa \\
#     & B &    miðin-te-ʒi &    racine(miðin)x1A22a3mu-ʒi &    miðin-θa-ʒi \\
#     & C &    ka-miðin-te &    ka-racine(miðin)x1A22a3mu &    ka-miðin-θa \\
#     & D &    miðin-te-la &    racine(miðin)x1A22a3mu-la &    miðin-θa-la \\
# \cline{1-5}
# \multirow{4}{*}{Dat} & A &  mo-miðin-te-ʃ &  mo-racine(miðin)x1A22a3mu-ʃ &  mo-miðin-θa-ʃ \\
#     & B &  miðin-te-ʒi-ʃ &  racine(miðin)x1A22a3mu-ʒi-ʃ &  miðin-θa-ʒi-ʃ \\
#     & C &  ka-miðin-te-ʃ &  ka-racine(miðin)x1A22a3mu-ʃ &  ka-miðin-θa-ʃ \\
#     & D &  miðin-te-la-ʃ &  racine(miðin)x1A22a3mu-la-ʃ &  miðin-θa-la-ʃ \\
# \cline{1-5}
# \multirow{4}{*}{Erg} & A &  mo-miðin-te-s &  mo-racine(miðin)x1A22a3mu-s &  mo-miðin-θa-s \\
#     & B &  miðin-te-ʒi-s &  racine(miðin)x1A22a3mu-ʒi-s &  miðin-θa-ʒi-s \\
#     & C &  ka-miðin-te-s &  ka-racine(miðin)x1A22a3mu-s &  ka-miðin-θa-s \\
#     & D &  miðin-te-la-s &  racine(miðin)x1A22a3mu-la-s &  miðin-θa-la-s \\
# \cline{1-5}
# \multirow{4}{*}{Obl} & A &  mo-miðin-te-θ &  mo-racine(miðin)x1A22a3mu-θ &  mo-miðin-θa-θ \\
#     & B &  miðin-te-ʒi-θ &  racine(miðin)x1A22a3mu-ʒi-θ &  miðin-θa-ʒi-θ \\
#     & C &  ka-miðin-te-θ &  ka-racine(miðin)x1A22a3mu-θ &  ka-miðin-θa-θ \\
#     & D &  miðin-te-la-θ &  racine(miðin)x1A22a3mu-la-θ &  miðin-θa-la-θ \\
# \bottomrule
# \end{tabular}
#
# A2 blanc
# \begin{tabular}{lllll}
# \toprule
#     & Nombre &             Sg &             Du &                            Pl \\
# Cas & Genre &                &                &                               \\
# \midrule
# \multirow{4}{*}{Abs} & A &    girit-te-ba &    girit-ðo-ba &    racine(girit)xʒu11V2o3e-ba \\
#     & B &    girit-te-ʒi &    girit-ðo-ʒi &    racine(girit)xʒu11V2o3e-ʒi \\
#     & C &       girit-te &       girit-ðo &       racine(girit)xʒu11V2o3e \\
#     & D &    me-girit-te &    me-girit-ðo &    me-racine(girit)xʒu11V2o3e \\
# \cline{1-5}
# \multirow{4}{*}{Dat} & A &  girit-te-ba-ʃ &  girit-ðo-ba-ʃ &  racine(girit)xʒu11V2o3e-ba-ʃ \\
#     & B &  girit-te-ʒi-ʃ &  girit-ðo-ʒi-ʃ &  racine(girit)xʒu11V2o3e-ʒi-ʃ \\
#     & C &     girit-te-ʃ &     girit-ðo-ʃ &     racine(girit)xʒu11V2o3e-ʃ \\
#     & D &  me-girit-te-ʃ &  me-girit-ðo-ʃ &  me-racine(girit)xʒu11V2o3e-ʃ \\
# \cline{1-5}
# \multirow{4}{*}{Erg} & A &  girit-te-ba-s &  girit-ðo-ba-s &  racine(girit)xʒu11V2o3e-ba-s \\
#     & B &  girit-te-ʒi-s &  girit-ðo-ʒi-s &  racine(girit)xʒu11V2o3e-ʒi-s \\
#     & C &     girit-te-s &     girit-ðo-s &     racine(girit)xʒu11V2o3e-s \\
#     & D &  me-girit-te-s &  me-girit-ðo-s &  me-racine(girit)xʒu11V2o3e-s \\
# \cline{1-5}
# \multirow{4}{*}{Obl} & A &  girit-te-ba-θ &  girit-ðo-ba-θ &  racine(girit)xʒu11V2o3e-ba-θ \\
#     & B &  girit-te-ʒi-θ &  girit-ðo-ʒi-θ &  racine(girit)xʒu11V2o3e-ʒi-θ \\
#     & C &     girit-te-θ &     girit-ðo-θ &     racine(girit)xʒu11V2o3e-θ \\
#     & D &  me-girit-te-θ &  me-girit-ðo-θ &  me-racine(girit)xʒu11V2o3e-θ \\
# \bottomrule
# \end{tabular}
#
# \section{VER}
# V1 rêvasser
# \begin{tabular}{llllll}
# \toprule
#     &   & Pers &                       3Du &                       3Pl &                     3Sg \\
# Temps & Genre & Trans &                           &                           &                         \\
# \midrule
# \multirow{4}{*}{PRS} & A & VI &  racine(mipir)x1V12a3-u-t &  racine(mipir)x1V12a3-u-θ &  racine(mipir)x1V12a3-u \\
#     & B & VI &  racine(mipir)x1V12a3-i-t &  racine(mipir)x1V12a3-i-θ &  racine(mipir)x1V12a3-i \\
#     & C & VI &  racine(mipir)x1V12a3-a-t &  racine(mipir)x1V12a3-a-θ &  racine(mipir)x1V12a3-a \\
#     & D & VI &  racine(mipir)x1V12a3-e-t &  racine(mipir)x1V12a3-e-θ &  racine(mipir)x1V12a3-e \\
# \cline{1-6}
# \multirow{4}{*}{PST} & A & VI &  racine(mipir)x1V2ʒa3-u-t &  racine(mipir)x1V2ʒa3-u-θ &  racine(mipir)x1V2ʒa3-u \\
#     & B & VI &  racine(mipir)x1V2ʒa3-i-t &  racine(mipir)x1V2ʒa3-i-θ &  racine(mipir)x1V2ʒa3-i \\
#     & C & VI &  racine(mipir)x1V2ʒa3-a-t &  racine(mipir)x1V2ʒa3-a-θ &  racine(mipir)x1V2ʒa3-a \\
#     & D & VI &  racine(mipir)x1V2ʒa3-e-t &  racine(mipir)x1V2ʒa3-e-θ &  racine(mipir)x1V2ʒa3-e \\
# \bottomrule
# \end{tabular}
#
# V2 fuir
# \begin{tabular}{llllll}
# \toprule
#     &   & Pers &                       3Du &                       3Pl &                       3Sg \\
# Temps & Genre & Trans &                           &                           &                           \\
# \midrule
# \multirow{4}{*}{PRS} & A & VI &  racine(loram)x1A2u33-u-g &  racine(loram)x1A2u33-u-g &  racine(loram)x1A2u33-u-b \\
#     & B & VI &  racine(loram)x1A2u33-u-g &  racine(loram)x1A2u33-u-g &  racine(loram)x1A2u33-u-b \\
#     & C & VI &  racine(loram)x1A2u33-e-g &  racine(loram)x1A2u33-e-g &  racine(loram)x1A2u33-e-b \\
#     & D & VI &  racine(loram)x1A2u33-e-g &  racine(loram)x1A2u33-e-g &  racine(loram)x1A2u33-e-b \\
# \cline{1-6}
# \multirow{4}{*}{PST} & A & VI &  racine(loram)x1V2ʒa3-u-g &  racine(loram)x1V2ʒa3-u-g &  racine(loram)x1V2ʒa3-u-b \\
#     & B & VI &  racine(loram)x1V2ʒa3-u-g &  racine(loram)x1V2ʒa3-u-g &  racine(loram)x1V2ʒa3-u-b \\
#     & C & VI &  racine(loram)x1V2ʒa3-e-g &  racine(loram)x1V2ʒa3-e-g &  racine(loram)x1V2ʒa3-e-b \\
#     & D & VI &  racine(loram)x1V2ʒa3-e-g &  racine(loram)x1V2ʒa3-e-g &  racine(loram)x1V2ʒa3-e-b \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Liste des lexèmes par CF
#
# => à intégrer aux tableaux...

# %%
for cat in "NOM ADJ VER".split(" "):
    classeCat=classesFlexionnelles[cat]
    print ur"\begin{description}"
    for c in classeCat:
        print ur"\item[- %s]"%c, ", ".join(sorted(classeCat[c]))
    print ur"\end{description}"
# Out:
# \begin{description}
# \item[- N1] Mahira, Nicole, balai, chasseur, combat, coup, croc, démon, forêt, fruit, infirmière, loup, maison, poisson, soeur, souffrance
# \item[- N2] Katisha, Nabil, arbre, autruche, chambre, corps, enfant, lueur, milieu, mort, ombre, sort, viande, visage, œuf
# \item[- N3] Kaleb, Violette, blessure, café, chatte, colère, cri, fille, gorge, main, plaine, table, village, villageois, villageoise
# \item[- N4] chat, chef, combattant, coussin, couteau, coyote, cuisine, homme, lance, lit, louve, lune, nuit, serpent, souris, thé
# \end{description}
# \begin{description}
# \item[- A1] bas, courageux, différent, grand, gros, noir, profond, rouge, suivant, trois
# \item[- A2] blanc, blessé, effrayé, furieux, jaune, maigre, petit, quatre, terrible
# \end{description}
# \begin{description}
# \item[- V1] acheter, apporter, boire, courir, dormir, dévorer, entrer, lancer, manger, offrir, parler, passer, pousser, recouvrir, rejoindre, rêvasser, supporter, tomber, transformer
# \item[- V2] aller, approcher, arriver, chasser, chercher, disparaître, donner, envahir, fuir, jeter, montrer, planter, prendre, protéger, sauter, sortir, transpercer, voir, être
# \end{description}
