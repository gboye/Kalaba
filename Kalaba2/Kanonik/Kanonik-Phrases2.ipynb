# %% [markdown]
# # Problèmes et Extensions
# - javascript runs fail
# - faire de nouvelles sorties pour les kalabas sans séparateurs de mots
#  - radicaux seuls
#  - découpage en syntagmes pour l'exercice sur l'ordre des syntagmes

# %% [markdown]
# ### Javascript from :
# https://stackoverflow.com/questions/12544056/how-to-i-get-the-current-ipython-notebook-name

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "theNotebook = " + "'"+thename+"'";
# kernel.execute(command);

# %%
print(theNotebook)
# Out:
# Kanonik-Phrases2

# %%
# -*- coding: utf8 -*-
from os.path import expanduser
from cellbell import ding
from itertools import groupby
home = expanduser("~")
annee="2020"
numGroupe=1
variante="-Corr"
#variante=""
RightLeft=True
repertoire=home+"/ownCloud/Cours/Bordeaux/L1-UE4-Morphologie/00-Kanonik/"+annee
serie=repertoire+"/"+"K%02d/"%numGroupe
complementPhrases=""
#########################IMPORTS############################################
import codecs, optparse
import re, random
import sys,os,time
import string
import yaml, warnings
import ParFuMor as PFM
from ParFuMor import *
import pickle,copy

# %%
#########################VARIABLES##########################################
version=os.path.basename("__file__")
time_stamp='%s' % time.strftime("%y%m%d-%H%M")
debug=1
debug_now=1

#casNombreDet=True

separateurPhonoCloze=" "
separateurMots=separateurPhonoCloze
print "séparateur",separateurMots
#separateurMots=" "
marqueurCommentaire="%"
print_no=True
print_taches=False
print_coffee=False
print_commands=True
print_ortho=True
print_phono=True
print_glose=False        #False
print_radicaux=False     #False
#if separateurMots=="":
#    print_glose=False
if variante=="-Corr":
    print_taches=False
    print_coffee=False
    print_commands=True
    print_ortho=True
    print_phono=True
    print_glose=True    
if print_glose:
    separateurMots=" "
if print_glose+print_ortho+print_phono>1:
    print_phrases=True
else:
    print_phrases=False
print_lexique=True
print_cloze=True
print_racines=True
# Out:
# séparateur

# %%
print_glose+print_ortho+print_phono
# Out:
# 3

# %%
prononciationBegin=[
    "\\begin{center}",
        "\\begin{tabular}{lcc}",
        "\\toprule",
        u"Graphie & Prononciation & Mot français \\\\",
        "\\midrule"
        ]
prononciationEnd=[
        "\\bottomrule",
        "\\end{tabular}",
    "\\end{center}"
]

# %%
with open(serie+"Gloses.yaml", 'r') as stream:
    gloses=yaml.safe_load(stream)
with open(serie+"Stems.yaml", 'r') as stream:
    stems=yaml.safe_load(stream)
with open(serie+"Phonology.yaml", 'r') as stream:
    phonology=yaml.safe_load(stream)
with open(serie+"MorphoSyntax.yaml", 'r') as stream:
    morphosyntax=yaml.safe_load(stream)
with open(serie+"Clozes.txt", 'r') as stream:
    clozeLines=stream.readlines()

discrimineur=[]
discriminant={}
for line in clozeLines:
    line=line.strip()
    if not line.startswith("#"):
        elementsCloze=line.split(";")
        discriminant[elementsCloze[0]]=";".join([element for element in elementsCloze[1:] if element!=elementsCloze[5]])

# %%
#discriminant

# %%
defaultCols=2
defaultLong=0
maxChunk=48
dimensionsTableaux={i:{} for i in gloses}
for categorie in gloses:
    if "Dimensions" in morphosyntax:
        if "maxChunk" in morphosyntax["Dimensions"]:
            maxChunk=morphosyntax["Dimensions"]["maxChunk"]
        print maxChunk
        if categorie in morphosyntax["Dimensions"] and morphosyntax["Dimensions"][categorie]:
#            print categorie
            if "cols" in morphosyntax["Dimensions"][categorie]:
                dimensionsTableaux[categorie]["cols"]=morphosyntax["Dimensions"][categorie]["cols"]
            else:
                dimensionsTableaux[categorie]["cols"]=defaultCols
            if "long" in morphosyntax["Dimensions"][categorie]:
                dimensionsTableaux[categorie]["long"]=morphosyntax["Dimensions"][categorie]["long"]
            else:
                dimensionsTableaux[categorie]["long"]=defaultLong
        else:
            dimensionsTableaux[categorie]["cols"]=defaultCols
            dimensionsTableaux[categorie]["long"]=defaultLong
    else:
        dimensionsTableaux[categorie]["cols"]=defaultCols
        dimensionsTableaux[categorie]["long"]=defaultLong
if print_radicaux:
    nomTableaux="Tableaux-Gloses.yaml"
else:
    nomTableaux="Tableaux.yaml"    
with open(serie+nomTableaux, 'r') as stream:
    tableaux=yaml.safe_load(stream)
with open(serie+"Hierarchie-S2.pkl", 'rb') as input:
   PFM.hierarchieCF = pickle.load(input)
with open(serie+"Lexique-S2.pkl", 'rb') as input:
   PFM.lexique = pickle.load(input)
with open(serie+"Regles-S2.pkl", 'rb') as input:
   PFM.regles = pickle.load(input)
# Out:
# 29
# 29
# 29
# 29
# 29

# %%
[morphosyntax["Contractions"][x] for x in morphosyntax["Contractions"]]
# Out:
# [[u'\xe0', 'les'], ['de', 'le'], ['de', 'les'], [u'\xe0', 'le'], ['de']]

# %% [markdown]
# #### Définition des entêtes

# %%
#########################CONSTANTS##########################################
head = [
"\\begin{tabular}[t]{|l|l|l|}",
"\\addlinespace[-1.0em]\\hline",
"Mot & Roman & Glose  \\\\",
"\\hline\\strutgh{14pt}%"
]
head_n = [
"\\begin{tabular}[t]{|l|c|c|c|}",
"\\addlinespace[-1.0em]\\hline",
"Nom & Genre & C\\indice{1}C\\indice{2}C\\indice{3} & V\\indice{L}  \\\\",
"\\hline\\strutgh{14pt}%"
]
head_v = [
"\\begin{tabular}[t]{|l|c|c|}",
"\\addlinespace[-1.0em]\\hline",
"Verbe & Type & C\\indice{1}C\\indice{2}C\\indice{3} \\\\",
"\\hline\\strutgh{14pt}%"
]

# %%
tail = [
"\\hline"
"\\end{tabular}\\columnbreak\\vfill"
]

# %% [markdown]
# #### Définition des structures pour impression

# %%
def accumulerMots(mot):
    accumulateur.append(mot)
    return

def ajouterExemple(exemple,printBool=False):
    if printBool:
        print exemple
    exemples.append(exemple.strip())
    del accumulateur[:]
    return
def ajouterVocabulaire(terme,printBool=False):
    if printBool:
        print terme
    vocabulaire.append(terme.strip())
    return

# %% [markdown]
# #### Définition des segments

# %%
consonnes=phonology["consonnes"]
voyelles=phonology["voyelles"]
gabarits=phonology["gabarits"]
derives=phonology["derives"]
nom_classe=phonology["nom_classe"]
nom_apo=phonology["apophonies"]

nom_mut=phonology["mutations"]

# %% [markdown]
# #### Définition des catégories

# %%
sujetVerbe=[]
if "Cas" in gloses["NOM"]:
    if "Nom" in gloses["NOM"]["Cas"]:
        sujetVerbe.append("Nom")
    if "Erg" in gloses["NOM"]["Cas"]:
        sujetVerbe.append("Abs")

# %%
#sujetVerbe

# %%
attributsMots=set()
valAttributs={}
for categorie in gloses:
    if gloses[categorie]:
        for element in gloses[categorie]:
            attributsMots.add(element)
            if gloses[categorie][element]:
                if not element in valAttributs:
                    valAttributs[element]=[]
                for attribut in gloses[categorie][element]:
                    if not attribut in valAttributs[element]:
                        valAttributs[element].append(attribut)

# %%
attributsMots
# Out:
# {'Genre', 'Nombre', 'Pers', 'Temps'}

# %%
boolAttribut={}
flexCategories=[element for element in gloses if gloses[element]]
for element in flexCategories:
    boolAttribut[element]={key:key in gloses[element] for key in attributsMots}
flexCategories
# Out:
# ['VER', 'NOM', 'DET', 'ADJ']

# %%
boolAttribut
# Out:
# {'ADJ': {'Genre': True, 'Nombre': True, 'Pers': False, 'Temps': False},
#  'DET': {'Genre': True, 'Nombre': True, 'Pers': False, 'Temps': False},
#  'NOM': {'Genre': True, 'Nombre': True, 'Pers': False, 'Temps': False},
#  'VER': {'Genre': True, 'Nombre': False, 'Pers': True, 'Temps': True}}

# %% [markdown]
# attributsDetAdjNom=["Genre","Nombre","Cas"]
# valAttribut={}
# for attribut in attributsDetAdjNom:
#     if attribut in gloses["N"]:
#         valAttribut[attribut]=gloses["N"][attribut]
#     elif attribut in gloses["ADJ"]:
#         valAttribut[attribut]=gloses["ADJ"][attribut]
#     elif attribut in gloses["DET"]:
#         valAttribut[attribut]=gloses["DET"][attribut]
#     else:
#         valAttribut[attribut]=[]
# boolAttribut={}
# for element in ["DET","ADJ","N"]:
#     boolAttribut[element]={key:key in gloses[element] for key in attributsDetAdjNom}

# %%
#types=gloses["V"]["CF"]
if "Cas" in morphosyntax:
    casSyntagmes=morphosyntax["Cas"]
else:
    casSyntagmes=""
lexiquePrepositions=[stems["PREP"][x][0] for x in stems["PREP"]]
casPreposition={}
for preposition in lexiquePrepositions:
    prep=preposition.upper()
    if casSyntagmes and prep in casSyntagmes:
        casPreposition[preposition]=casSyntagmes[prep].capitalize()
    elif casSyntagmes and "PREP" in casSyntagmes:
        casPreposition[preposition]=casSyntagmes["PREP"].capitalize()
    else:
        casPreposition[preposition]=""
        
i=2
verbe_forme={}
for forme in morphosyntax["VER"]["FormesBase"]:
    verbe_forme[i]=forme
    i+=1

# %%
#valAttribut

# %% [markdown]
# #### Remplacement des numéros de personnes pour les noms de macro LaTeX

# %%
def remplacerPersonnes(chaine):
    chaine.replace("1","Un")
    return chaine

# %%
remplacerPersonnes("1")
# Out:
# '1'

# %%
def recoder(chaine,table):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    return result

accentedIn = unicode(phonology["translations"]["deaccent"]["in"])
deaccentIn = [ord(char) for char in accentedIn]
deaccentOut = unicode(phonology["translations"]["deaccent"]["out"])
deaccent = dict(zip(deaccentIn, deaccentOut))

deligatures=phonology["translations"]["deligatures"]

# %%
syntagmes=morphosyntax["Syntagmes"]
syntagmesLR=copy.deepcopy(syntagmes)
print syntagmesLR
syntagmesRL=copy.deepcopy(syntagmes)
for element in syntagmesRL:
    syntagmesRL[element].reverse()
nomFonctions=syntagmes["Phrase"]
# Out:
# {'Phrase': ['VER', 'COMP', 'SUJ', 'AJOUT', 'OBJ', 'IND'], 'GP': ['GN', 'PREP'], 'GADJ': ['ADV', 'ADJ', 'GP'], 'GN': ['GADJ', 'NOM', 'DET', 'GP']}

# %%
"LR",syntagmesLR, "RL",syntagmesRL
# Out:
# ('LR',
#  {'GADJ': ['ADV', 'ADJ', 'GP'],
#   'GN': ['GADJ', 'NOM', 'DET', 'GP'],
#   'GP': ['GN', 'PREP'],
#   'Phrase': ['VER', 'COMP', 'SUJ', 'AJOUT', 'OBJ', 'IND']},
#  'RL',
#  {'GADJ': ['GP', 'ADJ', 'ADV'],
#   'GN': ['GP', 'DET', 'NOM', 'GADJ'],
#   'GP': ['PREP', 'GN'],
#   'Phrase': ['IND', 'OBJ', 'AJOUT', 'SUJ', 'COMP', 'VER']})

# %%
contractions=morphosyntax["Contractions"]
for contraction in contractions:
    temp=[]
    for element in contractions[contraction]:
        if isinstance(element,unicode):
            temp.append(element)
        else:
            temp.append(element.decode("utf8"))
    contractions[contraction]=temp

# %%
syllabes=phonology["syllabes"]

# %%
attributsFlexVerbe=[glosesVerbe for attributFlex in gloses["VER"] for glosesVerbe in gloses["VER"][attributFlex]]
attributsFlexVerbe
# Out:
# ['PRS', 'PST', '3Sg', '3Pl', 'M', 'F', 'N']

# %%
def taches():
    '''
    seuil1 pour avoir une tâche
    seuil2 pour avoir plusieurs tâches
    '''
    seuil1=8
    seuil2=14
    def makeStain():
        seed=random.randint(1,1000)
        x=random.gauss(10,5)-1
        y=random.gauss(2,1)
        minimum=random.gauss(.2,.1)+.1
        maximum=random.gauss(.1,.05)+.5
        return "\\taches{%s}{%s}{%s}{%s}{%s}"%(seed,x,y,minimum,maximum)

    if print_taches:
        n=random.gauss(10,2.5)
        if n<seuil1:
            return ""
        elif n<=seuil2:
            return makeStain()
        else:
            nTaches=int(n-seuil1)
            stains=""
            for i in range(nTaches):
                stains+=makeStain()
            return stains
    else:
        return ""

# %%
def faire_tableau(tableau,tab=(head,tail,"")):
    if len(tableau)==0: return
    comment=tab[2]
    for element in tab[0]:
        ajouterVocabulaire(comment+element)
    for element in tableau:
        ajouterVocabulaire(comment+element)
    for element in tab[1]:
        ajouterVocabulaire(comment+element)

# %%
def print_tableaux(cols,recuTableau,texte="",debut=0,tab=(head,tail,""),boolEchantillon=True):
    tableau=sorted(list(set(recuTableau)))
    if debug: print "recuTableau",(recuTableau)
#    print (tableau)
    ajouterVocabulaire(tab[2]+"\\begin{multicols}{"+str(cols)+"}")
#    if texte!="":
    (table,reste)=filtrer_tableau(tableau,texte)
#    print reste
#    else:
#        (table,reste)=tableau
#        reste=[]
    chunk=(len(table)-debut*cols)/cols+1
    faire_tableaux(table,debut,cols,tab)
    ajouterVocabulaire(tab[2]+"\\end{multicols}")
    echantillon=min(len(reste),3)
    if echantillon>0 and boolEchantillon:
        for element in random.sample(reste,echantillon):
#            print element
            colonnes=element.split("&")
            graphie=colonnes[0].strip()
            phonologie=colonnes[1].strip()
            glose=colonnes[2].strip().strip("\\")
            prononciationExtrait.append(graphie+"&")
            prononciationExtrait.append("\\blanc{%s}"%phonologie+"&")
            prononciationExtrait.append("\\blanc{%s}\\\\"%glose)
            if debug: print "".join(prononciationExtrait)

# %%
def faire_tableaux(tableau,debut=16,nombre=1,tab=(head,tail,"")):
    reste=[]
    if debug: print nombre,debut,tableau
    if debut!=0:
        for i in range(nombre):
            faire_tableau(tableau[debut*i:debut*(i+1)],tab)
        table=tableau[debut*nombre:]
    else:
        table=tableau
    longueur=len(table)
    chunk=longueur/nombre+1
    if debug: print "CHUNKING : ",longueur, nombre, chunk, table
    if chunk<maxChunk:
        chunks=chunk
    else:
        chunks=maxChunk
        reste=table[maxChunk*nombre:]
    if debug: print "RESTE : ", chunk, reste
    for i in range(nombre):
        faire_tableau(table[chunks*i:chunks*(i+1)],tab)
    if reste:
        faire_tableaux(reste,0,nombre,tab)

# %%
def filtrer_tableau(tableau,filtre):
    presents=[]
    absents=[]
    for line in tableau:
        elements=line.split(" ")
        cleElement=elements[0].replace("\\","")
        if elements[0] in filtre:
            if not discriminant[cleElement] in discrimineur:
                discrimineur.append(discriminant[cleElement])
    #                print "présent",elements[0]
            presents.append(line)
        else:
#                print "absent",elements[0]
            absents.append(line)
    return (presents,absents)

# %%
def faire_gn(depart,cas):
    global erg_genre, erg_nombre, abs_genre, abs_nombre
    if debug: print "groupe depart :", depart
    groupe_nom=[]
    groupe_nom.append(depart[0])
    if debug: print depart[0]
    for mot in depart[1:]:
        if debug: print mot
        if not "#" in mot:
            groupe_nom.extend(etendre_contraction([mot]))
    if debug: print "groupe nom :", groupe_nom
    mots=[]
    det=[]
    adj=[]
    nom=[]
    gp=[]
    structureSyntagme={key:[] for key in syntagmes['GN']}
    tete=""
    nombre=""
    classe=""
    classesNom=[]
    reste=0
    groupe_nom=[element for element in groupe_nom if element!=""]
    for mot in groupe_nom:
        if reste==0:
#            if mot=="deux" and "Du" in nombresNom:
            if mot=="deux" and "Du" in valAttributs["Nombre"]:
                nombre="DU"
                if det==[]: det.append(PFM.lexique.formeLexeme["des"][0])
            elif "Pau" in valAttributs["Nombre"] and mot in "deux trois quatre cinq".split():
                nombre="PAU"
                if det==[]: det.append(PFM.lexique.formeLexeme["des"][0])
            else:
                nomLexeme=PFM.lexique.formeLexeme[mot][0]
                categorie=PFM.lexique.lexemes[nomLexeme].classe.split(".")[-1]
                if debug or 0: 
                    print "mot",[mot]
                    print "vedette",PFM.lexique.formeLexeme[mot][0],categorie
                    print "categories",PFM.hierarchieCF.classes["NOM"],PFM.hierarchieCF.getCategory(categorie)
                if PFM.hierarchieCF.getCategory(categorie)=="NOM":
                    tete=categorie
                    if debug or 0: print "tête :", tete
                    tampon=tete.split('.')
#                    classe=tampon[0]
                    classesNom=PFM.lexique.formeLexeme[mot][0].split('.')[1:]
                    if debug or 0: print "classesNom",classesNom 
                    classe=[classeElement for classeElement in classesNom if classeElement in gloses["NOM"]["Genre"]][0]
                    if debug or 0: print "classes",mot,classe,classesNom
                    try:
                        typeMot=tampon[1]
                    except IndexError:
                        typeMot=''
                    # modif pour les mots à pluriels en x
                    # 23/11/19
                    #
                    if mot[len(mot)-1] in ['s',"x"]:
                        if nombre=="": nombre="PL"
                    else:
                        if nombre=="": nombre="SG"
                    nom.append(PFM.lexique.formeLexeme[mot][0])
#                    if typeCas=="NoCas":
#                        cas=""
                    if not "Cas" in boolAttribut["NOM"] or not boolAttribut["NOM"]["Cas"]:
                        cas=""
#                    else:
                    cellule=classe.capitalize()+nombre.capitalize()+cas.capitalize()
                    if cas=="ERG":
                        erg_genre=classe
                        erg_nombre=nombre
                        if debug: print "ERG",erg_genre, erg_nombre
                    elif cas=="ABS":
                        abs_genre=classe
                        abs_nombre=nombre
                        if debug: print "ABS",abs_genre, abs_nombre
                elif PFM.hierarchieCF.getCategory(categorie) in ["DET"]:
                    det.append(PFM.lexique.formeLexeme[mot][0])
#                elif PFM.hierarchieCF.getCategory(categorie) in ["ADJ"] or ("ADJ" in PFM.hierarchieCF.classes and categorie in PFM.hierarchieCF.classes["ADJ"]):
                elif PFM.hierarchieCF.getCategory(categorie) in ["ADJ"]:
                    adj.append(PFM.lexique.formeLexeme[mot][0])
                elif categorie=="PREP":			#Si on trouve une PREP, elle et le reste forment un GP
                    gp.append(mot)
                    reste=1
        else:							#On a trouvé une PREP, toute la suite va dans GP
            gp.append(mot)
    if debug: print "accord :", tete
    if reste==1: gp=faire_gp(gp)
    if debug: print "GP dans le GN : ", gp
    if debug: print "GN sans det ? ", det
    if not det: 
        if nom[0][0]==nom[0][0].upper():
            det.append(PFM.lexique.formeLexeme["les"][0])
        else:
            det.append(PFM.lexique.formeLexeme["des"][0])
    tempSyntagme=[]
    for mot in det:
        (casDet,nombreDet)=(cas,nombre)
        if not "Cas" in boolAttribut["DET"] or not boolAttribut["DET"]["Cas"]:
            casDet=""
        if not "Nombre" in boolAttribut["DET"] or not boolAttribut["DET"]["Nombre"]:
            nombreDet=""
        if not "Genre" in boolAttribut["DET"] or not boolAttribut["DET"]["Genre"]:
            classeDet=""
        else:
            classeDet=[classeElement for classeElement in classesNom if classeElement in gloses["DET"]["Genre"]][0]
#		glose=faire_glose(mot,classe,type,nombre)

        noligMot=mot.split(".")[0]
        for ligature in deligatures:
            noligMot=noligMot.replace(ligature,deligatures[ligature])
        noligMot=noligMot.replace("-","")
        ref="\\"+recoder(noligMot,deaccent).upper()
        for attributDet in morphosyntax["Attributs"]["DET"]:
            if attributDet=="Cas":
                ref+=casDet.capitalize()
            elif attributDet=="Nombre":
                ref+=nombreDet.capitalize()
            elif attributDet=="Genre":
                ref+=classeDet.capitalize()
        tempSyntagme.append(ref)
        lexemesLocaux.add(noligMot)
        texte.append(ref)
    structureSyntagme["DET"]=tempSyntagme
    mots.insert(syntagmes['GN'].index("DET"),separateurMots.join(structureSyntagme["DET"]))
    tempSyntagme=[]
    for mot in gp: 
#        mots.append(mot)
        tempSyntagme.append(mot)
    structureSyntagme["GP"]=tempSyntagme
    mots.insert(syntagmes['GN'].index("GP"),structureSyntagme["GP"])
    tempSyntagme=[]
    for mot in adj:
#		glose=faire_glose(mot,classe,type,nombre)
        (casAdj,nombreAdj)=(cas,nombre)
        if not "Cas" in boolAttribut["ADJ"] or not boolAttribut["ADJ"]["Cas"]:
            casAdj=""
        if not "Nombre" in boolAttribut["ADJ"] or not boolAttribut["ADJ"]["Nombre"]:
            nombreAdj=""
        if not "Genre" in boolAttribut["ADJ"] or not boolAttribut["ADJ"]["Genre"]:
            classeAdj=""
        else:
            classeAdj=[classeElement for classeElement in classesNom if classeElement in gloses["ADJ"]["Genre"]][0]

        noligMot=mot.split(".")[0]
        for ligature in deligatures:
            noligMot=noligMot.replace(ligature,deligatures[ligature])
        noligMot=noligMot.replace("-","")    
        ref="\\"+recoder(noligMot,deaccent).lower()+classeAdj.capitalize()+nombreAdj.capitalize()+casAdj.capitalize()
#        mots.append(ref)
        lexemesLocaux.add(noligMot)
        texte.append(ref)
        tempSyntagme.append(ref)
    structureSyntagme["GADJ"]=tempSyntagme
    mots.insert(syntagmes['GN'].index("GADJ"),structureSyntagme["GADJ"])
    tempSyntagme=[]
#    print "classe,nombre,cas", classe, nombre, cas
    for mot in nom:
#		glose=faire_glose(mot,classe,type,nombre)

        noligMot=mot.split(".")[0]
        for ligature in deligatures:
            noligMot=noligMot.replace(ligature,deligatures[ligature])
        noligMot=noligMot.replace("-","")    
        if mot.istitle():
            ref="\\"+recoder(noligMot,deaccent)+cellule
        else:
            ref="\\"+recoder(noligMot,deaccent).lower()+cellule
#        mots.append(ref)
        lexemesLocaux.add(noligMot)
        texte.append(ref)
        tempSyntagme.append(ref)
    structureSyntagme["NOM"]=tempSyntagme
    mots.insert(syntagmes['GN'].index("NOM"),structureSyntagme["NOM"])
    listeMots=[]
    for element in syntagmes['GN']:
        listeMots+=structureSyntagme[element]
    return (listeMots,(classesNom,nombre,cas))

# %% [raw]
# # https://stackoverflow.com/questions/14529523/python-split-for-lists
#
# l = ["data","more data",";","data 2","more data 2","danger",";","date3","lll"]
# [list(group) for k, group in groupby(l, lambda x: x == ";") if not k]

# %%
def multiplier_gp(groupe_prep,fonction=""):
    mots=[]
    lGroupes=[list(group) for k, group in groupby(groupe_prep, lambda x: x == ";") if not k]
    if len(lGroupes)>1:
        print lGroupes
    for lGp in lGroupes:
        mots.extend(faire_gp(lGp,fonction))
    return mots
    
def faire_gp(groupe_prep,fonction=""):
    mots=[]
    groupe_prep=etendre_contraction(groupe_prep)
    if debug: print "faire_gp", groupe_prep
    formePreposition=groupe_prep[0]
    if debug: print [formePreposition], formePreposition
    preposition=PFM.lexique.formeLexeme[formePreposition][0]
#    if preposition!="à" or typeCas=="NoCas":
    if not "Cas" in boolAttribut["NOM"] or not boolAttribut["NOM"]["Cas"] or fonction!="IND":
        if debug: print u"fonction!=IND",[groupe_prep[0],u"à"]

        noligMot=groupe_prep[0]
        for ligature in deligatures:
            noligMot=noligMot.replace(ligature,deligatures[ligature])
        noligMot=noligMot.replace("-","")
        ref="\\"+recoder(noligMot,deaccent).upper()
        
        if debug: print ref
        if casSyntagmes and preposition in casPreposition:
            if debug: 
                print casPreposition, casPreposition[preposition]
            cas=casPreposition[preposition]            
            if "+" in casPreposition[preposition]:
                cas=cas.strip("+")
                mots.append(ref)
                lexemesLocaux.add(noligMot.upper())
                texte.append(ref)
        else:
            if debug: print "pas de Cas"
            cas=""
            mots.append(ref)
            lexemesLocaux.add(noligMot.upper())
            texte.append(ref)
        if debug:
            print "groupe prep :", groupe_prep
            print ref
        if len(groupe_prep)>1:
            groupe_nom=groupe_prep[1:]
            if debug: print groupe_nom[0]
            #
            # Choisir le cas en fonction de la préposition
            #
            (localMots,(localClasses,localNombre,localCas))=faire_gn(groupe_nom,cas)
            mots.insert(syntagmes['GP'].index("GN"),localMots)
        if debug: 
            print groupe_prep, cas, mots
        return mots
    elif fonction=="IND":
        groupe_nom=groupe_prep[1:]
        cas=casSyntagmes["IND"]
        if "+" in casSyntagmes["IND"]:
            
            noligMot=groupe_prep[0]
            for ligature in deligatures:
                noligMot=noligMot.replace(ligature,deligatures[ligature])
            
            ref="\\"+recoder(noligMot,deaccent).upper()
            cas=cas.strip("+")
            mots.append(ref)
            lexemesLocaux.add(noligMot.upper())
            texte.append(ref)
        if debug: print "faire_gn", groupe_nom, faire_gn(groupe_nom,cas)
        (localMots,(localClasses,localNombre,localCas))=faire_gn(groupe_nom,cas)
        mots.append(localMots)
        return mots

# %%
def etendre_contraction(liste):
    result=[]
    if liste[0] in contractions.keys():
        if debug: print "EXT : ", liste, contractions[liste[0]],liste[1:] 
        result.extend(contractions[liste[0]])
        result.extend(liste[1:])
    else:
        result=liste
    return result

# %%
def printflat(liste,suffixe="",prefixe=""):
    if debug: print "printflat", liste
    if not isinstance(liste, basestring):
        for element in liste:
            accumulerMots(prefixe)
            printflat(element,suffixe)
    else:
#        if "{preview}" in liste:
#            print "preview",prefixe,liste,suffixe
        accumulerMots(prefixe)
        accumulerMots(liste+suffixe)

# %%
#######################
#
#	INITIALISATION DES VARIABLES
#
#######################

try:
    __IPYTHON__ 
    ipython=True
except: 
    ipython=False

# %%
################
#
# LECTURE DU FICHIER DE LEXEMES
#
#		LES LIGNES QUI COMMENCENT PAR # SONT IGNOREES
#
################
texHeader=[]
version=theNotebook
texHeader.append("%% script : "+version)
texHeader.append('%%%% run : %s' % time.strftime("%y%m%d-%H%M"))

if ipython or True:
#    lexeme_nom=serie+"Lexemes.txt"
#    phrase_nom=serie+"Phrases.txt"
    phrase_nom=serie+complementPhrases+"Phrases.csv"
    traduction_nom=serie+complementPhrases+"Traductions.csv"
    ecriture_nom=serie+complementPhrases+"Ecrit.csv"
    ordre_nom=serie+complementPhrases+"Ordre.csv"
    mots_nom=serie+complementPhrases+"Mots.csv"
    cloze_nom=serie+complementPhrases+"Clozes.txt"
else:
    parser=optparse.OptionParser()
    parser.add_option("-o", "--out", dest="outfile", action="store_true", help="write to FILE")
    parser.add_option("-c", "--cloze", dest="print_cloze", action="store_true", help="write a CLOZE FILE")
    parser.add_option("-l", "--lexicon", dest="print_lexique", action="store_true", help="append a lexicon")
    parser.add_option("-r", "--roots", dest="print_racines", action="store_true", help="append a root list")

    (options, args) = parser.parse_args()
    lexeme_nom=args[0]
    phrase_nom=args[1]
    if len(args)>=3:
        traduction_nom=args[2]
    else:
        traduction_nom=""
    if len(args)>=4:
        ecriture_nom=args[3]
    else:
        ecriture_nom=""
    if len(args)>=5:
        ordre_nom=args[4]
    else:
        ordre_nom=""
    if len(args)>=6:
        mots_nom=args[5]
    else:
        mots_nom=""

# %% [markdown]
# #### Ouverture du fichier lexique

# %%
def filtrerCloze(filtre):
    result=[]
    for ligne in clozeLines:
        if type(ligne)==str:
            ligne=unicode(ligne.decode('utf8'))
        ligne=ligne.strip()
        if not ligne.startswith("#"):
            clozeElements=ligne.split(";")
            if clozeElements[1] in filtre:
                result.append(ligne)
        else:
            result.append(ligne)
    return result

# %%
def flatten(lis):
     for item in lis:
         if not isinstance(item, basestring):
             for x in flatten(item):
                 yield x
         else:        
             yield item

# %%
previewerBegin="\\begin{preview}\\begin{flushleft}"
previewerEnd="\\end{flushleft}\\end{preview}"
def latex2ipa(mot):
    debutLignePreview="\\begin{preview}"
    finLignePreview="\\end{preview}"
    if " " in mot:
        result=[]
        for element in mot.split():
            result.append(latex2ipa(element))
        return separateurMots.join(result)
    else:
        mot=mot.replace(previewerBegin,"").replace(previewerEnd,"")
    #    print mot
        mot=mot.replace(debutLignePreview,"").replace(finLignePreview,"")
    #    print mot
        element=mot.replace("P{}"," ").replace("{}"," ")
    #    print element
        cleElement=element.strip().strip("\\{}")
    #    print cleElement
        if element=="\\ex": cleElement=""
        if cleElement:
            if not cleElement in traductions: 
                print cleElement
                print traductions
                warnings.warn("pas de transcription pour %s"%cleElement,mot)
                return None
            else:
                return traductions[cleElement]
        else:
            return None

# %%
#latex2ipa("\\begin{preview}\\DEFMSg{}")

# %%
def previewer(chaine,numLignesVides=0,suffixe=""):
    flatChaine=[mot+suffixe for mot in list(flatten(chaine))]
    result=previewerBegin+separateurMots.join(flatChaine)+"\\\\"*numLignesVides+previewerEnd
    return [result]

# %%
def recoder(chaine,table):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    return result

# %%
accentedIn = unicode(phonology["translations"]["deaccent"]["in"])
deaccentIn = [ord(char) for char in accentedIn]
deaccentOut = unicode(phonology["translations"]["deaccent"]["out"])
deaccent = dict(zip(deaccentIn, deaccentOut))

# %%
tipaIn = unicode(phonology["translations"]["ipa"]["in"])
ipaIn = [ord(char) for char in tipaIn]
ipaOut = unicode(phonology["translations"]["ipa"]["out"])
toipa = dict(zip(ipaIn, ipaOut))

# %%
#################################################
#################################################
#################################################
##
##
##	FAIRE LE TRI DES FORMES UTILISEES DANS LES PHRASES
##	AFFICHER DANS LES TABLEAUX SEULEMENT CES FORMES
##
##
#################################################
################################################
#
#
#	FAIRE LA LISTE DES PHRASES AVEC LES 4 LIGNES
#		GRAPHO, PHONO, GLOSE, TRAD
#
#
################################################
texte=[]
texteMots=set()
#graphies={}
#abs_genre=""
#abs_nombre=""
#PFM.lexique.formeLexeme

# %% [raw]
# PFM.lexique.lexemes["construire"].formes.index("construisit")
# valAttributs["Genre"]
# localClasses=["N"]
# [classeElement for classeElement in localClasses if classeElement in gloses["VER"]["Genre"]][0]
# localCas="Nom"
# not localCas or localCas in sujetVerbe
# sujetVerbe

# %%
def faire_phrases(phrase_file,sortie="latex"):
    print sortie
    phrasesLocales=phrase_file.readlines()
    syntagmesLocaux=[]
    numLignes=len(phrasesLocales)
    numImages=1
    numLignesVides=0
    if sortie in ["latex","traductions"]:
        finLigne="\\\\"
    elif sortie=="images":
        numImages=1
        numLignesVides=0
    else:
        finLigne="\n"
        numLignesVides=0

    debutLignePreview="\\begin{preview}"
    finLigneNoPreview="\\\\"*numLignesVides
    finLignePreview="\\\\"*numLignesVides+"\\end{preview}"
    numLignes=(len(phrasesLocales)//numImages)*numImages

    if print_phrases:
        comment=""
    else:
        comment="%"
    if sortie in ["latex","traductions"]: ajouterExemple("\\begin{phrases}")
    for nPhrase,line in enumerate(phrasesLocales[:numLignes]):
        #phrase contient une position par fonction
        #pour accueillir les équivalents kalabas des chunks français
        phrase=[0 for i in range(len(syntagmes['Phrase']))]
        tampon=(line.strip().rstrip('.')).replace("'"," ").replace(u"’"," ").split("\t")
    #    print tampon[0],type(tampon[0])
        if debug: 
            print "==========================================="            
            print line
        if not tampon[0].startswith("#"):
            verbe=tampon[1].split(" ")
            verbeForme=verbe[0]
            if len(PFM.lexique.formeLexeme[verbeForme])!=1:
                print "FORME AMBIGUË", PFM.lexique.formeLexeme[verbeForme]
            verbeLexeme=PFM.lexique.formeLexeme[verbeForme][0]
            tempVerbe=verbeLexeme.split(".")
            if debug or 0: print tempVerbe
            formeCitation=tempVerbe[0]
            lexemesLocaux.add(formeCitation)
            for element in tempVerbe[1:]:
                if element in attributsFlexVerbe:
                    formeCitation+=element.capitalize()
            if len(tempVerbe)>1:
                typeVerbe=tempVerbe[1]
            else: 
                typeVerbe=""
            classeVerbe=""
            nombreVerbe=""
            nombrePersonne=""
    #        print verbeLexeme, formeCitation,typeVerbe
            verbeLemme="%s%s"%(formeCitation,typeVerbe.capitalize())
            verbeFormeIndex=PFM.lexique.lexemes[verbeLexeme].formes.index(verbeForme)
            if debug: print "verbe :", verbe
    #        if verbeLexeme.endswith("VI"):
            if casSyntagmes and "SUJ" in casSyntagmes and "Erg" in casSyntagmes["SUJ"]:
                if ".VI" in verbeLexeme:            
    #                suj_cas="Abs"
                    frSujetCas="Abs"
                    klbSujet="SUJ"
                else:
    #                suj_cas="Erg"
    #                obj_cas="Abs"
                    frSujetCas="Erg"
                    frObjetCas="Abs"
                    klbSujet="OBJ"
            elif casSyntagmes and "SUJ" in casSyntagmes and "Nom" in casSyntagmes["SUJ"]:
                frSujetCas=casSyntagmes["SUJ"]
                frObjetCas=casSyntagmes["OBJ"]
                klbSujet="SUJ"
            else:
                frSujetCas=""
                frObjetCas=""
                klbSujet="SUJ"
            if debug: print (frSujetCas,frObjetCas,klbSujet)
            suj_genre=valAttributs["Genre"][0]
            suj_nombre=valAttributs["Nombre"][0]
            obj_genre=valAttributs["Genre"][0]
            obj_nombre=valAttributs["Nombre"][0]
            abs_genre=valAttributs["Genre"][0]
            abs_nombre=valAttributs["Nombre"][0]
            sujet=tampon[0].strip().split(" ")
            (localMots,(localClasses,localNombre,localCas))=faire_gn(sujet,frSujetCas)
            if (debug or 0) and nPhrase==0: print ("FAIRE_GN SUJET",localMots,(localClasses,localNombre,localCas))
            if sortie=="ordre":
                phrase[syntagmes['Phrase'].index('SUJ')]=previewer(localMots,suffixe="{}")
            else:
                phrase[syntagmes['Phrase'].index('SUJ')]=localMots
            if debug: print localCas,localNombre,localClasses,sujetVerbe
            if not localCas or localCas in sujetVerbe:
                if localClasses and "Genre" in gloses["VER"]:
                    localClasse=[classeElement for classeElement in localClasses if classeElement in gloses["VER"]["Genre"]][0]
                else:
                    localClasse=""
                classeVerbe=localClasse
                nombreVerbe=localNombre
                nombrePersonne=localNombre
                casVerbe=localCas
                if (debug or 0) and nPhrase==0: print "frSuj",nombrePersonne
            if debug: print "sujet :",phrase[1]
            if len(tampon)>=3:
                if tampon[2] and tampon[2].startswith(","):
                    tampon[2]=tampon[2][1:]
                objet=tampon[2].split(" ")
                if debug: print "objet : ",objet
                if objet!=['']: 
                    (localMots,(localClasses,localNombre,localCas))=faire_gn(objet,frObjetCas)
                    if (debug or 0) and nPhrase==0: print ("frObj",(localClasses,localNombre,localCas),line)
                    if sortie=="ordre":
                        phrase[syntagmes['Phrase'].index('OBJ')]=previewer(localMots,suffixe="{}")
                    else:
                        phrase[syntagmes['Phrase'].index('OBJ')]=localMots
                    if debug or 0: print ("obj :",localCas, sujetVerbe)
                    if localCas in sujetVerbe and localCas!="Nom":
                        if localClasses:
                            localClasse=[classeElement for classeElement in localClasses if classeElement in gloses["VER"]["Genre"]][0]
                        else:
                            localClasse=""
                        classeVerbe=localClasse
                        nombreVerbe=localNombre
                        nombrePersonne=localNombre
                        casVerbe=localCas
                        if (debug or 0) and nPhrase==0: print ("cas",nombrePersonne, line)
                elif klbSujet=="OBJ":
                    if boolAttribut["VER"]["Genre"]:
                        classeVerbe=morphosyntax["Defauts"]["Genre"]
                    if boolAttribut["VER"]["Nombre"]:
                        nombreVerbe=morphosyntax["Defauts"]["Nombre"]
                    if boolAttribut["VER"]["Pers"]:
                        nombrePersonne=morphosyntax["Defauts"]["NbPers"]
                    
            if len(tampon)>=4:
                if tampon[3] and tampon[3].startswith(","):
                    tampon[3]=tampon[3][1:]
                indirect=tampon[3].split(" ")
                if debug: print "indirect : ",indirect
                if indirect!=['']:
                    if sortie=="ordre":
                        phrase[syntagmes['Phrase'].index('IND')]=previewer(faire_gp(indirect,"IND"),suffixe="{}")
                    else:
                        phrase[syntagmes['Phrase'].index('IND')]=faire_gp(indirect,"IND")
            ###################
            #
            # Modification pour ajouts multiples séparés par ;
            # 24/11/19
            #
            ###################
            if len(tampon)>=5:
                if tampon[4] and tampon[4].startswith(","):
                    tampon[4]=tampon[4][1:]
                comp=tampon[4].split(" ")
                if comp!=['']:
                    if sortie=="ordre":
                        phrase[syntagmes['Phrase'].index('COMP')]=previewer(multiplier_gp(comp),suffixe="{}")
                    else:
                        phrase[syntagmes['Phrase'].index('COMP')]=multiplier_gp(comp)
            if len(tampon)>=6:
                if tampon[5] and tampon[5].startswith(","):
                    tampon[5]=tampon[5][1:]
                ajout=tampon[5].split(" ")
                if sortie=="ordre":
                    phrase[syntagmes['Phrase'].index('AJOUT')]=previewer(multiplier_gp(ajout),suffixe="{}")
                else:
                    phrase[syntagmes['Phrase'].index('AJOUT')]=multiplier_gp(ajout)
            if not boolAttribut["VER"]["Genre"]:
                classeVerbe=""
            if not boolAttribut["VER"]["Nombre"]:
                nombreVerbe=""
            if not boolAttribut["VER"]["Pers"]:
                nombrePersonne=""
            else:
                nombrePersonne="Trois"+nombrePersonne.capitalize()
            if (debug or 0) and nPhrase==0: print "accord Verbe",nombreVerbe, classeVerbe, sujetVerbe, line

            noligFormeCitation=formeCitation
            for ligature in deligatures:
                noligFormeCitation=noligFormeCitation.replace(ligature,deligatures[ligature])
            noligFormeCitation=noligFormeCitation.replace("-","")

            glose="\\"+recoder(noligFormeCitation,deaccent)\
                +morphosyntax["VER"]["FormesBase"][verbeFormeIndex].capitalize()\
                +nombrePersonne\
                +classeVerbe.capitalize()\
                +nombreVerbe.capitalize()
            if (debug or 0) and nPhrase<200: print "glose Verbe",glose
            if sortie=="ordre":
                phrase[syntagmes['Phrase'].index('VER')]=previewer([glose],suffixe="{}")
            else:
                phrase[syntagmes['Phrase'].index('VER')]=glose
            lexemesLocaux.add(noligFormeCitation)
            texte.append(glose)
            if sortie in ["latex","traductions"]: 
                ajouterExemple("\\ex")
                if print_glose and print_phono and print_ortho:
                    ajouterExemple(comment+"\\gloses")
                elif print_glose+print_ortho+print_phono==2:
                    ajouterExemple(comment+"\\gloses")
            syntagmesBruts=[]
            syntagmesEtiquetes=[]
            for nMot,mot in enumerate(phrase):
                if mot!=0:
                    
                    if isinstance(mot,basestring):
                        syntagmeLocal=latex2ipa(mot)
                    else:
                        interFlat=[]
                        for m in flatten(mot):
                            mList=re.findall(ur"\\[^{]+{}",m)
                            if mList:
                                interFlat.extend(mList)
                            else:
                                interFlat.append(m)
                        if debug: print "interFlat",interFlat
                        if "RightLeft" in globals() and RightLeft and sortie=="latex":
                            interFlat.reverse()
                        syntagmeLocal=separateurMots.join([latex2ipa(f) for f in interFlat])
                    syntagmesBruts.append(syntagmeLocal)
                    syntagmesEtiquetes.append(syntagmeLocal)
                    if "RightLeft" in globals() and RightLeft and sortie=="latex":
                        syntagmesEtiquetes.append(syntagmes["Phrase"][nMot])
                    else:
                        syntagmesEtiquetes.insert(-1,syntagmes["Phrase"][nMot])
#                    syntagmesEtiquetes.insert(-1,syntagmes["Phrase"][nMot])
                    printflat(mot,"{}")
            if "RightLeft" in globals() and RightLeft and sortie=="latex":
                ligneSyntagmesLocaux=separateurMots.join(syntagmesBruts[::-1])+";"+" ".join(syntagmesEtiquetes[::-1])
            else:
                ligneSyntagmesLocaux=separateurMots.join(syntagmesBruts)+";"+" ".join(syntagmesEtiquetes)
#            ligneSyntagmesLocaux=separateurMots.join(syntagmesBruts)+";"+" ".join(syntagmesEtiquetes)
#            print ligneSyntagmesLocaux
            syntagmesLocaux.append(ligneSyntagmesLocaux)
            localAccumulateur=[accu for accu in accumulateur if accu!=""]
            if print_ortho:
                prefixe=""
                if sortie=="images":
                    if nPhrase%numImages==0:
                        prefixe="\\begin{preview}"
                    else:
                        prefixe=""
                    if nPhrase%numImages==numImages-1:
                        finLigne=finLignePreview
                    else:
                        finLigne=finLigneNoPreview
                elif sortie=="mots":
                    localAccumulateur=[debutLignePreview+accu+finLignePreview for accu in accumulateur if accu!=""]
            else:
                prefixe=marqueurCommentaire
            ajouterExemple(prefixe+separateurMots.join(localAccumulateur)+finLigne)
            for mot in phrase:
                if mot!=0:
                    printflat(mot,"P{}")
            if print_phono:
                prefixe=""
                if sortie in ["images","ordre"]:
                    prefixe=marqueurCommentaire
            else:
                prefixe=marqueurCommentaire
            if "RightLeft" in globals() and RightLeft and sortie=="latex" and separateurMots=="":
                ajouterExemple(prefixe+separateurMots.join(accumulateur[::-1])+finLigne)
            else:
                ajouterExemple(prefixe+separateurMots.join(accumulateur)+finLigne)
            for mot in phrase:
                if mot!=0 and sortie in ["latex","traductions"]:
                    printflat(mot,"G{}")
            if print_glose:
                prefixe=""
                if sortie in ["images","ordre"]:
                    prefixe=marqueurCommentaire
            else:
                prefixe=marqueurCommentaire
            if sortie in ["latex","traductions"]: ajouterExemple(prefixe+separateurMots.join(accumulateur)+finLigne)
            ##############
            #
            # Modification pour ajouts multiples
            # suppression des ; de séparation dans la traduction
            #
            ##############
            if "," in line:
                consts=line.split("\t")
                disloc=[]
                canon=[]
                for const in consts:
                    if const.startswith(","):
                        if ";" in const:
                            subConsts=const.split(";")
                            print "##############@"
                            print subConsts
                            disloc.append(subConsts[0][1:])
                            for subConst in subConsts[1:]:
                                canon.append(subConst.lstrip())
                        else:
                            disloc.append(const[1:])
                    else:
                        canon.append(const)
                line=",\t".join(disloc).strip()+", "+"\t".join(canon)
            if " ; " in line:
                line=line.replace(" ; "," ")
                        
            traduction=(line.strip().rstrip('.')).split()
            start=1
            for element in traduction:			# convertir les S majuscules à la finale des mots en minuscules
                element=element.strip("#").replace(u"’","'")
                if element!="":
                    if start:
                        start=0
                        element=element.capitalize()
                    caracteres=element
                    if len(caracteres)>1 and caracteres!=caracteres.lower() and caracteres!=caracteres.capitalize():
                        caracteres=list(caracteres[0]+caracteres[1:].lower())
#                    accumulerMots("".join(caracteres).encode('utf8'))
                    accumulerMots("".join(caracteres))
            if sortie=="latex": 
                ajouterExemple(taches()+" ".join(accumulateur)+".")
            elif sortie=="images":
                ajouterExemple(marqueurCommentaire+"\\begin{preview}"+" ".join(accumulateur)+"."+"\\end{preview}")
            elif sortie in ["ordre","mots"]:
                ajouterExemple("\\begin{preview}"+" ".join(accumulateur)+"."+"\\end{preview}")
                #if sortie=="mots": ajouterExemple("\\begin{preview}"+"."+"\\end{preview}")
            else:
                if debug: print accumulateur
                ajouterExemple(" ".join(accumulateur)+".")
            del accumulateur[:]
            if sortie=="latex" and print_coffee and random.randint(1,4)==1:
                stain=random.choice(["A","B","C","D"])
                stain=random.choice(["A","B","C"])
                alpha=random.random()/1.5
                angle=random.randint(0,360)
                xoff=random.randint(-200,0)
#                ajouterExemple('\\\\\\cofe%sm{%.3f}{1}{%d}{%d}{0}' % (stain,alpha,angle,xoff))
                ajouterExemple('\\hspace{-.35\\textwidth}\\cofe%sm{%.3f}{1}{%d}{%d}{0}' % (stain,alpha,angle,xoff))

    if sortie in ["latex","traductions"]: ajouterExemple("\\end{phrases}")
    if sortie in ["latex","traductions"]:
        if ('options' in globals() and options.print_cloze) or print_lexique:
            tab=(head,tail,"")
        else:
            tab=(head,tail,"%")
#        prononciationExtrait=[]
        ajouterVocabulaire(tab[2]+"\\begin{itemize}")
        ajouterVocabulaire(tab[2]+"\\Needspace{8\\baselineskip}%")
        ajouterVocabulaire(tab[2]+"\\item NOMS\\\\[-3ex]")
        print_tableaux(dimensionsTableaux["NOM"]["cols"],tableaux["NOM"],texte,dimensionsTableaux["NOM"]["long"],tab,False)
        ajouterVocabulaire(tab[2]+"\\Needspace{8\\baselineskip}%")
        ajouterVocabulaire(tab[2]+"\\item ADJECTIFS\\\\[-3ex]")
        print_tableaux(dimensionsTableaux["ADJ"]["cols"],tableaux["ADJ"],texte,dimensionsTableaux["ADJ"]["long"],tab,False)
        ajouterVocabulaire(tab[2]+"\\Needspace{8\\baselineskip}%")
        ajouterVocabulaire(tab[2]+"\\item VERBES\\\\[-3ex]")
        print_tableaux(dimensionsTableaux["VER"]["cols"],tableaux["VER"],texte,dimensionsTableaux["VER"]["long"],tab,False)
#        print_tableaux(2,tableaux["VER"],texte,20,tab)
        ajouterVocabulaire(tab[2]+"\\Needspace{8\\baselineskip}%")
        ajouterVocabulaire(tab[2]+u"\\item DÉTERMINANTS\\\\[-3ex]")
        print_tableaux(dimensionsTableaux["DET"]["cols"],tableaux["DET"],texte,dimensionsTableaux["DET"]["long"],tab,False)
#        print_tableaux(3,tableaux["DET"],texte,0,tab)
        ajouterVocabulaire(tab[2]+"\\Needspace{8\\baselineskip}%")
        ajouterVocabulaire(tab[2]+u"\\item PRÉPOSITIONS\\\\[-3ex]")
        print_tableaux(dimensionsTableaux["PREP"]["cols"],tableaux["PREP"],texte,dimensionsTableaux["PREP"]["long"],tab,False)
#        print_tableaux(2,tableaux["PREP"],texte,0,tab)
        ajouterVocabulaire(tab[2]+"\\end{itemize}")

        if sortie=="latex":
            with codecs.open(serie+complementPhrases+"Exemples"+variante+".tex", 'wb',encoding="utf8") as output:
                for texHead in texHeader:
                    output.write(texHead+"\n")
                for exemple in exemples:
                    output.write(exemple+"\n")
            with codecs.open(serie+complementPhrases+"Syntagmes"+variante+".txt", 'wb',encoding="utf8") as output:
                for exemple in syntagmesLocaux:
                    output.write(exemple+"\n")

        elif (sortie=="traductions" and variante=="-Corr"):
            with codecs.open(serie+complementPhrases+"Traductions"+variante+".tex", 'wb',encoding="utf8") as output:
                for texHead in texHeader:
                    output.write(texHead+"\n")
                for exemple in exemples:
                    output.write(exemple+"\n")            

        if sortie=="latex":
            with codecs.open(serie+complementPhrases+"Vocabulaire"+variante+".tex", 'wb',encoding="utf8") as output:
                for texHead in texHeader:
                    output.write(texHead+"\n")
                for vocable in vocabulaire:
    #                print [vocable]
                    output.write(vocable+"\n")

            with codecs.open(serie+complementPhrases+"Prononciation"+variante+".tex", 'wb',encoding="utf8") as output:
                for texHead in texHeader:
                    output.write(texHead+"\n")
                for ligne in prononciationBegin+prononciationExtrait+prononciationEnd:
                    output.write(ligne+"\n")
#    elif sortie=="images":
#        with codecs.open(serie+complementPhrases+"Images"+variante+".tex", 'wb',encoding="utf8") as output:
#            for exemple in exemples:
#                output.write(exemple+"\n")
    elif sortie in ["images","ordre","mots"]:
        with codecs.open(serie+complementPhrases+sortie.capitalize()+variante+".tex", 'wb',encoding="utf8") as output:
            for texHead in texHeader:
                output.write(texHead+"\n")
            for exemple in exemples:
                output.write(exemple+"\n")
    if sortie in ["images","traductions","ordre","mots"]:
        clozeTraductions=[]
        clozeExemples=exemples[:]
        filtreLignes=["\\begin{phrases}","\\ex","\\gloses","\\end{phrases}"]
        if sortie=="traductions":
            clozeExemples=[exemple for exemple in clozeExemples if (not exemple in filtreLignes) and not exemple.startswith("%")]
        for orthoLigne,phonoLigne,tradLigne in zip(*[iter(clozeExemples)]*3):
            if sortie=="traductions" and 0:
                print "ortho",orthoLigne
                print "phono",phonoLigne
                print "trad",tradLigne
            phonoLigne=phonoLigne.replace(previewerBegin,"").replace(previewerEnd,"")
            phonoLigne=phonoLigne.replace("P{}"," ").replace("{}"," ")
            phonoLigne=phonoLigne.replace(debutLignePreview,"").replace(finLignePreview,"")
            phonoMots=phonoLigne.strip(marqueurCommentaire).replace(finLignePreview,"").strip().split()
            tradLigne=tradLigne.strip(marqueurCommentaire).replace(debutLignePreview,"").replace(finLignePreview,"")
            phonoPhrase=[]
            for element in phonoMots:
                cleElement=element.strip().strip("\\{}")
                if element=="\\ex": cleElement=""
                if cleElement:
                    if not cleElement in traductions: print cleElement,phonoMots
                    phonoPhrase.append(traductions[cleElement])
            if separateurPhonoCloze=="" : suppLigne=";"+" ".join(phonoPhrase)
            else: suppLigne=""
            result=separateurPhonoCloze.join(phonoPhrase)+";"+tradLigne+suppLigne
            clozeTraductions.append(result)
        with codecs.open(serie+complementPhrases+sortie.capitalize()+".txt", 'wb',encoding="utf8") as output:
            for ligne in clozeTraductions:
                output.write(ligne+"\n")
        if sortie=="ordre" and separateurMots=="":
            dictSyntagmes={}
            dictTraductions={}
            ordreCles=[]
            for element in syntagmesLocaux:
                clePhono,valSyntagmes=element.split(";")
                dictSyntagmes[clePhono]=" ".join([v for v in valSyntagmes.split() if not v in nomFonctions])
                ordreCles.append(clePhono)
            for element in clozeTraductions:
                clePhono,valTrad,valMots=element.split(";")
                dictTraductions[clePhono]=valTrad
            morceauxPhrases=["%s;%s"%(dictSyntagmes[c],dictTraductions[c]) for c in ordreCles]
            with codecs.open(serie+complementPhrases+"OrdreSyntagmes"+variante+".txt", 'wb',encoding="utf8") as output:
                for exemple in morceauxPhrases:
                    output.write(exemple+"\n")

# %% [markdown]
# #### Traitement du fichier phrases

# %%
nomTableaux="Tableaux.yaml"
with open(serie+nomTableaux, 'r') as stream:
    tableaux=yaml.safe_load(stream)

# %%
sortie="traductions"
syntagmes=syntagmesLR
print syntagmes

lexemesLocaux=set()
if traduction_nom.endswith("csv") and variante!="-Corr":
    try:
        traduction_file = codecs.open(traduction_nom,"r","utf8")
    except IOError:
        print 'I could not open the translation file', traduction_nom
        sys.exit()      
    else:
        try:
            cloze_file = codecs.open(cloze_nom,"r","utf8")
        except IOError:
            print 'I could not open the cloze file', cloze_nom
            sys.exit()
        else:
            traductions={}
            for line in cloze_file.readlines():
                line=line.strip()
                if not line.startswith("#"):
                    elementsCloze=line.split(";")
                    traductions[elementsCloze[0]]=elementsCloze[5]
            cloze_file.close()
            exemples=[]
            accumulateur=[]
            vocabulaire=[]
#            prononciationExtrait=[]
            faire_phrases(traduction_file,sortie=sortie)
            traduction_file.close()

localClozes=filtrerCloze(lexemesLocaux)
with codecs.open(serie+complementPhrases+"%s-Clozes"%sortie.capitalize()+".txt", 'wb',encoding="utf8") as output:
    for ligne in localClozes:
        output.write(ligne+"\n")
# Out:
# {'Phrase': ['VER', 'COMP', 'SUJ', 'AJOUT', 'OBJ', 'IND'], 'GP': ['GN', 'PREP'], 'GADJ': ['ADV', 'ADJ', 'GP'], 'GN': ['GADJ', 'NOM', 'DET', 'GP']}

# %%
sortie="latex"
if "RightLeft" in globals() and RightLeft:
    syntagmes=syntagmesRL
else:
    syntagmes=syntagmesLR
print syntagmes

lexemesLocaux=set()
try:
    phrase_file = codecs.open((phrase_nom),"r","utf8")
except IOError:
    print 'I could not open the sentence file', phrase_nom
    sys.exit()
exemples=[]
accumulateur=[]
vocabulaire=[]
prononciationExtrait=[]
faire_phrases(phrase_file,sortie=sortie)
phrase_file.close()

localClozes=filtrerCloze(lexemesLocaux)
with codecs.open(serie+complementPhrases+"Phrases-Clozes"+".txt", 'wb',encoding="utf8") as output:
    for ligne in localClozes:
        output.write(ligne+"\n")
# Out:
# {'Phrase': ['IND', 'OBJ', 'AJOUT', 'SUJ', 'COMP', 'VER'], 'GP': ['PREP', 'GN'], 'GADJ': ['GP', 'ADJ', 'ADV'], 'GN': ['GP', 'DET', 'NOM', 'GADJ']}
# latex
# ===========================================
# les parents	aiment	ces enfants
#
# [u'aimer']
# verbe : [u'aiment']
# ('', '', 'SUJ')
# groupe depart : [u'les', u'parents']
# les
# parents
# groupe nom : [u'les', u'parents']
# mot [u'les']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'parents']
# vedette parent.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes parents M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# ('FAIRE_GN SUJET', [u'\\DEFMPl', u'\\parentMPl'], ([u'N2', u'M'], 'PL', ''))
#  PL [u'N2', u'M'] []
# frSuj PL
# sujet : 0
# objet :  [u'ces', u'enfants']
# groupe depart : [u'ces', u'enfants']
# ces
# enfants
# groupe nom : [u'ces', u'enfants']
# mot [u'ces']
# vedette DEM DET
# categories ['N1', 'N2'] DET
# mot [u'enfants']
# vedette enfant.N2.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N2', u'N']
# classes enfants N [u'N2', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEM']
# ('frObj', ([u'N2', u'N'], 'PL', ''), u'les parents\taiment\tces enfants\n')
# ('obj :', '', [])
# accord Verbe  M [] les parents	aiment	ces enfants
#
# glose Verbe \aimerPrsTroisPlM
# interFlat [u'\\DEMNPl', u'\\enfantNPl']
# printflat [u'\\DEMNPl', u'\\enfantNPl']
# printflat \DEMNPl
# printflat \enfantNPl
# interFlat [u'\\DEFMPl', u'\\parentMPl']
# printflat [u'\\DEFMPl', u'\\parentMPl']
# printflat \DEFMPl
# printflat \parentMPl
# printflat \aimerPrsTroisPlM
# printflat [u'\\DEMNPl', u'\\enfantNPl']
# printflat \DEMNPl
# printflat \enfantNPl
# printflat [u'\\DEFMPl', u'\\parentMPl']
# printflat \DEFMPl
# printflat \parentMPl
# printflat \aimerPrsTroisPlM
# printflat [u'\\DEMNPl', u'\\enfantNPl']
# printflat \DEMNPl
# printflat \enfantNPl
# printflat [u'\\DEFMPl', u'\\parentMPl']
# printflat \DEFMPl
# printflat \parentMPl
# printflat \aimerPrsTroisPlM
# ===========================================
# le papa	aime	la maman
#
# [u'aimer']
# verbe : [u'aime']
# ('', '', 'SUJ')
# groupe depart : [u'le', u'papa']
# le
# papa
# groupe nom : [u'le', u'papa']
# mot [u'le']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'papa']
# vedette papa.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes papa M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
#  SG [u'N2', u'M'] []
# sujet : 0
# objet :  [u'la', u'maman']
# groupe depart : [u'la', u'maman']
# la
# maman
# groupe nom : [u'la', u'maman']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'maman']
# vedette maman.N1.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N1', u'F']
# classes maman F [u'N1', u'F']
# accord : F
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# ('obj :', '', [])
# glose Verbe \aimerPrsTroisSgM
# interFlat [u'\\DEFFSg', u'\\mamanFSg']
# printflat [u'\\DEFFSg', u'\\mamanFSg']
# printflat \DEFFSg
# printflat \mamanFSg
# interFlat [u'\\DEFMSg', u'\\papaMSg']
# printflat [u'\\DEFMSg', u'\\papaMSg']
# printflat \DEFMSg
# printflat \papaMSg
# printflat \aimerPrsTroisSgM
# printflat [u'\\DEFFSg', u'\\mamanFSg']
# printflat \DEFFSg
# printflat \mamanFSg
# printflat [u'\\DEFMSg', u'\\papaMSg']
# printflat \DEFMSg
# printflat \papaMSg
# printflat \aimerPrsTroisSgM
# printflat [u'\\DEFFSg', u'\\mamanFSg']
# printflat \DEFFSg
# printflat \mamanFSg
# printflat [u'\\DEFMSg', u'\\papaMSg']
# printflat \DEFMSg
# printflat \papaMSg
# printflat \aimerPrsTroisSgM
# ===========================================
# cet enfant calme	dormait				avec les jouets
#
# [u'dormir']
# verbe : [u'dormait']
# ('', '', 'SUJ')
# groupe depart : [u'cet', u'enfant', u'calme']
# cet
# enfant
# calme
# groupe nom : [u'cet', u'enfant', u'calme']
# mot [u'cet']
# vedette DEM DET
# categories ['N1', 'N2'] DET
# mot [u'enfant']
# vedette enfant.N2.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N2', u'N']
# classes enfant N [u'N2', u'N']
# mot [u'calme']
# vedette calme ADJ
# categories ['N1', 'N2'] ADJ
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEM']
#  SG [u'N2', u'N'] []
# sujet : 0
# objet :  [u'']
# indirect :  [u'']
# faire_gp [u'avec', u'les', u'jouets']
# [u'avec'] avec
# fonction!=IND [u'avec', u'\xe0']
# \AVEC
# pas de Cas
# groupe prep : [u'avec', u'les', u'jouets']
# \AVEC
# les
# groupe depart : [u'les', u'jouets']
# les
# jouets
# groupe nom : [u'les', u'jouets']
# mot [u'les']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'jouets']
# vedette jouet.N2.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N2', u'F']
# classes jouets F [u'N2', u'F']
# accord : F
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'avec', u'les', u'jouets']  [u'\\AVEC', [u'\\DEFFPl', u'\\jouetFPl']]
# glose Verbe \dormirPstTroisSgN
# interFlat [u'\\AVEC', u'\\DEFFPl', u'\\jouetFPl']
# printflat [u'\\AVEC', [u'\\DEFFPl', u'\\jouetFPl']]
# printflat \AVEC
# printflat [u'\\DEFFPl', u'\\jouetFPl']
# printflat \DEFFPl
# printflat \jouetFPl
# interFlat [u'\\DEMNSg', u'\\enfantNSg', u'\\calmeNSg']
# printflat [u'\\DEMNSg', u'\\enfantNSg', u'\\calmeNSg']
# printflat \DEMNSg
# printflat \enfantNSg
# printflat \calmeNSg
# printflat \dormirPstTroisSgN
# printflat [u'\\AVEC', [u'\\DEFFPl', u'\\jouetFPl']]
# printflat \AVEC
# printflat [u'\\DEFFPl', u'\\jouetFPl']
# printflat \DEFFPl
# printflat \jouetFPl
# printflat [u'\\DEMNSg', u'\\enfantNSg', u'\\calmeNSg']
# printflat \DEMNSg
# printflat \enfantNSg
# printflat \calmeNSg
# printflat \dormirPstTroisSgN
# printflat [u'\\AVEC', [u'\\DEFFPl', u'\\jouetFPl']]
# printflat \AVEC
# printflat [u'\\DEFFPl', u'\\jouetFPl']
# printflat \DEFFPl
# printflat \jouetFPl
# printflat [u'\\DEMNSg', u'\\enfantNSg', u'\\calmeNSg']
# printflat \DEMNSg
# printflat \enfantNSg
# printflat \calmeNSg
# printflat \dormirPstTroisSgN
# ===========================================
# la maman	reste			à la maison	pour Laura
#
# [u'rester']
# verbe : [u'reste']
# ('', '', 'SUJ')
# groupe depart : [u'la', u'maman']
# la
# maman
# groupe nom : [u'la', u'maman']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'maman']
# vedette maman.N1.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N1', u'F']
# classes maman F [u'N1', u'F']
# accord : F
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
#  SG [u'N1', u'F'] []
# sujet : 0
# objet :  [u'']
# indirect :  [u'']
# faire_gp [u'\xe0', u'la', u'maison']
# [u'\xe0'] à
# fonction!=IND [u'\xe0', u'\xe0']
# \A
# pas de Cas
# groupe prep : [u'\xe0', u'la', u'maison']
# \A
# la
# groupe depart : [u'la', u'maison']
# la
# maison
# groupe nom : [u'la', u'maison']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'maison']
# vedette maison.N2.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N2', u'N']
# classes maison N [u'N2', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'\xe0', u'la', u'maison']  [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# faire_gp [u'pour', u'Laura']
# [u'pour'] pour
# fonction!=IND [u'pour', u'\xe0']
# \POUR
# pas de Cas
# groupe prep : [u'pour', u'Laura']
# \POUR
# Laura
# groupe depart : [u'Laura']
# Laura
# groupe nom : [u'Laura']
# mot [u'Laura']
# vedette Laura.N1.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N1', u'F']
# classes Laura F [u'N1', u'F']
# accord : F
# GP dans le GN :  []
# GN sans det ?  []
# [u'pour', u'Laura']  [u'\\POUR', [u'\\DEFFSg', u'\\LauraFSg']]
# glose Verbe \resterPrsTroisSgF
# interFlat [u'\\POUR', u'\\DEFFSg', u'\\LauraFSg']
# printflat [u'\\POUR', [u'\\DEFFSg', u'\\LauraFSg']]
# printflat \POUR
# printflat [u'\\DEFFSg', u'\\LauraFSg']
# printflat \DEFFSg
# printflat \LauraFSg
# interFlat [u'\\DEFFSg', u'\\mamanFSg']
# printflat [u'\\DEFFSg', u'\\mamanFSg']
# printflat \DEFFSg
# printflat \mamanFSg
# interFlat [u'\\A', u'\\DEFNSg', u'\\maisonNSg']
# printflat [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \resterPrsTroisSgF
# printflat [u'\\POUR', [u'\\DEFFSg', u'\\LauraFSg']]
# printflat \POUR
# printflat [u'\\DEFFSg', u'\\LauraFSg']
# printflat \DEFFSg
# printflat \LauraFSg
# printflat [u'\\DEFFSg', u'\\mamanFSg']
# printflat \DEFFSg
# printflat \mamanFSg
# printflat [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \resterPrsTroisSgF
# printflat [u'\\POUR', [u'\\DEFFSg', u'\\LauraFSg']]
# printflat \POUR
# printflat [u'\\DEFFSg', u'\\LauraFSg']
# printflat \DEFFSg
# printflat \LauraFSg
# printflat [u'\\DEFFSg', u'\\mamanFSg']
# printflat \DEFFSg
# printflat \mamanFSg
# printflat [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \resterPrsTroisSgF
# ===========================================
# Christelle	garde	le bébé		pour une journée
#
# [u'garder']
# verbe : [u'garde']
# ('', '', 'SUJ')
# groupe depart : [u'Christelle']
# Christelle
# groupe nom : [u'Christelle']
# mot [u'Christelle']
# vedette Christelle.N2.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N2', u'F']
# classes Christelle F [u'N2', u'F']
# accord : F
# GP dans le GN :  []
# GN sans det ?  []
#  SG [u'N2', u'F'] []
# sujet : 0
# objet :  [u'le', u'b\xe9b\xe9']
# groupe depart : [u'le', u'b\xe9b\xe9']
# le
# bébé
# groupe nom : [u'le', u'b\xe9b\xe9']
# mot [u'le']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'b\xe9b\xe9']
# vedette bébé.N1.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N1', u'M']
# classes bébé M [u'N1', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# ('obj :', '', [])
# indirect :  [u'']
# faire_gp [u'pour', u'une', u'journ\xe9e']
# [u'pour'] pour
# fonction!=IND [u'pour', u'\xe0']
# \POUR
# pas de Cas
# groupe prep : [u'pour', u'une', u'journ\xe9e']
# \POUR
# une
# groupe depart : [u'une', u'journ\xe9e']
# une
# journée
# groupe nom : [u'une', u'journ\xe9e']
# mot [u'une']
# vedette IND DET
# categories ['N1', 'N2'] DET
# mot [u'journ\xe9e']
# vedette journée.N1.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N1', u'N']
# classes journée N [u'N1', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'IND']
# [u'pour', u'une', u'journ\xe9e']  [u'\\POUR', [u'\\INDNSg', u'\\journeeNSg']]
# glose Verbe \garderPrsTroisSgF
# interFlat [u'\\DEFMSg', u'\\bebeMSg']
# printflat [u'\\DEFMSg', u'\\bebeMSg']
# printflat \DEFMSg
# printflat \bebeMSg
# interFlat [u'\\DEFFSg', u'\\ChristelleFSg']
# printflat [u'\\DEFFSg', u'\\ChristelleFSg']
# printflat \DEFFSg
# printflat \ChristelleFSg
# interFlat [u'\\POUR', u'\\INDNSg', u'\\journeeNSg']
# printflat [u'\\POUR', [u'\\INDNSg', u'\\journeeNSg']]
# printflat \POUR
# printflat [u'\\INDNSg', u'\\journeeNSg']
# printflat \INDNSg
# printflat \journeeNSg
# printflat \garderPrsTroisSgF
# printflat [u'\\DEFMSg', u'\\bebeMSg']
# printflat \DEFMSg
# printflat \bebeMSg
# printflat [u'\\DEFFSg', u'\\ChristelleFSg']
# printflat \DEFFSg
# printflat \ChristelleFSg
# printflat [u'\\POUR', [u'\\INDNSg', u'\\journeeNSg']]
# printflat \POUR
# printflat [u'\\INDNSg', u'\\journeeNSg']
# printflat \INDNSg
# printflat \journeeNSg
# printflat \garderPrsTroisSgF
# printflat [u'\\DEFMSg', u'\\bebeMSg']
# printflat \DEFMSg
# printflat \bebeMSg
# printflat [u'\\DEFFSg', u'\\ChristelleFSg']
# printflat \DEFFSg
# printflat \ChristelleFSg
# printflat [u'\\POUR', [u'\\INDNSg', u'\\journeeNSg']]
# printflat \POUR
# printflat [u'\\INDNSg', u'\\journeeNSg']
# printflat \INDNSg
# printflat \journeeNSg
# printflat \garderPrsTroisSgF
# ===========================================
# le papa	mange				avec cette femme
#
# [u'manger']
# verbe : [u'mange']
# ('', '', 'SUJ')
# groupe depart : [u'le', u'papa']
# le
# papa
# groupe nom : [u'le', u'papa']
# mot [u'le']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'papa']
# vedette papa.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes papa M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
#  SG [u'N2', u'M'] []
# sujet : 0
# objet :  [u'']
# indirect :  [u'']
# faire_gp [u'avec', u'cette', u'femme']
# [u'avec'] avec
# fonction!=IND [u'avec', u'\xe0']
# \AVEC
# pas de Cas
# groupe prep : [u'avec', u'cette', u'femme']
# \AVEC
# cette
# groupe depart : [u'cette', u'femme']
# cette
# femme
# groupe nom : [u'cette', u'femme']
# mot [u'cette']
# vedette DEM DET
# categories ['N1', 'N2'] DET
# mot [u'femme']
# vedette femme.N1.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N1', u'N']
# classes femme N [u'N1', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEM']
# [u'avec', u'cette', u'femme']  [u'\\AVEC', [u'\\DEMNSg', u'\\femmeNSg']]
# glose Verbe \mangerPrsTroisSgM
# interFlat [u'\\AVEC', u'\\DEMNSg', u'\\femmeNSg']
# printflat [u'\\AVEC', [u'\\DEMNSg', u'\\femmeNSg']]
# printflat \AVEC
# printflat [u'\\DEMNSg', u'\\femmeNSg']
# printflat \DEMNSg
# printflat \femmeNSg
# interFlat [u'\\DEFMSg', u'\\papaMSg']
# printflat [u'\\DEFMSg', u'\\papaMSg']
# printflat \DEFMSg
# printflat \papaMSg
# printflat \mangerPrsTroisSgM
# printflat [u'\\AVEC', [u'\\DEMNSg', u'\\femmeNSg']]
# printflat \AVEC
# printflat [u'\\DEMNSg', u'\\femmeNSg']
# printflat \DEMNSg
# printflat \femmeNSg
# printflat [u'\\DEFMSg', u'\\papaMSg']
# printflat \DEFMSg
# printflat \papaMSg
# printflat \mangerPrsTroisSgM
# printflat [u'\\AVEC', [u'\\DEMNSg', u'\\femmeNSg']]
# printflat \AVEC
# printflat [u'\\DEMNSg', u'\\femmeNSg']
# printflat \DEMNSg
# printflat \femmeNSg
# printflat [u'\\DEFMSg', u'\\papaMSg']
# printflat \DEFMSg
# printflat \papaMSg
# printflat \mangerPrsTroisSgM
# ===========================================
# François	rentrait			à la maison
#
# [u'rentrer']
# verbe : [u'rentrait']
# ('', '', 'SUJ')
# groupe depart : [u'Fran\xe7ois']
# François
# groupe nom : [u'Fran\xe7ois']
# mot [u'Fran\xe7ois']
# vedette François.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes François M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  []
#  PL [u'N2', u'M'] []
# sujet : 0
# objet :  [u'']
# indirect :  [u'']
# faire_gp [u'\xe0', u'la', u'maison']
# [u'\xe0'] à
# fonction!=IND [u'\xe0', u'\xe0']
# \A
# pas de Cas
# groupe prep : [u'\xe0', u'la', u'maison']
# \A
# la
# groupe depart : [u'la', u'maison']
# la
# maison
# groupe nom : [u'la', u'maison']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'maison']
# vedette maison.N2.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N2', u'N']
# classes maison N [u'N2', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'\xe0', u'la', u'maison']  [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# glose Verbe \rentrerPstTroisPlM
# interFlat [u'\\DEFMPl', u'\\FrancoisMPl']
# printflat [u'\\DEFMPl', u'\\FrancoisMPl']
# printflat \DEFMPl
# printflat \FrancoisMPl
# interFlat [u'\\A', u'\\DEFNSg', u'\\maisonNSg']
# printflat [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \rentrerPstTroisPlM
# printflat [u'\\DEFMPl', u'\\FrancoisMPl']
# printflat \DEFMPl
# printflat \FrancoisMPl
# printflat [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \rentrerPstTroisPlM
# printflat [u'\\DEFMPl', u'\\FrancoisMPl']
# printflat \DEFMPl
# printflat \FrancoisMPl
# printflat [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \rentrerPstTroisPlM
# ===========================================
# les parents	aimaient	un enfant calme
#
# [u'aimer']
# verbe : [u'aimaient']
# ('', '', 'SUJ')
# groupe depart : [u'les', u'parents']
# les
# parents
# groupe nom : [u'les', u'parents']
# mot [u'les']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'parents']
# vedette parent.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes parents M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
#  PL [u'N2', u'M'] []
# sujet : 0
# objet :  [u'un', u'enfant', u'calme']
# groupe depart : [u'un', u'enfant', u'calme']
# un
# enfant
# calme
# groupe nom : [u'un', u'enfant', u'calme']
# mot [u'un']
# vedette IND DET
# categories ['N1', 'N2'] DET
# mot [u'enfant']
# vedette enfant.N2.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N2', u'N']
# classes enfant N [u'N2', u'N']
# mot [u'calme']
# vedette calme ADJ
# categories ['N1', 'N2'] ADJ
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'IND']
# ('obj :', '', [])
# glose Verbe \aimerPstTroisPlM
# interFlat [u'\\INDNSg', u'\\enfantNSg', u'\\calmeNSg']
# printflat [u'\\INDNSg', u'\\enfantNSg', u'\\calmeNSg']
# printflat \INDNSg
# printflat \enfantNSg
# printflat \calmeNSg
# interFlat [u'\\DEFMPl', u'\\parentMPl']
# printflat [u'\\DEFMPl', u'\\parentMPl']
# printflat \DEFMPl
# printflat \parentMPl
# printflat \aimerPstTroisPlM
# printflat [u'\\INDNSg', u'\\enfantNSg', u'\\calmeNSg']
# printflat \INDNSg
# printflat \enfantNSg
# printflat \calmeNSg
# printflat [u'\\DEFMPl', u'\\parentMPl']
# printflat \DEFMPl
# printflat \parentMPl
# printflat \aimerPstTroisPlM
# printflat [u'\\INDNSg', u'\\enfantNSg', u'\\calmeNSg']
# printflat \INDNSg
# printflat \enfantNSg
# printflat \calmeNSg
# printflat [u'\\DEFMPl', u'\\parentMPl']
# printflat \DEFMPl
# printflat \parentMPl
# printflat \aimerPstTroisPlM
# ===========================================
# le couple	mangeait	les fraises sucrées
#
# [u'manger']
# verbe : [u'mangeait']
# ('', '', 'SUJ')
# groupe depart : [u'le', u'couple']
# le
# couple
# groupe nom : [u'le', u'couple']
# mot [u'le']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'couple']
# vedette couple.N1.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N1', u'N']
# classes couple N [u'N1', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
#  SG [u'N1', u'N'] []
# sujet : 0
# objet :  [u'les', u'fraises', u'sucr\xe9es']
# groupe depart : [u'les', u'fraises', u'sucr\xe9es']
# les
# fraises
# sucrées
# groupe nom : [u'les', u'fraises', u'sucr\xe9es']
# mot [u'les']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'fraises']
# vedette fraise.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes fraises M [u'N2', u'M']
# mot [u'sucr\xe9es']
# vedette sucré ADJ
# categories ['N1', 'N2'] ADJ
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# ('obj :', '', [])
# glose Verbe \mangerPstTroisSgN
# interFlat [u'\\DEFMPl', u'\\fraiseMPl', u'\\sucreMPl']
# printflat [u'\\DEFMPl', u'\\fraiseMPl', u'\\sucreMPl']
# printflat \DEFMPl
# printflat \fraiseMPl
# printflat \sucreMPl
# interFlat [u'\\DEFNSg', u'\\coupleNSg']
# printflat [u'\\DEFNSg', u'\\coupleNSg']
# printflat \DEFNSg
# printflat \coupleNSg
# printflat \mangerPstTroisSgN
# printflat [u'\\DEFMPl', u'\\fraiseMPl', u'\\sucreMPl']
# printflat \DEFMPl
# printflat \fraiseMPl
# printflat \sucreMPl
# printflat [u'\\DEFNSg', u'\\coupleNSg']
# printflat \DEFNSg
# printflat \coupleNSg
# printflat \mangerPstTroisSgN
# printflat [u'\\DEFMPl', u'\\fraiseMPl', u'\\sucreMPl']
# printflat \DEFMPl
# printflat \fraiseMPl
# printflat \sucreMPl
# printflat [u'\\DEFNSg', u'\\coupleNSg']
# printflat \DEFNSg
# printflat \coupleNSg
# printflat \mangerPstTroisSgN
# ===========================================
# l’homme	restait			au travail	sans la famille
#
# [u'rester']
# verbe : [u'restait']
# ('', '', 'SUJ')
# groupe depart : [u'l', u'homme']
# l
# homme
# groupe nom : [u'l', u'homme']
# mot [u'l']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'homme']
# vedette homme.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes homme M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
#  SG [u'N2', u'M'] []
# sujet : 0
# objet :  [u'']
# indirect :  [u'']
# EXT :  [u'au', u'travail'] [u'\xe0', u'le'] [u'travail']
# faire_gp [u'\xe0', u'le', u'travail']
# [u'\xe0'] à
# fonction!=IND [u'\xe0', u'\xe0']
# \A
# pas de Cas
# groupe prep : [u'\xe0', u'le', u'travail']
# \A
# le
# groupe depart : [u'le', u'travail']
# le
# travail
# groupe nom : [u'le', u'travail']
# mot [u'le']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'travail']
# vedette travail.N1.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N1', u'F']
# classes travail F [u'N1', u'F']
# accord : F
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'\xe0', u'le', u'travail']  [u'\\A', [u'\\DEFFSg', u'\\travailFSg']]
# faire_gp [u'sans', u'la', u'famille']
# [u'sans'] sans
# fonction!=IND [u'sans', u'\xe0']
# \SANS
# pas de Cas
# groupe prep : [u'sans', u'la', u'famille']
# \SANS
# la
# groupe depart : [u'la', u'famille']
# la
# famille
# groupe nom : [u'la', u'famille']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'famille']
# vedette famille.N1.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N1', u'N']
# classes famille N [u'N1', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'sans', u'la', u'famille']  [u'\\SANS', [u'\\DEFNSg', u'\\familleNSg']]
# glose Verbe \resterPstTroisSgM
# interFlat [u'\\SANS', u'\\DEFNSg', u'\\familleNSg']
# printflat [u'\\SANS', [u'\\DEFNSg', u'\\familleNSg']]
# printflat \SANS
# printflat [u'\\DEFNSg', u'\\familleNSg']
# printflat \DEFNSg
# printflat \familleNSg
# interFlat [u'\\DEFMSg', u'\\hommeMSg']
# printflat [u'\\DEFMSg', u'\\hommeMSg']
# printflat \DEFMSg
# printflat \hommeMSg
# interFlat [u'\\A', u'\\DEFFSg', u'\\travailFSg']
# printflat [u'\\A', [u'\\DEFFSg', u'\\travailFSg']]
# printflat \A
# printflat [u'\\DEFFSg', u'\\travailFSg']
# printflat \DEFFSg
# printflat \travailFSg
# printflat \resterPstTroisSgM
# printflat [u'\\SANS', [u'\\DEFNSg', u'\\familleNSg']]
# printflat \SANS
# printflat [u'\\DEFNSg', u'\\familleNSg']
# printflat \DEFNSg
# printflat \familleNSg
# printflat [u'\\DEFMSg', u'\\hommeMSg']
# printflat \DEFMSg
# printflat \hommeMSg
# printflat [u'\\A', [u'\\DEFFSg', u'\\travailFSg']]
# printflat \A
# printflat [u'\\DEFFSg', u'\\travailFSg']
# printflat \DEFFSg
# printflat \travailFSg
# printflat \resterPstTroisSgM
# printflat [u'\\SANS', [u'\\DEFNSg', u'\\familleNSg']]
# printflat \SANS
# printflat [u'\\DEFNSg', u'\\familleNSg']
# printflat \DEFNSg
# printflat \familleNSg
# printflat [u'\\DEFMSg', u'\\hommeMSg']
# printflat \DEFMSg
# printflat \hommeMSg
# printflat [u'\\A', [u'\\DEFFSg', u'\\travailFSg']]
# printflat \A
# printflat [u'\\DEFFSg', u'\\travailFSg']
# printflat \DEFFSg
# printflat \travailFSg
# printflat \resterPstTroisSgM
# ===========================================
# les femmes	changeaient	les bébés
#
# [u'changer']
# verbe : [u'changeaient']
# ('', '', 'SUJ')
# groupe depart : [u'les', u'femmes']
# les
# femmes
# groupe nom : [u'les', u'femmes']
# mot [u'les']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'femmes']
# vedette femme.N1.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N1', u'N']
# classes femmes N [u'N1', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
#  PL [u'N1', u'N'] []
# sujet : 0
# objet :  [u'les', u'b\xe9b\xe9s']
# groupe depart : [u'les', u'b\xe9b\xe9s']
# les
# bébés
# groupe nom : [u'les', u'b\xe9b\xe9s']
# mot [u'les']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'b\xe9b\xe9s']
# vedette bébé.N1.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N1', u'M']
# classes bébés M [u'N1', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# ('obj :', '', [])
# glose Verbe \changerPstTroisPlN
# interFlat [u'\\DEFMPl', u'\\bebeMPl']
# printflat [u'\\DEFMPl', u'\\bebeMPl']
# printflat \DEFMPl
# printflat \bebeMPl
# interFlat [u'\\DEFNPl', u'\\femmeNPl']
# printflat [u'\\DEFNPl', u'\\femmeNPl']
# printflat \DEFNPl
# printflat \femmeNPl
# printflat \changerPstTroisPlN
# printflat [u'\\DEFMPl', u'\\bebeMPl']
# printflat \DEFMPl
# printflat \bebeMPl
# printflat [u'\\DEFNPl', u'\\femmeNPl']
# printflat \DEFNPl
# printflat \femmeNPl
# printflat \changerPstTroisPlN
# printflat [u'\\DEFMPl', u'\\bebeMPl']
# printflat \DEFMPl
# printflat \bebeMPl
# printflat [u'\\DEFNPl', u'\\femmeNPl']
# printflat \DEFNPl
# printflat \femmeNPl
# printflat \changerPstTroisPlN
# ===========================================
# un bébé	va			à la crèche	malgré cette après-midi ensoleillée
#
# [u'aller']
# verbe : [u'va']
# ('', '', 'SUJ')
# groupe depart : [u'un', u'b\xe9b\xe9']
# un
# bébé
# groupe nom : [u'un', u'b\xe9b\xe9']
# mot [u'un']
# vedette IND DET
# categories ['N1', 'N2'] DET
# mot [u'b\xe9b\xe9']
# vedette bébé.N1.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N1', u'M']
# classes bébé M [u'N1', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'IND']
#  SG [u'N1', u'M'] []
# sujet : 0
# objet :  [u'']
# indirect :  [u'']
# faire_gp [u'\xe0', u'la', u'cr\xe8che']
# [u'\xe0'] à
# fonction!=IND [u'\xe0', u'\xe0']
# \A
# pas de Cas
# groupe prep : [u'\xe0', u'la', u'cr\xe8che']
# \A
# la
# groupe depart : [u'la', u'cr\xe8che']
# la
# crèche
# groupe nom : [u'la', u'cr\xe8che']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'cr\xe8che']
# vedette crèche.N1.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N1', u'N']
# classes crèche N [u'N1', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'\xe0', u'la', u'cr\xe8che']  [u'\\A', [u'\\DEFNSg', u'\\crecheNSg']]
# faire_gp [u'malgr\xe9', u'cette', u'apr\xe8s-midi', u'ensoleill\xe9e']
# [u'malgr\xe9'] malgré
# fonction!=IND [u'malgr\xe9', u'\xe0']
# \MALGRE
# pas de Cas
# groupe prep : [u'malgr\xe9', u'cette', u'apr\xe8s-midi', u'ensoleill\xe9e']
# \MALGRE
# cette
# groupe depart : [u'cette', u'apr\xe8s-midi', u'ensoleill\xe9e']
# cette
# après-midi
# ensoleillée
# groupe nom : [u'cette', u'apr\xe8s-midi', u'ensoleill\xe9e']
# mot [u'cette']
# vedette DEM DET
# categories ['N1', 'N2'] DET
# mot [u'apr\xe8s-midi']
# vedette après-midi.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes après-midi M [u'N2', u'M']
# mot [u'ensoleill\xe9e']
# vedette ensoleillé ADJ
# categories ['N1', 'N2'] ADJ
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEM']
# [u'malgr\xe9', u'cette', u'apr\xe8s-midi', u'ensoleill\xe9e']  [u'\\MALGRE', [u'\\DEMMSg', u'\\apresmidiMSg', u'\\ensoleilleMSg']]
# glose Verbe \allerPrsTroisSgM
# interFlat [u'\\MALGRE', u'\\DEMMSg', u'\\apresmidiMSg', u'\\ensoleilleMSg']
# printflat [u'\\MALGRE', [u'\\DEMMSg', u'\\apresmidiMSg', u'\\ensoleilleMSg']]
# printflat \MALGRE
# printflat [u'\\DEMMSg', u'\\apresmidiMSg', u'\\ensoleilleMSg']
# printflat \DEMMSg
# printflat \apresmidiMSg
# printflat \ensoleilleMSg
# interFlat [u'\\INDMSg', u'\\bebeMSg']
# printflat [u'\\INDMSg', u'\\bebeMSg']
# printflat \INDMSg
# printflat \bebeMSg
# interFlat [u'\\A', u'\\DEFNSg', u'\\crecheNSg']
# printflat [u'\\A', [u'\\DEFNSg', u'\\crecheNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\crecheNSg']
# printflat \DEFNSg
# printflat \crecheNSg
# printflat \allerPrsTroisSgM
# printflat [u'\\MALGRE', [u'\\DEMMSg', u'\\apresmidiMSg', u'\\ensoleilleMSg']]
# printflat \MALGRE
# printflat [u'\\DEMMSg', u'\\apresmidiMSg', u'\\ensoleilleMSg']
# printflat \DEMMSg
# printflat \apresmidiMSg
# printflat \ensoleilleMSg
# printflat [u'\\INDMSg', u'\\bebeMSg']
# printflat \INDMSg
# printflat \bebeMSg
# printflat [u'\\A', [u'\\DEFNSg', u'\\crecheNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\crecheNSg']
# printflat \DEFNSg
# printflat \crecheNSg
# printflat \allerPrsTroisSgM
# printflat [u'\\MALGRE', [u'\\DEMMSg', u'\\apresmidiMSg', u'\\ensoleilleMSg']]
# printflat \MALGRE
# printflat [u'\\DEMMSg', u'\\apresmidiMSg', u'\\ensoleilleMSg']
# printflat \DEMMSg
# printflat \apresmidiMSg
# printflat \ensoleilleMSg
# printflat [u'\\INDMSg', u'\\bebeMSg']
# printflat \INDMSg
# printflat \bebeMSg
# printflat [u'\\A', [u'\\DEFNSg', u'\\crecheNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\crecheNSg']
# printflat \DEFNSg
# printflat \crecheNSg
# printflat \allerPrsTroisSgM
# ===========================================
# Hugo	oublie	un doudou		dans la maison
#
# [u'oublier']
# verbe : [u'oublie']
# ('', '', 'SUJ')
# groupe depart : [u'Hugo']
# Hugo
# groupe nom : [u'Hugo']
# mot [u'Hugo']
# vedette Hugo.N1.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N1', u'M']
# classes Hugo M [u'N1', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  []
#  SG [u'N1', u'M'] []
# sujet : 0
# objet :  [u'un', u'doudou']
# groupe depart : [u'un', u'doudou']
# un
# doudou
# groupe nom : [u'un', u'doudou']
# mot [u'un']
# vedette IND DET
# categories ['N1', 'N2'] DET
# mot [u'doudou']
# vedette doudou.N1.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N1', u'N']
# classes doudou N [u'N1', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'IND']
# ('obj :', '', [])
# indirect :  [u'']
# faire_gp [u'dans', u'la', u'maison']
# [u'dans'] dans
# fonction!=IND [u'dans', u'\xe0']
# \DANS
# pas de Cas
# groupe prep : [u'dans', u'la', u'maison']
# \DANS
# la
# groupe depart : [u'la', u'maison']
# la
# maison
# groupe nom : [u'la', u'maison']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'maison']
# vedette maison.N2.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N2', u'N']
# classes maison N [u'N2', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'dans', u'la', u'maison']  [u'\\DANS', [u'\\DEFNSg', u'\\maisonNSg']]
# glose Verbe \oublierPrsTroisSgM
# interFlat [u'\\INDNSg', u'\\doudouNSg']
# printflat [u'\\INDNSg', u'\\doudouNSg']
# printflat \INDNSg
# printflat \doudouNSg
# interFlat [u'\\DEFMSg', u'\\HugoMSg']
# printflat [u'\\DEFMSg', u'\\HugoMSg']
# printflat \DEFMSg
# printflat \HugoMSg
# interFlat [u'\\DANS', u'\\DEFNSg', u'\\maisonNSg']
# printflat [u'\\DANS', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \oublierPrsTroisSgM
# printflat [u'\\INDNSg', u'\\doudouNSg']
# printflat \INDNSg
# printflat \doudouNSg
# printflat [u'\\DEFMSg', u'\\HugoMSg']
# printflat \DEFMSg
# printflat \HugoMSg
# printflat [u'\\DANS', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \oublierPrsTroisSgM
# printflat [u'\\INDNSg', u'\\doudouNSg']
# printflat \INDNSg
# printflat \doudouNSg
# printflat [u'\\DEFMSg', u'\\HugoMSg']
# printflat \DEFMSg
# printflat \HugoMSg
# printflat [u'\\DANS', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \oublierPrsTroisSgM
# ===========================================
# Laura	rentre			à la maison	avec des copains
#
# [u'rentrer']
# verbe : [u'rentre']
# ('', '', 'SUJ')
# groupe depart : [u'Laura']
# Laura
# groupe nom : [u'Laura']
# mot [u'Laura']
# vedette Laura.N1.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N1', u'F']
# classes Laura F [u'N1', u'F']
# accord : F
# GP dans le GN :  []
# GN sans det ?  []
#  SG [u'N1', u'F'] []
# sujet : 0
# objet :  [u'']
# indirect :  [u'']
# faire_gp [u'\xe0', u'la', u'maison']
# [u'\xe0'] à
# fonction!=IND [u'\xe0', u'\xe0']
# \A
# pas de Cas
# groupe prep : [u'\xe0', u'la', u'maison']
# \A
# la
# groupe depart : [u'la', u'maison']
# la
# maison
# groupe nom : [u'la', u'maison']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'maison']
# vedette maison.N2.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N2', u'N']
# classes maison N [u'N2', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'\xe0', u'la', u'maison']  [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# faire_gp [u'avec', u'des', u'copains']
# [u'avec'] avec
# fonction!=IND [u'avec', u'\xe0']
# \AVEC
# pas de Cas
# groupe prep : [u'avec', u'des', u'copains']
# \AVEC
# des
# groupe depart : [u'des', u'copains']
# des
# copains
# groupe nom : [u'des', u'copains']
# mot [u'des']
# vedette IND DET
# categories ['N1', 'N2'] DET
# mot [u'copains']
# vedette copain.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes copains M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'IND']
# [u'avec', u'des', u'copains']  [u'\\AVEC', [u'\\INDMPl', u'\\copainMPl']]
# glose Verbe \rentrerPrsTroisSgF
# interFlat [u'\\AVEC', u'\\INDMPl', u'\\copainMPl']
# printflat [u'\\AVEC', [u'\\INDMPl', u'\\copainMPl']]
# printflat \AVEC
# printflat [u'\\INDMPl', u'\\copainMPl']
# printflat \INDMPl
# printflat \copainMPl
# interFlat [u'\\DEFFSg', u'\\LauraFSg']
# printflat [u'\\DEFFSg', u'\\LauraFSg']
# printflat \DEFFSg
# printflat \LauraFSg
# interFlat [u'\\A', u'\\DEFNSg', u'\\maisonNSg']
# printflat [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \rentrerPrsTroisSgF
# printflat [u'\\AVEC', [u'\\INDMPl', u'\\copainMPl']]
# printflat \AVEC
# printflat [u'\\INDMPl', u'\\copainMPl']
# printflat \INDMPl
# printflat \copainMPl
# printflat [u'\\DEFFSg', u'\\LauraFSg']
# printflat \DEFFSg
# printflat \LauraFSg
# printflat [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \rentrerPrsTroisSgF
# printflat [u'\\AVEC', [u'\\INDMPl', u'\\copainMPl']]
# printflat \AVEC
# printflat [u'\\INDMPl', u'\\copainMPl']
# printflat \INDMPl
# printflat \copainMPl
# printflat [u'\\DEFFSg', u'\\LauraFSg']
# printflat \DEFFSg
# printflat \LauraFSg
# printflat [u'\\A', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \A
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \rentrerPrsTroisSgF
# ===========================================
# le garçon	joue				avec un copain ; dans le salon
#
# [u'jouer']
# verbe : [u'joue']
# ('', '', 'SUJ')
# groupe depart : [u'le', u'gar\xe7on']
# le
# garçon
# groupe nom : [u'le', u'gar\xe7on']
# mot [u'le']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'gar\xe7on']
# vedette garçon.N1.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N1', u'M']
# classes garçon M [u'N1', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
#  SG [u'N1', u'M'] []
# sujet : 0
# objet :  [u'']
# indirect :  [u'']
# [[u'avec', u'un', u'copain'], [u'dans', u'le', u'salon']]
# faire_gp [u'avec', u'un', u'copain']
# [u'avec'] avec
# fonction!=IND [u'avec', u'\xe0']
# \AVEC
# pas de Cas
# groupe prep : [u'avec', u'un', u'copain']
# \AVEC
# un
# groupe depart : [u'un', u'copain']
# un
# copain
# groupe nom : [u'un', u'copain']
# mot [u'un']
# vedette IND DET
# categories ['N1', 'N2'] DET
# mot [u'copain']
# vedette copain.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes copain M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'IND']
# [u'avec', u'un', u'copain']  [u'\\AVEC', [u'\\INDMSg', u'\\copainMSg']]
# faire_gp [u'dans', u'le', u'salon']
# [u'dans'] dans
# fonction!=IND [u'dans', u'\xe0']
# \DANS
# pas de Cas
# groupe prep : [u'dans', u'le', u'salon']
# \DANS
# le
# groupe depart : [u'le', u'salon']
# le
# salon
# groupe nom : [u'le', u'salon']
# mot [u'le']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'salon']
# vedette salon.N1.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N1', u'N']
# classes salon N [u'N1', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'dans', u'le', u'salon']  [u'\\DANS', [u'\\DEFNSg', u'\\salonNSg']]
# glose Verbe \jouerPrsTroisSgM
# interFlat [u'\\AVEC', u'\\INDMSg', u'\\copainMSg', u'\\DANS', u'\\DEFNSg', u'\\salonNSg']
# printflat [u'\\AVEC', [u'\\INDMSg', u'\\copainMSg'], u'\\DANS', [u'\\DEFNSg', u'\\salonNSg']]
# printflat \AVEC
# printflat [u'\\INDMSg', u'\\copainMSg']
# printflat \INDMSg
# printflat \copainMSg
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\salonNSg']
# printflat \DEFNSg
# printflat \salonNSg
# interFlat [u'\\DEFMSg', u'\\garconMSg']
# printflat [u'\\DEFMSg', u'\\garconMSg']
# printflat \DEFMSg
# printflat \garconMSg
# printflat \jouerPrsTroisSgM
# printflat [u'\\AVEC', [u'\\INDMSg', u'\\copainMSg'], u'\\DANS', [u'\\DEFNSg', u'\\salonNSg']]
# printflat \AVEC
# printflat [u'\\INDMSg', u'\\copainMSg']
# printflat \INDMSg
# printflat \copainMSg
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\salonNSg']
# printflat \DEFNSg
# printflat \salonNSg
# printflat [u'\\DEFMSg', u'\\garconMSg']
# printflat \DEFMSg
# printflat \garconMSg
# printflat \jouerPrsTroisSgM
# printflat [u'\\AVEC', [u'\\INDMSg', u'\\copainMSg'], u'\\DANS', [u'\\DEFNSg', u'\\salonNSg']]
# printflat \AVEC
# printflat [u'\\INDMSg', u'\\copainMSg']
# printflat \INDMSg
# printflat \copainMSg
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\salonNSg']
# printflat \DEFNSg
# printflat \salonNSg
# printflat [u'\\DEFMSg', u'\\garconMSg']
# printflat \DEFMSg
# printflat \garconMSg
# printflat \jouerPrsTroisSgM
# ===========================================
# cette petite fille	aimait	les histoires avec deS princesses
#
# [u'aimer']
# verbe : [u'aimait']
# ('', '', 'SUJ')
# groupe depart : [u'cette', u'petite', u'fille']
# cette
# petite
# fille
# groupe nom : [u'cette', u'petite', u'fille']
# mot [u'cette']
# vedette DEM DET
# categories ['N1', 'N2'] DET
# mot [u'petite']
# vedette petit ADJ
# categories ['N1', 'N2'] ADJ
# mot [u'fille']
# vedette fille.N2.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N2', u'F']
# classes fille F [u'N2', u'F']
# accord : F
# GP dans le GN :  []
# GN sans det ?  [u'DEM']
#  SG [u'N2', u'F'] []
# sujet : 0
# objet :  [u'les', u'histoires', u'avec', u'deS', u'princesses']
# groupe depart : [u'les', u'histoires', u'avec', u'deS', u'princesses']
# les
# histoires
# avec
# deS
# princesses
# groupe nom : [u'les', u'histoires', u'avec', u'deS', u'princesses']
# mot [u'les']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'histoires']
# vedette histoire.N1.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N1', u'M']
# classes histoires M [u'N1', u'M']
# mot [u'avec']
# vedette avec PREP
# categories ['N1', 'N2'] PREP
# accord : M
# faire_gp [u'avec', u'deS', u'princesses']
# [u'avec'] avec
# fonction!=IND [u'avec', u'\xe0']
# \AVEC
# pas de Cas
# groupe prep : [u'avec', u'deS', u'princesses']
# \AVEC
# deS
# groupe depart : [u'deS', u'princesses']
# deS
# princesses
# groupe nom : [u'deS', u'princesses']
# mot [u'deS']
# vedette IND DET
# categories ['N1', 'N2'] DET
# mot [u'princesses']
# vedette princesse.N1.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N1', u'F']
# classes princesses F [u'N1', u'F']
# accord : F
# GP dans le GN :  []
# GN sans det ?  [u'IND']
# [u'avec', u'deS', u'princesses']  [u'\\AVEC', [u'\\INDFPl', u'\\princesseFPl']]
# GP dans le GN :  [u'\\AVEC', [u'\\INDFPl', u'\\princesseFPl']]
# GN sans det ?  [u'DEF']
# ('obj :', '', [])
# glose Verbe \aimerPstTroisSgF
# interFlat [u'\\AVEC', u'\\INDFPl', u'\\princesseFPl', u'\\DEFMPl', u'\\histoireMPl']
# printflat [u'\\AVEC', [u'\\INDFPl', u'\\princesseFPl'], u'\\DEFMPl', u'\\histoireMPl']
# printflat \AVEC
# printflat [u'\\INDFPl', u'\\princesseFPl']
# printflat \INDFPl
# printflat \princesseFPl
# printflat \DEFMPl
# printflat \histoireMPl
# interFlat [u'\\DEMFSg', u'\\filleFSg', u'\\petitFSg']
# printflat [u'\\DEMFSg', u'\\filleFSg', u'\\petitFSg']
# printflat \DEMFSg
# printflat \filleFSg
# printflat \petitFSg
# printflat \aimerPstTroisSgF
# printflat [u'\\AVEC', [u'\\INDFPl', u'\\princesseFPl'], u'\\DEFMPl', u'\\histoireMPl']
# printflat \AVEC
# printflat [u'\\INDFPl', u'\\princesseFPl']
# printflat \INDFPl
# printflat \princesseFPl
# printflat \DEFMPl
# printflat \histoireMPl
# printflat [u'\\DEMFSg', u'\\filleFSg', u'\\petitFSg']
# printflat \DEMFSg
# printflat \filleFSg
# printflat \petitFSg
# printflat \aimerPstTroisSgF
# printflat [u'\\AVEC', [u'\\INDFPl', u'\\princesseFPl'], u'\\DEFMPl', u'\\histoireMPl']
# printflat \AVEC
# printflat [u'\\INDFPl', u'\\princesseFPl']
# printflat \INDFPl
# printflat \princesseFPl
# printflat \DEFMPl
# printflat \histoireMPl
# printflat [u'\\DEMFSg', u'\\filleFSg', u'\\petitFSg']
# printflat \DEMFSg
# printflat \filleFSg
# printflat \petitFSg
# printflat \aimerPstTroisSgF
# ===========================================
# les parents	mangeaient	ces grosses fraises			dans la cuisine
#
# [u'manger']
# verbe : [u'mangeaient']
# ('', '', 'SUJ')
# groupe depart : [u'les', u'parents']
# les
# parents
# groupe nom : [u'les', u'parents']
# mot [u'les']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'parents']
# vedette parent.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes parents M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
#  PL [u'N2', u'M'] []
# sujet : 0
# objet :  [u'ces', u'grosses', u'fraises']
# groupe depart : [u'ces', u'grosses', u'fraises']
# ces
# grosses
# fraises
# groupe nom : [u'ces', u'grosses', u'fraises']
# mot [u'ces']
# vedette DEM DET
# categories ['N1', 'N2'] DET
# mot [u'grosses']
# vedette gros ADJ
# categories ['N1', 'N2'] ADJ
# mot [u'fraises']
# vedette fraise.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes fraises M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEM']
# ('obj :', '', [])
# indirect :  [u'']
# faire_gp [u'dans', u'la', u'cuisine']
# [u'dans'] dans
# fonction!=IND [u'dans', u'\xe0']
# \DANS
# pas de Cas
# groupe prep : [u'dans', u'la', u'cuisine']
# \DANS
# la
# groupe depart : [u'la', u'cuisine']
# la
# cuisine
# groupe nom : [u'la', u'cuisine']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'cuisine']
# vedette cuisine.N1.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N1', u'N']
# classes cuisine N [u'N1', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'dans', u'la', u'cuisine']  [u'\\DANS', [u'\\DEFNSg', u'\\cuisineNSg']]
# glose Verbe \mangerPstTroisPlM
# interFlat [u'\\DEMMPl', u'\\fraiseMPl', u'\\grosMPl']
# printflat [u'\\DEMMPl', u'\\fraiseMPl', u'\\grosMPl']
# printflat \DEMMPl
# printflat \fraiseMPl
# printflat \grosMPl
# interFlat [u'\\DANS', u'\\DEFNSg', u'\\cuisineNSg']
# printflat [u'\\DANS', [u'\\DEFNSg', u'\\cuisineNSg']]
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\cuisineNSg']
# printflat \DEFNSg
# printflat \cuisineNSg
# interFlat [u'\\DEFMPl', u'\\parentMPl']
# printflat [u'\\DEFMPl', u'\\parentMPl']
# printflat \DEFMPl
# printflat \parentMPl
# printflat \mangerPstTroisPlM
# printflat [u'\\DEMMPl', u'\\fraiseMPl', u'\\grosMPl']
# printflat \DEMMPl
# printflat \fraiseMPl
# printflat \grosMPl
# printflat [u'\\DANS', [u'\\DEFNSg', u'\\cuisineNSg']]
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\cuisineNSg']
# printflat \DEFNSg
# printflat \cuisineNSg
# printflat [u'\\DEFMPl', u'\\parentMPl']
# printflat \DEFMPl
# printflat \parentMPl
# printflat \mangerPstTroisPlM
# printflat [u'\\DEMMPl', u'\\fraiseMPl', u'\\grosMPl']
# printflat \DEMMPl
# printflat \fraiseMPl
# printflat \grosMPl
# printflat [u'\\DANS', [u'\\DEFNSg', u'\\cuisineNSg']]
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\cuisineNSg']
# printflat \DEFNSg
# printflat \cuisineNSg
# printflat [u'\\DEFMPl', u'\\parentMPl']
# printflat \DEFMPl
# printflat \parentMPl
# printflat \mangerPstTroisPlM
# ===========================================
# les filles joyeuses	jouent			dans la maison
#
# [u'jouer']
# verbe : [u'jouent']
# ('', '', 'SUJ')
# groupe depart : [u'les', u'filles', u'joyeuses']
# les
# filles
# joyeuses
# groupe nom : [u'les', u'filles', u'joyeuses']
# mot [u'les']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'filles']
# vedette fille.N2.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N2', u'F']
# classes filles F [u'N2', u'F']
# mot [u'joyeuses']
# vedette joyeux ADJ
# categories ['N1', 'N2'] ADJ
# accord : F
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
#  PL [u'N2', u'F'] []
# sujet : 0
# objet :  [u'']
# indirect :  [u'']
# faire_gp [u'dans', u'la', u'maison']
# [u'dans'] dans
# fonction!=IND [u'dans', u'\xe0']
# \DANS
# pas de Cas
# groupe prep : [u'dans', u'la', u'maison']
# \DANS
# la
# groupe depart : [u'la', u'maison']
# la
# maison
# groupe nom : [u'la', u'maison']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'maison']
# vedette maison.N2.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N2', u'N']
# classes maison N [u'N2', u'N']
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'dans', u'la', u'maison']  [u'\\DANS', [u'\\DEFNSg', u'\\maisonNSg']]
# glose Verbe \jouerPrsTroisPlF
# interFlat [u'\\DEFFPl', u'\\filleFPl', u'\\joyeuxFPl']
# printflat [u'\\DEFFPl', u'\\filleFPl', u'\\joyeuxFPl']
# printflat \DEFFPl
# printflat \filleFPl
# printflat \joyeuxFPl
# interFlat [u'\\DANS', u'\\DEFNSg', u'\\maisonNSg']
# printflat [u'\\DANS', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \jouerPrsTroisPlF
# printflat [u'\\DEFFPl', u'\\filleFPl', u'\\joyeuxFPl']
# printflat \DEFFPl
# printflat \filleFPl
# printflat \joyeuxFPl
# printflat [u'\\DANS', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \jouerPrsTroisPlF
# printflat [u'\\DEFFPl', u'\\filleFPl', u'\\joyeuxFPl']
# printflat \DEFFPl
# printflat \filleFPl
# printflat \joyeuxFPl
# printflat [u'\\DANS', [u'\\DEFNSg', u'\\maisonNSg']]
# printflat \DANS
# printflat [u'\\DEFNSg', u'\\maisonNSg']
# printflat \DEFNSg
# printflat \maisonNSg
# printflat \jouerPrsTroisPlF
# ===========================================
# Christelle	était			avec François ; dans la forêt
#
# [u'\xeatre']
# verbe : [u'\xe9tait']
# ('', '', 'SUJ')
# groupe depart : [u'Christelle']
# Christelle
# groupe nom : [u'Christelle']
# mot [u'Christelle']
# vedette Christelle.N2.F F
# categories ['N1', 'N2'] NOM
# tête : F
# classesNom [u'N2', u'F']
# classes Christelle F [u'N2', u'F']
# accord : F
# GP dans le GN :  []
# GN sans det ?  []
#  SG [u'N2', u'F'] []
# sujet : 0
# objet :  [u'']
# indirect :  [u'']
# [[u'avec', u'Fran\xe7ois'], [u'dans', u'la', u'for\xeat']]
# faire_gp [u'avec', u'Fran\xe7ois']
# [u'avec'] avec
# fonction!=IND [u'avec', u'\xe0']
# \AVEC
# pas de Cas
# groupe prep : [u'avec', u'Fran\xe7ois']
# \AVEC
# François
# groupe depart : [u'Fran\xe7ois']
# François
# groupe nom : [u'Fran\xe7ois']
# mot [u'Fran\xe7ois']
# vedette François.N2.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N2', u'M']
# classes François M [u'N2', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  []
# [u'avec', u'Fran\xe7ois']  [u'\\AVEC', [u'\\DEFMPl', u'\\FrancoisMPl']]
# faire_gp [u'dans', u'la', u'for\xeat']
# [u'dans'] dans
# fonction!=IND [u'dans', u'\xe0']
# \DANS
# pas de Cas
# groupe prep : [u'dans', u'la', u'for\xeat']
# \DANS
# la
# groupe depart : [u'la', u'for\xeat']
# la
# forêt
# groupe nom : [u'la', u'for\xeat']
# mot [u'la']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'for\xeat']
# vedette forêt.N1.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N1', u'M']
# classes forêt M [u'N1', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# [u'dans', u'la', u'for\xeat']  [u'\\DANS', [u'\\DEFMSg', u'\\foretMSg']]
# glose Verbe \etrePstTroisSgF
# interFlat [u'\\DEFFSg', u'\\ChristelleFSg']
# printflat [u'\\DEFFSg', u'\\ChristelleFSg']
# printflat \DEFFSg
# printflat \ChristelleFSg
# interFlat [u'\\AVEC', u'\\DEFMPl', u'\\FrancoisMPl', u'\\DANS', u'\\DEFMSg', u'\\foretMSg']
# printflat [u'\\AVEC', [u'\\DEFMPl', u'\\FrancoisMPl'], u'\\DANS', [u'\\DEFMSg', u'\\foretMSg']]
# printflat \AVEC
# printflat [u'\\DEFMPl', u'\\FrancoisMPl']
# printflat \DEFMPl
# printflat \FrancoisMPl
# printflat \DANS
# printflat [u'\\DEFMSg', u'\\foretMSg']
# printflat \DEFMSg
# printflat \foretMSg
# printflat \etrePstTroisSgF
# printflat [u'\\DEFFSg', u'\\ChristelleFSg']
# printflat \DEFFSg
# printflat \ChristelleFSg
# printflat [u'\\AVEC', [u'\\DEFMPl', u'\\FrancoisMPl'], u'\\DANS', [u'\\DEFMSg', u'\\foretMSg']]
# printflat \AVEC
# printflat [u'\\DEFMPl', u'\\FrancoisMPl']
# printflat \DEFMPl
# printflat \FrancoisMPl
# printflat \DANS
# printflat [u'\\DEFMSg', u'\\foretMSg']
# printflat \DEFMSg
# printflat \foretMSg
# printflat \etrePstTroisSgF
# printflat [u'\\DEFFSg', u'\\ChristelleFSg']
# printflat \DEFFSg
# printflat \ChristelleFSg
# printflat [u'\\AVEC', [u'\\DEFMPl', u'\\FrancoisMPl'], u'\\DANS', [u'\\DEFMSg', u'\\foretMSg']]
# printflat \AVEC
# printflat [u'\\DEFMPl', u'\\FrancoisMPl']
# printflat \DEFMPl
# printflat \FrancoisMPl
# printflat \DANS
# printflat [u'\\DEFMSg', u'\\foretMSg']
# printflat \DEFMSg
# printflat \foretMSg
# printflat \etrePstTroisSgF
# ===========================================
# des garçons	mangent	les bananes jaunes
#
# [u'manger']
# verbe : [u'mangent']
# ('', '', 'SUJ')
# groupe depart : [u'des', u'gar\xe7ons']
# des
# garçons
# groupe nom : [u'des', u'gar\xe7ons']
# mot [u'des']
# vedette IND DET
# categories ['N1', 'N2'] DET
# mot [u'gar\xe7ons']
# vedette garçon.N1.M M
# categories ['N1', 'N2'] NOM
# tête : M
# classesNom [u'N1', u'M']
# classes garçons M [u'N1', u'M']
# accord : M
# GP dans le GN :  []
# GN sans det ?  [u'IND']
#  PL [u'N1', u'M'] []
# sujet : 0
# objet :  [u'les', u'bananes', u'jaunes']
# groupe depart : [u'les', u'bananes', u'jaunes']
# les
# bananes
# jaunes
# groupe nom : [u'les', u'bananes', u'jaunes']
# mot [u'les']
# vedette DEF DET
# categories ['N1', 'N2'] DET
# mot [u'bananes']
# vedette banane.N1.N N
# categories ['N1', 'N2'] NOM
# tête : N
# classesNom [u'N1', u'N']
# classes bananes N [u'N1', u'N']
# mot [u'jaunes']
# vedette jaune ADJ
# categories ['N1', 'N2'] ADJ
# accord : N
# GP dans le GN :  []
# GN sans det ?  [u'DEF']
# ('obj :', '', [])
# glose Verbe \mangerPrsTroisPlM
# interFlat [u'\\DEFNPl', u'\\bananeNPl', u'\\jauneNPl']
# printflat [u'\\DEFNPl', u'\\bananeNPl', u'\\jauneNPl']
# printflat \DEFNPl
# printflat \bananeNPl
# printflat \jauneNPl
# interFlat [u'\\INDMPl', u'\\garconMPl']
# printflat [u'\\INDMPl', u'\\garconMPl']
# printflat \INDMPl
# printflat \garconMPl
# printflat \mangerPrsTroisPlM
# printflat [u'\\DEFNPl', u'\\bananeNPl', u'\\jauneNPl']
# printflat \DEFNPl
# printflat \bananeNPl
# printflat \jauneNPl
# printflat [u'\\INDMPl', u'\\garconMPl']
# printflat \INDMPl
# printflat \garconMPl
# printflat \mangerPrsTroisPlM
# printflat [u'\\DEFNPl', u'\\bananeNPl', u'\\jauneNPl']
# printflat \DEFNPl
# printflat \bananeNPl
# printflat \jauneNPl
# printflat [u'\\INDMPl', u'\\garconMPl']
# printflat \INDMPl
# printflat \garconMPl
# printflat \mangerPrsTroisPlM
# ===========================================
# un jouet jaune de ce garçon	était			dans une cuisine
#
# [u'\xeatre']
# verbe : [u'\xe9tait']
# ('', '', 'SUJ')
# groupe depart : [u'un', u'jouet', u'jaune', u'de', u'ce', u'gar\xe7on']
# un
# jouet
# jaune
# de
# ce
# garçon
# groupe nom : [u'un', u'jouet', u'jaune', u'de', u'ce', u'gar\xe7on']
# mot [u'un']
# vedette IND DET
# categories ['N1', 'N2'] DET
# mot [u'jouet']
# vedette jouet.N2.F F
# categories ['N1', 'N2'] NOM
# tête : F
# ...
# CHUNKING :  17 3 6 ['\\beauFPl & \\beauFPlP & \\blanc{\\beauFPlG} \\\\', '\\calmeNPl & \\calmeNPlP & \\blanc{\\calmeNPlG} \\\\', '\\calmeNSg & \\calmeNSgP & \\blanc{\\calmeNSgG} \\\\', '\\coloreFSg & \\coloreFSgP & \\blanc{\\coloreFSgG} \\\\', '\\contentNPl & \\contentNPlP & \\blanc{\\contentNPlG} \\\\', '\\ensoleilleMSg & \\ensoleilleMSgP & \\blanc{\\ensoleilleMSgG} \\\\', '\\grosMPl & \\grosMPlP & \\blanc{\\grosMPlG} \\\\', '\\grosMSg & \\grosMSgP & \\blanc{\\grosMSgG} \\\\', '\\jauneFPl & \\jauneFPlP & \\blanc{\\jauneFPlG} \\\\', '\\jauneFSg & \\jauneFSgP & \\blanc{\\jauneFSgG} \\\\', '\\jauneNPl & \\jauneNPlP & \\blanc{\\jauneNPlG} \\\\', '\\joyeuxFPl & \\joyeuxFPlP & \\blanc{\\joyeuxFPlG} \\\\', '\\petitFPl & \\petitFPlP & \\blanc{\\petitFPlG} \\\\', '\\petitFSg & \\petitFSgP & \\blanc{\\petitFSgG} \\\\', '\\petitNSg & \\petitNSgP & \\blanc{\\petitNSgG} \\\\', '\\rougeFSg & \\rougeFSgP & \\blanc{\\rougeFSgG} \\\\', '\\sucreMPl & \\sucreMPlP & \\blanc{\\sucreMPlG} \\\\']
# RESTE :  6 []
# recuTableau set(['\\etrePrsTroisPlN & \\etrePrsTroisPlNP & \\blanc{\\etrePrsTroisPlNG} \\\\', '\\jouerPstTroisSgN & \\jouerPstTroisSgNP & \\blanc{\\jouerPstTroisSgNG} \\\\', '\\changerPstTroisPlN & \\changerPstTroisPlNP & \\blanc{\\changerPstTroisPlNG} \\\\', '\\arriverPrsTroisPlF & \\arriverPrsTroisPlFP & \\blanc{\\arriverPrsTroisPlFG} \\\\', '\\rentrerPrsTroisPlF & \\rentrerPrsTroisPlFP & \\blanc{\\rentrerPrsTroisPlFG} \\\\', '\\aimerPstTroisPlM & \\aimerPstTroisPlMP & \\blanc{\\aimerPstTroisPlMG} \\\\', '\\rentrerPrsTroisSgF & \\rentrerPrsTroisSgFP & \\blanc{\\rentrerPrsTroisSgFG} \\\\', '\\garderPrsTroisPlF & \\garderPrsTroisPlFP & \\blanc{\\garderPrsTroisPlFG} \\\\', '\\mangerPstTroisPlN & \\mangerPstTroisPlNP & \\blanc{\\mangerPstTroisPlNG} \\\\', '\\resterPrsTroisSgN & \\resterPrsTroisSgNP & \\blanc{\\resterPrsTroisSgNG} \\\\', '\\changerPrsTroisPlF & \\changerPrsTroisPlFP & \\blanc{\\changerPrsTroisPlFG} \\\\', '\\mangerPstTroisSgM & \\mangerPstTroisSgMP & \\blanc{\\mangerPstTroisSgMG} \\\\', '\\etrePrsTroisSgM & \\etrePrsTroisSgMP & \\blanc{\\etrePrsTroisSgMG} \\\\', '\\allerPstTroisSgM & \\allerPstTroisSgMP & \\blanc{\\allerPstTroisSgMG} \\\\', '\\oublierPstTroisPlF & \\oublierPstTroisPlFP & \\blanc{\\oublierPstTroisPlFG} \\\\', '\\changerPrsTroisPlN & \\changerPrsTroisPlNP & \\blanc{\\changerPrsTroisPlNG} \\\\', '\\arriverPstTroisPlF & \\arriverPstTroisPlFP & \\blanc{\\arriverPstTroisPlFG} \\\\', '\\aimerPstTroisSgF & \\aimerPstTroisSgFP & \\blanc{\\aimerPstTroisSgFG} \\\\', '\\etrePrsTroisPlF & \\etrePrsTroisPlFP & \\blanc{\\etrePrsTroisPlFG} \\\\', '\\mangerPrsTroisPlN & \\mangerPrsTroisPlNP & \\blanc{\\mangerPrsTroisPlNG} \\\\', '\\oublierPstTroisSgN & \\oublierPstTroisSgNP & \\blanc{\\oublierPstTroisSgNG} \\\\', '\\dormirPrsTroisPlM & \\dormirPrsTroisPlMP & \\blanc{\\dormirPrsTroisPlMG} \\\\', '\\garderPrsTroisSgN & \\garderPrsTroisSgNP & \\blanc{\\garderPrsTroisSgNG} \\\\', '\\aimerPstTroisSgM & \\aimerPstTroisSgMP & \\blanc{\\aimerPstTroisSgMG} \\\\', '\\dormirPstTroisSgM & \\dormirPstTroisSgMP & \\blanc{\\dormirPstTroisSgMG} \\\\', '\\dormirPstTroisSgF & \\dormirPstTroisSgFP & \\blanc{\\dormirPstTroisSgFG} \\\\', '\\aimerPrsTroisSgN & \\aimerPrsTroisSgNP & \\blanc{\\aimerPrsTroisSgNG} \\\\', '\\arriverPstTroisPlM & \\arriverPstTroisPlMP & \\blanc{\\arriverPstTroisPlMG} \\\\', '\\etrePrsTroisPlM & \\etrePrsTroisPlMP & \\blanc{\\etrePrsTroisPlMG} \\\\', '\\rentrerPrsTroisPlN & \\rentrerPrsTroisPlNP & \\blanc{\\rentrerPrsTroisPlNG} \\\\', '\\mangerPstTroisSgF & \\mangerPstTroisSgFP & \\blanc{\\mangerPstTroisSgFG} \\\\', '\\rentrerPstTroisPlM & \\rentrerPstTroisPlMP & \\blanc{\\rentrerPstTroisPlMG} \\\\', '\\dormirPrsTroisSgM & \\dormirPrsTroisSgMP & \\blanc{\\dormirPrsTroisSgMG} \\\\', '\\aimerPrsTroisPlF & \\aimerPrsTroisPlFP & \\blanc{\\aimerPrsTroisPlFG} \\\\', '\\jouerPstTroisPlF & \\jouerPstTroisPlFP & \\blanc{\\jouerPstTroisPlFG} \\\\', '\\etrePstTroisPlN & \\etrePstTroisPlNP & \\blanc{\\etrePstTroisPlNG} \\\\', '\\resterPstTroisPlM & \\resterPstTroisPlMP & \\blanc{\\resterPstTroisPlMG} \\\\', '\\mangerPstTroisPlM & \\mangerPstTroisPlMP & \\blanc{\\mangerPstTroisPlMG} \\\\', '\\oublierPstTroisPlM & \\oublierPstTroisPlMP & \\blanc{\\oublierPstTroisPlMG} \\\\', '\\etrePstTroisPlM & \\etrePstTroisPlMP & \\blanc{\\etrePstTroisPlMG} \\\\', '\\rentrerPrsTroisPlM & \\rentrerPrsTroisPlMP & \\blanc{\\rentrerPrsTroisPlMG} \\\\', '\\changerPrsTroisSgF & \\changerPrsTroisSgFP & \\blanc{\\changerPrsTroisSgFG} \\\\', '\\resterPstTroisPlF & \\resterPstTroisPlFP & \\blanc{\\resterPstTroisPlFG} \\\\', '\\jouerPstTroisPlN & \\jouerPstTroisPlNP & \\blanc{\\jouerPstTroisPlNG} \\\\', '\\prendrePstTroisSgN & \\prendrePstTroisSgNP & \\blanc{\\prendrePstTroisSgNG} \\\\', '\\oublierPrsTroisPlM & \\oublierPrsTroisPlMP & \\blanc{\\oublierPrsTroisPlMG} \\\\', '\\etrePstTroisSgN & \\etrePstTroisSgNP & \\blanc{\\etrePstTroisSgNG} \\\\', '\\jouerPrsTroisSgM & \\jouerPrsTroisSgMP & \\blanc{\\jouerPrsTroisSgMG} \\\\', '\\prendrePstTroisPl ...
# 3 0 ['\\aimerPrsTroisPlM & \\aimerPrsTroisPlMP & \\blanc{\\aimerPrsTroisPlMG} \\\\', '\\aimerPrsTroisSgM & \\aimerPrsTroisSgMP & \\blanc{\\aimerPrsTroisSgMG} \\\\', '\\aimerPrsTroisSgN & \\aimerPrsTroisSgNP & \\blanc{\\aimerPrsTroisSgNG} \\\\', '\\aimerPstTroisPlM & \\aimerPstTroisPlMP & \\blanc{\\aimerPstTroisPlMG} \\\\', '\\aimerPstTroisSgF & \\aimerPstTroisSgFP & \\blanc{\\aimerPstTroisSgFG} \\\\', '\\allerPrsTroisSgM & \\allerPrsTroisSgMP & \\blanc{\\allerPrsTroisSgMG} \\\\', '\\allerPstTroisPlM & \\allerPstTroisPlMP & \\blanc{\\allerPstTroisPlMG} \\\\', '\\allerPstTroisSgF & \\allerPstTroisSgFP & \\blanc{\\allerPstTroisSgFG} \\\\', '\\arriverPrsTroisPlM & \\arriverPrsTroisPlMP & \\blanc{\\arriverPrsTroisPlMG} \\\\', '\\arriverPstTroisSgM & \\arriverPstTroisSgMP & \\blanc{\\arriverPstTroisSgMG} \\\\', '\\changerPstTroisPlN & \\changerPstTroisPlNP & \\blanc{\\changerPstTroisPlNG} \\\\', '\\dormirPrsTroisPlN & \\dormirPrsTroisPlNP & \\blanc{\\dormirPrsTroisPlNG} \\\\', '\\dormirPstTroisSgN & \\dormirPstTroisSgNP & \\blanc{\\dormirPstTroisSgNG} \\\\', '\\etrePrsTroisPlF & \\etrePrsTroisPlFP & \\blanc{\\etrePrsTroisPlFG} \\\\', '\\etrePrsTroisSgF & \\etrePrsTroisSgFP & \\blanc{\\etrePrsTroisSgFG} \\\\', '\\etrePrsTroisSgM & \\etrePrsTroisSgMP & \\blanc{\\etrePrsTroisSgMG} \\\\', '\\etrePstTroisPlN & \\etrePstTroisPlNP & \\blanc{\\etrePstTroisPlNG} \\\\', '\\etrePstTroisSgF & \\etrePstTroisSgFP & \\blanc{\\etrePstTroisSgFG} \\\\', '\\garderPrsTroisSgF & \\garderPrsTroisSgFP & \\blanc{\\garderPrsTroisSgFG} \\\\', '\\jouerPrsTroisPlF & \\jouerPrsTroisPlFP & \\blanc{\\jouerPrsTroisPlFG} \\\\', '\\jouerPrsTroisPlN & \\jouerPrsTroisPlNP & \\blanc{\\jouerPrsTroisPlNG} \\\\', '\\jouerPrsTroisSgM & \\jouerPrsTroisSgMP & \\blanc{\\jouerPrsTroisSgMG} \\\\', '\\jouerPstTroisPlF & \\jouerPstTroisPlFP & \\blanc{\\jouerPstTroisPlFG} \\\\', '\\jouerPstTroisSgN & \\jouerPstTroisSgNP & \\blanc{\\jouerPstTroisSgNG} \\\\', '\\mangerPrsTroisPlM & \\mangerPrsTroisPlMP & \\blanc{\\mangerPrsTroisPlMG} \\\\', '\\mangerPrsTroisSgM & \\mangerPrsTroisSgMP & \\blanc{\\mangerPrsTroisSgMG} \\\\', '\\mangerPstTroisPlM & \\mangerPstTroisPlMP & \\blanc{\\mangerPstTroisPlMG} \\\\', '\\mangerPstTroisSgN & \\mangerPstTroisSgNP & \\blanc{\\mangerPstTroisSgNG} \\\\', '\\oublierPrsTroisSgM & \\oublierPrsTroisSgMP & \\blanc{\\oublierPrsTroisSgMG} \\\\', '\\prendrePrsTroisPlN & \\prendrePrsTroisPlNP & \\blanc{\\prendrePrsTroisPlNG} \\\\', '\\prendrePrsTroisSgF & \\prendrePrsTroisSgFP & \\blanc{\\prendrePrsTroisSgFG} \\\\', '\\prendrePstTroisPlN & \\prendrePstTroisPlNP & \\blanc{\\prendrePstTroisPlNG} \\\\', '\\prendrePstTroisSgM & \\prendrePstTroisSgMP & \\blanc{\\prendrePstTroisSgMG} \\\\', '\\rentrerPrsTroisSgF & \\rentrerPrsTroisSgFP & \\blanc{\\rentrerPrsTroisSgFG} \\\\', '\\rentrerPstTroisPlM & \\rentrerPstTroisPlMP & \\blanc{\\rentrerPstTroisPlMG} \\\\', '\\resterPrsTroisPlN & \\resterPrsTroisPlNP & \\blanc{\\resterPrsTroisPlNG} \\\\', '\\resterPrsTroisSgF & \\resterPrsTroisSgFP & \\blanc{\\resterPrsTroisSgFG} \\\\', '\\resterPstTroisSgM & \\resterPstTroisSgMP & \\blanc{\\resterPstTroisSgMG} \\\\']
# CHUNKING :  38 3 13 ['\\aimerPrsTroisPlM & \\aimerPrsTroisPlMP & \\blanc{\\aimerPrsTroisPlMG} \\\\', '\\aimerPrsTroisSgM & \\aimerPrsTroisSgMP & \\blanc{\\aimerPrsTroisSgMG} \\\\', '\\aimerPrsTroisSgN & \\aimerPrsTroisSgNP & \\blanc{\\aimerPrsTroisSgNG} \\\\', '\\aimerPstTroisPlM & \\aimerPstTroisPlMP & \\blanc{\\aimerPstTroisPlMG} \\\\', '\\aimerPstTroisSgF & \\aimerPstTroisSgFP & \\blanc{\\aimerPstTroisSgFG} \\\\', '\\allerPrsTroisSgM & \\allerPrsTroisSgMP & \\blanc{\\allerPrsTroisSgMG} \\\\', '\\allerPstTroisPlM & \\allerPstTroisPlMP & \\blanc{\\allerPstTroisPlMG} \\\\', '\\allerPstTroisSgF & \\allerPstTroisSgFP & \\blanc{\\allerPstTroisSgFG} \\\\', '\\arriverPrsTroisPlM & \\arriverPrsTroisPlMP & \\blanc{\\arriverPrsTroisPlMG} \\\\', '\\arriverPstTroisSgM & \\arriverPstTroisSgMP & \\blanc{\\arriverPstTroisSgMG} \\\\', '\\changerPstTroisPlN & \\changerPstTroisPlNP & \\blanc{\\changerPstTroisPlNG} \\\\', '\\dormirPrsTroisPlN & \\dormirPrsTroisPlNP & \\blanc{\\dormirPrsTroisPlNG} \\\\', '\\dormirPstTroisSgN & \\dormirPstTroisSgNP & \\blanc{\\dormirPstTroisSgNG} \\\\', '\\etrePrsTroisPlF & \\etrePrsTroisPlFP & \\blanc{\\etrePrsTroisPlFG} \\\\', '\\etrePrsTroisSgF & \\etrePrsTroisSgFP & \\blanc{\\etrePrsTroisSgFG} \\\\', '\\etrePrsTroisSgM & \\etrePrsTroisSgMP & \\blanc{\\etrePrsTroisSgMG} \\\\', '\\etrePstTroisPlN & \\etrePstTroisPlNP & \\blanc{\\etrePstTroisPlNG} \\\\', '\\etrePstTroisSgF & \\etrePstTroisSgFP & \\blanc{\\etrePstTroisSgFG} \\\\', '\\garderPrsTroisSgF & \\garderPrsTroisSgFP & \\blanc{\\garderPrsTroisSgFG} \\\\', '\\jouerPrsTroisPlF & \\jouerPrsTroisPlFP & \\blanc{\\jouerPrsTroisPlFG} \\\\', '\\jouerPrsTroisPlN & \\jouerPrsTroisPlNP & \\blanc{\\jouerPrsTroisPlNG} \\\\', '\\jouerPrsTroisSgM & \\jouerPrsTroisSgMP & \\blanc{\\jouerPrsTroisSgMG} \\\\', '\\jouerPstTroisPlF & \\jouerPstTroisPlFP & \\blanc{\\jouerPstTroisPlFG} \\\\', '\\jouerPstTroisSgN & \\jouerPstTroisSgNP & \\blanc{\\jouerPstTroisSgNG} \\\\', '\\mangerPrsTroisPlM & \\mangerPrsTroisPlMP & \\blanc{\\mangerPrsTroisPlMG} \\\\', '\\mangerPrsTroisSgM & \\mangerPrsTroisSgMP & \\blanc{\\mangerPrsTroisSgMG} \\\\', '\\mangerPstTroisPlM & \\mangerPstTroisPlMP & \\blanc{\\mangerPstTroisPlMG} \\\\', '\\mangerPstTroisSgN & \\mangerPstTroisSgNP & \\blanc{\\mangerPstTroisSgNG} \\\\', '\\oublierPrsTroisSgM & \\oublierPrsTroisSgMP & \\blanc{\\oublierPrsTroisSgMG} \\\\', '\\prendrePrsTroisPlN & \\prendrePrsTroisPlNP & \\blanc{\\prendrePrsTroisPlNG} \\\\', '\\prendrePrsTroisSgF & \\prendrePrsTroisSgFP & \\blanc{\\prendrePrsTroisSgFG} \\\\', '\\prendrePstTroisPlN & \\prendrePstTroisPlNP & \\blanc{\\prendrePstTroisPlNG} \\\\', '\\prendrePstTroisSgM & \\prendrePstTroisSgMP & \\blanc{\\prendrePstTroisSgMG} \\\\', '\\rentrerPrsTroisSgF & \\rentrerPrsTroisSgFP & \\blanc{\\rentrerPrsTroisSgFG} \\\\', '\\rentrerPstTroisPlM & \\rentrerPstTroisPlMP & \\blanc{\\rentrerPstTroisPlMG} \\\\', '\\resterPrsTroisPlN & \\resterPrsTroisPlNP & \\blanc{\\resterPrsTroisPlNG} \\\\', '\\resterPrsTroisSgF & \\resterPrsTroisSgFP & \\blanc{\\resterPrsTroisSgFG} \\\\', '\\resterPstTroisSgM & \\resterPstTroisSgMP & \\blanc{\\resterPstTroisSgMG} \\\\']
# RESTE :  13 []
# recuTableau set(['\\DEFNSg & \\DEFNSgP & \\blanc{\\DEFNSgG} \\\\', '\\INDFPl & \\INDFPlP & \\blanc{\\INDFPlG} \\\\', '\\INDNSg & \\INDNSgP & \\blanc{\\INDNSgG} \\\\', '\\DEMNSg & \\DEMNSgP & \\blanc{\\DEMNSgG} \\\\', '\\DEMFPl & \\DEMFPlP & \\blanc{\\DEMFPlG} \\\\', '\\INDNPl & \\INDNPlP & \\blanc{\\INDNPlG} \\\\', '\\DEFFPl & \\DEFFPlP & \\blanc{\\DEFFPlG} \\\\', '\\INDMSg & \\INDMSgP & \\blanc{\\INDMSgG} \\\\', '\\DEMMPl & \\DEMMPlP & \\blanc{\\DEMMPlG} \\\\', '\\INDFSg & \\INDFSgP & \\blanc{\\INDFSgG} \\\\', '\\DEFNPl & \\DEFNPlP & \\blanc{\\DEFNPlG} \\\\', '\\DEFFSg & \\DEFFSgP & \\blanc{\\DEFFSgG} \\\\', '\\DEFMSg & \\DEFMSgP & \\blanc{\\DEFMSgG} \\\\', '\\INDMPl & \\INDMPlP & \\blanc{\\INDMPlG} \\\\', '\\DEFMPl & \\DEFMPlP & \\blanc{\\DEFMPlG} \\\\', '\\DEMFSg & \\DEMFSgP & \\blanc{\\DEMFSgG} \\\\', '\\DEMNPl & \\DEMNPlP & \\blanc{\\DEMNPlG} \\\\', '\\DEMMSg & \\DEMMSgP & \\blanc{\\DEMMSgG} \\\\'])
# 4 0 ['\\DEFFPl & \\DEFFPlP & \\blanc{\\DEFFPlG} \\\\', '\\DEFFSg & \\DEFFSgP & \\blanc{\\DEFFSgG} \\\\', '\\DEFMPl & \\DEFMPlP & \\blanc{\\DEFMPlG} \\\\', '\\DEFMSg & \\DEFMSgP & \\blanc{\\DEFMSgG} \\\\', '\\DEFNPl & \\DEFNPlP & \\blanc{\\DEFNPlG} \\\\', '\\DEFNSg & \\DEFNSgP & \\blanc{\\DEFNSgG} \\\\', '\\DEMFPl & \\DEMFPlP & \\blanc{\\DEMFPlG} \\\\', '\\DEMFSg & \\DEMFSgP & \\blanc{\\DEMFSgG} \\\\', '\\DEMMPl & \\DEMMPlP & \\blanc{\\DEMMPlG} \\\\', '\\DEMMSg & \\DEMMSgP & \\blanc{\\DEMMSgG} \\\\', '\\DEMNPl & \\DEMNPlP & \\blanc{\\DEMNPlG} \\\\', '\\DEMNSg & \\DEMNSgP & \\blanc{\\DEMNSgG} \\\\', '\\INDFPl & \\INDFPlP & \\blanc{\\INDFPlG} \\\\', '\\INDFSg & \\INDFSgP & \\blanc{\\INDFSgG} \\\\', '\\INDMPl & \\INDMPlP & \\blanc{\\INDMPlG} \\\\', '\\INDMSg & \\INDMSgP & \\blanc{\\INDMSgG} \\\\', '\\INDNPl & \\INDNPlP & \\blanc{\\INDNPlG} \\\\', '\\INDNSg & \\INDNSgP & \\blanc{\\INDNSgG} \\\\']
# CHUNKING :  18 4 5 ['\\DEFFPl & \\DEFFPlP & \\blanc{\\DEFFPlG} \\\\', '\\DEFFSg & \\DEFFSgP & \\blanc{\\DEFFSgG} \\\\', '\\DEFMPl & \\DEFMPlP & \\blanc{\\DEFMPlG} \\\\', '\\DEFMSg & \\DEFMSgP & \\blanc{\\DEFMSgG} \\\\', '\\DEFNPl & \\DEFNPlP & \\blanc{\\DEFNPlG} \\\\', '\\DEFNSg & \\DEFNSgP & \\blanc{\\DEFNSgG} \\\\', '\\DEMFPl & \\DEMFPlP & \\blanc{\\DEMFPlG} \\\\', '\\DEMFSg & \\DEMFSgP & \\blanc{\\DEMFSgG} \\\\', '\\DEMMPl & \\DEMMPlP & \\blanc{\\DEMMPlG} \\\\', '\\DEMMSg & \\DEMMSgP & \\blanc{\\DEMMSgG} \\\\', '\\DEMNPl & \\DEMNPlP & \\blanc{\\DEMNPlG} \\\\', '\\DEMNSg & \\DEMNSgP & \\blanc{\\DEMNSgG} \\\\', '\\INDFPl & \\INDFPlP & \\blanc{\\INDFPlG} \\\\', '\\INDFSg & \\INDFSgP & \\blanc{\\INDFSgG} \\\\', '\\INDMPl & \\INDMPlP & \\blanc{\\INDMPlG} \\\\', '\\INDMSg & \\INDMSgP & \\blanc{\\INDMSgG} \\\\', '\\INDNPl & \\INDNPlP & \\blanc{\\INDNPlG} \\\\', '\\INDNSg & \\INDNSgP & \\blanc{\\INDNSgG} \\\\']
# RESTE :  5 []
# recuTableau set(['\\SANS & \\SANSP & \\blanc{\\SANSG} \\\\', '\\POUR & \\POURP & \\blanc{\\POURG} \\\\', '\\DANS & \\DANSP & \\blanc{\\DANSG} \\\\', '\\A & \\AP & \\blanc{\\AG} \\\\', '\\AVEC & \\AVECP & \\blanc{\\AVECG} \\\\', '\\VERS & \\VERSP & \\blanc{\\VERSG} \\\\', '\\DE & \\DEP & \\blanc{\\DEG} \\\\', '\\SUR & \\SURP & \\blanc{\\SURG} \\\\', '\\MALGRE & \\MALGREP & \\blanc{\\MALGREG} \\\\'])
# 4 0 ['\\A & \\AP & \\blanc{\\AG} \\\\', '\\AVEC & \\AVECP & \\blanc{\\AVECG} \\\\', '\\DANS & \\DANSP & \\blanc{\\DANSG} \\\\', '\\DE & \\DEP & \\blanc{\\DEG} \\\\', '\\MALGRE & \\MALGREP & \\blanc{\\MALGREG} \\\\', '\\POUR & \\POURP & \\blanc{\\POURG} \\\\', '\\SANS & \\SANSP & \\blanc{\\SANSG} \\\\', '\\SUR & \\SURP & \\blanc{\\SURG} \\\\', '\\VERS & \\VERSP & \\blanc{\\VERSG} \\\\']
# CHUNKING :  9 4 3 ['\\A & \\AP & \\blanc{\\AG} \\\\', '\\AVEC & \\AVECP & \\blanc{\\AVECG} \\\\', '\\DANS & \\DANSP & \\blanc{\\DANSG} \\\\', '\\DE & \\DEP & \\blanc{\\DEG} \\\\', '\\MALGRE & \\MALGREP & \\blanc{\\MALGREG} \\\\', '\\POUR & \\POURP & \\blanc{\\POURG} \\\\', '\\SANS & \\SANSP & \\blanc{\\SANSG} \\\\', '\\SUR & \\SURP & \\blanc{\\SURG} \\\\', '\\VERS & \\VERSP & \\blanc{\\VERSG} \\\\']
# RESTE :  3 []

# %%
ding()
if variante=="": 
    print "faire la correction"
    time.sleep(1)
    ding()
    time.sleep(1)
    ding()
    time.sleep(1)
    ding()
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
sortie="images"
if "RightLeft" in globals() and RightLeft:
    syntagmes=syntagmesRL
else:
    syntagmes=syntagmesLR
print syntagmes

lexemesLocaux=set()
if ecriture_nom.endswith("csv"):
    try:
        ecriture_file = codecs.open(ecriture_nom,"r","utf8")
    except IOError:
        print 'I could not open the file', ecriture_nom
        sys.exit()      
    else:
        try:
            cloze_file = codecs.open(cloze_nom,"r","utf8")
        except IOError:
            print 'I could not open the cloze file', cloze_nom
            sys.exit()
        else:
            ecriture={}
            for line in cloze_file.readlines():
                line=line.strip()
                if not line.startswith("#"):
                    elementsCloze=line.split(";")
                    ecriture[elementsCloze[0]]=elementsCloze[5]
            cloze_file.close()
            exemples=[]
            accumulateur=[]
            vocabulaire=[]
#            prononciationExtrait=[]
            faire_phrases(ecriture_file,sortie=sortie)
            ecriture_file.close()

localClozes=filtrerCloze(lexemesLocaux)
with codecs.open(serie+complementPhrases+"%s-Clozes"%sortie.capitalize()+".txt", 'wb',encoding="utf8") as output:
    for ligne in localClozes:
        output.write(ligne+"\n")

# %%
sortie="ordre"
syntagmes=syntagmesLR
print syntagmes

lexemesLocaux=set()
if ordre_nom.endswith("csv"):
    try:
        ordre_file = codecs.open(ordre_nom,"r","utf8")
    except IOError:
        print 'I could not open the file', ordre_nom
        sys.exit()      
    else:
        try:
            cloze_file = codecs.open(cloze_nom,"r","utf8")
        except IOError:
            print 'I could not open the cloze file', cloze_nom
            sys.exit()
        else:
            ordre={}
            for line in cloze_file.readlines():
                line=line.strip()
                if not line.startswith("#"):
                    elementsCloze=line.split(";")
                    ordre[elementsCloze[0]]=elementsCloze[5]
            cloze_file.close()
            exemples=[]
            accumulateur=[]
            vocabulaire=[]
#            prononciationExtrait=[]
            faire_phrases(ordre_file,sortie=sortie)
            ordre_file.close()

localClozes=filtrerCloze(lexemesLocaux)
with codecs.open(serie+complementPhrases+"%s-Clozes"%sortie.capitalize()+".txt", 'wb',encoding="utf8") as output:
    for ligne in localClozes:
        output.write(ligne+"\n")

# %%
sortie="mots"
if "RightLeft" in globals() and RightLeft:
    syntagmes=syntagmesRL
else:
    syntagmes=syntagmesLR
print syntagmes

lexemesLocaux=set()
if mots_nom.endswith("csv"):
    try:
        mots_file = codecs.open(mots_nom,"r","utf8")
    except IOError:
        print 'I could not open the file', mots_nom
        sys.exit()      
    else:
        try:
            cloze_file = codecs.open(cloze_nom,"r","utf8")
        except IOError:
            print 'I could not open the cloze file', cloze_nom
            sys.exit()
        else:
            motsIsoles={}
            for line in cloze_file.readlines():
                line=line.strip()
                if not line.startswith("#"):
                    elementsCloze=line.split(";")
                    motsIsoles[elementsCloze[0]]=elementsCloze[5]
            cloze_file.close()
            exemples=[]
            accumulateur=[]
            vocabulaire=[]
#            prononciationExtrait=[]
            faire_phrases(mots_file,sortie=sortie)
            mots_file.close()

localClozes=filtrerCloze(lexemesLocaux)
with codecs.open(serie+complementPhrases+"%s-Clozes"%sortie.capitalize()+".txt", 'wb',encoding="utf8") as output:
    for ligne in localClozes:
        output.write(ligne+"\n")

# %%
#PFM.hierarchieCF.classes
#discrimineur
#tableaux["NOM"]

# %%
faire_gn("des villageoises dans les arbres".split(),"")

# %%
PFM.lexique.formeLexeme[u"villageoise"]

# %%
PFM.lexique.formeLexeme[u"grand"][0]

# %%
#filtrerCloze(lexemesLocaux)

# %%
ding()
