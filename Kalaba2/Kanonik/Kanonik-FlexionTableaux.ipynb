# %%
import glob,codecs
import pandas as pd
from unidecode import unidecode
from os.path import expanduser
from cellbell import ding
from IPython.core.display import HTML,display

# %%
# %store -r numerosKanoniks
#numerosKanoniks=[40]
print numerosKanoniks
# Out:
# [25]

# %%
debug=0

home = expanduser("~")
annee="2020"
annee="20-Kanoniks"
repertoire=home+"/ownCloud/Cours/Bordeaux/L1-UE4-Morphologie/00-Kanonik/"+annee
serie=repertoire+"/"
nomKanoniks=[serie+"K%02d/"%num for num in numerosKanoniks]

nomDeclarationRad="Declarations-Radicaux.tex"
nomDeclarationDec="Declarations-Decoupages.tex"
nomTableauxRad="Tableaux-Gloses.yaml"
nomDeclaration="Declarations.tex"
nomTableaux="Tableaux.yaml"

# %%
glob.glob(nomKanoniks[0]+"*.txt")
# Out:
# ['/Users/gilles/ownCloud/Cours/Bordeaux/L1-UE4-Morphologie/00-Kanonik/20-Kanoniks/K25/Traductions-Clozes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-UE4-Morphologie/00-Kanonik/20-Kanoniks/K25/Syntagmes-Corr.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-UE4-Morphologie/00-Kanonik/20-Kanoniks/K25/Syntagmes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-UE4-Morphologie/00-Kanonik/20-Kanoniks/K25/Phrases-Clozes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-UE4-Morphologie/00-Kanonik/20-Kanoniks/K25/Clozes.txt',
#  '/Users/gilles/ownCloud/Cours/Bordeaux/L1-UE4-Morphologie/00-Kanonik/20-Kanoniks/K25/Traductions.txt']

# %%
flexion=pd.read_csv(nomKanoniks[0]+"Clozes.txt",sep=";",header=None, names=list(range(20)),encoding="utf8").dropna(axis='columns', how='all')
flexion.head()
# Out:
#         0     1    2      3        5          6                        7   \
# 0   #\tADJ   NaN  NaN    NaN      NaN        NaN                      NaN
# 1        #   NaN  NaN    NaN      NaN        NaN                      NaN
# 2        #   NaN  NaN    NaN      NaN        NaN                      NaN
# 3  noirMSg  noir  ADJ  pusis  pusisaŋ  pusis-a-ŋ  ADJ, Genre=M, Nombre=Sg
# 4  noirMPl  noir  ADJ  pusis  pusisad  pusis-a-d  ADJ, Genre=M, Nombre=Pl
#
#           8    9     10   11   12   13   14
# 0        NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 1        NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 2        NaN  NaN   NaN  NaN  NaN  NaN  NaN
# 3  noir-M-Sg  3.0  noir   -M  -Sg  NaN  NaN
# 4  noir-M-Pl  3.0  noir   -M  -Pl  NaN  NaN

# %%
categories=flexion[2].dropna().unique().tolist()
categories
# Out:
# [u'ADJ', u'DET', u'VER', u'PREP', u'NOM']

# %% [markdown]
# bFlex sélectionne les lignes non-vides correspondant à une catégorie

# %%
bFlex={c:(flexion[7].notnull()) & (flexion[2]==c.upper()) for c in categories}
flexion[bFlex["NOM"]]
# Out:
#                 0           1    2        3          5           6   \
# 379     cuisineNSg     cuisine  NOM     kupa     kupaja     kupa-ja
# 380     cuisineNPl     cuisine  NOM     kupa     kupadu     kupa-du
# 381        fourNSg        four  NOM     ʒuko     ʒukoja     ʒuko-ja
# 382        fourNPl        four  NOM     ʒuko     ʒukodu     ʒuko-du
# 383  coquelicotNSg  coquelicot  NOM     vabo     vaboja     vabo-ja
# 384  coquelicotNPl  coquelicot  NOM     vabo     vabodu     vabo-du
# 385      loucheNSg      louche  NOM   biseki   bisekija   biseki-ja
# 386      loucheNPl      louche  NOM   biseki   bisekidu   biseki-du
# 387       verreNSg       verre  NOM     roʃa     roʃaja     roʃa-ja
# 388       verreNPl       verre  NOM     roʃa     roʃadu     roʃa-du
# 389      gateauNSg      gâteau  NOM  barneto  barnetoja  barneto-ja
# 390      gateauNPl      gâteau  NOM  barneto  barnetodu  barneto-du
# 391       patteNSg       patte  NOM   tapana   tapanaja   tapana-ja
# 392       patteNPl       patte  NOM   tapana   tapanadu   tapana-du
# 393       tableNSg       table  NOM   jolade   joladeja   jolade-ja
# 394       tableNPl       table  NOM   jolade   joladedu   jolade-du
# 395     journeeNSg     journée  NOM    rapum    rapumja    rapum-ja
# 396     journeeNPl     journée  NOM    rapum    rapumdu    rapum-du
# 397        platNSg        plat  NOM     sugu     suguja     sugu-ja
# 398        platNPl        plat  NOM     sugu     sugudu     sugu-du
# 399       FelixMSg       Félix  NOM   feliʃi   feliʃija   feliʃi-ja
# 400       FelixMPl       Félix  NOM   feliʃi   feliʃidu   feliʃi-du
# 401      soleilMSg      soleil  NOM   ʃufawa   ʃufawaja   ʃufawa-ja
# 402      soleilMPl      soleil  NOM   ʃufawa   ʃufawadu   ʃufawa-du
# 403     marmiteMSg     marmite  NOM   dusoli   dusolija   dusoli-ja
# 404     marmiteMPl     marmite  NOM   dusoli   dusolidu   dusoli-du
# 405      cabaneMSg      cabane  NOM     sebi     sebija     sebi-ja
# 406      cabaneMPl      cabane  NOM     sebi     sebidu     sebi-du
# 407     biscuitMSg     biscuit  NOM   tanisu   tanisuja   tanisu-ja
# 408     biscuitMPl     biscuit  NOM   tanisu   tanisudu   tanisu-du
# ..             ...         ...  ...      ...        ...         ...
# 411      patateMSg      patate  NOM   gakeku   gakekuja   gakeku-ja
# 412      patateMPl      patate  NOM   gakeku   gakekudu   gakeku-du
# 413   croquetteMSg   croquette  NOM    ovina    ovinaja    ovina-ja
# 414   croquetteMPl   croquette  NOM    ovina    ovinadu    ovina-du
# 415      MartinMSg      Martin  NOM   martiŋ   martiŋja   martiŋ-ja
# 416      MartinMPl      Martin  NOM   martiŋ   martiŋdu   martiŋ-du
# 417     fromageMSg     fromage  NOM   lebeʒe   lebeʒeja   lebeʒe-ja
# 418     fromageMPl     fromage  NOM   lebeʒe   lebeʒedu   lebeʒe-du
# 419      pouletFSg      poulet  NOM   pitamo   pitamoja   pitamo-ja
# 420      pouletFPl      poulet  NOM   pitamo   pitamodu   pitamo-du
# 421    chocolatFSg    chocolat  NOM    ljuʒu    ljuʒuja    ljuʒu-ja
# 422    chocolatFPl    chocolat  NOM    ljuʒu    ljuʒudu    ljuʒu-du
# 423      JohanaFSg      Johana  NOM    joana    joanaja    joana-ja
# 424      JohanaFPl      Johana  NOM    joana    joanadu    joana-du
# 425      jambonFSg      jambon  NOM   tivoʃa   tivoʃaja   tivoʃa-ja
# 426      jambonFPl      jambon  NOM   tivoʃa   tivoʃadu   tivoʃa-du
# 427       repasFSg       repas  NOM     kuse     kuseja     kuse-ja
# 428       repasFPl       repas  NOM     kuse     kusedu     kuse-du
# 429     boissonFSg     boisson  NOM   veroma   veromaja   veroma-ja
# 430     boissonFPl     boisson  NOM   veroma   veromadu   veroma-du
# 431      valleeFSg      vallée  NOM     kalu     kaluja     kalu-ja
# 432      valleeFPl      vallée  NOM     kalu     kaludu     kalu-du
# 433      enfantFSg      enfant  NOM     molo     moloja     molo-ja
# 434      enfantFPl      enfant  NOM     molo     molodu     molo-du
# 435        piedFSg        pied  NOM    zepek    zepekja    zepek-ja
# 436        piedFPl        pied  NOM    zepek    zepekdu    zepek-du
# 437    dimancheFSg    dimanche  NOM     deŋe     deŋeja     deŋe-ja
# 438    dimancheFPl    dimanche  NOM     deŋe     deŋedu     deŋe-du
# 439        chatFSg        chat  NOM     wili     wilija     wili-ja
# 440        chatFPl        chat  NOM     wili     wilidu     wili-du
#
#                           7                8    9           10  11   12   13  \
# 379  NOM, Genre=N, Nombre=Sg     cuisine.N-Sg  3.0     cuisine  .N  -Sg  NaN
# 380  NOM, Genre=N, Nombre=Pl     cuisine.N-Pl  3.0     cuisine  .N  -Pl  NaN
# 381  NOM, Genre=N, Nombre=Sg        four.N-Sg  3.0        four  .N  -Sg  NaN
# 382  NOM, Genre=N, Nombre=Pl        four.N-Pl  3.0        four  .N  -Pl  NaN
# 383  NOM, Genre=N, Nombre=Sg  coquelicot.N-Sg  3.0  coquelicot  .N  -Sg  NaN
# 384  NOM, Genre=N, Nombre=Pl  coquelicot.N-Pl  3.0  coquelicot  .N  -Pl  NaN
# 385  NOM, Genre=N, Nombre=Sg      louche.N-Sg  3.0      louche  .N  -Sg  NaN
# 386  NOM, Genre=N, Nombre=Pl      louche.N-Pl  3.0      louche  .N  -Pl  NaN
# 387  NOM, Genre=N, Nombre=Sg       verre.N-Sg  3.0       verre  .N  -Sg  NaN
# 388  NOM, Genre=N, Nombre=Pl       verre.N-Pl  3.0       verre  .N  -Pl  NaN
# 389  NOM, Genre=N, Nombre=Sg      gâteau.N-Sg  3.0      gâteau  .N  -Sg  NaN
# 390  NOM, Genre=N, Nombre=Pl      gâteau.N-Pl  3.0      gâteau  .N  -Pl  NaN
# 391  NOM, Genre=N, Nombre=Sg       patte.N-Sg  3.0       patte  .N  -Sg  NaN
# 392  NOM, Genre=N, Nombre=Pl       patte.N-Pl  3.0       patte  .N  -Pl  NaN
# 393  NOM, Genre=N, Nombre=Sg       table.N-Sg  3.0       table  .N  -Sg  NaN
# 394  NOM, Genre=N, Nombre=Pl       table.N-Pl  3.0       table  .N  -Pl  NaN
# 395  NOM, Genre=N, Nombre=Sg     journée.N-Sg  3.0     journée  .N  -Sg  NaN
# 396  NOM, Genre=N, Nombre=Pl     journée.N-Pl  3.0     journée  .N  -Pl  NaN
# 397  NOM, Genre=N, Nombre=Sg        plat.N-Sg  3.0        plat  .N  -Sg  NaN
# 398  NOM, Genre=N, Nombre=Pl        plat.N-Pl  3.0        plat  .N  -Pl  NaN
# 399  NOM, Genre=M, Nombre=Sg       Félix.M-Sg  3.0       Félix  .M  -Sg  NaN
# 400  NOM, Genre=M, Nombre=Pl       Félix.M-Pl  3.0       Félix  .M  -Pl  NaN
# 401  NOM, Genre=M, Nombre=Sg      soleil.M-Sg  3.0      soleil  .M  -Sg  NaN
# 402  NOM, Genre=M, Nombre=Pl      soleil.M-Pl  3.0      soleil  .M  -Pl  NaN
# 403  NOM, Genre=M, Nombre=Sg     marmite.M-Sg  3.0     marmite  .M  -Sg  NaN
# 404  NOM, Genre=M, Nombre=Pl     marmite.M-Pl  3.0     marmite  .M  -Pl  NaN
# 405  NOM, Genre=M, Nombre=Sg      cabane.M-Sg  3.0      cabane  .M  -Sg  NaN
# 406  NOM, Genre=M, Nombre=Pl      cabane.M-Pl  3.0      cabane  .M  -Pl  NaN
# 407  NOM, Genre=M, Nombre=Sg     biscuit.M-Sg  3.0     biscuit  .M  -Sg  NaN
# 408  NOM, Genre=M, Nombre=Pl     biscuit.M-Pl  3.0     biscuit  .M  -Pl  NaN
# ..                       ...              ...  ...         ...  ..  ...  ...
# 411  NOM, Genre=M, Nombre=Sg      patate.M-Sg  3.0      patate  .M  -Sg  NaN
# 412  NOM, Genre=M, Nombre=Pl      patate.M-Pl  3.0      patate  .M  -Pl  NaN
# 413  NOM, Genre=M, Nombre=Sg   croquette.M-Sg  3.0   croquette  .M  -Sg  NaN
# 414  NOM, Genre=M, Nombre=Pl   croquette.M-Pl  3.0   croquette  .M  -Pl  NaN
# 415  NOM, Genre=M, Nombre=Sg      Martin.M-Sg  3.0      Martin  .M  -Sg  NaN
# 416  NOM, Genre=M, Nombre=Pl      Martin.M-Pl  3.0      Martin  .M  -Pl  NaN
# 417  NOM, Genre=M, Nombre=Sg     fromage.M-Sg  3.0     fromage  .M  -Sg  NaN
# 418  NOM, Genre=M, Nombre=Pl     fromage.M-Pl  3.0     fromage  .M  -Pl  NaN
# 419  NOM, Genre=F, Nombre=Sg      poulet.F-Sg  3.0      poulet  .F  -Sg  NaN
# 420  NOM, Genre=F, Nombre=Pl      poulet.F-Pl  3.0      poulet  .F  -Pl  NaN
# 421  NOM, Genre=F, Nombre=Sg    chocolat.F-Sg  3.0    chocolat  .F  -Sg  NaN
# 422  NOM, Genre=F, Nombre=Pl    chocolat.F-Pl  3.0    chocolat  .F  -Pl  NaN
# 423  NOM, Genre=F, Nombre=Sg      Johana.F-Sg  3.0      Johana  .F  -Sg  NaN
# 424  NOM, Genre=F, Nombre=Pl      Johana.F-Pl  3.0      Johana  .F  -Pl  NaN
# 425  NOM, Genre=F, Nombre=Sg      jambon.F-Sg  3.0      jambon  .F  -Sg  NaN
# 426  NOM, Genre=F, Nombre=Pl      jambon.F-Pl  3.0      jambon  .F  -Pl  NaN
# 427  NOM, Genre=F, Nombre=Sg       repas.F-Sg  3.0       repas  .F  -Sg  NaN
# 428  NOM, Genre=F, Nombre=Pl       repas.F-Pl  3.0       repas  .F  -Pl  NaN
# 429  NOM, Genre=F, Nombre=Sg     boisson.F-Sg  3.0     boisson  .F  -Sg  NaN
# 430  NOM, Genre=F, Nombre=Pl     boisson.F-Pl  3.0     boisson  .F  -Pl  NaN
# 431  NOM, Genre=F, Nombre=Sg      vallée.F-Sg  3.0      vallée  .F  -Sg  NaN
# 432  NOM, Genre=F, Nombre=Pl      vallée.F-Pl  3.0      vallée  .F  -Pl  NaN
# 433  NOM, Genre=F, Nombre=Sg      enfant.F-Sg  3.0      enfant  .F  -Sg  NaN
# 434  NOM, Genre=F, Nombre=Pl      enfant.F-Pl  3.0      enfant  .F  -Pl  NaN
# 435  NOM, Genre=F, Nombre=Sg        pied.F-Sg  3.0        pied  .F  -Sg  NaN
# 436  NOM, Genre=F, Nombre=Pl        pied.F-Pl  3.0        pied  .F  -Pl  NaN
# 437  NOM, Genre=F, Nombre=Sg    dimanche.F-Sg  3.0    dimanche  .F  -Sg  NaN
# 438  NOM, Genre=F, Nombre=Pl    dimanche.F-Pl  3.0    dimanche  .F  -Pl  NaN
# 439  NOM, Genre=F, Nombre=Sg        chat.F-Sg  3.0        chat  .F  -Sg  NaN
# 440  NOM, Genre=F, Nombre=Pl        chat.F-Pl  3.0        chat  .F  -Pl  NaN
#
#       14
# 379  NaN
# 380  NaN
# 381  NaN
# 382  NaN
# 383  NaN
# 384  NaN
# 385  NaN
# 386  NaN
# 387  NaN
# 388  NaN
# 389  NaN
# 390  NaN
# 391  NaN
# 392  NaN
# 393  NaN
# 394  NaN
# 395  NaN
# 396  NaN
# 397  NaN
# 398  NaN
# 399  NaN
# 400  NaN
# 401  NaN
# 402  NaN
# 403  NaN
# 404  NaN
# 405  NaN
# 406  NaN
# 407  NaN
# 408  NaN
# ..   ...
# 411  NaN
# 412  NaN
# 413  NaN
# 414  NaN
# 415  NaN
# 416  NaN
# 417  NaN
# 418  NaN
# 419  NaN
# 420  NaN
# 421  NaN
# 422  NaN
# 423  NaN
# 424  NaN
# 425  NaN
# 426  NaN
# 427  NaN
# 428  NaN
# 429  NaN
# 430  NaN
# 431  NaN
# 432  NaN
# 433  NaN
# 434  NaN
# 435  NaN
# 436  NaN
# 437  NaN
# 438  NaN
# 439  NaN
# 440  NaN
#
# [62 rows x 14 columns]

# %% [markdown]
# ### Analyse de la case
# on fait un dict à partir de la case pour éclater en colonne puis faire un pivot_table

# %%
def makeParadigme(row):
    result={}
    parts=row["Case"].split(", ")
    for part in parts[1:]:
        attr,val=part.split("=")
        result[attr.strip()]=val
    return result

# %% [markdown]
# # Tableaux pour une catégorie

# %%
def reindexNombre(tableau):
    result=tableau
    if "Du" in tableau.columns:
        result=tableau.reindex("Sg Du Pl".split(" "),axis=1)
    elif "Pau" in tableau.columns:
        result=tableau.reindex("Sg Pau Pl".split(" "),axis=1)
    elif "Sg" in tableau.columns:
        result=tableau.reindex("Sg Pl".split(" "),axis=1)
    return result

def reindexPers(tableau):
    result=tableau
    if "3Du" in tableau.columns:
        result=tableau.reindex("3Sg 3Du 3Pl".split(" "),axis=1)
    elif "3Pau" in tableau.columns:
        result=tableau.reindex("3Sg 3Pau 3Pl".split(" "),axis=1)
    elif "3Sg" in tableau.columns:
        result=tableau.reindex("3Sg 3Pl".split(" "),axis=1)
    return result

def reindexTableau(tableau):
    return reindexNombre(reindexPers(tableau))

# %%
def makeTableaux(cat):
    # sel sélectionne la catégorie cat dans flexion
    # les colonnes 1, 6 et 7 correspondent à la catégorie, la forme et la case
    sel=bFlex[cat]
    # la colonnne 3 contient le radical
    lDF=flexion[sel][[1,6,7]]
    lDF=flexion[sel][[1,3,6,7]]
    lDF.columns=(u"%s Radical Forme Case"%cat).split(" ")
    # on ajoute une colonne avec un dict correspondant à attribut:valeur
    lDF["dCell"]=lDF.apply(makeParadigme,axis=1)
    if lDF.iloc[0]["dCell"]!={}:
        # on éclate le dict attribut:valeur en colonnes
        # on calcule les dimensions du tableau croisé pour pivot_table
        dfCat=pd.concat([lDF.drop(['Case',"dCell"], axis=1), lDF['dCell'].apply(pd.Series)], axis=1)
        setColonnes=set(dfCat.columns.tolist())
        if cat=="NOM":
            setColonnes-=set(["Genre"])
        if "Nombre" in setColonnes:
            colonnes="Nombre"
            lignes=setColonnes-set([cat,"Radical","Forme","CF","Nombre"])
        elif "Pers" in setColonnes:
            colonnes="Pers"
            lignes=list(setColonnes-set([cat,"Radical","Forme","CF","Pers"]))
        if debug: print colonnes, lignes
        # on fait la liste des lexèmes de la catégorie cat
        listCat=dfCat[cat].unique().tolist()
        if debug: display(dfCat.head())
        catTableaux={}
        catCF={}
        radCF={}
        cfLexemes={}
        for l in listCat:
            catL=dfCat[dfCat[cat]==l]
            radical=catL["Radical"].values[0]
            if "CF" in dfCat.columns:
                lCF=catL["CF"].values[0]
                if lCF not in cfLexemes:
                    cfLexemes[lCF]=[]
                cfLexemes[lCF].append(l)
                #
                # reindexNombre présente les colonnes concernant le nombre dans l'ordre traditionnel
                # SG < DU/PAU < PL
                #
                if lCF not in catCF:
                    catTableaux[lCF]=pd.pivot_table(catL,index=lignes,columns=colonnes,values="Forme", aggfunc='first')
                    catCF[lCF]=l
                    radCF[lCF]=radical
            else:
                catCF[cat]=l
                radCF[cat]=radical
                catTableaux[cat]=pd.pivot_table(catL,index=lignes,columns=colonnes,values="Forme", aggfunc='first')
        for t in catTableaux:   
            if debug: display(HTML("<h1>%s, %s</h1>"%(t,catCF[t])),reindexTableau(catTableaux[t]))
#             print t,catCF[t],radCF[t]
#             print reindexTableau(catTableaux[t]).to_latex(multirow=True)
    return catTableaux,cfLexemes,catCF,radCF

# %%
tableaux={}
tableauxLatex=[]
lexemesCF={}
cfLexs={}
cfRads={}
tableauxLatex.append(ur"\subsection*{Tableaux de flexion}")
for cat in "DET NOM ADJ VER".split(" "):
#    print ur"\section{%s}"%cat
    tableauxLatex.append(ur"\subsubsection*{%s}"%cat)
    tableaux[cat],lexemesCF[cat],cfLexs[cat],cfRads[cat]=makeTableaux(cat)
#     print tableaux[cat]
#     print lexemesCF[cat]
    for t in tableaux[cat]:
#        print t
        tableauxLatex.append(u"\\noindent\n%s %s => %s\\\\"%(t,cfLexs[cat][t],cfRads[cat][t]))
        tableauxLatex.append(reindexTableau(tableaux[cat][t]).to_latex(multirow=True)+u" \\\\ \\medskip")
        tableauxLatex.append("")
print "\n".join(tableauxLatex)
# Out:
# \subsection*{Tableaux de flexion}
# \subsubsection*{DET}
# \noindent
# DET DEM => t\\
# \begin{tabular}{lll}
# \toprule
# Nombre &      Sg &      Pl \\
# Genre &         &         \\
# \midrule
# F     &  t-u-mi &  t-u-ra \\
# M     &  t-a-mi &  t-a-ra \\
# N     &  t-i-mi &  t-i-ra \\
# \bottomrule
# \end{tabular}
#  \\ \medskip
#
# \subsubsection*{NOM}
# \noindent
# NOM chat => wili\\
# \begin{tabular}{lll}
# \toprule
# Nombre &       Sg &       Pl \\
# \midrule
# Forme &  wili-ja &  wili-du \\
# \bottomrule
# \end{tabular}
#  \\ \medskip
#
# \subsubsection*{ADJ}
# \noindent
# ADJ vieux => rekod\\
# \begin{tabular}{lll}
# \toprule
# Nombre &         Sg &         Pl \\
# Genre &            &            \\
# \midrule
# F     &  rekod-i-ŋ &  rekod-i-d \\
# M     &  rekod-a-ŋ &  rekod-a-d \\
# N     &  rekod-o-ŋ &  rekod-o-d \\
# \bottomrule
# \end{tabular}
#  \\ \medskip
#
# \subsubsection*{VER}
# \noindent
# V1 agripper => laslo\\
# \begin{tabular}{llll}
# \toprule
#     & Pers &           3Sg &           3Pl \\
# Temps & Genre &               &               \\
# \midrule
# \multirow{3}{*}{PRS} & F &  laslo-ob-i-k &  laslo-ob-i-d \\
#     & M &  laslo-ob-a-k &  laslo-ob-a-d \\
#     & N &  laslo-ob-e-k &  laslo-ob-e-d \\
# \cline{1-4}
# \multirow{3}{*}{PST} & F &  laslo-uz-i-k &  laslo-uz-i-d \\
#     & M &  laslo-uz-a-k &  laslo-uz-a-d \\
#     & N &  laslo-uz-e-k &  laslo-uz-e-d \\
# \bottomrule
# \end{tabular}
#  \\ \medskip
#
# \noindent
# V2 sauter => salur\\
# \begin{tabular}{llll}
# \toprule
#     & Pers &           3Sg &           3Pl \\
# Temps & Genre &               &               \\
# \midrule
# \multirow{3}{*}{PRS} & F &  salur-ak-o-m &  salur-ak-o-p \\
#     & M &  salur-ak-u-m &  salur-ak-u-p \\
#     & N &  salur-ak-a-m &  salur-ak-a-p \\
# \cline{1-4}
# \multirow{3}{*}{PST} & F &  salur-ed-o-m &  salur-ed-o-p \\
#     & M &  salur-ed-u-m &  salur-ed-u-p \\
#     & N &  salur-ed-a-m &  salur-ed-a-p \\
# \bottomrule
# \end{tabular}
#  \\ \medskip

# %% [markdown]
# # Liste des lexèmes par CF
#
# => à intégrer aux tableaux...

# %%
cfLatex=[]
cfLatex.append(ur"\subsection*{Classes flexionnelles}")
for cat in "NOM ADJ VER".split(" "):
    classeCat=lexemesCF[cat]
    if classeCat:
        if debug: print cat+" : "
        cfLatex.append(cat+" : ")
        if debug: print ur"\begin{description}"
        cfLatex.append(ur"\begin{description}")
        for c in classeCat:
            if debug: print ur"\item[- %s] %s"%(c,", ".join(sorted(classeCat[c])))
            cfLatex.append(ur"\item[- %s] %s"%(c,", ".join(sorted(classeCat[c]))))
        if debug: print ur"\end{description}"
        cfLatex.append(ur"\end{description}")
if len(cfLatex)<2:
    cfLatex=[]
print "\n".join(cfLatex)
# Out:
# \subsection*{Classes flexionnelles}
# VER :
# \begin{description}
# \item[- V1] accompagner, acheter, agripper, boire, chasser, finir, manger, offrir, préparer, regarder, être
# \item[- V2] aimer, apporter, cuisiner, demander, fondre, habiter, lécher, recouvrir, sauter, sentir
# \end{description}

# %% [markdown]
# # Liste des noms par genre
#
# - on ajoute une colonne genre en coupant dans la matrice de traits
# - on fait la liste des genres
# - on fait la liste des noms par genre
# - on fabrique la structure LaTeX

# %%
genresLatex=[]

genresLatex.append(ur"\subsection*{Genre des noms}")

# Ajout de la colonne genre
flexion["genre"]=flexion[bFlex["NOM"]][7].str.extract("Genre=(.),")

# Liste des genres
genres=sorted([g for g in flexion["genre"].unique().tolist() if isinstance(g,unicode)])
genreNoms={}

# Liste des noms par genre
for g in genres:
    genreNoms[g]=flexion[flexion.genre==g][1].unique().tolist()

# LaTeX
if debug: print ur"\begin{description}"
genresLatex.append(ur"\begin{description}")
for g in genres:
    if debug: print ur"\item[- %s]"%g, ", ".join(sorted(genreNoms[g]))
    genresLatex.append(ur"\item[- %s] %s"%(g, ", ".join(sorted(genreNoms[g]))))
if debug: print ur"\end{description}"
genresLatex.append(ur"\end{description}")

print "\n".join(genresLatex)
# Out:
# \subsection*{Genre des noms}
# \begin{description}
# \item[- F] Johana, boisson, chat, chocolat, dimanche, enfant, jambon, pied, poulet, repas, vallée
# \item[- M] Félix, Martin, biscuit, cabane, croquette, fromage, marmite, patate, soleil, viande
# \item[- N] coquelicot, cuisine, four, gâteau, journée, louche, patte, plat, table, verre
# \end{description}

# %%
with codecs.open(nomKanoniks[0]+"Flexions.tex","w",encoding="utf8") as outFile:
    print "\n".join(tableauxLatex+cfLatex+genresLatex)
    outFile.write("\n".join(tableauxLatex+cfLatex+genresLatex))
# Out:
# \subsection*{Tableaux de flexion}
# \subsubsection*{DET}
# \noindent
# DET DEM => t\\
# \begin{tabular}{lll}
# \toprule
# Nombre &      Sg &      Pl \\
# Genre &         &         \\
# \midrule
# F     &  t-u-mi &  t-u-ra \\
# M     &  t-a-mi &  t-a-ra \\
# N     &  t-i-mi &  t-i-ra \\
# \bottomrule
# \end{tabular}
#  \\ \medskip
#
# \subsubsection*{NOM}
# \noindent
# NOM chat => wili\\
# \begin{tabular}{lll}
# \toprule
# Nombre &       Sg &       Pl \\
# \midrule
# Forme &  wili-ja &  wili-du \\
# \bottomrule
# \end{tabular}
#  \\ \medskip
#
# \subsubsection*{ADJ}
# \noindent
# ADJ vieux => rekod\\
# \begin{tabular}{lll}
# \toprule
# Nombre &         Sg &         Pl \\
# Genre &            &            \\
# \midrule
# F     &  rekod-i-ŋ &  rekod-i-d \\
# M     &  rekod-a-ŋ &  rekod-a-d \\
# N     &  rekod-o-ŋ &  rekod-o-d \\
# \bottomrule
# \end{tabular}
#  \\ \medskip
#
# \subsubsection*{VER}
# \noindent
# V1 agripper => laslo\\
# \begin{tabular}{llll}
# \toprule
#     & Pers &           3Sg &           3Pl \\
# Temps & Genre &               &               \\
# \midrule
# \multirow{3}{*}{PRS} & F &  laslo-ob-i-k &  laslo-ob-i-d \\
#     & M &  laslo-ob-a-k &  laslo-ob-a-d \\
#     & N &  laslo-ob-e-k &  laslo-ob-e-d \\
# \cline{1-4}
# \multirow{3}{*}{PST} & F &  laslo-uz-i-k &  laslo-uz-i-d \\
#     & M &  laslo-uz-a-k &  laslo-uz-a-d \\
#     & N &  laslo-uz-e-k &  laslo-uz-e-d \\
# \bottomrule
# \end{tabular}
#  \\ \medskip
#
# \noindent
# V2 sauter => salur\\
# \begin{tabular}{llll}
# \toprule
#     & Pers &           3Sg &           3Pl \\
# Temps & Genre &               &               \\
# \midrule
# \multirow{3}{*}{PRS} & F &  salur-ak-o-m &  salur-ak-o-p \\
#     & M &  salur-ak-u-m &  salur-ak-u-p \\
#     & N &  salur-ak-a-m &  salur-ak-a-p \\
# \cline{1-4}
# \multirow{3}{*}{PST} & F &  salur-ed-o-m &  salur-ed-o-p \\
#     & M &  salur-ed-u-m &  salur-ed-u-p \\
#     & N &  salur-ed-a-m &  salur-ed-a-p \\
# \bottomrule
# \end{tabular}
#  \\ \medskip
#
# \subsection*{Classes flexionnelles}
# VER :
# \begin{description}
# \item[- V1] accompagner, acheter, agripper, boire, chasser, finir, manger, offrir, préparer, regarder, être
# \item[- V2] aimer, apporter, cuisiner, demander, fondre, habiter, lécher, recouvrir, sauter, sentir
# \end{description}
# \subsection*{Genre des noms}
# \begin{description}
# \item[- F] Johana, boisson, chat, chocolat, dimanche, enfant, jambon, pied, poulet, repas, vallée
# \item[- M] Félix, Martin, biscuit, cabane, croquette, fromage, marmite, patate, soleil, viande
# \item[- N] coquelicot, cuisine, four, gâteau, journée, louche, patte, plat, table, verre
# \end{description}

# %%
ding()
