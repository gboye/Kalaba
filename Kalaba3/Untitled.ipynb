# %%
import yaml
import networkx as nx

# %%
serie="/Users/gilles/sDrive/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/25-K6/"
with open(serie+"Stems.yaml", 'r') as inFile:
    stems=yaml.safe_load(inFile)
with open(serie+"Blocks.yaml", 'r') as inFile:
    blocks=yaml.safe_load(inFile)
with open(serie+"Gloses.yaml", 'r') as inFile:
    gloses=yaml.safe_load(inFile)

# %%
gloses["NOM"]["Genre"]
# Out:
# ['Hum', 'NonHum', 'Anim', 'Inan']

# %%
def lDict(d):
    result=[]
    for k,v in d.items():
        if isinstance(v,dict):
            result.append(k)
    return result

# %%
for k in lDict(stems["NOM"]):
    print(k,lDict(stems["NOM"][k]))
# Out:
# Anim ['NonHum', 'Hum']
# Inan ['N1', 'N2']
